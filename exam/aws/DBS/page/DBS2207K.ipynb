# %% [markdown]
# # 001

# %% [markdown]
# **[Q#001. Q#111. Q#018.](https://www.examtopics.com/discussions/amazon/view/25182-exam-aws-certified-database-specialty-topic-1-question-1/)**
# 회사에서 새 AWS 계정에 전자 상거래 웹 애플리케이션을 배포했습니다. MySQL용 Amazon RDS 다중 AZ DB 인스턴스는 포트 3306에서 수신하는 database-1.xxxxxxxxxxxx.us-east-1.rds.amazonaws.com 엔드포인트가 있는 이 배포의 일부입니다. 회사의 데이터베이스 전문가는 다음에 로그인할 수 있습니다. MySQL 및 이러한 세부 정보를 사용하여 배스천 호스트에서 쿼리를 실행합니다.
# 사용자가 AWS 계정에서 호스팅되는 애플리케이션을 활용하려고 하면 일반 오류 메시지가 표시됩니다. 애플리케이션 서버가 '서버에 연결할 수 없음: 연결 시간 초과' 오류 메시지를 Amazon CloudWatch Logs에 기록합니다.
# 이 오류의 원인은 무엇입니까?
#
# >**A.** 응용 프로그램에서 사용하는 사용자 이름과 암호가 올바르지 않습니다.
# **B.** 애플리케이션 서버에 할당된 보안 그룹에는 DB 인스턴스로부터의 인바운드 연결을 허용하는 데 필요한 규칙이 없습니다.
# **C.** DB 인스턴스에 할당된 보안 그룹에는 애플리케이션 서버로부터의 인바운드 연결을 허용하는 데 필요한 규칙이 없습니다.
# **D.** 사용자 이름과 암호가 정확하지만 사용자에게 DB 인스턴스를 사용할 권한이 없습니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : C(100%)  <br>
# >DB는 인바운드를 허용해야 합니다.(C)<br>
# >기본적으로 연결시간 초과 오류이므로 A,D를 삭제할 수 있습니다. B는 SG 규칙에 문제가 있으면 인바운드가 아닌 아웃바운드에 영향을 미치기 때문에 잘못된 것이므로 DB 인스턴스 SG에 대한 인바운드 규칙인 C가 맞습니다.
# </div></details>
#
# **[Q#002. Q#087. Q#120.](https://www.examtopics.com/discussions/amazon/view/67312-exam-aws-certified-database-specialty-topic-1-question-2/)**
# Amazon RDS DB 인스턴스가 포함된 AWS CloudFormation 스택이 실수로 삭제되어 최근 데이터가 손실되었습니다. 데이터베이스 전문가는 향후 우발적인 인스턴스 데이터 손실 가능성을 줄이기 위해 CloudFormation 템플릿에 RDS 설정을 추가해야 합니다.
# 이 요구 사항을 충족하는 설정은 무엇입니까? (3개를 선택하세요.)
#
# >**A.** DeletionProtection을 True로 설정
# **B.** MultiAZ를 True로 설정
# **C.** TerminationProtection을 True로 설정
# **D.** DeleteAutomatedBackups를 False로 설정
# **E.** DeletionPolicy를 삭제로 설정
# **F.** DeletionPolicy를 유지로 설정
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : ADF(100%)  <br>
# >DeletionProtection: True(o), DeletionPolicy: Retain(o), DeleteAutomatedBackups: False(o, Prevent Automated Backups from being deleted)  <br>
# >TerminationProtection: True(x, RDS doenst have termination protection, only deletion protection)  <br>
# >
# >[Amazon RDS, 이제 데이터베이스 삭제 보호 기능 제공](https://aws.amazon.com/about-aws/whats-new/2018/09/amazon-rds-now-provides-database-deletion-protection/)<br>
# >[백업 작업](https://docs.aws.amazon.com/AmazonRDS/latest/UserGuide/USER_WorkingWithAutomatedBackups.html)<br>
# >[DeletionPolicy 속성](https://docs.aws.amazon.com/AWSCloudFormation/latest/UserGuide/aws-attribute-deletionpolicy.html)
# </div></details>
#
# **[Q#003. Q#136. Q#174.](https://www.examtopics.com/discussions/amazon/view/25011-exam-aws-certified-database-specialty-topic-1-question-3/)**
# 데이터베이스 전문가가 지난 2개월 동안 문제 없이 실행되었던 여러 Aurora 복제본이 있는 Amazon Aurora DB 클러스터에서 애플리케이션 연결 실패 문제를 해결하고 있습니다. 연결 실패는 5분 동안 지속되었고 그 후 자체적으로 수정되었습니다. 데이터베이스 전문가는 Amazon RDS 이벤트를 검토하고 해당 시점에 장애 조치 이벤트가 발생한 것으로 확인했습니다. 장애 조치 프로세스를 완료하는 데 약 15초가 소요되었습니다.
# 5분 간의 연결 중단의 가장 가능성 있는 원인은 무엇입니까?
#
# >**A.** 데이터베이스 충돌 후 Aurora는 마지막 데이터베이스 체크포인트에서 다시 실행 로그를 재생해야 했습니다.
# **B.** 클라이언트 측 애플리케이션이 DNS 데이터를 캐싱하고 TTL이 너무 높게 설정되어 있습니다.
# **C.** 장애 조치 후 Aurora DB 클러스터는 클라이언트 연결을 수락하기 전에 워밍업 시간이 필요합니다.
# **D.** Aurora DB 클러스터에 활성 Aurora 복제본이 없었습니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : B(100%)  <br>
# >클라이언트 애플리케이션이 DB 인스턴스의 DNS 데이터를 캐싱하는 경우 TTL(Time-to-Live) 값을 너무 높게 설정되어 있습니다.<br>
# >장애 조치 후 DB 인스턴스의 기본 IP 주소가 변경될 수 있으므로 DNS 데이터를 장기간 캐싱하면 애플리케이션이 더 이상 사용되지 않는 IP 주소에 연결을 시도하면 연결 실패가 발생할 수 있습니다.<br>
# </div></details>
#
# **[Q#004. Q#148. Q#044.](https://www.examtopics.com/discussions/amazon/view/25029-exam-aws-certified-database-specialty-topic-1-question-4/)**
# 회사는 온프레미스 시스템에서 마이그레이션하여 Amazon Aurora에 솔루션을 배포하고 있습니다. IT 부서는 회사 데이터 센터에서 AWS Direct Connect 링크를 설정했습니다. 회사의 데이터베이스 전문가는 일반 텍스트 데이터가 네트워크를 통해 설정되는 것을 방지하기 위해 연결에 SSL/TLS를 요구하는 옵션을 선택했습니다. 마이그레이션이 성공적으로 작동하는 것으로 보이며 데스크톱 컴퓨터에서 데이터를 쿼리할 수 있습니다.
# 두 명의 데이터 분석가에게 새로운 Aurora DB 클러스터의 데이터를 쿼리하고 검증해 달라는 요청을 받았습니다. 두 분석가 모두 Aurora에 연결할 수 없습니다. 사용자 이름과 암호가 유효한 것으로 확인되었으며 데이터베이스 전문가는 계정을 사용하여 DB 클러스터에 연결할 수 있습니다. Database Specialist는 또한 보안 그룹 구성이 모든 회사 IP 주소의 네트워크를 허용하는지 확인했습니다.
# 데이터베이스 전문가는 데이터 분석가의 연결할 수 없는 문제를 해결하기 위해 무엇을 해야 합니까?
#
# >**A.** DB 클러스터를 다시 시작하여 SSL 변경 사항을 적용합니다.
# **B.** 데이터 분석가에게 루트 인증서를 다운로드하고 연결 문자열의 SSL 인증서를 사용하도록 지시합니다.
# **C.** 데이터 분석가의 IP 주소와 DB 클러스터에 할당된 보안 그룹의 인스턴스 간에 명시적 매핑을 추가합니다.
# **D.** AWS에 대한 네트워크 트래픽을 허용하도록 데이터 분석가의 로컬 클라이언트 방화벽을 수정합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : B(100%)  <br>
# >SSL을 사용하여 연결하려면:  <br>
# >• SSLTrust 인증서 제공(AWS에서 다운로드 가능)  <br>
# >• 데이터베이스에 연결할 때 SSL 옵션 제공  <br>
# >• SSL을 적용하는 DB에서 SSL을 사용하지 않으면 오류가 발생합니다.<br>
# >
# >[새 SSL/TLS 인증서를 사용해 Aurora PostgreSQL DB 클러스터에 연결할 애플리케이션 업데이트](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/ssl-certificate-rotation-aurora-postgresql.html)
# </div></details>
#
# **[Q#005. Q#123. Q#126.](https://www.examtopics.com/discussions/amazon/view/25030-exam-aws-certified-database-specialty-topic-1-question-5/)**
# 데이터를 삭제하기 전에 2일 동안만 저장하면 되는 Amazon DynamoDB를 사용하는 대규모 트랜잭션 애플리케이션의 비용을 우려하는 회사가 있습니다. 테이블을 살펴보면서 데이터베이스 전문가는 많은 데이터가 몇 개월 전의 것임을 알아차리고 애플리케이션이 처음 배포되었을 때로 되돌아갑니다.
# 데이터베이스 전문가는 전체 비용을 줄이기 위해 무엇을 할 수 있습니까?
#
# >**A.** 각 테이블에 새 속성을 생성하여 만료 시간을 추적하고 AWS Glue 변환을 생성하여 2일이 지난 항목을 삭제합니다.
# **B.** 각 테이블에 새 속성을 생성하여 만료 시간을 추적하고 각 테이블에서 DynamoDB 스트림을 활성화합니다.
# **C.** 만료 시간을 추적하고 각 테이블에서 TTL(Time to Live)을 활성화하기 위해 각 테이블에 새 속성을 만듭니다.
# **D.** AWS Data Pipeline을 사용하여 매일 Amazon S3로 데이터를 내보내는 Amazon CloudWatch Events 이벤트를 생성한 다음 Amazon DynamoDB 테이블을 자릅니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : C(100%)  <br>
# >자동 삭제를 위해 Dynamo DB TTL 속성 지정<br>
# >
# >[DynamoDB 유지 시간(TTL)을 사용하여 항목 만료](https://docs.aws.amazon.com/ko_kr/amazondynamodb/latest/developerguide/TTL.html)
# </div></details>
#
# **[Q#006. Q#094. Q#114.](https://www.examtopics.com/discussions/amazon/view/25032-exam-aws-certified-database-specialty-topic-1-question-6/)**
# 회사에는 데이터베이스 종료, 삭제, 생성 및 백업을 포함하여 데이터베이스 수명 동안 발생하는 다양한 데이터베이스 작업을 추적하는 온프레미스 시스템이 있습니다.
# 이 회사는 최근 두 개의 데이터베이스를 Amazon RDS로 이전했으며 이러한 요구 사항을 충족하는 솔루션을 찾고 있습니다. 데이터는 회사 내의 다른 시스템에서 사용할 수 있습니다.
# 최소한의 노력으로 이러한 요구 사항을 충족하는 솔루션은 무엇입니까?
#
# >**A.** Amazon RDS에서 추적해야 하는 작업으로 Amazon CloudWatch Events 규칙을 생성합니다. 이러한 규칙에 따라 작동하는 AWS Lambda 함수를 생성하고 추적 시스템에 출력을 씁니다.
# **B.** AWS CloudTrail API 호출에서 트리거할 AWS Lambda 함수를 생성합니다. 특정 RDS API 호출을 필터링하고 추적 시스템에 출력을 씁니다.
# **C.** RDS 이벤트 구독을 생성합니다. 추적 시스템이 특정 RDS 이벤트 시스템 알림을 구독하도록 합니다.
# **D.** Amazon Kinesis Data Firehose에 RDS 로그를 작성합니다. 이러한 규칙에 따라 작동하는 AWS Lambda 함수를 생성하고 추적 시스템에 출력을 씁니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : C(100%)  <br>
# >RDS 이벤트 구독을 생성합니다. 추적 시스템이 특정 RDS 이벤트 시스템 알림을 구독하도록 합니다.<br>
# >B도 답이 될 수 있지만 질문은 최소한의 노력으로 이루어집니다. 따라서 답은 C입니다.<br>
# >
# >[Amazon RDS 이벤트 알림 작업](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/USER_Events.html)
# </div></details>
#
# **[Q#007. Q#060. Q#095.](https://www.examtopics.com/discussions/amazon/view/25044-exam-aws-certified-database-specialty-topic-1-question-7/)**
# 의류 회사는 맞춤형 전자상거래 애플리케이션과 PostgreSQL 데이터베이스를 사용하여 여러 국가의 수천 명의 사용자에게 의류를 판매합니다. 이 회사는 온프레미스 데이터 센터에서 AWS 클라우드로 애플리케이션과 데이터베이스를 마이그레이션하고 있습니다. 이 회사는 애플리케이션으로 Amazon EC2를 선택하고 데이터베이스로 PostgreSQL용 Amazon RDS를 선택했습니다. 회사는 데이터베이스 비밀번호를 60일마다 변경하도록 요구합니다. 데이터베이스 전문가는 웹 애플리케이션이 데이터베이스에 연결하는 데 사용하는 자격 증명이 안전하게 관리되는지 확인해야 합니다.
# 데이터베이스 전문가는 데이터베이스 자격 증명을 안전하게 관리하기 위해 어떤 접근 방식을 취해야 합니까?
#
# >**A.** 자격 증명을 Amazon S3 버킷의 텍스트 파일에 저장합니다. 버킷에 대한 권한을 인스턴스 프로파일과 연결된 IAM 역할로만 제한합니다. 텍스트 파일을 다운로드하고 시작할 때 자격 증명을 검색하도록 응용 프로그램을 수정합니다. 60일마다 텍스트 파일을 업데이트합니다.
# **B.** 애플리케이션이 데이터베이스에 연결할 수 있도록 IAM 데이터베이스 인증을 구성합니다. IAM 사용자를 생성하고 각 전자상거래 사용자에 대해 별도의 데이터베이스 사용자에 매핑합니다. 사용자에게 60일마다 비밀번호를 업데이트하도록 요구합니다.
# **C.** 자격 증명을 AWS Secrets Manager에 저장합니다. 보안 암호에 대한 권한을 인스턴스 프로파일과 연결된 IAM 역할로만 제한합니다. 시작할 때 Secrets Manager에서 자격 증명을 검색하도록 애플리케이션을 수정합니다. 순환 간격을 60일로 구성합니다.
# **D.** 애플리케이션 AMI의 암호화된 텍스트 파일에 자격 증명을 저장합니다. AWS KMS를 사용하여 텍스트 파일의 암호 해독을 위한 키를 저장합니다. 텍스트 파일의 암호를 해독하고 시작 시 자격 증명을 검색하도록 응용 프로그램을 수정합니다. 텍스트 파일을 업데이트하고 60일마다 새 AMI를 게시합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : C(100%)  <br>
# >Secret Manager -> 60일 마다 교체 -> 인스턴스 전용 IAM 역할에 대한 보안 액세스 -> 시작 시 앱이 비밀번호를 가져오기 위해 Secret Manager를 참조<br>
# >IAM DB 인증 토큰은 15분 동안만 유효할 수 있음.
# </div></details>
#
# **[Q#008. Q#134. Q#078.](https://www.examtopics.com/discussions/amazon/view/67043-exam-aws-certified-database-specialty-topic-1-question-8/)**
# 금융 서비스 회사는 회사 전체의 다양한 애플리케이션을 지원하는 공유 데이터 서비스를 개발하고 있습니다. 데이터베이스 전문가는 클러스터 모드가 활성화된 Redis용 Amazon ElastiCache를 활용하여 성능과 확장성을 향상시키는 솔루션을 설계했습니다. 클러스터는 포트 6379에서 수신 대기하도록 구성되어 있습니다.
# 데이터베이스 전문가는 캐시 데이터를 보호하고 무단 액세스로부터 보호하기 위해 어떤 단계 조합을 취해야 합니까? (3개를 선택하세요.)
#
# >**A.** ElastiCache 클러스터에서 전송 중 및 저장 데이터 암호화를 활성화합니다.
# **B.** Amazon CloudWatch 지표가 ElastiCache 클러스터에 구성되어 있는지 확인합니다.
# **C.** ElastiCache 클러스터의 보안 그룹이 자체의 모든 인바운드 트래픽과 신뢰할 수 있는 클라이언트의 TCP 포트 6379에 대한 인바운드 트래픽만 허용하는지 확인합니다.
# **D.** 애플리케이션 서비스 역할이 모든 ElastiCache API 작업에 액세스하도록 허용하는 IAM 정책을 생성합니다.
# **E.** ElastiCache 클라이언트의 보안 그룹이 신뢰할 수 있는 ElastiCache 클러스터의 보안 그룹에서 들어오는 인바운드 TCP 포트 6379 및 포트 22 트래픽을 승인하는지 확인합니다.
# **F.** 클러스터가 auth-token 매개변수로 생성되고 매개변수가 모든 후속 명령에서 사용되는지 확인하십시오.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : ACF(100%)  <br>
# >CloudWatch(x), Port 22(x), 모든 ElasticCache API 허용(x)<br>
# >
# >[Amazon ElastiCache의 데이터 보안](https://docs.aws.amazon.com/ko_kr/AmazonElastiCache/latest/red-ug/encryption.html)
# </div></details>
#
# **[Q#009. Q#102. Q#068.](https://www.examtopics.com/discussions/amazon/view/25084-exam-aws-certified-database-specialty-topic-1-question-9/)**
# 회사에서 PostgreSQL DB 인스턴스용 Amazon RDS를 실행하고 있으며 이를 Amazon Aurora PostgreSQL DB 클러스터로 마이그레이션하려고 합니다. 현재 데이터베이스의 크기는 1TB입니다. 마이그레이션은 다운타임을 최소화해야 합니다.
# 이를 수행하는 가장 빠른 방법은 무엇입니까?
#
# >**A.** Aurora PostgreSQL DB 클러스터를 생성합니다. AWS DMS를 사용하여 PostgreSQL용 원본 RDS DB 인스턴스에서 대상 DB 클러스터로 복제를 설정합니다.
# **B.** pg_dump 및 pg_restore 유틸리티를 사용하여 RDS for PostgreSQL DB 인스턴스를 추출하고 Aurora PostgreSQL DB 클러스터로 복원합니다.
# **C.** RDS for PostgreSQL DB 인스턴스의 데이터베이스 스냅샷을 생성하고 이 스냅샷을 사용하여 Aurora PostgreSQL DB 클러스터를 생성합니다.
# **D.** Aurora 복제본을 사용하여 RDS for PostgreSQL DB 인스턴스에서 Aurora PostgreSQL DB 클러스터로 데이터를 마이그레이션합니다. 컷오버 중에 복제본을 승격합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : D(100%)  <br>
# >읽기 전용 복제본이 스냅샷보다 빠름<br>
# >스냅샷에 시간이 걸리고 새 트랜잭션이 손실됨, 복제본이 빠름<br>
# >
# >[데이터를 PostgreSQL과 호환되는 Amazon Aurora로 마이그레이션](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/AuroraPostgreSQL.Migrating.html#AuroraPostgreSQL.Migrating.RDSPostgreSQL)
# </div></details>
#
# **[Q#010. Q#167. Q#157.](https://www.examtopics.com/discussions/amazon/view/25049-exam-aws-certified-database-specialty-topic-1-question-10/)**
# 데이터베이스 전문가가 AWS DMS를 사용하여 2TB Amazon RDS for Oracle DB 인스턴스를 RDS for PostgreSQL DB 인스턴스로 마이그레이션하고 있습니다. 소스 RDS Oracle DB 인스턴스는 us-east-1 리전의 VPC에 있습니다. PostgreSQL DB 인스턴스용 대상 RDS는 use-west-2 리전의 VPC에 있습니다.
# 가장 최적의 성능을 위해 AWS DMS 복제 인스턴스를 어디에 배치해야 합니까?
#
# >**A.** 원본 DB 인스턴스의 동일한 리전 및 VPC에서
# **B.** 대상 DB 인스턴스와 동일한 리전 및 VPC에서
# **C.** 대상 DB 인스턴스와 동일한 VPC 및 가용 영역에서
# **D.** 원본 DB 인스턴스와 동일한 VPC 및 가용 영역에서
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : C(100%)  <br>
# >최상의 결과를 얻으려면 대상 DB와 동일한 VPC 및 가용 영역에서 복제 인스턴스를 찾는다.<br>
# >
# >[복제 인스턴스용으로 네트워크 설정](https://docs.aws.amazon.com/ko_kr/dms/latest/userguide/CHAP_ReplicationInstance.VPC.html#CHAP_ReplicationInstance.VPC.%20Configurations.ScenarioVPCPeer)
# </div></details>

# %% [markdown]
# # 011

# %% [markdown]
# **[Q#011. Q#081. Q#042.](https://www.examtopics.com/discussions/amazon/view/25052-exam-aws-certified-database-specialty-topic-1-question-11/)**
# 개발 팀은 최근 Amazon Aurora MySQL DB 클러스터에서 여러 DDL(데이터 정의 언어) 및 DML(데이터 조작 언어) 문을 포함하는 데이터베이스 스크립트를 실행했습니다. 이 릴리스는 중요한 테이블에서 실수로 수천 개의 행을 삭제하고 일부 응용 프로그램 기능을 손상시켰습니다.
# 이는 출시 4시간 만에 발견됐다. 조사 시 데이터베이스 전문가는 잘못된 행 집합을 필터링하는 잘못된 WHERE 절 을 사용하여 스크립트의 DELETE 명령에 대한 문제를 추적했습니다.
# Aurora DB 클러스터에는 8시간의 역추적 기간으로 역추적이 활성화되어 있습니다. 데이터베이스 관리자는 릴리스가 시작되기 전에 DB 클러스터의 수동 스냅샷도 찍었습니다. 전체 응용 프로그램 기능을 다시 시작하려면 데이터베이스를 가능한 한 빨리 올바른 상태로 되돌려야 합니다. 데이터 손실이 최소화되어야 합니다.
# 데이터베이스 전문가는 어떻게 이를 수행할 수 있습니까?
#
# >**A.** Backtrack을 사용하여 DB 클러스터를 릴리스 이전 시점으로 빠르게 되감습니다.
# **B.** DB 클러스터의 PITR(point-in-time recovery)을 릴리스 이전 시점으로 수행하고 복원된 데이터베이스에서 삭제된 행을 원본 데이터베이스로 복사합니다.
# **C.** 릴리스 이전에 생성된 수동 백업 스냅샷을 사용하여 DB 클러스터를 복원하고 새 DB 클러스터를 가리키도록 애플리케이션 구성 설정을 변경합니다.
# **D.** Backtrack이 활성화된 DB 클러스터의 클론을 생성합니다. 복제된 클러스터를 릴리스 전의 특정 시점으로 되감습니다. 클론에서 삭제된 행을 원본 데이터베이스로 복사합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : A(33%), B(33%), D(33%)<br>
# >Ax: 데이터베이스를 4시간 전으로 되감는 데 몇 분이 소요되지만 지난 4시간 동안 데이터가 손실됨.
# >B: 데이터베이스를 유지하고 복원 지점에서 생성된 데이터베이스에서 삭제된 레코드를 다시 삽입하여 수정합니다. 시간이 더 소요되지만 데이터 손실 없음.<br>
# >PITR 테이블 -> 특정 시점 복구 프로세스는 항상 새 테이블로 복원됩니다. -> 복원된 데이터베이스에서 삭제된 행을 원본 데이터베이스로 복사합니다.<br>
# >
# >[Aurora DB 클러스터 역추적](https://docs.aws.amazon.com/AmazonRDS/latest/AuroraUserGuide/AuroraMySQL.Managing.Backtrack.html)
# </div></details>
#
# **★★★[Q#012. Q#098. Q#107.](https://www.examtopics.com/discussions/amazon/view/25180-exam-aws-certified-database-specialty-topic-1-question-12/)**
# 회사는 AWS에서 AWS CloudFormation 템플릿을 사용하여 배포한 3계층 프로덕션 웹 애플리케이션을 로드 테스트하고 있습니다. 애플리케이션 팀은 부하 테스트 용량을 확장하기 위해 추가 Amazon EC2 및 AWS Lambda 리소스를 배포하도록 변경하고 있습니다. 데이터베이스 전문가는 애플리케이션 팀이 변경한 사항이 이미 배포된 Amazon RDS 데이터베이스 리소스를 변경하지 않도록 하려고 합니다.
# 데이터베이스 전문가가 이 작업을 수행할 수 있도록 하는 단계 조합은 무엇입니까? (2개를 선택하세요.)
#
# >**A.** 템플릿을 수정하기 전에 스택 드리프트를 검토하십시오.
# **B.** 적용하기 전에 변경 세트 생성 및 검토
# **C.** 데이터베이스 리소스를 스택 출력으로 내보내기
# **D.** 중첩 스택에서 데이터베이스 리소스 정의
# **E.** 데이터베이스 리소스에 대한 스택 정책 설정
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : BE(100%)<br>
# >B: 변경을 수락하기 전에 변경 세트를 검토해야 합니다. E: 리소스에 대한 업데이트를 방지하기 위해 스택 집합 정책을 사용합니다.<br>
# >B. 변경 세트는 앱 개발 수정이 리소스에 영향을 미치지 않도록 합니다. E. 리소스가 변경될 경우 배포 실패에 대한 정책 규칙이 추가됩니다.<br>
# >
# >[스택을 업데이트하기 전에 변경 세트 생성](https://docs.amazonaws.cn/en_us/AWSCloudFormation/latest/UserGuide/best-practices.html#cfn-best-practices-changesets)
# </div></details>
#
# **★★★[Q#013. Q#113. Q#057.](https://www.examtopics.com/discussions/amazon/view/25790-exam-aws-certified-database-specialty-topic-1-question-13/)**
# 제조 회사의 웹 사이트는 Amazon Aurora PostgreSQL DB 클러스터를 사용합니다.
# 어떤 구성이 장애 조치 중 애플리케이션 다운타임을 최소화합니까? (3개를 선택하세요.)
#
# >**A.** 제공된 읽기 및 쓰기 Aurora 엔드포인트를 사용하여 Aurora DB 클러스터에 대한 연결을 설정합니다.
# **B.** 기본 Aurora DB 클러스터에 연결할 수 없을 때 다른 가용 영역에서 복원을 트리거하는 Amazon CloudWatch 알림을 생성합니다.
# **C.** 파라미터 그룹에서 Aurora DB 클러스터 캐시 관리를 편집하고 활성화합니다.
# **D.** TCP 연결 유지 매개변수를 높은 값으로 설정합니다.
# **E.** JDBC 연결 문자열 시간 초과 변수를 낮은 값으로 설정합니다.
# **F.** Java DNS 캐싱 시간 초과를 높은 값으로 설정합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : ACE(100%)<br>
# >클러스터링에 Aurora EndPoint 사용(o), CloudWatch(x), 복제본에서 캐시를 동기화 상태로 유지(o), TCP Keepalive 높게(x, 낮게), JDBC Connection String Timeout 낮게(o), Java DNS 캐싱 Timeout 높게(x, 낮게)<br>
# >장애 조치가 발생한 경우 Aurora PostgreSQL 클러스터에 라이터 DB 인스턴스를 신속하게 복구하려면 Amazon Aurora PostgreSQL용 클러스터 캐시 관리를 사용하십시오. 장애 조치가 발생한 경우 클러스터 캐시 관리를 통해 애플리케이션 성능을 유지할 수 있습니다.<br>
# >
# >[Amazon Aurora PostgreSQL를 사용한 빠른 장애 조치](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/AuroraPostgreSQL.BestPractices.html)<br>
# >[장애 조치 후 Aurora PostgreSQL용 클러스터 캐시 관리를 통한 신속한 복구](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/AuroraPostgreSQL.cluster-cache-mgmt.html)
# </div></details>
#
# **[Q#014. Q#067. Q#156.](https://www.examtopics.com/discussions/amazon/view/66148-exam-aws-certified-database-specialty-topic-1-question-14/)**
# 회사는 Amazon Redshift 클러스터에서 중요한 비즈니스 데이터를 호스팅하고 있습니다. 데이터의 민감한 특성으로 인해 클러스터는 AWS KMS를 사용하여 미사용 시 암호화됩니다. 재해 복구 요구 사항의 일부로 회사는 Amazon Redshift 스냅샷을 다른 리전에 복사해야 합니다.
# 재해 복구 요구 사항을 충족하려면 AWS Management 콘솔에서 어떤 단계를 수행해야 합니까?
#
# >**A.** 소스 리전에서 새 KMS 고객 마스터 키를 생성합니다. 대상 리전으로 전환하고 Amazon Redshift 교차 리전 스냅샷을 활성화하고 소스 리전의 KMS 키를 사용합니다.
# **B.** KMS 키에 대한 액세스 권한이 있는 새 IAM 역할을 생성합니다. 새 IAM 역할을 사용하여 Amazon Redshift 교차 리전 복제를 활성화하고 소스 리전의 KMS 키를 사용합니다.
# **C.** 원본 리전에서 Amazon Redshift 교차 리전 스냅샷을 활성화하고 스냅샷 복사 권한을 생성하고 대상 리전에서 KMS 키를 사용합니다.
# **D.** 대상 리전에서 새 KMS 고객 마스터 키를 만들고 새 KMS 키에 대한 액세스 권한이 있는 새 IAM 역할을 만듭니다. 원본 리전에서 Amazon Redshift 교차 리전 복제를 활성화하고 대상 리전의 KMS 키를 사용합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C(100%)<br>
# >AWS KMS로 암호화된 클러스터에 대해 교차 리전 스냅샷 복사를 활성화하려면 대상 AWS 리전에서 루트 키에 대한 스냅샷 복사 권한을 구성해야 합니다.<br>
# >Source Region: AWS KMS 암호화 클러스터에 대한 교차 리전 스냅샷 구성<br>
# >Destination AWS Region: 스냅샷을 복사할 AWS 리전을 선택합니다. 새 KMS, 스냅샷 복사권한 구성<br>
# >
# >[Amazon Redshift 데이터베이스 암호화](https://docs.aws.amazon.com/redshift/latest/mgmt/working-with-db-encryption.html)<br>
# >[AWS KMS 암호화 클러스터에 대한 리전 간 스냅샷 복사 구성](https://docs.aws.amazon.com/redshift/latest/mgmt/managing-snapshots-console.html#xregioncopy-kms-encrypted-snapshot)
# </div></details>
#
# **[Q#015. Q#130. Q#046.](https://www.examtopics.com/discussions/amazon/view/25069-exam-aws-certified-database-specialty-topic-1-question-15/)**
# 회사에 OLTP(온라인 트랜잭션 처리) 트랜잭션과 컴퓨팅 집약적 보고서를 모두 제공하는 프로덕션 Amazon Aurora Db 클러스터가 있습니다. 보고서는 OLTP 트랜잭션이 항상 실행되는 동안 총 클러스터 가동 시간의 10%에 대해 실행됩니다. 회사는 워크로드를 벤치마킹하여 6노드 Aurora DB 클러스터가 피크 워크로드에 적합하다고 결정했습니다.
# 회사는 이제 이 DB 클러스터의 비용 ​​절감을 모색하고 있지만 클러스터에 다른 시간의 워크로드를 지원하기 위해 충분한 수의 노드가 필요합니다. 워크로드는 이전 벤치마킹 연습 이후 변경되지 않았습니다.
# Database Specialist는 최소한의 사용자 개입으로 이러한 요구 사항을 어떻게 해결할 수 있습니까?
#
# >**A.** DB 클러스터를 두 개의 다른 클러스터로 분할합니다. 하나는 OLTP용이고 다른 하나는 보고용입니다. 데이터 일관성을 유지하기 위해 두 클러스터 간의 복제를 모니터링하고 설정합니다.
# **B.** 모두 검토하여 최대 결합 작업 부하를 평가합니다. DB 클러스터 노드의 사용률이 허용 가능한 수준인지 확인합니다. 필요한 경우 인스턴스 수를 조정합니다.
# **C.** 클러스터 중지 기능을 사용하여 워크로드가 최소인 시간 동안 DB 클러스터의 모든 노드를 중지합니다. 클러스터는 당시의 워크로드에 따라 다시 시작할 수 있습니다.
# **D.** DB 클러스터에서 자동 확장을 설정합니다. 이렇게 하면 필요할 때 보고 작업 부하에 맞게 리더 노드 수가 자동으로 조정됩니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : D(100%)<br>
# >Auto-scaling은 워크로드에 따라 읽기 전용 복제본의 수를 자동으로 확장/축소합니다.<br>
# >
# </div></details>
#
# **[Q#016. Q#019. Q#030.](https://www.examtopics.com/discussions/amazon/view/66661-exam-aws-certified-database-specialty-topic-1-question-16/)**
# 회사에서 MySQL DB 인스턴스용 Amazon RDS에서 금융 애플리케이션을 실행하고 있습니다. 응용 프로그램은 여러 금융 규제 기관에서 관리합니다.
# RDS DB 인스턴스는 특정 Amazon EC2 서버에 대한 액세스만 허용하도록 보안 그룹으로 설정됩니다. AWS KMS는 저장 데이터 암호화에 사용됩니다.
# 어떤 단계가 추가 보안을 제공합니까?
#
# >**A.** 전체 EC2 서브넷이 DB 인스턴스에 액세스하도록 허용하는 NACL 설정
# **B.** 마스터 사용자 계정 비활성화
# **C.** DB 인스턴스에 대한 SSH를 차단하는 보안 그룹 설정
# **D.** 전송 중인 데이터에 SSL을 사용하도록 RDS 설정
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : D(100%)<br>
# >AWS KMS는 저장 데이터를 암호화, 전송 중인 데이터 암호화는 SSL<br>
# >
# </div></details>
#
# **[Q#017. Q#097. Q#125.](https://www.examtopics.com/discussions/amazon/view/26261-exam-aws-certified-database-specialty-topic-1-question-17/)**
# 회사에는 데이터를 일관되고 고도로 구조화된 형식으로 유지하는 데이터 웨어하우스 솔루션이 필요합니다. 회사는 현재 연도의 데이터를 볼 때 최종 사용자 쿼리에 대한 빠른 응답을 요구하고 사용자는 필요할 때 전체 15년 데이터 세트에 액세스할 수 있어야 합니다. 이 솔루션은 또한 변동하는 수신 쿼리를 처리해야 합니다. 100TB의 데이터에 대한 스토리지 비용은 낮게 유지되어야 합니다.
# 어떤 솔루션이 이러한 요구 사항을 충족합니까?
#
# >**A.** 모든 데이터를 로컬 Amazon Redshift 스토리지에 유지하면서 고밀도 스토리지 인스턴스 유형을 사용하는 Amazon Redshift 데이터 웨어하우스 솔루션을 활용합니다. 높은 수요를 지원하기에 충분한 인스턴스를 프로비저닝합니다.
# **B.** 고밀도 스토리지 인스턴스를 사용하는 Amazon Redshift 데이터 웨어하우스 솔루션을 활용하여 최신 데이터를 저장합니다. Amazon S3에 기록 데이터를 보관하고 Amazon Redshift Spectrum 계층을 사용하여 액세스합니다. 높은 수요를 지원하기에 충분한 인스턴스를 프로비저닝합니다.
# **C.** 고밀도 스토리지 인스턴스를 사용하는 Amazon Redshift 데이터 웨어하우스 솔루션을 활용하여 최신 데이터를 저장합니다. Amazon S3에 기록 데이터를 보관하고 Amazon Redshift Spectrum 계층을 사용하여 액세스합니다. Amazon Redshift 동시성 확장을 활성화합니다.
# **D.** 고밀도 스토리지 인스턴스를 사용하는 Amazon Redshift 데이터 웨어하우스 솔루션을 활용하여 최신 데이터를 저장합니다. Amazon S3에 기록 데이터를 보관하고 Amazon Redshift Spectrum 계층을 사용하여 액세스합니다. Amazon Redshift 탄력적 크기 조정을 활용합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C(100%)<br>
# >동시성 확장 기능을 사용하면 지속적으로 빠른 쿼리 성능으로 거의 무제한의 동시 사용자 및 동시 쿼리를 지원할 수 있습니다.<br>
# >동시성 조정이 활성화된 경우 Amazon Redshift는 동시 읽기 쿼리의 증가를 처리하는 데 필요할 때 클러스터 용량을 자동으로 추가합니다.<br>
# >S3 + 로컬 스토리지 + 동시성 확장<br>
# >
# >[동시성 확장 작업](https://docs.aws.amazon.com/ko_kr/redshift/latest/dg/concurrency-scaling.html)
# </div></details>
#
# **[Q#018. Q#085. Q#173.](https://www.examtopics.com/discussions/amazon/view/26011-exam-aws-certified-database-specialty-topic-1-question-18/)**
# 게임 회사에서 여러 지역에 게임을 배포하려고 합니다. 회사는 각 리전의 Amazon DynamoDB 테이블에 로컬 최고 점수를 저장할 계획입니다. 데이터베이스 전문가는 필요에 따라 추가 리전에서 동일한 구성으로 데이터베이스 배포를 자동화하는 솔루션을 설계해야 합니다. 솔루션은 또한 모든 리전에서 구성 변경을 자동화해야 합니다.
# 이러한 요구 사항을 충족하고 DynamoDB 테이블을 배포하는 솔루션은 무엇입니까?
#
# >**A.** DynamoDB 테이블을 모든 리전에 배포하고 향후 배포를 위해 저장하는 AWS CLI 명령을 생성합니다.
# **B.** AWS CloudFormation 템플릿을 생성하고 템플릿을 모든 리전에 배포합니다.
# **C.** AWS CloudFormation 템플릿을 생성하고 스택 세트를 사용하여 템플릿을 모든 리전에 배포합니다.
# **D.** 모든 리전에서 AWS Management 콘솔을 사용하여 DynamoDB 테이블을 생성하고 향후 배포를 위한 단계별 가이드를 생성합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C(100%)<br>
# >AWS CloudFormation 템플릿 생성 -> 스택 세트 사용 -> 템플릿을 모든 리전에 배포합니다.<br>
# >스택 세트를 사용하면 단일 CloudFormation 템플릿을 사용하여 여러 리전의 AWS 계정에 스택을 생성할 수 있습니다.<br>
# >
# >[CloudFormation StackSets를 사용하여 여러 AWS 계정 및 리전에 리소스 프로비저닝](https://aws.amazon.com/ko/blogs/aws/use-cloudformation-stacksets-to-provision-resources-across-multiple-aws-accounts-and-regions/)
# </div></details>
#
# **[Q#019. Q#030. Q#117.](https://www.examtopics.com/discussions/amazon/view/25643-exam-aws-certified-database-specialty-topic-1-question-19/)**
# 데이터베이스 전문가 팀은 현재 Amazon RDS for MySQL DB 인스턴스의 성능 문제를 조사하고 관련 지표를 검토하고 있습니다. 팀은 상황을 더 잘 이해하기 위해 특정 데이터베이스 대기 이벤트로 가능성을 좁히기를 원합니다.
# 데이터베이스 전문가는 어떻게 이를 수행할 수 있습니까?
#
# >**A.** 고급 분석을 위해 모든 데이터베이스 로그를 Amazon CloudWatch로 푸시하는 옵션을 활성화합니다.
# **B.** 특정 기간을 포함할 적절한 Amazon CloudWatch 대시보드 생성
# **C.** Amazon RDS 성능 개선 도우미 활성화 및 적절한 대시보드 검토
# **D.** 향상된 모니터링 활성화는 적절한 설정을 할 것입니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C(100%)<br>
# >Amazon RDS 성능 개선 도우미를 활성화하면 대시보드가 있는 데이터베이스에 대한 메트릭이 제공됩니다. 향상된 모니터링은 OS 정보를 위한 것입니다.<br>
# >Amazon RDS 성능 개선 도우미 활성화는 대시보드가 ​​있는 데이터베이스에 대한 메트릭을 제공하여 데이터베이스 성능 활동을 보기 위해 시각적으로 탐색할 수 있도록 합니다.<br>
# >
# >[성능 개선 도우미를 사용하여 MySQL용 Amazon RDS 조정](https://aws.amazon.com/ko/blogs/database/tuning-amazon-rds-for-mysql-with-performance-insights/)
# </div></details>
#
# **[Q#020. Q#026. Q#063.](https://www.examtopics.com/discussions/amazon/view/65817-exam-aws-certified-database-specialty-topic-1-question-20/)**
# 대기업에서 Java 애플리케이션과 함께 Oracle 다중 AZ DB 인스턴스용 Amazon RDS를 사용하고 있습니다. 재해 복구 연례 테스트의 일환으로 이 회사는 가용 영역 장애를 시뮬레이션하고 DB 인스턴스 장애 조치 활동 중에 애플리케이션이 어떻게 반응하는지 기록하려고 합니다. 회사는 이 활동에 대한 코드 변경을 원하지 않습니다.
# 최단 시간 내에 이를 달성하기 위해 기업은 무엇을 해야 할까요?
#
# >**A.** 완전한 애플리케이션 수준 장애 조치 테스트와 함께 블루-그린 배포 사용
# **B.** RDS 콘솔을 사용하여 장애 조치와 함께 재부팅하는 옵션을 선택하여 DB 인스턴스를 재부팅합니다.
# **C.** RDS 오류 주입 쿼리를 사용하여 기본 노드 오류 시뮬레이션
# **D.** 단일 가용 영역과 연결된 서브넷의 모든 트래픽을 거부하는 규칙을 NACL에 추가
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : B(100%)<br>
# >장애 조치 테스트는 장애 조치가 있는 재부팅을 통해 수행됩니다.<br>
# >결함 주입 쿼리는 RDS DB 클러스터가 아닌 Aurora DB 클러스터에서만 사용할 수 있습니다.<br>
# >
# >[오류 삽입 쿼리를 사용하여 Amazon Aurora 테스트](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/AuroraMySQL.Managing.FaultInjectionQueries.html)
# </div></details>

# %% [markdown]
# # 021

# %% [markdown]
# **[Q#021. Q#035. Q#027.](https://www.examtopics.com/discussions/amazon/view/26014-exam-aws-certified-database-specialty-topic-1-question-21/)**
# 회사는 MySQL 및 PostgreSQL용 Amazon RDS를 사용하여 여러 데이터베이스를 유지 관리합니다. 각 RDS 데이터베이스는 보존 기간이 기본값으로 설정된 로그 파일을 생성합니다. 이 회사는 이제 실시간 및 사후 분석을 용이하게 하기 위해 중앙 집중식 저장소에서 데이터베이스 로그를 최대 90일 동안 유지하도록 의무화했습니다.
# 데이터베이스 전문가는 최소한의 노력으로 이러한 요구 사항을 충족하기 위해 무엇을 해야 합니까?
#
# >**A.** AWS Lambda 함수를 생성하여 RDS 데이터베이스에서 로그를 가져오고 Amazon S3 버킷에 로그 파일을 통합합니다. 객체가 90일 후에 만료되도록 수명 주기 정책을 설정합니다.
# **B.** Amazon CloudWatch Logs에 로그를 게시하도록 RDS 데이터베이스를 수정합니다. 각 로그 그룹에 대한 로그 보존 정책을 변경하여 90일 후에 이벤트를 만료시킵니다.
# **C.** 각 RDS 데이터베이스에 저장 프로시저를 작성하여 Amazon S3 버킷에 로그를 다운로드하고 로그 파일을 통합합니다. 객체가 90일 후에 만료되도록 수명 주기 정책을 설정합니다.
# **D.** AWS Lambda 함수를 생성하여 RDS 데이터베이스에서 로그를 다운로드하고 로그를 Amazon CloudWatch Logs에 게시합니다. 90일 후에 이벤트가 만료되도록 로그 그룹에 대한 로그 보존 정책을 변경합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : B(100%)<br>
# >최소한의 노력을 위해서는 내장된 기능을 사용합니다. 람다 작성은 최소한의 노력이 아닙니다.<br>
# >B: 최소한의 노력과 실시간으로 최상의 옵션.<br>
# >
# >[Amazon CloudWatch Logs에 데이터베이스 로그 게시](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/USER_LogAccess.Procedural.UploadtoCloudWatch.html)
# </div></details>
#
# **[Q#022. Q#154. Q#159.](https://www.examtopics.com/discussions/amazon/view/25813-exam-aws-certified-database-specialty-topic-1-question-22/)**
# 데이터베이스 전문가는 집중적인 비즈니스 크리티컬 애플리케이션을 위해 기본 인스턴스 1개와 Aurora 복제본 3개로 새로운 Amazon Aurora DB 클러스터를 설정하고 있습니다. Aurora DB 클러스터에는 중형 기본 인스턴스 1개, 대형 복제본 1개, 중형 복제본 2개가 있습니다. 데이터베이스 전문가가 복제본에 승격 계층을 할당하지 않았습니다.
# 기본 장애가 발생하면 어떻게 됩니까?
#
# >**A.** Aurora는 기본 인스턴스와 동일한 크기의 Aurora 복제본을 승격합니다.
# **B.** Aurora는 임의의 Aurora 복제본을 승격합니다.
# **C.** Aurora는 가장 큰 크기의 Aurora 복제본을 프로모션합니다.
# **D.** Aurora는 Aurora 복제본을 승격하지 않습니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C(100%)<br>
# >두 개 이상의 Aurora 복제본이 동일한 우선 순위를 공유하는 경우 Amazon RDS는 크기가 가장 큰 복제본을 승격합니다.<br>
# >둘 이상의 Aurora 복제본이 동일한 우선 순위와 크기를 공유하는 경우 Amazon RDS는 동일한 승격 티어에서 임의의 복제본을 승격합니다.<br>
# >
# >[Aurora DB 클러스터에 대한 내결함성](https://docs.amazonaws.cn/en_us/AmazonRDS/latest/AuroraUserGuide/Concepts.AuroraHighAvailability.html#Aurora.Managing.FaultTolerance)
# </div></details>
#
# **[Q#023. Q#093. Q#032.](https://www.examtopics.com/discussions/amazon/view/25547-exam-aws-certified-database-specialty-topic-1-question-23/)**
# 회사는 영구 데이터 저장소에서 MySQL용 Amazon RDS를 사용하는 AWS에서 비즈니스 애플리케이션을 실행하고 있습니다. 이 회사는 데이터베이스를 Amazon Aurora로 마이그레이션할 때 가동 중지 시간을 최소화하려고 합니다.
# 데이터베이스 전문가는 어떤 마이그레이션 방법을 사용해야 합니까?
#
# >**A.** RDS for MySQL DB 인스턴스의 스냅샷을 만들고 스냅샷 마이그레이션 옵션이 있는 새 Aurora DB 클러스터를 생성합니다.
# **B.** mysqldump 유틸리티를 사용하여 RDS for MySQL DB 인스턴스를 백업하고 새 Aurora DB 클러스터를 생성하고 백업을 복원합니다.
# **C.** RDS for MySQL DB 인스턴스에서 Aurora 복제본을 생성하고 Aurora DB 클러스터를 승격합니다.
# **D.** RDS for MySQL DB 인스턴스의 복제본을 생성하고 Aurora DB 클러스터를 승격합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C(100%)<br>
# >C. RDS for MySQL DB 인스턴스에서 Aurora 복제본을 생성하고 Aurora DB 클러스터를 승격합니다. 이것은 가장 빠르지 않을 수 있지만 문제는 "다운타임 최소화"입니다.<br>
# >MySQL DB 인스턴스 -> Aurora 복제본 생성(시간 소요) -> Aurora DB 클러스터 승격(다운타임 최소화)<br>
# >
# >[RDS for MySQL 데이터베이스를 Amazon Aurora로 마이그레이션하기 위한 모범 사례](https://aws.amazon.com/blogs/database/best-practices-for-migrating-rds-for-mysql-databases-to-amazon-aurora/)
# </div></details>
#
# **[Q#024. Q#168. Q#161.](https://www.examtopics.com/discussions/amazon/view/25814-exam-aws-certified-database-specialty-topic-1-question-24/)**
# 금융 회사의 보안 팀은 3주 전에 발생한 내부 보안 침해에 대해 통보받았습니다. 데이터베이스 전문가는 보안 팀이 모니터링 및 알림에 사용할 프로덕션 Amazon Aurora PostgreSQL 클러스터에서 감사 로그 생성을 시작해야 합니다. 보안 팀은 Aurora DB 클러스터 외부에서 실시간 알림 및 모니터링을 수행해야 하며 클러스터가 암호화된 파일을 선택한 솔루션으로 푸시하도록 하려고 합니다.
# 어떤 접근 방식이 이러한 요구 사항을 충족합니까?
#
# >**A.** pg_audit를 사용하여 감사 로그를 생성하고 보안 팀에 로그를 보냅니다.
# **B.** AWS CloudTrail을 사용하여 DB 클러스터를 감사하면 보안 팀이 Amazon S3에서 데이터를 가져옵니다.
# **C.** 데이터베이스 활동 스트림을 설정하고 Amazon Kinesis의 데이터 스트림을 소비자 애플리케이션에 연결합니다.
# **D.** 자세한 로깅을 켜고 보안 팀을 위해 로그를 덤프할 일정을 설정합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C(100%)<br>
# >질문이 "실시간 알림 또는 스트림"을 원할 때마다 거의 항상 Kinesis 스트림입니다.<br>
# >PostgreSQL과 호환되는 Amazon Aurora용 데이터베이스 활동 스트림은 관계형 데이터베이스의 데이터베이스 활동에 대한 거의 실시간 데이터 스트림을 제공하여 활동을 모니터링하는 데 도움이 됩니다.<br>
# >Cloudtrail은 여기에 필요한 로깅 유형을 지원하지 않는다고 생각합니다. 내부 데이터베이스 정보가 아닙니다<br>
# >
# >[Amazon Aurora with PostgreSQL Compatibility, 실시간 모니터링을 위해 데이터베이스 활동 스트림 지원](https://aws.amazon.com/about-aws/whats-new/2019/05/amazon-aurora-with-postgresql-compatibility-supports-database-activity-streams/)<br>
# >[데이터베이스 활동 스트림 개요](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/DBActivityStreams.Overview.html)<br>
# >[Amazon Aurora의 로깅 및 모니터링](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/Overview.LoggingAndMonitoring.html)
# </div></details>
#
# **★★★[Q#025. Q#142. Q#023.](https://www.examtopics.com/discussions/amazon/view/25405-exam-aws-certified-database-specialty-topic-1-question-25/)**
# 회사에서 MySQL용 Amazon RDS를 사용하여 비즈니스 애플리케이션을 재설계하고 있습니다. 데이터베이스 전문가는 개발자가 스키마 업데이트에서 실수를 범할 때 개발 팀이 MySQL 데이터베이스를 하루에도 여러 번 복원한다는 사실을 알아냈습니다 . 개발자는 복원이 완료될 때까지 몇 시간을 기다려야 하는 경우가 있습니다.
# 여러 팀 구성원이 프로젝트에 참여하고 있어 각 실수에 대한 올바른 복원 지점을 찾기가 어렵습니다.
# 데이터베이스 전문가는 다운타임을 줄이기 위해 어떤 접근 방식을 취해야 합니까?
#
# >**A.** 여러 읽기 전용 복제본을 배포하고 팀 구성원이 개별 복제본 인스턴스를 변경하도록 합니다.
# **B.** SQL Server용 Amazon RDS로 마이그레이션하고, 스냅샷을 생성하고, 스냅샷에서 복원합니다.
# **C.** Amazon Aurora MySQL로 마이그레이션하고 Aurora 역추적 기능 활성화
# **D.** Amazon RDS for MySQL 역추적 기능 활성화
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C(100%)
# >RDS-MySQL은 수정 가능한 읽기 전용 복제본을 허용합니다. 그러나 최소한의 중단으로 데이터베이스를 이전의 정상 상태로 복원하기 위한 기본 요구 사항은 Aurora의 고유한 기능인 역추적을 필요로 합니다.<br>
# >ReadReplica는 쓰기 가능하지만 개발자가 변경 사항을 롤백해야 하는 경우 다시 복원해야 하므로 더 많은 시간이 소요됩니다. 따라서 aurora로 마이그레이션하고 역추적을 사용하는 것이 올바른 옵션입니다.<br>
# >
# >[Amazon Aurora 역추적 – 시간을 되돌리기](https://aws.amazon.com/ko/blogs/aws/amazon-aurora-backtrack-turn-back-time/)
# </div></details>
#
# **[Q#026. Q#063. Q#084.](https://www.examtopics.com/discussions/amazon/view/25406-exam-aws-certified-database-specialty-topic-1-question-26/)**
# 미디어 회사는 Amazon RDS for PostgreSQL을 사용하여 사용자 데이터를 저장하고 있습니다. RDS DB 인스턴스는 현재 공개적으로 액세스할 수 있는 설정이 활성화되어 있으며 퍼블릭 서브넷에서 호스팅됩니다. 최근 AWS Well-Architected Framework 검토에 따라 데이터베이스 전문가에게 새로운 보안 요구 사항이 주어졌습니다.
#
# - 특정 사내 네트워크 IP만 DB 인스턴스에 연결해야 합니다.
# - 회사 네트워크에서만 연결이 허용됩니다.
#
# Database Specialist는 이러한 새로운 요구 사항을 충족하기 위해 어떤 단계를 조합해야 합니까? (3개를 선택하세요.)
#
# >**A.** pg_hba.conf 파일을 수정합니다. 필요한 회사 네트워크 IP를 추가하고 원하지 않는 IP를 제거합니다.
# **B.** 연결된 보안 그룹을 수정합니다. 필요한 회사 네트워크 IP를 추가하고 원하지 않는 IP를 제거합니다.
# **C.** AWS DMS를 사용하여 DB 인스턴스를 프라이빗 서브넷으로 이동합니다.
# **D.** 회사 네트워크에서 실행되는 애플리케이션 호스트와 DB 인스턴스와 연결된 VPC 간에 VPC 피어링을 활성화합니다.
# **E.** 공개적으로 액세스할 수 있는 설정을 비활성화합니다.
# **F.** 사설 IP와 VPN을 사용하여 DB 인스턴스에 연결합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : BEF (100%)  <br>
# >데이터베이스가 프라이빗 서브넷에 있을 필요는 없음.(질문에는 요구 사항이 없습니다). 퍼블릭 액세스를 비활성화하면 인스턴스에서 연결된 퍼블릭 IP 주소가 제거됩니다.<br>
# >RDS는 구성파일을 직접 편집 않음(Ax), 데이터베이스가 프라이빗 서브넷에 있을 필요가 없음(Cx), 퍼블릭 액세스를 비활성화하면 인스턴스에서 연결된 퍼블릭 IP 주소가 제거됨. 회사 네트워크는 온프레미스, VPC 피어링은 AWS VPC간에 사용(Dx)<br>
# >
# </div></details>
#
# **[Q#027. Q#150. Q#016.](https://www.examtopics.com/discussions/amazon/view/25515-exam-aws-certified-database-specialty-topic-1-question-27/)**
# 회사에서 신제품을 출시하려고 하고 테스트 데이터베이스는 프로덕션 데이터에서 다시 생성해야 합니다. 이 회사는 Amazon Aurora MySQL DB 클러스터에서 프로덕션 데이터베이스를 실행합니다. 데이터베이스 전문가는 최소한의 관리 노력으로 가능한 한 빨리 이러한 테스트 데이터베이스를 생성할 수 있는 솔루션을 배포해야 합니다.
# 데이터베이스 전문가는 이러한 요구 사항을 충족하기 위해 무엇을 해야 합니까?
#
# >**A.** 프로덕션 클러스터에서 테스트 클러스터로 스냅샷 복원
# **B.** 프로덕션 클러스터의 논리적 덤프를 만들고 새 테스트 클러스터로 복원합니다.
# **C.** 데이터베이스 복제를 사용하여 프로덕션 클러스터의 복제본 생성
# **D.** 프로덕션 클러스터에 읽기 전용 복제본을 추가하고 해당 노드를 테스트용으로 사용합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : C(100%)  <br>
# >Aurora 클러스터 복제는 데이터베이스 변경 사항의 영향을 평가하려는 경우 또는 워크로드 집약적인 작업을 수행해야 하거나 단순히 개발 또는 테스트 환경에서 프로덕션 데이터베이스의 복사본을 사용하려는 경우 Aurora DB 클러스터의 여러 클론을 만들 수 있습니다.<br>
# >클론 데이터베이스가 원본 데이터베이스와 동일한 지역에 생성되어야 한다는 제약 조건으로 다른 클론에서 추가 클론을 생성할 수도 있습니다.<br>
# >Aurora 클러스터 복제는 "기록 중 복사" 프로토콜을 사용하는 최선의 선택이며 데이터베이스는 몇 분 안에 사용할 수 있게 됩니다.<br>
# >
# >[빠른 데이터베이스 복제 및 역추적으로 애플리케이션 개발 가속화](https://aws.amazon.com/getting-started/hands-on/aurora-cloning-backtracking/)
# </div></details>
#
# **[Q#028. Q#116. Q#008.](https://www.examtopics.com/discussions/amazon/view/25516-exam-aws-certified-database-specialty-topic-1-question-28/)**
# 포틀랜드, 뉴욕 및 싱가포르에 지사가 있는 회사에는 공유 데이터베이스를 활용하는 3계층 웹 응용 프로그램이 있습니다. 데이터베이스는
# MySQL용 Amazon RDS에서 실행되며 us-west-2 리전에서 호스팅됩니다. 애플리케이션에는 us-west-2, ap-southeast-1 및 us-east-2 리전에 배포된 분산 프런트 엔드가 있습니다.
# 이 프런트 엔드는 각 지점의 영업 관리자가 현재 판매 통계를 볼 수 있는 대시보드로 사용됩니다. 대시보드가 ​​포틀랜드나 뉴욕보다 싱가포르 위치에서 더 느리게 작동한다는 불만이 있습니다. 각 위치의 모든 사용자에게 일관된 성능을 제공하려면 솔루션이 필요합니다.
# 이러한 요구 사항을 충족하는 일련의 작업은 무엇입니까?
#
# >**A.** us-west-2 리전에서 인스턴스의 스냅샷을 만듭니다. ap-southeast-1 리전의 스냅샷에서 새 인스턴스를 생성합니다. 이 인스턴스에 액세스하려면 ap-Southeast-1 프런트 엔드 대시보드를 재구성하십시오.
# **B.** us-west-2 리전의 기본 RDS DB 인스턴스에서 ap-southeast-1 리전에 RDS 읽기 전용 복제본을 생성합니다. 이 인스턴스에 액세스하려면 ap-southeast-1 프런트 엔드 대시보드를 재구성하십시오.
# **C.** ap-southeast-1 리전에 새 RDS 인스턴스를 생성합니다. AWS DMS 및 변경 데이터 캡처(CDC)를 사용하여 ap-southeast-1 리전에서 새 인스턴스를 업데이트합니다. 이 인스턴스에 액세스하려면 ap-southeast-1 프런트 엔드 대시보드를 재구성하십시오.
# **D.** 기본 인스턴스가 있는 us-west-2 리전에 RDS 읽기 전용 복제본을 생성합니다. us-west-2 리전에 있는 읽기 전용 복제본에서 ap-southeast-1 리전에 읽기 전용 복제본을 생성합니다. 이 인스턴스에 액세스하려면 ap-southeast-1 프런트 엔드 대시보드를 재구성하십시오.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : B(100%)  <br>
# >Amazon RDS 읽기 전용 복제본은 RDS 데이터베이스(DB) 인스턴스에 대해 향상된 성능과 내구성을 제공합니다. 이를 통해 읽기가 많은 데이터베이스 워크로드에 대한 단일 DB 인스턴스의 용량 제약을 쉽게 탄력적으로 확장할 수 있습니다.<br>
# >Amazon RDS를 사용하면 소스 DB 인스턴스와 다른 AWS 리전에서 MariaDB, MySQL, Oracle 또는 PostgreSQL 읽기 전용 복제본을 생성할 수 있습니다. Amazon RDS의 SQL Server에서는 리전 간 읽기 전용 복제본을 생성할 수 없습니다.<br>
# >
# >[Amazon RDS 읽기 전용 복제본](https://aws.amazon.com/ko/rds/features/read-replicas/)<br>
# >[다른 AWS 리전에서 읽기 전용 복제본 생성](https://docs.aws.amazon.com/AmazonRDS/latest/UserGuide/USER_ReadRepl.XRgn.html)
# </div></details>
#
# **[Q#029. Q#071. Q#021.](https://www.examtopics.com/discussions/amazon/view/67416-exam-aws-certified-database-specialty-topic-1-question-29/)**
# 회사에서 기존 온프레미스 Oracle 데이터베이스를 Amazon Aurora PostgreSQL로 마이그레이션하려고 합니다. 마이그레이션은 AWS DMS를 사용하여 최소한의 가동 중지 시간으로 완료해야 합니다. 데이터베이스 전문가는 전환 전에 데이터가 소스에서 대상으로 정확하게 마이그레이션되었는지 확인해야 합니다. 마이그레이션은 원본 데이터베이스의 성능에 최소한의 영향을 미쳐야 합니다.
# 어떤 접근 방식이 이러한 요구 사항을 가장 효과적으로 충족합니까?
#
# >**A.** AWS Schema Conversion Tool(AWS SCT)을 사용하여 소스 Oracle 데이터베이스 스키마를 대상 Aurora DB 클러스터로 변환합니다. 열의 데이터 유형을 확인하십시오.
# **B.** 데이터 마이그레이션을 위해 생성된 AWS DMS 작업의 테이블 지표를 사용하여 마이그레이션되는 테이블에 대한 통계를 확인하고 데이터 정의 언어(DDL) 문이 완료되었는지 확인합니다.
# **C.** AWS Schema Conversion Tool(AWS SCT) 사전 마이그레이션 검증을 활성화하고 마이그레이션 전 체크리스트를 검토하여 변환에 문제가 없는지 확인합니다.
# **D.** AWS DMS 작업이 소스 및 대상 레코드를 비교하고 불일치를 보고하도록 작업에 대한 AWS DMS 데이터 검증을 활성화합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : D(100%)  <br>
# >데이터가 원본에서 대상으로 정확하게 마이그레이션되었는지 확인하려면 데이터 유효성 검사를 사용할 수 있으며, DMS 작업이 시작되기 전과 마이그레이션이 완료된 후에 활성화해야 합니다.<br>
# >AWS DMS의 테이블 지표는 DMS 작업에 대해 수동으로 확인할 수 있습니다. 이러한 메트릭을 읽고 모든 것이 잘 진행되었는지 확인하는 자동화를 제공하는 메커니즘은 없습니다. 100개 이상의 테이블을 작업하는 경우 DMS 데이터 유효성 검사가 유일한 옵션입니다.<br>
# >
# >[AWS DMS 데이터 유효성 검사](https://docs.aws.amazon.com/ko_kr/dms/latest/userguide/CHAP_Validating.html)
# </div></details>
#
# **[Q#030. Q#117. Q#138.](https://www.examtopics.com/discussions/amazon/view/26016-exam-aws-certified-database-specialty-topic-1-question-30/)**
# 회사가 며칠 동안 문을 닫을 계획입니다. 데이터베이스 전문가는 이 시간 동안 직원이 시스템에 액세스할 수 없도록 DB 인스턴스와 함께 모든 애플리케이션을 중지해야 합니다. 모든 데이터베이스는 MySQL용 Amazon RDS에서 실행됩니다.
# Database Specialist는 모든 DB 인스턴스를 중지하는 스크립트를 작성하고 실행했습니다. 데이터베이스 전문가는 로그를 검토할 때 읽기 전용 복제본이 있는 Amazon RDS DB 인스턴스가 중지되지 않았음을 발견했습니다.
# 데이터베이스 전문가는 이 문제를 해결하기 위해 스크립트를 어떻게 편집해야 합니까?
#
# >**A.** 읽기 전용 복제본을 중지하기 전에 소스 인스턴스를 중지하십시오.
# **B.** 해당 소스 인스턴스를 중지하기 전에 각 읽기 전용 복제본을 삭제합니다.
# **C.** 원본 인스턴스를 중지하기 전에 읽기 전용 복제본을 중지합니다.
# **D.** AWS CLI를 사용하여 각 읽기 전용 복제본과 소스 인스턴스를 동시에 중지
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : B(100%)<br>
# >읽기 전용 복제본이 있거나 읽기 전용 복제본인 DB 인스턴스는 중지할 수 없습니다. 중지하려면 읽기 전용 복제본을 삭제해야 합니다.<br>
# >
# >[Amazon RDS DB 인스턴스의 일시적 중지](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/USER_StopInstance.html)
# </div></details>

# %% [markdown]
# # 031

# %% [markdown]
# **[Q#031. Q#089. Q#185.](https://www.examtopics.com/discussions/amazon/view/67316-exam-aws-certified-database-specialty-topic-1-question-31/)**
# 글로벌 디지털 광고 회사는 검색 메타데이터를 캡처하여 관련 이미지, 페이지 및 대상 사용자에 대한 링크를 상황에 맞게 표시합니다. 단일 페이지 로드는 개별적으로 저장해야 하는 여러 이벤트를 생성할 수 있습니다. 이벤트의 최대 크기는 200KB이고 평균 크기는 10KB입니다. 각 페이지 로드는 타겟팅 권장 사항을 제공하기 위해 사용자의 검색 기록을 쿼리해야 합니다.
# 광고 회사는 미국, 유럽, 홍콩 및 인도 의 사용자가 하루에 10억 개 이상의 페이지를 방문할 것으로 예상합니다. 메타데이터의 구조는 이벤트에 따라 다릅니다. 또한 브라우징 메타데이터는 사용자에게 좋은 시청 경험을 보장하기 위해 매우 짧은 대기 시간으로 쓰고 읽어야 합니다.
# 이러한 요구 사항을 충족하는 데이터베이스 솔루션은 무엇입니까?
#
# >**A.** Amazon DocumentDB
# **B.** Amazon RDS 다중 AZ 배포
# **C.** Amazon DynamoDB 전역 테이블
# **D.** Amazon Aurora 글로벌 데이터베이스
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : C(100%)<br>
# >이벤트에 따라 정보 구조가 다름 => Schemaless Amazon DynamoDB 글로벌 테이블
# </div></details>
#
# **[Q#032. Q#115. Q#074.](https://www.examtopics.com/discussions/amazon/view/66151-exam-aws-certified-database-specialty-topic-1-question-32/)**
# 데이터베이스 전문가가 현재 프로덕션 Amazon RDS for SQL Server 다중 AZ DB 인스턴스와 연결된 기존 파라미터 그룹을 수정했습니다. 변경 사항은 회사의 가장 중요한 RDS SQL Server DB 인스턴스에서 허용되는 사용자 연결 수를 제어하는 ​​정적 매개변수 유형과 연결되어 있습니다. 이 변경은 사용자에게 미치는 영향을 최소화하는 데 도움이 되도록 특정 유지 관리 기간에 대해 승인되었습니다.
# Database Specialist는 DB 인스턴스에 대한 파라미터 그룹 변경 사항을 어떻게 적용해야 합니까?
#
# >**A.** 변경 사항을 즉시 적용하는 옵션 선택
# **B.** 주어진 DB 인스턴스에 대해 사전 구성된 RDS 유지 관리 기간을 허용하여 변경 사항이 적용되는 시기를 제어합니다.
# **C.** 승인된 유지 관리 기간 동안 DB 인스턴스를 재부팅하여 변경 사항을 수동으로 적용합니다.
# **D.** 보조 다중 AZ DB 인스턴스 재부팅
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : C(100%)<br>
# >정적 매개변수는 수동 재부팅이 필요합니다. 즉시 또는 유지 관리 기간 동안 수행할 수 있습니다.<br>
# >
# >[파라미터 그룹 작업](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/USER_WorkingWithParamGroups.html#USER_WorkingWithParamGroups.Modifying)
# </div></details>
#
# **[Q#033. Q#105. Q#049.](https://www.examtopics.com/discussions/amazon/view/25605-exam-aws-certified-database-specialty-topic-1-question-33/)**
# 데이터베이스 전문가는 차량 호출 애플리케이션을 위한 새로운 데이터베이스 인프라를 설계하고 있습니다. 애플리케이션 데이터에는
# 모든 라이드에 대한 GPS 좌표를 저장하는 라이드 추적 시스템이 포함됩니다. 실시간 통계 및 메타데이터 조회는 높은 처리량과 마이크로초 지연 시간으로 수행되어야 합니다. 데이터베이스는 최소한의 운영 오버헤드와 개발 노력으로 내결함성이 있어야 합니다.
# 어떤 솔루션이 가장 효율적인 방식으로 이러한 요구 사항을 충족합니까?
#
# >**A.** MySQL용 Amazon RDS를 데이터베이스로 사용하고 Amazon ElastiCache를 사용합니다.
# **B.** Amazon DynamoDB를 데이터베이스로 사용하고 DynamoDB Accelerator를 사용합니다.
# **C.** Amazon Aurora MySQL을 데이터베이스로 사용하고 Aurora의 버퍼 캐시 사용
# **D.** Amazon DynamoDB를 데이터베이스로 사용하고 Amazon API Gateway를 사용합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : B(100%)  <br>
# >NoSQL이 여기에 이상적입니다. DynamoDB+DAX(Amazon DynamoDB Accelerator)는 마이크로초 지연 시간을 제공합니다.<br>
# >DAX는 DynamoDB용 완전 관리형 고가용성 인메모리 캐시로, 초당 수백만 건의 요청에서도 밀리초에서 마이크로초로 최대 10배의 성능 향상을 제공합니다.<br>
# >API 게이트웨이는 이 질문의 요구 사항과 아무 관련이 없습니다.<br>
# >마이크로초 = DynamoDB DAX<br>
# >
# >[Amazon DynamoDB Accelerator(DAX)](https://aws.amazon.com/ko/dynamodb/dax/#:~:text=Amazon%20DynamoDB%20Accelerator%20(DAX)%20is,millions%20of%20requests%20per%20second.)<br>
# >[DAX: 작동 방식](https://docs.aws.amazon.com/ko_kr/amazondynamodb/latest/developerguide/DAX.concepts.html)
# </div></details>
#
# **[Q#034. Q#037. Q#147.](https://www.examtopics.com/discussions/amazon/view/25720-exam-aws-certified-database-specialty-topic-1-question-34/)**
# 회사는 고가용성 및 읽기 전용 워크로드 확장을 위해 xlarge 기본 인스턴스 마스터와 2개의 대형 Aurora 복제본이 있는 Amazon Aurora PostgreSQL DB 클러스터를 사용하고 있습니다. 장애 조치 이벤트가 발생하고 몇 분 동안 애플리케이션 성능이 저하됩니다. 이 시간 동안 모든 가용영역의 애플리케이션 서버는 정상 상태이며 정상적으로 응답합니다.
# 회사는 이 애플리케이션 성능 문제를 제거하기 위해 무엇을 해야 합니까?
#
# >**A.** 두 Aurora 복제본을 기본 DB 인스턴스와 동일한 인스턴스 클래스로 구성합니다. DB 클러스터에서 캐시 일관성을 활성화하고 기본 DB 인스턴스 장애 조치 우선 순위를 Tier-0으로 설정하고 Tier-1의 장애 조치 우선 순위를 복제본에 할당합니다.
# **B.** DescribeDBInstances 작업을 호출하는 AWS Lambda 함수를 배포하여 실패한 인스턴스를 설정한 다음, PromoteReadReplica 작업을 사용하여 하나의 Aurora 복제본을 기본 DB 인스턴스로 승격합니다. Lambda 함수가 구독되는 Amazon SNS 주제에 알림을 보내도록 Amazon RDS 이벤트 구독을 구성합니다.
# **C.** 기본 DB 인스턴스와 동일한 인스턴스 클래스를 갖도록 하나의 Aurora 복제본을 구성합니다. Aurora PostgreSQL DB 클러스터 캐시 관리를 구현합니다. 기본 DB 인스턴스와 동일한 인스턴스 클래스를 가진 하나의 복제본에 대해 장애 조치 우선 순위를 Tier-0으로 설정합니다. 다른 복제본에 대해 장애 조치 우선 순위를 Tier-1로 설정합니다.
# **D.** 기본 DB 인스턴스와 동일한 인스턴스 클래스를 갖도록 두 Aurora 복제본을 구성합니다. Aurora PostgreSQL DB 클러스터 캐시 관리를 구현합니다. 장애 조치 우선 순위를 기본 DB 인스턴스의 경우 Tier-0으로, 복제본의 경우 Tier-1로 설정합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C(100%)  <br>
# >기본 DB와 동일한 인스턴스 클래스의 Aurora 복제본 1개<br>
# > -> Aurora PostgreSQL DB 클러스터 캐시 관리(CCM) 구현<br>
# > -> 기본 DB 인스턴스와 인스턴스 클래스가 동일한 1개의 복제본에 대해 장애 조치 우선 순위 Tier-0으로 설정<br>
# > -> 다른 복제본에 대해 장애 조치 우선 순위 tier-1으로 설정<br>
# >
# >일반적인 장애 조치 상황에서는 장애 조치 DB 인스턴스가 시작될 때 버퍼 캐시가 비어 있어(콜드캐시) 느린 디스크에서 읽어야 하기 때문에 장애 조치 후 일시적이지만 큰 성능 저하를 볼 수 있습니다.<br>
# >클러스터 캐시 관리(CCM)를 사용하여 특정 Reader DB 인스턴스를 장애 조치 대상으로 설정하고, 지정된 Reader의 캐시에 있는 데이터가 Writer DB 인스턴스의 캐시 데이터와 동기화된 상태를 유지하도록(웜캐시) 하여 장애 조치가 발생하면 지정된 Reader는 새 Writer DB 인스턴스로 승격되는 즉시 웜 캐시의 값을 사용하여 훨씬 더 나은 복구 성능을 제공합니다.<br>
# >CCM은 하나의 복제본으로만 설정할 수 있습니다. 이것이 바로 CCM 지원 복제본으로 장애 조치를 보장하기 위해 Tier-0에 배치한 이유입니다.<br>
# >
# >[장애 조치 후 Aurora PostgreSQL용 클러스터 캐시 관리를 통한 신속한 복구](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/AuroraPostgreSQL.cluster-cache-mgmt.html)<br>
# >[Aurora PostgreSQL 클러스터 캐시 관리 소개](https://aws.amazon.com/ko/blogs/database/introduction-to-aurora-postgresql-cluster-cache-management/)
# </div></details>
#
# **[Q#035. Q#027. Q#150.](https://www.examtopics.com/discussions/amazon/view/25721-exam-aws-certified-database-specialty-topic-1-question-35/)**
# 회사에 Amazon RDS for SQL Server 환경에 Amazon CloudWatch를 사용하는 데이터베이스 모니터링 솔루션이 있습니다. 최근 CPU 사용률 급증의 원인은 수집된 표준 메트릭을 사용하여 확인되지 않았습니다. CPU 스파이크로 인해 애플리케이션이 제대로 수행되지 않아 사용자에게 영향을 미쳤습니다. 데이터베이스 전문가는 CPU 스파이크의 원인을 파악해야 합니다.
# CPU 부하가 증가하는 동안 실행되는 프로세스와 쿼리에 대한 가시성을 높이기 위해 취해야 하는 단계의 조합은 무엇입니까? (2개를 선택하세요.)
#
# >**A.** Amazon CloudWatch Events를 활성화하고 CPU 스파이크를 유발하는 수신 T-SQL 문을 확인합니다.
# **B.** 향상된 모니터링 지표를 활성화하여 RDS SQL Server DB 인스턴스 수준에서 CPU 사용률을 확인합니다.
# **C.** RDS SQL Server DB 인스턴스에서 반복되는 쿼리를 지원하는 캐싱 계층을 구현합니다.
# **D.** Amazon QuickSight를 사용하여 실행 중인 SQL 문을 봅니다.
# **E.** Amazon RDS 성능 개선 도우미를 활성화하여 데이터베이스 로드를 보고 대기, SQL 문, 호스트 또는 사용자별로 로드를 필터링합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : BE(100%)  <br>
# >Enhanced Monitoring의 운영 체제(OS) 프로세스 목록 섹션에서 OS 프로세스와 RDS 프로세스를 검토하고 프로세스의 CPU 사용율 지표를 검토합니다.<br>
# >성능 개선 도우미(Performance Insights)를 사용하여 인스턴스에서 실행 중이며 CPU 사용량을 높이는 쿼리를 정확히 식별할 수 있습니다
# >
# >[Amazon RDS for MySQL 인스턴스에서 높은 CPU 사용률 문제 해결방법](https://aws.amazon.com/ko/premiumsupport/knowledge-center/rds-instance-high-cpu/)
# </div></details>
#
# **[Q#036. Q#141. Q#053.](https://www.examtopics.com/discussions/amazon/view/25722-exam-aws-certified-database-specialty-topic-1-question-36/)**
# 회사는 읽기 전용 워크로드 확장을 위해 Amazon을 Aurora 복제본과 함께 사용하고 있습니다. 데이터베이스 전문가는 각 애플리케이션이 항상 전용 복제본에 연결되도록 두 개의 읽기 전용 애플리케이션을 분할해야 합니다. Database Specialist는 읽기 전용 애플리케이션에 대한 로드 밸런싱 및 고가용성을 구현하려고 합니다.
# 어떤 솔루션이 이러한 요구 사항을 충족합니까?
#
# >**A.** 각 복제본에 대해 특정 인스턴스 엔드포인트를 사용하고 각 읽기 전용 응용 프로그램 연결 문자열에 인스턴스 엔드포인트를 추가합니다.
# **B.** 읽기 전용 워크로드 애플리케이션 모두에 대해 리더 엔드포인트를 사용합니다.
# **C.** 하나의 읽기 전용 애플리케이션에는 리더 엔드포인트를 사용하고 다른 읽기 전용 애플리케이션에는 인스턴스 엔드포인트를 사용합니다.
# **D.** 두 개의 읽기 전용 응용 프로그램에 대해 사용자 지정 엔드포인트를 사용합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : D(100%)  <br>
# >사용자 정의 엔드포인트에 의한 각 애플리케이션에 전용 엔드포인트를 지정하여 각 응용 프로그램이 특정 인스턴스에 연결하고 하나의 읽기 전용 복제본이 다운될 경우 DNS를 대칭 이동하여 HA를 제공합니다.<br>
# >사용자 지정 요구 사항에 대한 사용자 지정 엔드포인트<br>
# >
# >[사용자 지정 EndPoint](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/Aurora.Overview.Endpoints.html#Aurora.Endpoints.Reader)
# </div></details>
#
# **[Q#037. Q#147. Q#031.](https://www.examtopics.com/discussions/amazon/view/26355-exam-aws-certified-database-specialty-topic-1-question-37/)**
# 온라인 게임 회사는 Amazon DynamoDB를 데이터 저장소로 사용하여 새 게임을 출시할 계획입니다. 데이터베이스는 다음 사용 사례를 지원하도록 지정되어야 합니다.
# - 플레이어가 게임을 할 때마다 실시간으로 점수를 업데이트합니다.
# - 특정 게임 세션에 대한 플레이어의 점수 세부 정보를 검색합니다.
#
# 데이터베이스 전문가가 DynamoDB 테이블을 구현하기로 결정했습니다. 각 플레이어에는 고유한 user_id가 있고 각 게임에는 고유한 game_id가 있습니다.
# DynamoDB 테이블에 권장되는 키 선택은 무엇입니까?
#
# >**A.** game_id를 파티션 키로 사용하여 글로벌 보조 인덱스 생성
# **B.**  user_id를 파티션 키로 사용하여 글로벌 보조 인덱스 생성
# **C.** game_id를 파티션 키로, user_id를 정렬 키로 사용하여 복합 기본 키를 만듭니다.
# **D.** user_id를 파티션 키로, game_id를 정렬 키로 사용하여 복합 기본 키를 만듭니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : D(50%), C(50%)  <br>
# >점수는 플레이어가 게임에 참여할 때마다 실시간으로 업데이트되어야 합니다. -> game_id는 파티션 키입니다.<br>
# >특정 게임 세션에 대한 플레이어의 점수 정보를 검색합니다. - > game_id 및 user_id는 기본 키입니다(예: user_id는 정렬 키).<br>
# >player_id가 있으면 핫 파티셔닝이 발생합니다. 그래서 D는 틀렸다. game_id가 더 높은 카디널리티를 가지므로 C가 정확합니다.<br>
# >
# >[DynamoDB에서 글로벌 보조 인덱스 사용](https://docs.aws.amazon.com/ko_kr/amazondynamodb/latest/developerguide/GSI.html)
# </div></details>
#
# **[Q#038. Q#128. Q#176.](https://www.examtopics.com/discussions/amazon/view/25724-exam-aws-certified-database-specialty-topic-1-question-38/)**
# 데이터베이스 전문가가 기존 프로덕션 MySQL 데이터베이스를 온프레미스에서 Amazon RDS for MySQL DB 인스턴스로 마이그레이션했습니다. 그러나 마이그레이션 후에는 AWS KMS를 사용하여 미사용 데이터베이스를 암호화해야 했습니다. 데이터베이스의 크기로 인해 암호화된 데이터베이스에 데이터를 다시 로드하는 것은 시간이 너무 오래 걸리므로 선택 사항이 아닙니다.
# 데이터베이스 전문가는 이 새로운 요구 사항을 어떻게 충족해야 합니까?
#
# >**A.** 암호화되지 않은 RDS DB 인스턴스의 스냅샷을 생성합니다. 암호화되지 않은 스냅샷의 암호화된 복사본을 만듭니다. 암호화된 스냅샷 복사본을 복원합니다.
# **B.** RDS DB 인스턴스를 수정합니다. AWS CLI를 활용하는 AWS KMS 암호화 옵션을 활성화합니다.
# **C.** 암호화되지 않은 스냅샷을 암호화된 MySQL RDS DB 인스턴스로 복원합니다.
# **D.** RDS DB 인스턴스의 암호화된 읽기 전용 복제본을 생성합니다. 마스터로 승격하십시오.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : A(100%)<br>
# >암호화되지 않은 스냅샷 -> 암호화된 스냅샷 복사본 -> 암호화된 스냅샷 사본을 복원합니다.<br>
# >
# >[Amazon RDS 리소스 암호화](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/Overview.Encryption.html)
# </div></details>
#
# **[Q#039. Q#178. Q#039.](https://www.examtopics.com/discussions/amazon/view/65852-exam-aws-certified-database-specialty-topic-1-question-39/)**
# 데이터베이스 전문가가 기존 Amazon RDS for MySQL 다중 AZ DB 인스턴스의 읽기 전용 복제본을 생성할 계획입니다. AWS Management
# 콘솔을 사용하여 이 작업을 수행할 때 데이터베이스 전문가는 원본 RDS DB 인스턴스가 읽기 전용 복제본 소스 선택 상자에 나타나지 않아 읽기 전용 복제본을 생성할 수 없음을 발견했습니다.
# 이에 대한 가장 가능성 있는 이유는 무엇입니까?
#
# >**A.** 원본 DB 인스턴스에서 읽기 전용 복제본을 생성하려면 먼저 단일 AZ로 변환해야 합니다.
# **B.** 원본 DB 인스턴스에서 Enhanced Monitoring이 활성화되어 있지 않습니다.
# **C.** 원본 DB 인스턴스의 마이너 MySQL 버전은 읽기 전용 복제본을 지원하지 않습니다.
# **D.** 소스 DB 인스턴스에서 자동 백업이 활성화되어 있지 않습니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : D(100%)<br>
# >읽기 전용 복제본을 생성하려면 원본DB 인스턴스에 자동 백업을 활성화해야 합니다.<br>
# >
# >[DBInstanceReadReplica 생성](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/APIReference/API_CreateDBInstanceReadReplica.html)
# </div></details>
#
# **[Q#040. Q#077. Q#175.](https://www.examtopics.com/discussions/amazon/view/25619-exam-aws-certified-database-specialty-topic-1-question-40/)**
# 데이터베이스 전문가가 온프레미스 Oracle 데이터베이스를 Amazon Aurora PostgreSQL로 마이그레이션했습니다. 스키마와 데이터가 성공적으로 마이그레이션되었습니다.
# 온프레미스 데이터베이스 서버는 데이터 제거 및 데이터 내보내기 생성을 포함한 작업을 수행하기 위해 Python으로 작성된 데이터베이스 유지 관리 크론 작업을 실행하는 데에도 사용되었습니다. 이러한 작업에 대한 로그는 대부분의 경우 작업이 5분 이내에 완료되었음을 보여주지만 일부 작업은 완료하는 데 최대 10분이 소요되었습니다. 이러한 유지 관리 작업은 Aurora PostgreSQL에 대해 설정해야 합니다.
# 데이터베이스 전문가가 이러한 작업을 예약하여 설정에서 유지 관리를 최소화하고 고가용성을 제공하도록 하려면 어떻게 해야 합니까?
#
# >**A.** Amazon EC2 인스턴스에서 cron 작업을 생성하여 필요한 일정에 따라 유지 관리 작업을 실행합니다.
# **B.** Aurora 호스트에 연결하고 cron 작업을 생성하여 필요한 일정에 따라 유지 관리 작업을 실행합니다.
# **C.** AWS Lambda 함수를 생성하여 유지 관리 작업을 실행하고 Amazon CloudWatch Events로 예약합니다.
# **D.** Amazon CloudWatch 작업 예약 플러그인을 사용하여 유지 관리 작업을 생성합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C(100%)  <br>
# >Amazon RDS 또는 Amazon Aurora PostgreSQL로 마이그레이션하면 호스트 인스턴스에 로그인하여 cron 작업을 예약하는 기능을 잃게 됩니다.<br>
# >CloudWatch 작업 예약 플러그인 같은 것은 없음.<br>
# >CloudWatch 스케줄링 및 Lambda 실행이며 이 옵션은 작업이 15분 이내에 완료되는 한 괜찮을 것입니다.<br>
# >
# >[AWS에서 Cron 작업을 실행하는 4가지 방법](https://betterprogramming.pub/cron-job-patterns-in-aws-126fbf54a276)<br>
# >[CloudWatch Events를 사용하여 AWS Lambda 함수 예약](https://docs.aws.amazon.com/ko_kr/AmazonCloudWatch/latest/events/RunLambdaSchedule.html)
# </div></details>

# %% [markdown]
# # 041

# %% [markdown]
# **[Q#041. Q#131. Q#121.](https://www.examtopics.com/discussions/amazon/view/25680-exam-aws-certified-database-specialty-topic-1-question-41/)**
# 회사에 크기가 200GB이고 RPO가 6시간인 Amazon RDS 다중 AZ DB 인스턴스가 있습니다. 회사의 재해 복구 정책을 충족하려면 데이터베이스 백업을 다른 지역에 복사해야 합니다. 회사는 비용 효율적이고 운영 효율성이 높은 솔루션이 필요합니다.
# 데이터베이스 전문가는 데이터베이스 백업을 다른 지역으로 복사하기 위해 무엇을 해야 합니까?
#
# >**A.** Amazon RDS 자동 스냅샷을 사용하고 AWS Lambda를 사용하여 다른 리전에 스냅샷 복사
# **B.** 6시간마다 Amazon RDS 자동 스냅샷을 사용하고 Amazon S3 교차 리전 복제를 사용하여 스냅샷을 다른 리전으로 복사
# **C.** 6시간마다 Amazon RDS 스냅샷을 생성하는 AWS Lambda 함수를 생성하고 두 번째 Lambda 함수를 사용하여 스냅샷을 다른 리전으로 복사
# **D.** 다른 리전에서 Amazon RDS용 교차 리전 읽기 전용 복제본을 생성하고 읽기 전용 복제본의 자동화된 스냅샷을 생성합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C(100%)<br>
# >Ax Amazon RDS 자동 스냅샷은 하루에 한번만 생성되어 6시간 RPO 불가<br>
# >Bx Amazon RDS 자동 스냅샷을 6시간마다 사용불가<br>
# >Co 6시간마다 Amazon RDS 스냅샷을 생성하고 두 번째 Lambda 함수를 사용하여 스냅샷을 복사하는 AWS Lambda 함수를 생성합니다. 다른 리전에서만 가능한 옵션<br>
# >Dx 읽기전용 복제본은 비용 효율적이지 않고 가장 비용이 많이 드는 DR 옵션.<br>
# >자동 백업은 매일 수행되므로 6시간 RPO는 불가능합니다.<br>
# >
# >[Amazon RDS로 재해 복구 전략 구현](https://aws.amazon.com/ko/blogs/database/implementing-a-disaster-recovery-strategy-with-amazon-rds/)
# </div></details>
#
# **[Q#042. Q#165. Q#050.](https://www.examtopics.com/discussions/amazon/view/26019-exam-aws-certified-database-specialty-topic-1-question-42/)**
# 프로비저닝된 IOPS(PIOPS) 스토리지가 있는 Amazon RDS EBS 최적화 인스턴스는 일정한 부하에서 몇 ​​시간 동안 할당된 IOPS의 절반 미만을 사용하고 있습니다. RDS 인스턴스는 몇 초의 읽기 및 쓰기 지연 시간을 나타내며 읽기 처리량에 대해 최대 대역폭을 모두 사용하지만 인스턴스는 CPU 및 RAM 리소스의 절반 미만을 사용합니다.
# 이 상황에서 데이터베이스 전문가는 성능을 높이고 대기 시간을 1초 미만 수준으로 되돌리기 위해 무엇을 해야 합니까?
#
# >**A.** DB 인스턴스 스토리지 크기 늘리기
# **B.** 기본 EBS 스토리지 유형을 범용 SSD(gp2)로 변경
# **C.** DB 인스턴스에서 EBS 최적화 비활성화
# **D.** DB 인스턴스를 최대 대역폭이 더 높은 인스턴스 클래스로 변경
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : D(100%)<br>
# >목표는 사용된 읽기 처리량에 대한 최대 대역폭을 처리하는 것입니다<br>
# >Ax DB 인스턴스 스토리지의 크기를 늘립니다(관련 없음)<br>
# >Bx 기본 EBS 스토리지 유형을 범용 SSD(gp2)로 변경(속도가 느려짐, gp2는 io2보다 느림)<br>
# >Cx DB 인스턴스에서 EBS 최적화 비활성화(속도가 느려짐)<br>
# >Do DB 인스턴스를 최대 대역폭이 더 높은 인스턴스 클래스로 변경, 처리량은 인스턴스 크기/유형과 관련이 있음.
# >
# >[Amazon EBS 최적화 인스턴스](https://docs.aws.amazon.com/ko_kr/AWSEC2/latest/UserGuide/ebs-optimized.html)
# </div></details>
#
# **[Q#043. Q#164. Q#025.](https://www.examtopics.com/discussions/amazon/view/25820-exam-aws-certified-database-specialty-topic-1-question-43/)**
# 3일 전의 Amazon RDS 스냅샷을 복원한 후 회사의 개발 팀이 복원된 RDS DB 인스턴스에 연결할 수 없습니다. 이 문제의 가능한 원인은 무엇입니까?
#
# >**A.** 복원된 DB 인스턴스에 Enhanced Monitoring이 활성화되어 있지 않습니다.
# **B.** 프로덕션 DB 인스턴스가 사용자 지정 파라미터 그룹을 사용하고 있습니다.
# **C.** 복원된 DB 인스턴스가 기본 보안 그룹을 사용 중입니다.
# **D.** 프로덕션 DB 인스턴스가 사용자 지정 옵션 그룹을 사용 중입니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C(75%), B(25%)<br>
# >DB 인스턴스 복원 시 다른 항목을 선택하지 않는 한 기본 VPC, DB 서브넷 그룹 및 VPC 보안 그룹이 복원된 인스턴스와 연결됨.<br>
# >Ax 향상된 모니터링이 활성화됨(관련 없음 - 성능 확인용)<br>
# >Bx 프로덕션 DB 인스턴스가 사용자 지정 파라미터 그룹을 사용하고 있음(DB 인스턴스를 복원할 때 파라미터 그룹을 지정할 수 있음)<br>
# >Co 복원된 DB 인스턴스가 기본 보안 그룹을 사용하고 있음. 보안 그룹이 DB 인스턴스에 대한 연결을 제어하기 때문에 문제의 원인일 수 있음.<br>
# >Dx 프로덕션 DB 인스턴스는 사용자 지정 옵션 그룹 사용(관련 없음)<br>
# >
# >[DB 스냅샷에서 복원](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/USER_RestoreFromSnapshot.html)
# </div></details>
#
# **[Q#044. Q#129. Q#065.](https://www.examtopics.com/discussions/amazon/view/67555-exam-aws-certified-database-specialty-topic-1-question-44/)**
# 게임 회사는 Redis용 Amazon ElastiCache 내 정렬된 집합 데이터 구조를 사용하여 AWS에서 리더보드를 구현했습니다. ElastiCache 클러스터는 클러스터 모드가 비활성화된 상태로 배포되었으며 2개의 추가 복제본과 함께 배포된 복제 그룹이 있습니다. 이 회사는 전 세계적인 게임 이벤트를 계획하고 있으며 현재 클러스터가 처리할 수 있는 것보다 더 높은 쓰기 로드를 예상하고 있습니다.
# 데이터베이스 전문가는 다가오는 이벤트에 앞서 ElastiCache 클러스터를 확장하기 위해 어떤 방법을 사용해야 합니까?
#
# >**A.** 기존 ElastiCache 클러스터에서 클러스터 모드를 활성화하고 클러스터의 모든 노드에서 Sorted Set에 대해 별도의 샤드를 구성합니다.
# **B.** ElastiCache 클러스터 노드의 크기를 더 큰 인스턴스 크기로 늘립니다.
# **C.** 추가 ElastiCache 클러스터를 생성하고 두 클러스터 간에 트래픽 로드 밸런싱을 수행합니다.
# **D.** EXPIRE 명령을 사용하고 주어진 키를 증가시키기 위해 각 호출 후에 더 높은 TTL(Time to Live)을 설정합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : B(100%)<br>
# >Ax 기존 클러스터에서 클러스터 모드를 활성화할 수 없습니다.<br>
# >Bo 클러스터 모드를 비활성화하면 수직 확장만 허용됩니다.<br>
# >클러스터 모드가 활성화된 새 클러스터를 프로비저닝하고 S3에서 백업된 데이터를 복원해야 합니다.<br>
# >
# >[복제: Redis(클러스터 모드 비활성화됨) 대 Redis(클러스터 모드 활성화됨)](https://docs.aws.amazon.com/ko_kr/AmazonElastiCache/latest/red-ug/Replication.Redis-RedisCluster.html)
# </div></details>
#
# **[Q#045. Q#101. Q#072.](https://www.examtopics.com/discussions/amazon/view/26361-exam-aws-certified-database-specialty-topic-1-question-45/)**
# 전자 상거래 회사는 데이터베이스 전문가에게 Amazon Aurora에서 실행되는 핵심 프로덕션 데이터베이스에서 가져올 중요한 비즈니스 지표를 시각화하는 보고 대시보드를 만드는 작업을 맡겼습니다. 대시보드에서 읽는 데이터는 업데이트 후 100밀리초 이내에 사용할 수 있어야 합니다.
# 데이터베이스 전문가는 Aurora DB 클러스터의 현재 구성을 검토하고 비용 효율적인 솔루션을 개발해야 합니다. 솔루션은 DB 클러스터의 쓰기 가용성 및 성능에 영향을 미치지 않으면서 보고 대시보드에서 예측할 수 없는 읽기 워크로드를 수용해야 합니다.
# 어떤 솔루션이 이러한 요구 사항을 충족합니까?
#
# >**A.** DB 클러스터에서 서버리스 옵션을 켜서 수요에 따라 자동으로 확장할 수 있습니다.
# **B.** 새 애플리케이션 팀을 위해 기존 DB 클러스터의 복제본을 프로비저닝합니다.
# **C.** 새 워크로드에 대해 별도의 DB 클러스터를 생성하고, 원본 DB 클러스터에서 새로 고침하고, AWS DMS 변경 데이터 캡처(CDC)를 사용하여 지속적인 복제를 설정합니다.
# **D.** DB 클러스터에 자동 조정 정책을 추가하여 CPU 사용량에 따라 클러스터에 Aurora 복제본을 추가합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : D(100%)<br>
# >Do 모든 Aurora 복제본은 최소 복제본 지연으로 쿼리 결과에 대해 동일한 데이터를 반환합니다. 이 지연은 100밀리초 미만입니다.<br>
# >Ax 서버리스 옵션을 켤 수 없습니다. 스냅샷을 찍어 Aurora 서버리스로 복원해야 합니다. 서버리스 마이그레이션 필요<br>
# >Bx 복제본은 읽기 워크로드를 확장해 주지 못함. 읽기전용 복제본으로만 달성할 수 있음.<br>
# >
# >[Amazon Aurora를 사용한 복제](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/Aurora.Replication.html)
# </div></details>
#
# **[Q#046. Q#166. Q#056.](https://www.examtopics.com/discussions/amazon/view/68554-exam-aws-certified-database-specialty-topic-1-question-46/)**
# 한 소매 회사가 온라인 및 모바일 스토어를 AWS로 마이그레이션하려고 합니다. 회사의 CEO는 브랜드를 전 세계적으로 성장시키기 위한 전략적 계획을 가지고 있습니다. 데이터베이스 전문가는 운영 오버헤드를 최소화하면서 예측 가능한 읽기 및 쓰기 데이터베이스 성능을 제공해야 하는 과제를 안고 있습니다.
# 데이터베이스 전문가는 이러한 요구 사항을 충족하기 위해 무엇을 해야 합니까?
#
# >**A.** Amazon DynamoDB 전역 테이블을 사용하여 트랜잭션 동기화
# **B.** Amazon EMR을 사용하여 리전 간에 주문 테이블 데이터 복사
# **C.** Amazon Aurora 글로벌 데이터베이스를 사용하여 모든 트랜잭션 동기화
# **D.** Amazon DynamoDB 스트림을 사용하여 모든 DynamoDB 트랜잭션을 복제하고 동기화
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : A(100%)<br>
# >DynamoDB 전역 테이블을 사용하면 전 세계에 분산된 애플리케이션이 선택한 리전에서 로컬로 데이터를 액세스할 수 있으므로 10밀리초 이내의 읽기 및 쓰기 성능을 달성할 수 있습니다.<br>
# >DynamoDB는 수평 조정 확장을 통해 모든 크기의 테이블을 지원하는 키 값과 문서 데이터모델을 지원하는 NoSQL 데이터베이스입니다.<br>
# >Aurora 글로벌 데이터베이스를 통해 전 세계적으로 데이터베이스 읽기의 크기를 손쉽게 조정하고, 애플리케이션을 사용자 가까이에 배치할 수 있습니다.<br>
# >[Amazon DynamoDB 기능](https://aws.amazon.com/dynamodb/features/)<br>
# >[Amazon Aurora 글로벌 데이터베이스](https://aws.amazon.com/ko/rds/aurora/global-database/?nc1=h_ls)
# </div></details>
#
# **[Q#047. Q#100. Q#088.](https://www.examtopics.com/discussions/amazon/view/26022-exam-aws-certified-database-specialty-topic-1-question-47/)**
# 한 회사가 원격 데이터 센터 중 하나를 폐쇄하고 있습니다. 이 사이트는 100TB 온프레미스 데이터 웨어하우스 솔루션을 실행합니다. 회사는 AWS로의 마이그레이션을 위해 AWS Schema Conversion Tool(AWS SCT)과 AWS DMS를 사용할 계획입니다. 사이트 네트워크 대역폭은 500Mbps입니다. 데이터베이스 전문가는 Amazon S3를 데이터 레이크로 사용하고 Amazon Redshift를 데이터 웨어하우스로 사용하여 온프레미스 데이터를 마이그레이션하려고 합니다. 이 이동은 유지 관리를 위해 소스 시스템이 종료되는 2주 동안 수행해야 합니다. 데이터는 저장 및 전송 중에 암호화된 상태로 유지되어야 합니다.
# 다음 중 성공적인 데이터 전송의 위험이 가장 적고 가능성이 가장 높은 접근 방식은 무엇입니까?
#
# >**A.** 네트워크를 통해 데이터 센터에서 AWS로 데이터를 암호화하기 위한 VPN 터널을 설정합니다. AWS SCT를 활용하고 변환된 스키마를 Amazon Redshift에 적용합니다. 완료되면 AWS DMS 작업을 시작하여 소스에서 Amazon S3로 데이터를 이동합니다. AWS Glue를 사용하여 Amazon S3에서 Amazon Redshift로 데이터를 로드합니다.
# **B.** AWS SCT를 활용하고 변환된 스키마를 Amazon Redshift에 적용합니다. 두 개의 AWS Snowball Edge 디바이스로 AWS DMS 작업을 시작하여 AWS KMS 암호화를 사용하여 온프레미스에서 Amazon S3로 데이터를 복사합니다. AWS DMS를 사용하여 Amazon Redshift에 데이터 복사를 마칩니다.
# **C.** AWS SCT를 활용하고 변환된 스키마를 Amazon Redshift에 적용합니다. 완료되면 AWS Import/Export 기능을 사용하여 10TB 전용 암호화 드라이브를 사용하여 AWS KMS 암호화를 통해 온프레미스에서 Amazon S3로 데이터를 복사합니다. AWS Glue를 사용하여 Amazon redshift에 데이터를 로드합니다.
# **D.** 네트워크를 통해 데이터 센터에서 AWS로 데이터를 암호화하기 위한 VPN 터널을 설정합니다. 기본 데이터베이스 내보내기 기능을 활용하여 데이터를 내보내고 파일을 압축합니다. aws S3 cp multi-port upload 명령을 사용하여 AWS KMS 암호화를 사용하여 이러한 파일을 Amazon S3에 업로드합니다. 완료되면 AWS Glue를 사용하여 Amazon Redshift에 데이터를 로드합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : B(100%)<br>
# >주어진 대역폭으로 다른 옵션은 20일 이상 소요됩니다.<br>
# >AWS SCT와 AWS Snowball Edge 디바이스를 사용할 때 데이터를 두 단계로 마이그레이션합니다. 먼저 AWS SCT를 사용하여 데이터를 로컬에서 처리한 다음 해당 데이터를 AWS Snowball Edge 디바이스로 이동합니다. 그런 다음 디바이스를 전송합니다. AWS Snowball Edge 프로세스를 사용하여 AWS로 전송하면 AWS가 자동으로 데이터를 Amazon S3 버킷으로 로드합니다.<br>
# >하나의 Snowball 장치가 최대 80TB의 데이터를 저장할 수 있으므로 두개의 Snowball Edge 장치가 필요합니다.<br>
# >
# >[Migrating data from an on-premises data warehouse to Amazon Redshift](https://docs.aws.amazon.com/SchemaConversionTool/latest/userguide/agents.dw.html)
# </div></details>
#
# **[Q#048. Q#169. Q#012.](https://www.examtopics.com/discussions/amazon/view/26418-exam-aws-certified-database-specialty-topic-1-question-48/)**
# 회사는 1TB Oracle 데이터베이스를 온프레미스에서 Amazon Aurora PostgreSQL DB 클러스터로 마이그레이션하려고 합니다. 이 회사의 Database Specialist는 Oracle 데이터베이스가 여러 테이블에 걸쳐 100GB의 대형 바이너리 개체(LOB)를 저장하고 있음을 발견했습니다. Oracle 데이터베이스의 최대 LOB 크기는 500MB이고 평균 LOB 크기는 350MB입니다. Database Specialist는 가장 큰 복제 인스턴스로 데이터를 마이그레이션하기 위해 AWS DMS를 선택했습니다.
# Database Specialist는 AWS DMS를 사용하여 데이터베이스 마이그레이션을 어떻게 최적화해야 합니까?
#
# >**A.** 데이터와 LOB를 함께 마이그레이션하기 위해 LOB 청크 크기가 500MB인 전체 LOB 모드를 사용하여 단일 작업을 생성합니다.
# **B.** LOB 청크 크기가 500MB인 전체 LOB 모드를 사용하여 LOB 테이블이 있는 Task1과 LOB가 없는 Task2의 두 가지 작업을 만듭니다.
# **C.** 최대 LOB 크기가 500MB인 제한된 LOB 모드를 사용하여 LOB 테이블이 있는 Task1과 LOB가 없는 Task2의 두 가지 작업을 만듭니다.
# **D.** 데이터와 LOB를 함께 마이그레이션하기 위해 최대 LOB 크기가 500MB인 제한된 LOB 모드를 사용하여 단일 작업을 만듭니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : B(100%)<br>
# >제한된 LOB 최대 크기는 100MB입니다. 이 질문은 LOB 평균 350MB에 관한 것입니다. 전체 LOB가 더 나은 옵션입니다.<br>
# >전체 LOB 모드 : AWS DMS는 크기에 상관 없이 모든 LOB를 원본에서 대상으로 마이그레이션합니다. 이 구성에서 AWS DMS에는 예상할 수 있는 최대 크기의 LOB 정보가 없습니다. 또한, LOB는 한 번에 하나씩, 조각별로 마이그레이션됩니다. 전체 LOB 모드는 매우 느릴 수 있습니다.<br>
# >제한적 LOB 모드 : DMS가 수용할 최대 LOB 크기를 설정합니다. 이렇게 하면 DMS가 메모리를 미리 할당하고 LOB 데이터를 대량으로 로드할 수 있습니다. 최대 LOB 크기를 초과하는 LOB는 잘리고 경고가 로그 파일에 기록됩니다. 제한적 LOB 모드는 전체 LOB 모드에 비해 상당한 성능을 얻을 수 있습니다. 가능하다면 제한적 LOB 모드 사용을 권장합니다. 권장되는 최대 값은 100MB 입니다.<br>
# >
# >[AWS DMS 작업의 소스 데이터베이스에 대한 LOB 지원 설정](https://docs.aws.amazon.com/ko_kr/dms/latest/userguide/CHAP_Tasks.LOBSupport.html)
# </div></details>
#
# **[Q#049. Q#108. Q#106.](https://www.examtopics.com/discussions/amazon/view/64810-exam-aws-certified-database-specialty-topic-1-question-49/)**
# 데이터베이스 전문가가 프로덕션 Amazon DynamoDB 테이블에 대한 재해 복구 전략을 설계하고 있습니다. 이 테이블은 프로비저닝된 읽기/쓰기 용량 모드, 글로벌 보조 인덱스 및 TTL(Time to Live)을 사용합니다. 데이터베이스 전문가가 최신 백업을 새 테이블로 복원했습니다.
# 동일한 설정으로 새 테이블을 준비하려면 어떤 단계를 수행해야 합니까? (2개를 선택하세요.)
#
# >**A.** 새 테이블에서 글로벌 보조 인덱스 다시 생성
# **B.** 새 테이블에 대한 액세스를 위한 IAM 정책 정의
# **C.** TTL 설정 정의
# **D.** AWS Management 콘솔에서 테이블을 암호화하거나 update-table 명령을 사용합니다.
# **E.** 프로비저닝된 읽기 및 쓰기 용량 설정
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : BC(100%)<br>
# >DynamoDB 테이블을 복원한 후 복원된 테이블에서 다음을 수동으로 설정해야 합니다.<br>
# >- Auto Scaling 정책, AWS IAM 정책, Amazon CloudWatch 지표 및 경보, 태그, 스트림 설정, Time To Live(TTL) 설정<br>
# >
# >[DynamoDB를 사용하여 DynamoDB 테이블 백업 및 복원: 작동 방식](https://docs.aws.amazon.com/ko_kr/amazondynamodb/latest/developerguide/CreateBackup.html)
# </div></details>
#
# **[Q#050. Q#177. Q#139.](https://www.examtopics.com/discussions/amazon/view/25382-exam-aws-certified-database-specialty-topic-1-question-50/)**
# 데이터베이스 전문가는 개발 AWS 계정을 사용하여 애플리케이션 팀을 위해 Amazon DynamoDB 테이블, Amazon CloudWatch 경보 및 관련 인프라를 생성하고 있습니다. 팀은 환경별 설정을 별도로 관리하면서 핵심 솔루션 구성 요소를 표준화하는 배포 방식을 원하고 구성 오류로 인한 재작업을 최소화하고자 합니다.
# 데이터베이스 전문가는 이러한 요구 사항을 충족하기 위해 어떤 프로세스를 권장해야 합니까?
#
# >**A.** AWS Systems Manager Parameter Store에서 공통 및 환경별 파라미터를 계층적으로 구성한 다음 AWS CloudFormation 템플릿에서 동적으로 파라미터를 참조합니다. 환경 이름을 매개변수로 사용하여 CloudFormation 스택을 배포합니다.
# **B.** 필요한 객체를 구축하는 매개변수화된 AWS CloudFormation 템플릿을 생성합니다. 별도의 Amazon S3 버킷에 별도의 환경 파라미터 파일을 보관하십시오. 적절한 파라미터 버킷을 직접 참조하는 CloudFormation 스택을 배포하는 AWS CLI 명령을 제공합니다.
# **C.** 필요한 객체를 빌드하는 매개변수화된 AWS CloudFormation 템플릿을 생성합니다. 템플릿을 AWS Management 콘솔의 CloudFormation 인터페이스로 가져옵니다. 매개변수를 필요한 대로 변경하고 CloudFormation 스택을 배포합니다.
# **D.** AWS SDK를 사용하여 필요한 객체를 빌드하는 AWS Lambda 함수를 생성합니다. 필요에 따라 애플리케이션 팀이 수정할 수 있는 각 환경에 대한 Lambda 콘솔의 테스트 이벤트에서 필수 파라미터 값을 설정합니다. 콘솔에서 테스트 이벤트를 트리거하여 인프라를 배포합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : A(100%)<br>
# >AWS Systems Manager 파라미터 스토어<br>
# >Parameter Store는 구성 데이터 관리 및 암호 관리를 위한 안전한 계층적 스토리지를 제공합니다.<br>
# >
# >[AWS Systems Manager Parameter Store](https://docs.aws.amazon.com/ko_kr/systems-manager/latest/userguide/systems-manager-parameter-store.html)
# </div></details>

# %% [markdown]
# # 051

# %% [markdown]
# **[Q#051. Q#003. Q#136.](https://www.examtopics.com/discussions/amazon/view/26423-exam-aws-certified-database-specialty-topic-1-question-51/)**
# 회사는 Amazon RDS for PostgreSQL 다중 AZ DB 인스턴스에서 OLTP(온라인 트랜잭션 처리) 워크로드를 실행합니다. 작업 시간 이후에 데이터베이스에서 테스트가 실행되어 추가 데이터베이스 로그가 생성되었습니다. 이러한 추가 로그로 인해 RDS DB 인스턴스의 무료 스토리지가 부족합니다.
# 이 공간 제약 문제를 해결하기 위해 회사는 무엇을 해야 합니까?
#
# >**A.** 호스트에 로그인하고 rm `$PGDATA/pg_logs/*` 명령을 실행합니다.
# **B.** rds.log_retention_period 매개변수를 1440으로 수정하고 데이터베이스 로그가 삭제될 때까지 최대 24시간을 기다립니다.
# **C.** AWS Support에 티켓을 생성하여 로그를 삭제합니다.
# **D.** SELECT rds_rotate_error_log() 저장 프로시저를 실행하여 로그 회전
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : B(100%)<br>
# >rds.log_retention_period - 지정된 시간(분)보다 오래된 PostgreSQL 로그가 삭제됩니다. 기본값인 4,320분으로 지정하면 3일이 지난 로그 파일이 삭제됩니다.<br>
# >SELECT rds_rotate_error_log()가 RDS에 존재하지 않습니다.
# >
# >[PostgreSQL 데이터베이스 로그 파일](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/USER_LogAccess.Concepts.PostgreSQL.html)
# </div></details>
#
# **[Q#052. Q#124. Q#082.](https://www.examtopics.com/discussions/amazon/view/67549-exam-aws-certified-database-specialty-topic-1-question-52/)**
# 사용자에게 비관계형 키-값 데이터베이스가 있습니다. 사용자는 분산 데이터베이스 운영 및 확장의 관리 부담을 덜어줄 완전관리형 AWS 서비스를 찾고 있습니다. 솔루션은 비용 효율적이어야 하고 예측할 수 없는 애플리케이션 트래픽을 처리할 수 있어야 합니다.
# 데이터베이스 전문가는 이 사용자에게 무엇을 권장해야 합니까?
#
# >**A.** 프로비저닝된 용량 모드로 Amazon DynamoDB 테이블 생성
# **B.** Amazon DocumentDB 클러스터 생성
# **C.** 온디맨드 용량 모드로 Amazon DynamoDB 테이블 생성
# **D.** Amazon Aurora Serverless DB 클러스터 생성
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C(100%)  <br>
# >Key-Value 데이터베이스 -> DynamoDB<br>
# >예상치 못한 애플리케이션 트래픽 처리 가능 -> 온디맨드 용량 모드
# </div></details>
#
# **[Q#053. Q#041. Q#131.](https://www.examtopics.com/discussions/amazon/view/65859-exam-aws-certified-database-specialty-topic-1-question-53/)**
# 게임 회사는 전 세계의 많은 사용자가 액세스할 수 있는 모바일 게임 앱을 설계하고 있습니다. 이 회사는 다중 마스터 쓰기에 대한 복제 및 완전한 지원을 원합니다. 회사는 또한 앱 사용자를 위해 짧은 대기 시간과 일관된 성능을 보장하기를 원합니다.
# 어떤 솔루션이 이러한 요구 사항을 충족합니까?
#
# >**A.** Amazon DynamoDB 글로벌 테이블을 스토리지에 사용하고 DynamoDB 자동 조정 활성화
# **B.** Amazon Aurora를 스토리지에 사용하고 교차 리전 Aurora 복제본 활성화
# **C.** Amazon Aurora를 저장용으로 사용하고 Amazon ElastiCache로 사용자 콘텐츠 캐시
# **D.** Amazon Neptune을 스토리지로 사용
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : A(100%)  <br>
# >DynamoDB 전역 테이블은 모든 지역에서 읽고 쓸 수 있음. DynamoDB Global Table은 Aurora Multi Master 와 같은 Multi Master 임.<br>
# >Aurora Multi-Master 또는 DynamoDB 글로벌 테이블은 세계 모은 지역에서 읽고 쓸 수 있습니다.
# </div></details>
#
# **[Q#054. Q#163. Q#140.](https://www.examtopics.com/discussions/amazon/view/25201-exam-aws-certified-database-specialty-topic-1-question-54/)**
# 데이터베이스 전문가는 Amazon Aurora PostgreSQL DB 클러스터에서 발생할 수 있는 장애 조치의 속도를 높여야 합니다. Aurora DB 클러스터에는 현재 기본 인스턴스와 3개의 Aurora 복제본이 포함되어 있습니다.
# Database Specialist는 애플리케이션의 가동 중지 시간을 최소화하면서 장애 조치가 발생하도록 하려면 어떻게 해야 합니까?
#
# >**A.** TCP keepalive 매개변수를 낮게 설정
# **B.** AWS CLI failover-db-cluster 명령 호출
# **C.** DB 클러스터에서 Enhanced Monitoring 활성화
# **D.** DB 클러스터에서 데이터베이스 활동 스트림 시작
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : A(100%)  <br>
# >TCP keepalive 파라미터를 활성화하고 적극적으로 설정하면 클라이언트가 더 이상 데이터베이스에 연결할 수 없을 경우 활성 연결이 빠르게 종료됩니다. 이 작업을 통해 애플리케이션이 연결할 새 호스트를 선택하는 등 적절히 대응할 수 있습니다.
# >
# >[TCP Keepalives 파라미터 설정](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/AuroraPostgreSQL.BestPractices.html#AuroraPostgreSQL.BestPractices.FastFailover.TCPKeepalives)
# </div></details>
#
# **[Q#055. Q#153. Q#061.](https://www.examtopics.com/discussions/amazon/view/25202-exam-aws-certified-database-specialty-topic-1-question-55/)**
# 데이터베이스 전문가는 온프레미스 Oracle 데이터베이스를 Amazon Aurora MySQL DB 클러스터로 마이그레이션하기 위한 데이터베이스 마이그레이션 전략을 정의해야 합니다. 회사는 데이터 마이그레이션을 위해 거의 제로에 가까운 다운타임이 필요합니다. 솔루션은 또한 비용 효율적이어야 합니다.
# 데이터베이스 전문가는 어떤 접근 방식을 취해야 합니까?
#
# >**A.** 데이터 펌프(expdp)를 사용하여 Oracle 데이터베이스의 모든 테이블을 Amazon S3 버킷으로 덤프합니다. AWS Glue에서 데이터 변환을 실행합니다. S3 버킷에서 Aurora DB 클러스터로 데이터를 로드합니다.
# **B.** AWS Snowball 어플라이언스를 주문하고 Oracle 백업을 Snowball 어플라이언스에 복사합니다. Snowball 데이터가 Amazon S3로 전송되면 새 Aurora DB 클러스터를 생성합니다. Amazon S3에서 Amazon RDS로 데이터를 직접 마이그레이션하려면 S3 통합을 활성화합니다.
# **C.** AWS Schema Conversion Tool(AWS SCT)을 사용하여 스키마 마이그레이션 중에 데이터베이스 객체를 MySQL에 다시 쓸 수 있습니다. AWS DMS를 사용하여 전체 로드 및 변경 데이터 캡처(CDC) 작업을 수행합니다.
# **D.** AWS Server Migration Service(AWS SMS)를 사용하여 Oracle 가상 머신 이미지를 Amazon EC2 인스턴스로 가져옵니다. Oracle Logical Dump 유틸리티를 사용하여 Amazon EC2에서 Aurora DB 클러스터로 Oracle 데이터를 마이그레이션합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : C(100%)  <br>
# >이것은 이기종 마이그레이션이며 DMS(Database Migration Service)와 SCT(Schema Conversion Tool)가 필요합니다.<br>
# >제로 다운 타임 = 첫 번째 SCT, 그 다음 DMS 전체 및 CDC<br>
# >스키마 마이그레이션 중에 데이터베이스 객체를 MySQL에 다시 쓰는 데 도움이 되는 AWS Schema Conversion Tool(AWS SCT). AWS DMS를 사용하여 전체 로드 및 변경 데이터 캡처(CDC) 작업을 수행합니다.
# </div></details>
#
# **[Q#056. Q#054. Q#163.](https://www.examtopics.com/discussions/amazon/view/65887-exam-aws-certified-database-specialty-topic-1-question-56/)**
# 마케팅 회사에서 Amazon DocumentDB를 사용 중이며 데이터베이스 감사 로그를 활성화해야 합니다. 데이터베이스 전문가는 수행된 모든 DDL(데이터 정의 언어) 문을 관리자가 볼 수 있도록 모니터링을 구성해야 합니다. 데이터베이스 전문가는 클러스터 파라미터 그룹에서 audit_logs 파라미터를 활성화로 설정했습니다.
# 데이터베이스 전문가는 관리자에 대한 데이터베이스 로그를 자동으로 수집하기 위해 무엇을 해야 합니까?
#
# >**A.** DocumentDB를 활성화하여 Amazon CloudWatch Logs로 로그 내보내기
# **B.** AWS CloudTrail로 로그를 내보내도록 DocumentDB 활성화
# **C.** DocumentDB 이벤트를 활성화하여 Amazon CloudWatch Logs로 로그 내보내기
# **D.** download-db-log-file-portion 작업을 사용하여 로그를 다운로드하고 Amazon S3에 로그를 저장하도록 AWS Lambda 함수 구성
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : A(100%)  <br>
# >감사가 활성화되면 Amazon DocumentDB가 데이터 정의 언어 (DDL), 인증, 권한 부여 및 사용자 관리 이벤트를 Amazon CloudWatch Logs 에 기록합니다.<br>
# >감사가 활성화되면 Amazon DocumentDB가 클러스터의 감사 레코드 (JSON 문서) 를 Amazon CloudWatch Logs 로 내보냅니다. Amazon CloudWatch Logs 를 사용하여 Amazon DocumentDB 감사 이벤트를 분석, 모니터링 및 보관할 수 있습니다.<br>
# >A. logs -> CloudWatch<br>
# >x B. CloudTrail is to enable auditing not file destination<br>
# >x C. DocumentDB Events do not support DDL<br>
# >x D.
# >
# >[Amazon DocumentDB 이벤트 감사](https://docs.aws.amazon.com/ko_kr/documentdb/latest/developerguide/event-auditing.html)
# </div></details>
#
# **[Q#057. Q#069. Q#036.](https://www.examtopics.com/discussions/amazon/view/26760-exam-aws-certified-database-specialty-topic-1-question-57/)**
# 한 회사에서 IBM POWER7 서버에서 AIX를 실행하는 온프레미스 IBM Db2 데이터베이스를 이동하려고 합니다. 증가하는 지원 및 유지 관리 비용으로 인해 회사는 워크로드를 Amazon Aurora PostgreSQL DB 클러스터로 이동하는 옵션을 모색하고 있습니다.
# 회사가 마이그레이션 호환성에 대한 데이터를 수집하는 가장 빠른 방법은 무엇입니까?
#
# >**A.** Db2 데이터베이스에서 논리적 덤프를 수행하고 이를 Aurora DB 클러스터로 복원합니다. 원본 및 대상 테이블의 행 수를 비교하여 마이그레이션된 개체의 격차와 호환성을 식별합니다.
# **B.** Db2 데이터베이스에서 Aurora DB 클러스터로 AWS DMS를 실행합니다. 원본 및 대상 테이블의 행 수를 비교하여 마이그레이션된 개체의 격차 및 호환성을 식별합니다.
# **C.** Db2 데이터베이스에서 Aurora DB 클러스터로 네이티브 PostgreSQL 논리적 복제를 실행하여 마이그레이션 호환성을 평가합니다.
# **D.** Db2 데이터베이스에서 Aurora DB 클러스터로 AWS Schema Conversion Tool(AWS SCT)을 실행합니다. 마이그레이션 평가 보고서를 작성하여 마이그레이션 호환성을 평가하십시오.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : D(100%)<br>
# >DB2 데이터베이스에서 Aurora DB 클러스터로 AWS SCT를 실행합니다. -> 마이그레이션 호환성을 평가하기 위해 마이그레이션 평가 보고서를 만듭니다.<br>
# </div></details>
#
# **[Q#058. Q#040. Q#077.](https://www.examtopics.com/discussions/amazon/view/25735-exam-aws-certified-database-specialty-topic-1-question-58/)**
# 전자 상거래 회사는 주문 처리 애플리케이션의 백엔드로 Amazon DynamoDB를 사용하고 있습니다. 주문 수가 꾸준히 증가하면 DynamoDB 비용이 증가합니다. 주문 확인 및 보고는 유사한 데이터 세트를 가져오는 여러 GetItem 기능을 반복적으로 수행하며 이러한 읽기 활동은 비용 증가에 기여합니다. 회사는 상당한 개발 노력 없이 이러한 비용을 통제하기를 원합니다.
# 데이터베이스 전문가는 이러한 요구 사항을 어떻게 해결해야 합니까?
#
# >**A.** AWS DMS를 사용하여 DynamoDB에서 Amazon DocumentDB로 데이터 마이그레이션
# **B.** Amazon DynamoDB 스트림 및 Amazon Kinesis Data Firehose를 사용하여 데이터를 Amazon Redshift로 푸시
# **C.** DynamoDB 앞에서 Redis용 Amazon ElastiCache를 사용하여 읽기 성능 향상
# **D.** DynamoDB Accelerator를 사용하여 읽기 오프로드
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : D (100%)  <br>
# >많은 수의 반복 GetItem 메서드 => DAX(DynamoDB Accelerator)<br>
# >서비스 비용이 문제가 아니라 개발 비용이 문제입니다.<br>
# >읽기를 오프로드하고 비용을 줄이기 위한 캐싱 솔루션이 필요합니다. DAX는 DynamoDB API 호출을 위한 최고의 캐싱 솔루션입니다.<br>
# >
# >[DynamoDB Accelerator(DAX)를 사용한 인메모리 가속](https://docs.amazonaws.cn/en_us/amazondynamodb/latest/developerguide/DAX.html)
# </div></details>
#
# **[Q#059. Q#058. Q#040.](https://www.examtopics.com/discussions/amazon/view/25738-exam-aws-certified-database-specialty-topic-1-question-59/)**
# IT 컨설팅 회사는 개발 환경 데이터베이스를 운영할 때 비용을 절감하고자 합니다. 회사의 워크플로 는 각 개발 그룹에 대해 여러 Amazon Aurora MySQL DB 클러스터를 생성합니다. Aurora DB 클러스터는 하루 8시간 동안만 사용됩니다. 그런 다음 DB 클러스터는 2주 동안 지속되는 개발 주기가 끝나면 삭제할 수 있습니다.
# 다음 중 가장 비용 효율적인 솔루션을 제공하는 것은 무엇입니까?
#
# >**A.** AWS CloudFormation 템플릿을 사용합니다. 각 개발 그룹에 대한 DB 클러스터와 함께 스택을 배포합니다. 개발 주기가 끝나면 스택을 삭제합니다.
# **B.** Aurora DB 복제 기능을 사용합니다. 단일 개발을 배포하고 Aurora DB 인스턴스를 테스트하고 개발 그룹에 대한 클론 인스턴스를 생성합니다. 개발 주기가 끝나면 클론을 삭제합니다.
# **C.** Aurora 복제본을 사용합니다. 마스터 자동 일시 중지 컴퓨팅 용량 옵션에서 각 개발 그룹에 대한 복제본을 만들고 각 복제본을 마스터로 승격합니다. 개발 주기가 끝나면 복제본을 삭제합니다.
# **D.** Aurora 서버리스를 사용합니다. 현재 Aurora 스냅샷을 복원하고 각 개발 그룹의 서버리스 클러스터에 배포합니다. 클러스터의 컴퓨팅 용량을 일시 중지하고 적절한 시간 초과를 설정하는 옵션을 활성화합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : B(100%)  <br>
# >A - 기본 요구 사항을 충족합니다. 그러나 비용 효율적이지 않습니다.  <br>
# >B - 좋은 옵션입니다. Copy-On-Write 기능으로 스토리지 계층의 비용을 절감합니다.<br>
# >C - 요구 사항을 충족하지만 비용 효율적이지 않습니다.<br>
# >D - 가장 비용 효율적입니다. <br>
# >DB 클러스터가 일시 중지되면 컴퓨팅 또는 메모리 활동이 발생하지 않고 스토리지에 대한 요금만 청구됩니다. Aurora Serverless v1 DB 클러스터가 일시 중지되었을 때 데이터베이스 연결이 요청되면 DB 클러스터가 자동으로 작동을 재개해 연결 요청을 처리합니다.<br>
# >
# >[Aurora Serverless v1 일시 중지 및 다시 시작](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/aurora-serverless-v1.how-it-works.html#aurora-serverless.how-it-works.pause-resume)
# </div></details>
#
# **[Q#060. Q#095. Q#005.](https://www.examtopics.com/discussions/amazon/view/65688-exam-aws-certified-database-specialty-topic-1-question-60/)**
# 회사에는 안전한 온프레미스 데이터베이스의 데이터를 제공하는 여러 애플리케이션이 있습니다. 회사는 모든 애플리케이션과 데이터베이스를 AWS
# 클라우드로 마이그레이션하고 있습니다. IT 위험 및 규정 준수 부서에서는 모든 로그인, 로그아웃, 로그인 실패, 권한 변경 및 데이터베이스 스키마 변경을 캡처하기 위해 모든 보안 데이터베이스에서 감사를 활성화해야 합니다. 데이터베이스 전문가는 Amazon Aurora MySQL을 마이그레이션 대상으로 권장하고 Aurora의 고급 감사 기능을 활용합니다.
# 최소 감사 요구 사항을 충족하려면 고급 감사 구성에서 어떤 이벤트를 지정해야 합니까? (3개를 선택하세요.)
#
# >**A.** CONNECT
# **B.** QUERY_DCL
# **C.** QUERY_DDL
# **D.** QUERY_DML
# **E.** TABLE
# **F.** QUERY
#
# ><details><summary>해설</summary><div markdown="1">
# >A. CONNECT(로그인 및 로그아웃, 로그인 실패), B. QUERY_DCL(허가 - 권한 수정용), C. QUERY_DDL(스키마 변경용)<br>
# > x D. QUERY_DML, x E. TABLE, x F. QUERY<br>
# >
# >[Amazon Aurora MySQL DB 클러스터에서 고급 감사 사용](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/AuroraMySQL.Auditing.html)
# </div></details>

# %% [markdown]
# # 061

# %% [markdown]
# **[Q#061. Q#080. Q#135.](https://www.examtopics.com/discussions/amazon/view/67116-exam-aws-certified-database-specialty-topic-1-question-61/)**
# 최근 한 게임 회사가 휴가철에 특히 인기 있는 iOS 게임을 성공적으로 인수했습니다. 이 회사는 Amazon DynamoDB를 사용하는 게임에 리더보드를 추가하기로 결정했습니다. 애플리케이션 로드는 휴가철에 증가할 것으로 예상됩니다.
# 가장 저렴한 비용으로 이러한 요구 사항을 충족하는 솔루션은 무엇입니까?
#
# >**A.** DynamoDB 스트림
# **B.** DynamoDB Accelerator가 있는 DynamoDB
# **C.** 온디맨드 용량 모드가 있는 DynamoDB
# **D.** Auto Scaling으로 프로비저닝된 용량 모드가 있는 DynamoDB
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C (100%)  <br>
# >x A. DynamoDB 스트림<br>
# >x B. DynamoDB Accelerator가 포함된 DynamoDB(DAX는 빠른 정적 읽기용이지만 여기서는 데이터가 빠르게 변경됨)<br>
# >x C. 주문형 용량 모드가 있는 DynamoDB<br>
# > D. Auto Scaling이 포함된 프로비저닝된 용량 모드가 있는 DynamoDB(예측 가능한 경우 Auto Scaling이 On-Demand 대비 더 경제적)<br>
# >게임은 다른 회사에서 구입합니다. 그래서 그것은 얼마 동안 실행되어 왔으며 부하가 알려져 있습니다. 회사는 크리스마스 기간에도 급증을 식별할 수 있습니다. 프로비저닝된 용량은 온디맨드에 비해 더 경제적입니다.<br>
# >Auto Scaling은 DynamoDB 사용자가 예측 가능한 트래픽 패턴이 있는 워크로드 비용을 낮추는 데 계속 도움이 됩니다. <br>
# >
# >[Amazon DynamoDB Auto Scaling: 모든 규모의 성능 및 비용 최적화](https://aws.amazon.com/ko/blogs/database/amazon-dynamodb-auto-scaling-performance-and-cost-optimization-at-any-scale/)
# </div></details>
#
# **★★★[Q#062. Q#145. Q#033.](https://www.examtopics.com/discussions/amazon/view/27667-exam-aws-certified-database-specialty-topic-1-question-62/)**
# 회사의 보안 부서는 내부 사용자가 회사 AD(Active Directory) 자격 증명을 사용하여 기존 Amazon RDS for SQL Server DB 인스턴스에 연결해야 한다는 새로운 요구 사항을 설정했습니다. 데이터베이스 전문가는 이 요구 사항을 충족하는 데 필요한 수정 작업을 수행해야 합니다.
# 데이터베이스 전문가는 어떤 조합의 조치를 취해야 합니까? (3개를 선택하세요.)
#
# >**A.** RDS SQL Server DB 인스턴스에서 TDE(투명한 데이터 암호화)를 비활성화합니다.
# **B.** Windows 인증에 디렉터리를 사용하도록 RDS SQL Server DB 인스턴스를 수정합니다. 적절한 새 로그인을 만듭니다.
# **C.** AWS Management 콘솔을 사용하여 AWS Managed Microsoft AD를 생성합니다. 회사 AD와 신뢰 관계를 만듭니다.
# **D.** RDS SQL Server DB 인스턴스를 중지하고 Windows 인증용 디렉터리를 사용하도록 수정한 후 다시 시작합니다. 적절한 새 로그인을 만듭니다.
# **E.** AWS Management 콘솔을 사용하여 AD 커넥터를 생성합니다. 회사 AD와 신뢰 관계를 만듭니다.
# **F.** AWS Managed Microsoft AD 도메인 컨트롤러 보안 그룹을 구성합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >x A. TDE 비활성화(관련 없음)<br>
# > B. Windows 인증에 AD를 사용하도록 RDS SQL Server DB 인스턴스를 수정합니다. 적절한 새 로그인을 생성합니다.(재부팅해야 함)<br>
# > C. AWS Management 콘솔을 사용하여 AWS Managed Microsoft AD를 생성합니다. 회사 AD와 신뢰 관계를 만듭니다.<br>
# >x D. RDS SQL Server DB 인스턴스 Stop-Start는 처음이 아니라 끝에 있어야 함. Windows 인증을 사용하도록 RDS를 수정하는 것은 RDS가 사용 가능한 상태일 때 수행해야 함.<br>
# >x E. AWS Management 콘솔을 사용하여 AD 커넥터를 생성합니다. 회사 AD와 신뢰 관계를 만듭니다.(커넥터는 프록시이므로 신뢰 관계를 설정할 수 없음.)<br>
# >F. AWS Managed Microsoft AD 도메인 컨트롤러 보안 그룹을 구성합니다.<br>
# >
# >[Amazon RDS for SQL Server DB 인스턴스에 Windows 인증 사용](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/USER_SQLServerWinAuth.html)
# </div></details>
#
# **[Q#063. Q#084. Q#146.](https://www.examtopics.com/discussions/amazon/view/65905-exam-aws-certified-database-specialty-topic-1-question-63/)**
# 데이터베이스 전문가는 간단한 데이터베이스 동작을 확인하기 위해 소규모 인스턴스를 사용하여 Amazon Aurora로 개념 증명을 수행하고 있습니다. 큰 데이터 세트를 로드하고 인덱스를 생성할 때 데이터베이스 전문가는 Aurora에서 다음과 같은 오류 메시지를 보게 됩니다.
# 오류: 클라우드가 임시 파일의 블록 7507718을 쓰지 않습니다: 장치에 공간이 없습니다. 이 문제를 해결하려면?
#
# >**A.** Aurora 스토리지의 확장은 데이터 로드를 따라잡을 수 없습니다. 데이터베이스 전문가는 데이터를 느리게 로드하도록 워크로드를 수정해야 합니다.
# **B.** Aurora 스토리지의 확장은 데이터 로드를 따라잡을 수 없습니다. Database Specialist는 Aurora 스토리지 확장을 활성화해야 합니다.
# **C.** 임시 테이블을 저장하는 데 사용되는 로컬 저장소가 가득 찼습니다. 데이터베이스 전문가는 인스턴스를 확장해야 합니다.
# **D.** 임시 테이블을 저장하는 데 사용되는 로컬 저장소가 가득 찼습니다. Database Specialist는 로컬 스토리지 확장을 활성화해야 합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C (100%)
# >임시 테이블을 저장하는 데 사용되는 로컬 저장소가 가득 찼습니다. 그리고 로컬 스토리지를 늘리는 유일한 방법은 인스턴스 유형을 업그레이드하는 것입니다. 데이터베이스 전문가는 인스턴스를 확장해야 합니다.
# </div></details>
#
# **[Q#064. Q#171. Q#017.](https://www.examtopics.com/discussions/amazon/view/26777-exam-aws-certified-database-specialty-topic-1-question-64/)**
# 금융 회사에서 민감한 사용자 데이터를 Amazon Aurora PostgreSQL DB 클러스터에 저장하려고 합니다. 데이터베이스는 회사 전체의 여러 애플리케이션에서 액세스합니다. 회사는 데이터베이스에 대한 모든 통신을 암호화하고 서버 ID의 유효성을 검사하도록 명령했습니다. 비 SSL 기반 연결은 데이터베이스에 대한 액세스를 허용하지 않아야 합니다.
# 이러한 요구 사항을 해결하는 솔루션은 무엇입니까?
#
# >**A.** DB 파라미터 그룹에서 rds.force_ssl=0 파라미터를 설정합니다. Amazon RDS 인증서 번들을 다운로드하여 사용하고 sslmode=allow로 PostgreSQL 연결 문자열을 구성합니다.
# **B.** DB 파라미터 그룹에서 rds.force_ssl=1 파라미터를 설정합니다. Amazon RDS 인증서 번들을 다운로드하여 사용하고 sslmode=disable로 PostgreSQL 연결 문자열을 구성합니다.
# **C.** DB 파라미터 그룹에서 rds.force_ssl=0 파라미터를 설정합니다. Amazon RDS 인증서 번들을 다운로드하여 사용하고 sslmode=verify-ca로 PostgreSQL 연결 문자열을 구성합니다.
# **D.** DB 파라미터 그룹에서 rds.force_ssl=1 파라미터를 설정합니다. Amazon RDS 인증서 번들을 다운로드하여 사용하고 sslmode=verify-full로 PostgreSQL 연결 문자열을 구성합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >DB 파라미터 그룹: rds.force_ssl=1(o=>false, 1=>true)<br>
# >Amazon RDS 인증서 번들 다운로드 및 사용<br>
# >sslmode=verify-full로 PostgreSQL 연결 문자열을 구성합니다.<br>
# >
# >sslmode=verify-ca : 내 데이터를 암호화하고 내가 신뢰하는 서버에 연결하고 있는지 확인하고 싶습니다.<br>
# >sslmode=verify-full : 내 데이터를 암호화하고 내가 신뢰하는 서버에 연결하고 내가 지정한 서버인지 확인하고 싶습니다.
# >
# >[PostgreSQL JDBC Driver](https://jdbc.postgresql.org/documentation/head/ssl-client.html)
# </div></details>
#
# **[Q#065. Q#149. Q#152.](https://www.examtopics.com/discussions/amazon/view/26594-exam-aws-certified-database-specialty-topic-1-question-65/)**
# 회사는 5TB Amazon RDS DB 인스턴스를 사용하고 있으며 규정 준수를 위해 5년 동안 매월 데이터베이스 백업을 유지해야 합니다. 데이터베이스
# 관리자는 감사자에게 24시간 이내에 데이터를 제공해야 합니다.
# 어떤 솔루션이 이러한 요구 사항을 충족하고 운영상 가장 효율적입니까?
#
# >**A.** 매월 1일에 실행할 AWS Lambda 함수를 생성하여 수동 RDS 스냅샷을 생성합니다. 스냅샷을 회사의 Amazon S3 버킷으로 이동합니다.
# **B.** 매월 1일에 실행할 AWS Lambda 함수를 생성하여 수동 RDS 스냅샷을 생성합니다.
# **C.** AWS Management 콘솔에서 RDS 스냅샷 일정을 생성하여 30일마다 스냅샷을 생성합니다.
# **D.** 매월 1일에 실행할 AWS Lambda 함수를 생성하여 자동화된 RDS 스냅샷을 생성합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : A (67%) B (33%)  <br>
# >자동 백업과 달리 수동 스냅샷에는 백업 보존 기간이 적용되지 않습니다. 스냅샷이 만료되지 않습니다.
# >MariaDB, MySQL 및 PostgreSQL 데이터를 매우 장기간 백업하려면 스냅샷 데이터를 Amazon S3로 내보내는 것이 좋습니다.
# >
# >[DB 스냅샷 생성](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/USER_CreateSnapshot.html)
# </div></details>
#
# **[Q#066. Q#182. Q#048.](https://www.examtopics.com/discussions/amazon/view/26778-exam-aws-certified-database-specialty-topic-1-question-66/)**
# 회사는 나중에 사용할 수 있도록 안전하게 저장할 임의의 자격 증명을 사용하여 보안 테스트 데이터베이스 생성을 자동화하려고 합니다. 자격 증명에는 연결을 시작하고 자동 자격 증명 교체를 수행하기 위해 각 테스트 데이터베이스에 대한 충분한 정보가 있어야 합니다. 자격 증명은 암호화되지 않은 형태로 어디에도 기록되거나 저장되어서는 안 됩니다.
# 데이터베이스 전문가는 AWS CloudFormation 템플릿을 사용하여 이러한 요구 사항을 충족하기 위해 어떤 단계를 수행해야 합니까?
#
# >**A.** MasterUserName 및 MasterUserPassword 속성이 기본값으로 설정된 데이터베이스를 생성합니다. 그런 다음 동일한 기본값으로 설정된 사용자 이름과 암호를 사용하여 암호를 만듭니다. SecretId 및 TargetId 속성이 암호 및 데이터베이스의 Amazon 리소스 이름(ARN)으로 설정된 Secret Target Attachment 리소스를 추가합니다. 마지막으로 GenerateSecretString 속성으로 설정한 무작위로 생성된 문자열로 비밀의 암호 값을 업데이트합니다.
# **B.** 데이터베이스 Amazon 리소스 이름(ARN)의 매핑 속성을 보안 ARN에 추가합니다. 그런 다음 선택한 사용자 이름과 GenerateSecretString 속성에서 설정한 임의로 생성된 암호로 비밀을 만듭니다. MasterUserName 및 MasterUserPassword 속성이 비밀의 사용자 이름으로 설정된 데이터베이스를 추가합니다.
# **C.** AWS::SecretsManager::Secret 유형의 리소스를 추가하고 GenerateSecretString 속성을 지정합니다. 그런 다음 SecureStringTemplate 템플릿에서 데이터베이스 사용자 이름을 정의합니다. 데이터베이스에 대한 리소스를 만들고 MasterUserName 및 MasterUserPassword 속성에 대한 비밀 문자열을 참조합니다. 그런 다음 SecretId 및 TargetId 속성이 보안 암호 및 데이터베이스의 Amazon 리소스 이름(ARN)으로 설정된 AWS::SecretsManagerSecretTargetAttachment 유형의 리소스를 추가합니다.
# **D.** 선택한 사용자 이름과 GenerateSecretString 속성에서 설정한 무작위로 생성된 비밀번호로 비밀을 만듭니다. SecretId 속성이 보안 암호의 Amazon 리소스 이름(ARN)으로 설정되고 TargetId 속성이 원하는 데이터베이스 ARN과 일치하는 파라미터 값으로 설정된 SecretTargetAttachment 리소스를 추가합니다. 그런 다음 MasterUserName 및 MasterUserPassword 속성이 암호에서 이전에 만든 값으로 설정된 데이터베이스를 만듭니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : C(100%)  <br>
# >SecretsManager가 필요합니다.<br>
# >
# >AWS::SecretsManager::Secret 유형의 리소스 추가<br>
# >-> GenerateSecretString 속성 지정<br>
# >-> SecureStringTemplate 템플릿에서 데이터베이스 사용자 이름을 정의.<br>
# >-> 데이터베이스에 대한 리소스 만들기<br>
# >-> MasterUserName 및 MasterUserPassword 속성에 대한 비밀 문자열을 참조.<br>
# >-> SecretId 및 TargetId 속성이 보안 암호 및 데이터베이스의 Amazon 리소스 이름(ARN)으로 설정된 AWS::SecretsManagerSecretTargetAttachment 유형의 리소스를 추가합니다.
# </div></details>
#
# **[Q#067. Q#156. Q#043.](https://www.examtopics.com/discussions/amazon/view/26925-exam-aws-certified-database-specialty-topic-1-question-67/)**
# 회사는 애플리케이션 백엔드에 Amazon Aurora PostgreSQL DB 클러스터를 사용하려고 합니다. DB 클러스터에는 민감한 데이터가 포함된 일부 테이블이 있습니다. 데이터베이스 전문가는 테이블 수준에서 액세스 권한을 제어해야 합니다.
# 데이터베이스 전문가는 이러한 요구 사항을 어떻게 충족할 수 있습니까?
#
# >**A.** AWS IAM 데이터베이스 인증을 사용하고 IAM 정책을 사용하여 테이블에 대한 액세스를 제한합니다.
# **B.** Aurora DB 클러스터의 아웃바운드 트래픽을 제한하도록 NACL의 규칙을 구성합니다.
# **C.** 민감한 데이터가 포함된 테이블에 대한 액세스를 제한하는 GRANT 및 REVOKE 명령을 실행합니다.
# **D.** pg_hba.conf 파일에 민감한 데이터가 포함된 테이블에 대한 액세스 권한을 정의합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : C(100%)  <br>
# >테이블 수준 액세스는 Oracle과 Postgres를 포함한 많은 데이터베이스 유형에 대해 GRANT,REVOKE입니다.
# </div></details>
#
# **[Q#068. Q#143. Q#184.](https://www.examtopics.com/discussions/amazon/view/26856-exam-aws-certified-database-specialty-topic-1-question-68/)**
# 데이터베이스 전문가는 여러 Aurora 복제본을 사용하여 Amazon Aurora에 구축된 새 웹 사이트를 시작하기 위해 회사와 협력하고 있습니다. 이 새로운 웹사이트는 레거시 관계형 데이터베이스에 연결된 온프레미스 웹사이트를 대체합니다. 레거시 데이터베이스의 안정성 문제로 인해 회사는
# Aurora의 복원력을 테스트하려고 합니다.
# 데이터베이스 전문가는 Aurora DB 클러스터의 복원력을 테스트하기 위해 어떤 조치를 취할 수 있습니까?
#
# >**A.** DB 클러스터를 중지하고 웹사이트가 어떻게 반응하는지 분석
# **B.** Aurora 결함 주입을 사용하여 마스터 DB 인스턴스 충돌
# **C.** DB 클러스터 엔드포인트를 제거하여 마스터 DB 인스턴스 장애 시뮬레이션
# **D.** Aurora Backtrack을 사용하여 DB 클러스터 충돌
#
# ><details><summary>해설</summary><div markdown="1">
# >결함 주입 쿼리를 사용하여 Amazon Aurora DB 클러스터의 내결함성을 테스트할 수 있습니다.
# >
# >[결함 주입 쿼리를 사용하여 Amazon Aurora 테스트](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/AuroraMySQL.Managing.FaultInjectionQueries.html)
# </div></details>
#
# **[Q#069. Q#036. Q#141.](https://www.examtopics.com/discussions/amazon/view/26780-exam-aws-certified-database-specialty-topic-1-question-69/)**
# 회사는 온프레미스 Oracle 데이터베이스에서 Amazon Aurora PostgreSQL로 방금 마이그레이션했습니다. 마이그레이션 후 회사는 응용 프로그램의 응답 시간이 눈에 띄게 느린 매일 오후 3시경에 시간이 있음을 발견했습니다. 회사는 이 문제의 원인을 애플리케이션이 아닌 데이터베이스로 좁혔습니다.
# 문제가 있는 PostgreSQL 쿼리를 가장 효율적으로 찾기 위해 데이터베이스 전문가는 어떤 단계를 수행해야 합니까?
#
# >**A.** Amazon CloudWatch 대시보드를 생성하여 연결 수, CPU 사용량 및 디스크 공간 사용량을 표시합니다. 다음 느린 기간 동안 이 대시보드를 시청하십시오.
# **B.** Amazon EC2 인스턴스를 시작하고 출력 오류 로그를 기반으로 보고서를 실행할 오픈 소스 PostgreSQL 모니터링 도구를 설치 및 구성합니다.
# **C.** 로깅 데이터베이스 매개변수를 수정하여 데이터베이스 잠금과 관련된 모든 쿼리를 기록하고 이 정보에 대해 다음 느린 기간 후에 로그를 확인합니다.
# **D.** PostgreSQL 데이터베이스에서 Amazon RDS 성능 개선 도우미를 활성화합니다. 지표를 사용하여 다음 느린 기간 동안 그래프의 스파이크와 관련된 쿼리를 식별합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >RDS 성능 개선 도우미 -> 다음 느린 기간 동안 그래프의 스파이크와 관련된 쿼리를 식별합니다.
# >
# >[성능 개선 도우미](https://aws.amazon.com/ko/rds/performance-insights/)<br>
# >[기본 및 외부 도구를 기반으로 Amazon RDS PostgreSQL에서 쿼리 최적화 및 조정](https://aws.amazon.com/ko/blogs/database/optimizing-and-tuning-queries-in-amazon-rds-postgresql-based-on-native-and-external-tools/)
# </div></details>
#
# **[Q#070. Q#001. Q#111.](https://www.examtopics.com/discussions/amazon/view/25207-exam-aws-certified-database-specialty-topic-1-question-70/)**
# 회사에 Amazon DynamoDB를 사용하는 웹 기반 설문 조사 애플리케이션이 있습니다. 사용량이 가장 많은 동안 설문 조사 응답을 수집할 때 데이터베이스
# 전문가에게 ProvisionedThroughputExceededException 오류가 표시됩니다.
# 데이터베이스 전문가는 이 오류를 해결하기 위해 무엇을 할 수 있습니까? (2개를 선택하세요.)
#
# >**A.** Amazon DynamoDB 스트림을 사용하도록 테이블 변경
# **B.** 영향을 받는 리전에서 DynamoDB 예약 용량 구매
# **C.** 특정 테이블에 대한 쓰기 용량 단위 늘리기
# **D.** 테이블 용량 모드를 주문형으로 변경
# **E.** 테이블 유형을 처리량 최적화로 변경
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : CD(100%)  <br>
# >특정 테이블에 대한 쓰기 용량 단위를 늘립니다 --> 테이블 용량 모드를 온디맨드로 변경<br>
# >DynamoDB는 처리량 최적화 테이블 유형 없음. 예약용량은 예약한 것 보다 더 많은 것을 제공하지 않음.<br>
# >
# >[읽기/쓰기 용량 모드 변경 시 고려 사항](https://docs.aws.amazon.com/ko_kr/amazondynamodb/latest/developerguide/switching.capacitymode.html)
# </div></details>

# %% [markdown]
# # 071

# %% [markdown]
# **★★★[Q#071. Q#021. Q#035.](https://www.examtopics.com/discussions/amazon/view/25623-exam-aws-certified-database-specialty-topic-1-question-71/)**
# 회사는 하나의 AWS 계정에서 2계층 전자상거래 애플리케이션을 실행하고 있습니다. 웹 서버는 Amazon RDS for MySQL 다중 AZ DB 인스턴스를 사용하여 배포됩니다. 개발자가 프로덕션 환경에서 실수로 데이터베이스를 삭제했습니다. 데이터베이스가 복원되었지만 이로 인해 몇 시간의 가동 중지 시간과 수익 손실이 발생했습니다.
# 향후 이와 같은 오류가 발생하지 않도록 데이터베이스 전문가는 기존 IAM 정책에서 어떤 조합을 변경해야 합니까? (3개를 선택하세요.)
#
# >**A.** 그룹, 사용자 및 역할에 최소 권한 부여
# **B.** 모든 사용자가 백업에서 데이터베이스를 복원할 수 있도록 허용하여 데이터베이스 복원을 위한 전체 가동 중지 시간을 줄입니다.
# **C.** 민감한 리소스 및 API 작업에 액세스하기 위해 민감한 작업에 대해 다단계 인증을 활성화합니다.
# **D.** 정책 조건을 사용하여 선택적 IP 주소에 대한 액세스 제한
# **E.** AccessList Controls 정책 유형을 사용하여 데이터베이스 인스턴스 삭제에 대한 사용자 제한
# **F.** AWS CloudTrail 로깅 및 향상된 모니터링 활성화
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : ACD(100%)  <br>
# >RDS가 ​AccessList Controls 정책 유형을 지원하지 않음(E x) <br>
# >최소 권한 부여, 다단계 인증, 액세스 제한
# >
# >[Amazon RDS 자격 증명 기반 정책 예제](https://docs.aws.amazon.com/AmazonRDS/latest/UserGuide/security_iam_id-based-policy-examples.html)
# </div></details>
#
# **[Q#072. Q#158. Q#073.](https://www.examtopics.com/discussions/amazon/view/26782-exam-aws-certified-database-specialty-topic-1-question-72/)**
# 한 회사는 사용자 요청이 Amazon Aurora MySQL DB 클러스터에 삽입을 수행하는 AWS Lambda 함수를 트리거하는 새로운 웹 플랫폼을 구축하고 있습니다. 새로운 플랫폼에서 10명 미만의 사용자를 대상으로 한 초기 테스트에서는 성공적인 실행과 빠른 응답 시간이 나타났습니다. 그러나 실제 동시 사용자 3,000명을 대상으로 한 보다 광범위한 테스트에서 Lambda 함수는 DB 클러스터에 연결할 수 없으며 너무 많은 연결 오류를 수신합니다.
# 다음 중 이 문제를 해결할 수 있는 것은 무엇입니까?
#
# >**A.** DB 클러스터의 my.cnf 파일을 편집하여 max_connections를 늘립니다.
# **B.** DB 클러스터의 인스턴스 크기 늘리기
# **C.** DB 클러스터를 다중 AZ로 변경
# **D.** Aurora 복제본의 수를 늘립니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >인스턴스에 따라 더 많은 연결이 필요한 DB 클러스터의 인스턴스 크기를 늘립니다.<br>
# >Max_connection은 RDS 파라미터 그룹의 수식입니다. GREATEST({log(DBInstanceClassMemory/805306368)*45},{log(DBInstanceClassMemory/8187281408)*1000})
# >
# >[Amazon Aurora MySQL에 대한 성능 및 조정 관리](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/AuroraMySQL.Managing.Performance.html)
# </div></details>
#
# **[Q#073. Q#144. Q#066.](https://www.examtopics.com/discussions/amazon/view/26783-exam-aws-certified-database-specialty-topic-1-question-73/)**
# 한 회사에서 Amazon Aurora를 데이터베이스로 사용하여 AWS에서 호스팅되는 다중 계층 웹 애플리케이션을 개발하고 있습니다. 애플리케이션은 프로덕션 및 기타 비프로덕션 환경에 배포해야 합니다.
# 데이터베이스 전문가는 자동 배포에 사용되는 AWS CloudFormation 템플릿 에서 서로 다른 MasterUsername 및 MasterUserPassword 속성을 지정해야 합니다. CloudFormation 템플릿은 회사의 코드 저장소에서 버전 제어됩니다. 또한 회사는 프로덕션을 위해 데이터베이스 마스터 암호를 정기적으로 교체하여 규정 준수 요구 사항을 충족해야 합니다.
# 마스터 비밀번호를 저장하는 가장 안전한 솔루션은 무엇입니까?
#
# >**A.** 마스터 패스워드는 각 환경의 파라미터 파일에 저장한다. CloudFormation 템플릿에서 환경별 매개변수 파일을 참조하십시오.
# **B.** AWS KMS 키를 사용하여 마스터 암호를 암호화합니다. CloudFormation 템플릿에 암호화된 마스터 비밀번호를 저장합니다.
# **C.** secretsmanager 동적 참조를 사용하여 AWS Secrets Manager에 저장된 마스터 암호를 검색하고 자동 교체를 활성화합니다.
# **D.** ssm 동적 참조를 사용하여 AWS Systems Manager Parameter Store에 저장된 마스터 암호를 검색하고 자동 교체를 활성화합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : C(100%)  <br>
# >동적 참조와 함께 CloudFormation의 보안 문자열 지원을 사용하면 인프라를 코드로 더 잘 유지 관리할 수 있습니다. 템플릿에 비밀번호를 하드 코딩하는 것을 피할 수 있고 이러한 런타임 구성 매개변수를 코드와 분리된 상태로 유지할 수 있습니다. 적절하게 사용된 보안 문자열은 개발 및 프로덕션 코드를 가능한 한 유사하게 유지하는 동시에 인프라 코드를 지속적인 배포 파이프라인에 적합하게 만드는 데 도움이 됩니다.
# </div></details>
#
# **[Q#074. Q#172. Q#024.](https://www.examtopics.com/discussions/amazon/view/26784-exam-aws-certified-database-specialty-topic-1-question-74/)**
# 한 회사에서 주간 TV 게임 쇼에 사용할 새 설문 조사 응용 프로그램을 작성하고 있습니다. 신청서는 매주 2시간 동안 사용할 수 있습니다. 회사는 매주 500,000개 이상의 항목을 수신할 것으로 예상하며 각 설문조사는 각 사용자에게 2-3개의 객관식 질문을 요구합니다. 데이터베이스 전문가는 예상되는 볼륨을 처리하기 위해 많은 수의 동시 쓰기에 대해 확장성이 뛰어난 플랫폼을 선택해야 합니다.
# 데이터베이스 전문가는 어떤 AWS 서비스를 고려해야 합니까? (2개를 선택하세요.)
#
# >**A.** Amazon DynamoDB
# **B.** Amazon Redshift
# **C.** Amazon Neptune
# **D.** Amazon Elasticsearch Service
# **E.** Amazon ElastiCache
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : AE(100%)  <br>
# >A. Amazon DynamoDB (2시간 동안 500K의 높은 응답)<br>
# >E. Amazon ElastiCache (질문과 옵션에 대한 2시간 동안 500K의 높은 정적 읽기)<br>
# >AWS Neptune은 Graph 데이터베이스
# >
# >[실시간 애플리케이션을 위한 AWS 데이터베이스](https://aws.amazon.com/ko/products/databases/real-time-apps-elasticache-for-redis/)
# </div></details>
#
# **[Q#075. Q#170. Q#059.](https://www.examtopics.com/discussions/amazon/view/26802-exam-aws-certified-database-specialty-topic-1-question-75/)**
# 회사에서 단일 MySQL 데이터베이스를 Amazon Aurora로 마이그레이션했습니다. 프로덕션 데이터는 VPC_PROD의 DB 클러스터에서 호스팅되고, 12개의 테스트 환경은 동일한 AWS 계정을 사용하여 VPC_TEST에서 호스팅됩니다. 테스트 결과 테스트 데이터에 대한 변경이 최소화됩니다. 개발 팀은 각 테스트 데이터베이스에 매일 새로운 프로덕션 데이터가 포함되도록 각 환경을 매일 밤 새로 고치기를 원합니다.
# 어떤 마이그레이션 접근 방식을 구현하는 것이 가장 빠르고 비용 효율적입니까?
#
# >**A.** Amazon Aurora MySQL에서 마스터를 실행합니다. VPC_TEST에 12개의 클론을 생성하고 매일 밤 삭제 및 재생성할 클론을 스크립팅합니다.
# **B.** Amazon Aurora MySQL에서 마스터를 실행합니다. 야간 스냅샷을 만들고 Aurora Serverless를 사용하여 VPC_TEST의 12개 데이터베이스로 복원합니다.
# **C.** Amazon Aurora MySQL에서 마스터를 실행합니다. VPC_TEST에서 12개의 Aurora 복제본을 생성하고 야간에 복제본을 삭제하고 다시 생성하도록 스크립팅합니다.
# **D.** Aurora Serverless를 사용하여 Amazon Aurora MySQL에서 마스터를 실행합니다. VPC_TEST에 12개의 클론을 생성하고 매일 밤 삭제 및 재생성할 클론을 스크립팅합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : A(50%) D(50%)  <br>
# >x A. (2021년 6월 이전의 정답은 옵션 D의 서버리스가 이전 복제를 허용하지 않았기 때문)<br>
# >x B. 스냅샷은 Full disk dump 방식이므로 클론(copy-on-write) 보다 느림<br>
# >x C. Aurora Replica에는 쓰기작업이 불가, 테스트용 활용불가<br>
# >D. (2021년 6월 이후 정답, serverless v1은 동일한 계정으로 복제 지원)<br>
# >
# >[Amazon Aurora Serverless v1, 빠른 데이터베이스 복제 지원](https://aws.amazon.com/ko/about-aws/whats-new/2021/06/amazon-aurora-serverless-v1-supports-fast-database-cloning/)<br>
# >[Aurora DB 클러스터에 대한 볼륨 복제](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/Aurora.Managing.Clone.html)
# </div></details>
#
# **[Q#076. Q#090. Q#064.](https://www.examtopics.com/discussions/amazon/view/25628-exam-aws-certified-database-specialty-topic-1-question-76/)**
# 대형 전자 상거래 회사는 Amazon DynamoDB를 사용하여 웹 포털에서 트랜잭션을 처리합니다. 일년 내내 교통 패턴은 일반적으로 안정적입니다. 그러나 큰 행사가 계획되어 있습니다. 회사는 트래픽이 3일 이벤트 동안 정상 부하의 최대 10배까지 증가할 것임을 알고 있습니다. 이벤트 기간 동안 판매 가격이 공개되면 트래픽이 급격히 증가합니다.
# 데이터베이스 전문가는 DynamoDB가 증가된 트래픽을 처리할 수 있도록 어떻게 해야 합니까?
#
# >**A.** 테이블이 항상 피크 요구 사항을 충족하도록 프로비저닝되었는지 확인합니다 .
# **B.** 추가 부하를 처리할 수 있는 버스트 용량 허용
# **C.** 트래픽 증가를 처리하기 위해 테이블에 대한 AWS Application Auto Scaling 정책 설정
# **D.** 알려진 피크에 대해 추가 용량을 사전 프로비저닝한 다음 이벤트 후에 용량을 줄입니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : D(71%) C (29%)  <br>
# >판매로 인한 트래픽 증가를 미리 알고 있기 때문에 사전 프로비저닝으로 진행합니다. 버스트 용량은 최대 5분까지 알 수 없는 스파이크에 적합합니다. 이벤트 기간은 3일 동안이다.<br>
# >DynamoDB를 사전 프로비저닝합니다. (프로비저닝된 모드를 사용하여 일반 부하보다 10배 높은 RCU 및 WCU 할당), 알려진 워크로드에는 프로비저닝된 용량이 더 좋습니다.
# </div></details>
#
# **[Q#077. Q#175. Q#052.](https://www.examtopics.com/discussions/amazon/view/27045-exam-aws-certified-database-specialty-topic-1-question-77/)**
# 데이터베이스 전문가는 AWS DMS를 사용하여 온프레미스 Microsoft SQL Server 애플리케이션 데이터베이스를 PostgreSQL용 Amazon RDS로 마이그레이션하고 있습니다. 애플리케이션은 RDS DB 인스턴스가 가동될 때 최소한의 가동 중지 시간이 필요합니다.
# 데이터베이스 전문가는 마이그레이션을 활성화하기 위해 어떤 변경을 해야 합니까?
#
# >**A.** 지속적인 변경 데이터 캡처(CDC)를 통해 AWS DMS 전체 로드의 소스 역할을 하도록 온프레미스 애플리케이션 데이터베이스를 구성합니다.
# **B.** 전체 로드 및 지속적인 변경 데이터 캡처(CDC)를 모두 허용하도록 AWS DMS 복제 인스턴스 구성
# **C.** 지속적인 변경 데이터 캡처(CDC)를 허용하도록 전체 로그를 생성하도록 AWS DMS 작업 구성
# **D.** 지속적인 변경 데이터 캡처(CDC)를 허용하도록 양방향 통신을 허용하도록 AWS DMS 연결을 구성합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : A(100%)  <br>
# >복제 인스턴스에서 전체 로드 또는 CDC를 정의할 수 없습니다.(B x), 소스노드 즉 온프레미스 DB에서 정의해야 함.
# >
# >[Amazon RDS DB 인스턴스로 데이터를 가져오기](https://aws.amazon.com/ko/premiumsupport/knowledge-center/rds-import-data/)
# </div></details>
#
# **[Q#078. Q#029. Q#071.](https://www.examtopics.com/discussions/amazon/view/26311-exam-aws-certified-database-specialty-topic-1-question-78/)**
# 금융 회사는 마이그레이션 작업을 수용하기 위해 대용량 스토리지를 갖춘 Amazon RDS MariaDB DB 인스턴스를 할당했습니다. 회사는 마이그레이션 후 인스턴스에서 원치 않는 데이터를 제거했습니다. 이 회사는 이제 비용을 절약하기 위해 스토리지를 축소하려고 합니다. 솔루션은 생산에 최소한의 영향을 미치고 가동 중지 시간이 거의 없어야 합니다.
# 어떤 솔루션이 이러한 요구 사항을 충족합니까?
#
# >**A.** 이전 데이터베이스의 스냅샷을 만들고 필요한 스토리지로 스냅샷을 복원합니다.
# **B.** 필요한 스토리지로 새 RDS DB 인스턴스를 생성하고 AWS DMS를 사용하여 이전 인스턴스에서 새 인스턴스로 데이터베이스를 이동합니다.
# **C.** 기본 백업 및 복원을 사용하여 새 데이터베이스 생성
# **D.** 새 읽기 전용 복제본을 만들고 기존 기본 복제본을 종료하여 기본 복제본으로 만듭니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : B (100%)  <br>
# >x A. (크기가 줄어들지 않음)<br>
# >B. DB를 새로 생성해야 하며 DMS는 다운타임이 거의 없음<br>
# >x C. (크기가 줄어들지 않음)<br>
# >x D. 읽기 전용 복제본을 생성할 때 스토리지 크기를 설정할 수 없음.
# </div></details>
#
# **[Q#079. Q#118. Q#007.](https://www.examtopics.com/discussions/amazon/view/26024-exam-aws-certified-database-specialty-topic-1-question-79/)**
# 대규모 금융 서비스 회사에서는 전송 시 모든 데이터를 암호화해야 합니다. 개발자가 데이터베이스 전문가가 제공한 자격 증명으로 처음으로 회사 VPC를 사용하여 Amazon RDS DB 인스턴스에 연결을 시도하고 있습니다. 개발 팀의 다른 구성원은 연결할 수 있지만 이 사용자는 통신 링크 실패를 나타내는 오류를 지속적으로 수신하고 있습니다. 개발자는 데이터베이스 전문가에게 비밀번호 재설정을 여러 번 요청했지만 오류가 지속됩니다.
# 이 문제를 해결하려면 어떤 조치를 취해야 합니까?
#
# >**A.** RDS DB 인스턴스에 대한 데이터베이스 옵션 그룹이 개발자 머신의 IP 주소로부터의 수신을 허용하는지 확인하십시오.
# **B.** 개발자가 연결할 수 있도록 RDS DB 인스턴스의 서브넷 그룹에 퍼블릭 서브넷이 포함되어 있는지 확인합니다.
# **C.** RDS DB 인스턴스가 최대 연결 한도에 도달하지 않았는지 확인합니다.
# **D.** 연결이 SSL을 사용하고 있고 RDS DB 인스턴스가 암호화된 연결을 수신 대기하는 포트의 주소를 지정하는지 확인합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : D(88%) B(13%)<br>
# >전송 중인 모든 데이터가 암호화되어야 하기 때문에 SSL 사용을 하고 있는지 확인필요<br>
# >
# >[Microsoft SQL Server DB 인스턴스와 함께 SSL 사용](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/SQLServer.Concepts.General.SSL.Using.html)
# </div></details>
#
# **[Q#080. Q#135. Q#110.](https://www.examtopics.com/discussions/amazon/view/25210-exam-aws-certified-database-specialty-topic-1-question-80/)**
# 회사에서 워크로드를 위해 Amazon RDS for MySQL을 실행하고 있습니다. Amazon RDS에서 지정한 유지 관리 기간 동안 AWS 운영 체제 패치가 적용될 때 가동 중지 시간이 있습니다.
# 다운타임을 피하기 위해 취해야 하는 가장 비용 효율적인 조치는 무엇입니까?
#
# >**A.** Amazon RDS for MySQL에서 Amazon DynamoDB로 워크로드 마이그레이션
# **B.** 교차 리전 읽기 전용 복제본을 활성화하고 Amazon RDS가 다운될 때 읽기 트래픽을 해당 복제본으로 보냅니다.
# **C.** Amazon RDS가 다운될 때 읽기 전용 복제본을 활성화하고 읽기 트래픽을 해당 복제본으로 보냅니다.
# **D.** Amazon RDS for MySQL 다중 AZ 구성 활성화
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : D(100%)<br>
# >x A. DynamoDB는 RDS 워크로드를 인수하는 데 적합하지 않습니다.<br>
# >x B. 쓰기 트래픽은 어떻습니까? 동일한 지역에 읽기 전용 복제본이 있을 수 있는데 왜 교차 지역이 필요한가요?<br>
# >x C. 쓰기 트래픽은 어떻습니까?<br>
# >D. Amazon RDS for MySQL 다중 AZ 구성 활성화 유지 관리(단순한 장애 조치)에 필요한 중단을 줄이는 데 도움이 됨. 중단을 줄이면서 R+W 워크로드에 대한 유지 관리를 수행가능.
# >
# >[필수 Amazon RDS 유지 관리 동안 가동 중지를 최소화하려면](https://aws.amazon.com/ko/premiumsupport/knowledge-center/rds-required-maintenance/)
# </div></details>

# %% [markdown]
# # 081

# %% [markdown]
# **[Q#081. Q#042. Q#165.](https://www.examtopics.com/discussions/amazon/view/26312-exam-aws-certified-database-specialty-topic-1-question-81/)**
# 데이터베이스 전문가는 Amazon RDS for MySQL DB 인스턴스에 대한 읽기 전용 쿼리를 분리하기 위해 읽기 전용 복제본을 생성해야 합니다. 읽기 전용 복제본을 생성한 직후 이를 쿼리하는 사용자는 느린 응답 시간을 보고합니다.
# 이러한 느린 응답 시간의 원인은 무엇입니까?
#
# >**A.** 스냅샷에서 생성된 새 볼륨은 백그라운드에서 느리게 로드됩니다.
# **B.** 마스터에 대한 장기 실행 문
# **C.** 마스터의 리소스 부족
# **D.** 마스터에 대한 과도한 쓰기로 인한 단일 복제 스레드의 과부하
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : A (100%)<br>
# >데이터가 로드되지 않은 상태에서 볼륨에 액세스하는 경우 스냅샷이 지연 로드됨. 볼륨에 액세스하는 애플리케이션은 데이터가 로드되는 동안 평소보다 더 긴 대기 시간에 직면함.<br>
# >새 복제본을 스핀업하면 해당 EBS 볼륨이 백그라운드에서 느리게 로드됩니다.<br>
# >
# >[Amazon EBS FSR(빠른 스냅샷 복원)](https://aws.amazon.com/ko/about-aws/whats-new/2019/11/amazon-ebs-fast-snapshot-restore-eliminates-need-for-prewarming-data-into-volumes-created-snapshots/)
# </div></details>
#
# **[Q#082. Q#079. Q#118.](https://www.examtopics.com/discussions/amazon/view/27047-exam-aws-certified-database-specialty-topic-1-question-82/)**
# 회사는 AWS 계정에서 모든 새 Amazon DynamoDB 테이블을 생성하는 데 사용되는 AWS CloudFormation 템플릿을 개발했습니다. 템플릿은 하드 코딩된 값을 사용하여 프로비저닝된 처리 용량을 구성합니다. 회사는 나중에 생성하는 테이블에 독립적으로 구성 가능한 읽기 및 쓰기 용량 단위가 할당되도록 템플릿을 변경하려고 합니다.
# 이 변화를 가능하게 하는 솔루션은 무엇입니까?
#
# >**A.** 템플릿의 매핑 섹션에 rcuCount 및 wcuCount 매개변수 값을 추가합니다. 스택의 매핑을 사용하여 처리량 용량을 프로비저닝하도록 DynamoDB를 구성합니다.
# **B.** 두 개의 Number 매개변수 rcuCount 및 wcuCount에 대한 값을 템플릿에 추가합니다. 하드 코딩된 값을 새 매개변수를 참조하는 Ref 내장 함수에 대한 호출로 바꿉니다.
# **C.** 템플릿의 출력으로 rcuCount 및 wcuCount 매개변수에 대한 값을 추가합니다. 스택 출력을 사용하여 처리량 용량을 프로비저닝하도록 DynamoDB를 구성합니다.
# **D.** rcuCount 및 wcuCount 매개변수에 대한 값을 템플릿의 매핑 섹션에 추가합니다. 하드 코딩된 값을 새 매개변수를 참조하는 Ref 내장 함수에 대한 호출로 바꿉니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : B (100%)  <br>
# >두 개의 Number 매개변수인 rcuCount 및 wcuCount에 대한 값을 템플릿에 추가합니다. 하드 코딩된 값을 새 매개변수를 참조하는 Ref 내장 함수에 대한 호출로 바꿉니다.<br>
# >
# >[AWS CloudFormation 파라미터](https://docs.aws.amazon.com/ko_kr/AWSCloudFormation/latest/UserGuide/parameters-section-structure.html)
# ><pre>
# >"Parameters" : {
# >  "InstanceTypeParameter" : {
# >    "Type" : "String",
# >    "Default" : "t2.micro",
# >    "AllowedValues" : ["t2.micro", "m1.small", "m1.large"],
# >    "Description" : "Enter t2.micro, m1.small, or m1.large. Default is t2.micro."
# >  }
# >}
# >
# >"Ec2Instance" : {
# >  "Type" : "AWS::EC2::Instance",
# >  "Properties" : {
# >    "InstanceType" : { "Ref" : "InstanceTypeParameter" },
# >    "ImageId" : "ami-0ff8a91507f77f867"
# >  }
# >}
# ></pre>
# </div></details>
#
# **[Q#083. Q#133. Q#103.](https://www.examtopics.com/discussions/amazon/view/26804-exam-aws-certified-database-specialty-topic-1-question-83/)**
# 뉴욕에 본사가 있고 도쿄에 또 다른 사무실이 있는 소매 회사는 AWS에서 데이터베이스 솔루션을 구축할 계획입니다. 회사의 주요 워크로드는 데이터 저장소에서 애플리케이션 데이터를 업데이트하는 미션 크리티컬 애플리케이션으로 구성됩니다. 도쿄 사무소의 팀은 애플리케이션 데이터를 사용하여 복잡한 분석 쿼리가 포함된 대시보드를 구축하고 있습니다. 대시보드는 구매 결정을 내리는 데 사용되므로 1초 이내에 애플리케이션 데이터에 액세스할 수 있어야 합니다.
# 어떤 솔루션이 이러한 요구 사항을 충족합니까?
#
# >**A.** us-east-1 리전에 배포된 Amazon RDS DB 인스턴스를 ap-northeast-1 리전에 있는 읽기 전용 복제본 인스턴스와 함께 사용하십시오. ap-northeast-1 리전에 Amazon ElastiCache 클러스터를 생성하여 복제본에서 애플리케이션 데이터를 캐시하여 대시보드를 생성합니다.
# **B.** us-east-1 리전의 Amazon DynamoDB 글로벌 테이블을 사용하여 ap-northeast-1 리전으로 복제합니다. 대시보드 결과를 표시하려면 Amazon QuickSight를 사용하십시오.
# **C.** ap-northeast-1 리전의 읽기 전용 복제본 인스턴스와 함께 us-east-1 리전에 배포된 Amazon RDS for MySQL DB 인스턴스를 사용합니다. 읽기 전용 복제본에서 대시보드 애플리케이션을 읽도록 합니다.
# **D.** Amazon Aurora 글로벌 데이터베이스를 사용합니다. us-east-1 리전에 라이터 인스턴스를 배포하고 ap-northeast-1 리전에 복제본을 배포합니다. 복제본 ap-northeast-1 리전에서 대시보드 애플리케이션을 읽도록 합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : D (100%)<br>
# >Amazon Aurora 글로벌 데이터베이스를 사용합니다.<br>
# >Quicksight는 DynamoDB와 통신할 수 없습니다. (Bx)<br>
# >먼저 DynamoDB에서 S3로 데이터를 내보내고 Athena를 사용하여 S3에서 읽는 것은 2000ms 이상으로 느립니다. 이 질문에서 대시보드는 애플리케이션 데이터에 대한 즉각적인 액세스가 필요합니다.<br>
# >복잡한 쿼리와 분석은 DynamoDB가 아니라 RDS를 사용하는 것이 핵심.<br>
# </div></details>
#
# **[Q#084. Q#146. Q#112.](https://www.examtopics.com/discussions/amazon/view/25211-exam-aws-certified-database-specialty-topic-1-question-84/)**
# 회사에서 PostgreSQL용 Amazon RDS를 사용하고 있습니다. 보안 팀은 모든 데이터베이스 연결 요청이 기록되고 180일 동안 유지되기를 원합니다. RDS for PostgreSQL DB 인스턴스는 현재 기본 파라미터 그룹을 사용하고 있습니다. 데이터베이스 전문가는 log_connections 매개변수를 1로 설정하면 연결 로깅이 활성화된다는 것을 확인했습니다.
# 데이터베이스 전문가는 로깅 및 보존 요구 사항을 충족하기 위해 어떤 단계를 조합해야 합니까? (2개를 선택하세요.)
#
# >**A.** 기본 파라미터 그룹에서 log_connections 파라미터 업데이트
# **B.** 사용자 지정 파라미터 그룹을 생성하고, log_connections 파라미터를 업데이트하고, 파라미터를 DB 인스턴스와 연결합니다.
# **C.** Amazon CloudWatch Logs에 데이터베이스 엔진 로그 게시를 활성화하고 이벤트 만료를 180일로 설정합니다.
# **D.** Amazon S3 버킷에 데이터베이스 엔진 로그 게시를 활성화하고 수명 주기 정책을 180일로 설정합니다.
# **E.** RDS PostgreSQL 호스트에 연결하고 postgresql.conf 파일에서 log_connections 매개변수를 업데이트합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : BC (100%)  <br>
# >AWS는 인스턴스에 사용할 기본 구성 설정을 파라미터 그룹에 제공합니다. 그러나 기본 설정을 변경하려면 기본 파라미터 그룹의 복제본을 생성하고 수정한 다음 인스턴스에 연결해야 합니다.<br>
# >DB 인스턴스에 대한 로깅 파라미터를 설정하려면 DB 파라미터 그룹에서 파라미터를 설정하고 해당 파라미터 그룹을 DB 인스턴스와 연결합니다.<br>
# >이전 로그를 유지하려면 Amazon CloudWatch Logs에 게시하십시오.
# >
# >[PostgreSQL 데이터베이스 로그 파일](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/USER_LogAccess.Concepts.PostgreSQL.html#USER_LogAccess.PostgreSQL.log_retention_period)
# </div></details>
#
# **★★★[Q#085. Q#173. Q#038.](https://www.examtopics.com/discussions/amazon/view/26224-exam-aws-certified-database-specialty-topic-1-question-85/)**
# 데이터베이스 전문가가 새 Amazon Neptune DB 클러스터를 생성하고 Neptune 벌크 로더 API 를 사용하여 Amazon S3에서 Neptune DB 클러스터로 데이터를 로드하려고 합니다 . Database Specialist는 다음 오류를 수신합니다.
#  - Unable to connect to s3 endpoint. Provided source = s3://mybucket/graphdata/ and region = us-east-1. S3 구성을 확인하십시오.
# 데이터베이스 전문가가 문제를 해결하기 위해 취해야 하는 작업 조합은 무엇입니까? (2개를 선택하세요.)
#
# >**A.** Amazon S3에 Neptune에 대한 읽기 액세스 권한을 부여하는 IAM 역할이 있는지 확인
# **B.** Amazon S3 VPC 엔드포인트가 있는지 확인
# **C.** Neptune VPC 엔드포인트가 있는지 확인
# **D.** Amazon EC2에 Amazon S3에 대한 읽기 액세스 권한을 부여하는 IAM 역할이 있는지 확인
# **E.** Neptune에 Amazon S3에 대한 읽기 액세스 권한을 부여하는 IAM 역할이 있는지 확인
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : BE(100%)<br>
# >S3 VPC 엔드포인트가 있어야 합니다. - Neptune에는 S3 버킷에 대한 액세스 권한이 있는 IAM 역할 및 정책이 있어야 합니다.<br>
# >
# >[Amazon Neptune IAM 역할 및 Amazon S3 액세스](https://docs.aws.amazon.com/ko_kr/neptune/latest/userguide/bulk-load-tutorial-IAM.html)<br>
# >[Neptune DB 인스턴스에 데이터 로드](https://docs.aws.amazon.com/ko_kr/neptune/latest/userguide/bulk-load-data.html)
# </div></details>
#
# **[Q#086. Q#015. Q#130.](https://www.examtopics.com/discussions/amazon/view/48806-exam-aws-certified-database-specialty-topic-1-question-86/)**
# 데이터베이스 전문가는 회사의 중요한 MySQL용 Amazon RDS DB 인스턴스를 관리합니다. 매일 저장되는 데이터는 현재 데이터베이스 크기의 0.01%에서 10%까지 다양할 수 있습니다. 데이터베이스 전문가는 DB 인스턴스 스토리지가 필요에 따라 증가하는지 확인해야 합니다.
# 운영상 가장 효율적이고 비용 효율적인 솔루션은 무엇입니까?
#
# >**A.** RDS Storage Auto Scaling을 구성합니다.
# **B.** RDS 인스턴스 Auto Scaling을 구성합니다.
# **C.** DB 인스턴스 할당 스토리지를 예측 요구 사항에 맞게 수정합니다.
# **D.** Amazon CloudWatch FreeStorageSpace 지표를 매일 모니터링하고 필요에 따라 스토리지를 추가합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : A (100%)  <br>
# >워크로드를 예측할 수 없는 경우 Amazon RDS DB 인스턴스에 대해 스토리지 자동 확장을 활성화할 수 있습니다. 스토리지 자동 크기 조정이 활성화된 상태에서 Amazon RDS는 사용 가능한 데이터베이스 공간이 부족함을 감지하면 자동으로 스토리지를 확장합니다.<br>
# >Amazon RDS for MySQL DB 인스턴스 Autoscaling 서비스는 없음(Aurora에서만 사용 가능). 그리고 그것은 저장 문제를 해결하지 못함.<br>
# >
# >[Amazon RDS 스토리지 Autoscaling으로 자동으로 용량 관리](https://docs.aws.amazon.com/AmazonRDS/latest/UserGuide/USER_PIOPS.StorageTypes.html#USER_PIOPS.Autoscaling)
# </div></details>
#
# **[Q#087. Q#120. Q#086.](https://www.examtopics.com/discussions/amazon/view/49114-exam-aws-certified-database-specialty-topic-1-question-87/)**
# 회사에서 데이터베이스 라이선스를 갱신해야 합니다. 이 회사는 80TB 트랜잭션 데이터베이스 시스템을 온프레미스에서 AWS 클라우드로 마이그레이션하려고 합니다.
# 마이그레이션은 다운스트림 데이터베이스 응용 프로그램에서 가능한 최소한의 가동 중지 시간을 발생시켜야 합니다. 회사의 네트워크 인프라에는 다른 응용 프로그램과 공유되는 네트워크 대역폭이 제한되어 있습니다.
# 데이터베이스 전문가가 적시에 마이그레이션하려면 어떤 솔루션을 사용해야 합니까?
#
# >**A.** 원본 데이터베이스의 전체 백업을 AWS Snowball Edge 어플라이언스로 수행하고 Amazon S3에 로드되도록 배송합니다. AWS DMS를 사용하여 원본 데이터베이스에서 Amazon S3로 변경 데이터 캡처(CDC) 데이터를 마이그레이션합니다. 두 번째 AWS DMS 작업을 사용하여 모든 S3 데이터를 대상 데이터베이스로 마이그레이션합니다.
# **B.** 소스 데이터베이스의 전체 백업을 AWS Snowball Edge 어플라이언스로 수행하고 Amazon S3에 로드되도록 배송합니다. 다른 Snowball Edge 어플라이언스에 제공할 원본 데이터베이스의 증분 백업을 주기적으로 수행하여 원본에서 대상 데이터베이스로의 CDC(변경 데이터 캡처) 데이터 동기화를 처리합니다.
# **C.** AWS DMS를 사용하여 기본 연결에 인터넷을 사용하는 VPN 터널을 통해 원본 데이터베이스의 전체 로드를 마이그레이션합니다. AWS DMS가 원본에서 대상 데이터베이스로의 CDC(변경 데이터 캡처) 데이터 동기화를 처리하도록 허용합니다.
# **D.** AWS Schema Conversion Tool(AWS SCT)을 사용하여 기본 연결에 인터넷을 사용하는 VPN 터널을 통해 원본 데이터베이스의 전체 로드를 마이그레이션합니다. AWS SCT가 원본에서 대상 데이터베이스로의 CDC(변경 데이터 캡처) 데이터 동기화를 처리하도록 허용합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : B (100%)  <br>
# >80TB = 1 Snowball -> S3 -> DMS -> CDC -> Target<br>
# >
# >[Amazon S3를 AWS Database Migration Service의 대상으로 사용](https://docs.aws.amazon.com/dms/latest/userguide/CHAP_Target.S3.html)
# </div></details>
#
# **★★★[Q#088. Q#109. Q#183.](https://www.examtopics.com/discussions/amazon/view/48781-exam-aws-certified-database-specialty-topic-1-question-88/)**
# 데이터베이스 전문가는 하나의 읽기 전용 복제본이 있는 MySQL DB 인스턴스용 Amazon RDS를 담당합니다. DB 인스턴스와 읽기 전용 복제본은 기본 파라미터 그룹에 할당됩니다. 데이터베이스 팀은 현재 읽기 전용 복제본에 대해 테스트 쿼리를 실행하고 있습니다. 데이터베이스 팀은 테스트에 도움이 되도록 읽기 전용 복제본에서만 액세스할 수 있는 추가 테이블을 읽기 전용 복제본에 생성하려고 합니다.
# 데이터베이스 팀이 테스트 테이블을 생성할 수 있도록 데이터베이스 전문가는 무엇을 해야 합니까?
#
# >**A.** 읽기 전용 복제본에서 읽기 전용 모드를 비활성화하려면 AWS 지원에 문의하십시오. 읽기 전용 복제본을 재부팅합니다. 읽기 전용 복제본에 연결하고 테이블을 생성합니다.
# **B.** 읽기 전용 복제본의 기본 파라미터 그룹에서 read_only 파라미터를 false(read_only=0)로 변경합니다. 장애 조치 없이 재부팅을 수행합니다. 읽기 전용 복제본에 연결하고 local_only MySQL 옵션을 사용하여 테이블을 생성합니다.
# **C.** 기본 파라미터 그룹에서 read_only 파라미터를 false(read_only=0)로 변경합니다. 읽기 전용 복제본을 재부팅합니다. 읽기 전용 복제본에 연결하고 테이블을 생성합니다.
# **D.** 새 DB 파라미터 그룹을 생성합니다. read_only 매개변수를 false로 변경합니다(read_only=0). 읽기 전용 복제본을 새 그룹과 연결합니다. 읽기 전용 복제본을 재부팅합니다. 읽기 전용 복제본에 연결하고 테이블을 생성합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : D (100%)  <br>
# >기본 파라미터 그룹의 read_only는 변경할 수 없습니다(사용자 지정 파라미터 그룹에서 가능)<br>
# >Amazon RDS DB 인스턴스 읽기 전용 복제본을 읽기/쓰기로 구성하려면 다음 단계를 따르세요.<br>
# >1. MySQL 인스턴스 또는 MariaDB 인스턴스에 대한 DB 파라미터 그룹을 생성합니다.<br>
# >2. 파라미터 그룹을 수정합니다.<br>
# >3. RDS DB 인스턴스를 DB 파라미터 그룹과 연결합니다.<br>
# >
# >[읽기 전용 복제본에 쓰기 작업을 수행하려면](https://aws.amazon.com/ko/premiumsupport/knowledge-center/rds-read-replica/)
# </div></details>
#
# **[Q#089. Q#185. Q#075.](https://www.examtopics.com/discussions/amazon/view/48680-exam-aws-certified-database-specialty-topic-1-question-89/)**
# 회사에는 핵심 비즈니스에 대한 OLTP(온라인 트랜잭션 처리) 및 인사 부서에 대한 OLAP 보고서를 처리하는 이기종 6노드 프로덕션 Amazon Aurora DB 클러스터가 있습니다. 컴퓨팅 리소스를 사용 사례에 맞추기 위해 회사는 인사 부서의 보고 워크로드가 Aurora DB 클러스터의 2개의 작은 노드로 전달되고 다른 모든 워크로드는 동일한 DB 클러스터의 4개의 큰 노드로 전달되도록 결정했습니다.
# 이러한 요구 사항을 충족하면서 적절한 워크로드에 대해 항상 올바른 노드를 사용할 수 있도록 하는 옵션은 무엇입니까?
#
# >**A.** OLTP의 경우 작성자 끝점을 사용하고 OLAP 보고 작업 부하의 경우 판독기 끝점을 사용합니다.
# **B.** Aurora 복제본에 대한 자동 조정을 사용하여 원하는 워크로드에 적절한 수의 복제본을 갖습니다.
# **C.** 다양한 시나리오를 수용하기 위해 추가 독자를 만듭니다.
# **D.** 사용자 지정 끝점을 사용하여 다양한 작업 부하를 충족합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : D(100%)  <br>
# >사용자 지정 끝점(custom endpoints). OLTP는 마스터 인스턴스 끝점에서만 작동할 수 있습니다. OLAP 보고서는 마스터 인스턴스/리더 엔드포인트의 모든 조합에서 작동할 수 있습니다.<br>
# >이제 Amazon Aurora 데이터베이스에 대한 사용자 지정 엔드포인트를 생성할 수 있습니다. 이를 통해 Aurora 클러스터의 다양한 데이터베이스 인스턴스 세트에 워크로드를 분산하고 로드 밸런싱할 수 있습니다.<br>
# </div></details>
#
# **[Q#090. Q#064. Q#171.](https://www.examtopics.com/discussions/amazon/view/48681-exam-aws-certified-database-specialty-topic-1-question-90/)**
# 개발자는 새로운 타사 마케팅 데이터를 로드할 수 있도록 새로운 Amazon Redshift 클러스터를 요청했습니다. 새 클러스터가 준비되고 사용자 자격 증명이 개발자에게 제공됩니다. 개발자에 따르면 복사 작업은 다음 오류 메시지와 함께 실패합니다.
#  - 'Amazon Invalid operation: S3ServiceException:Access Denied,Status 403,Error AccessDenied'
# 개발자는 이 데이터를 곧 로드해야 하므로 데이터베이스 전문가는 이 문제를 해결하기 위해 신속하게 조치를 취해야 합니다.
# 가장 안전한 솔루션은 무엇입니까?
#
# >**A.** Amazon Redshift 개발자 사용자 ID와 동일한 사용자 이름으로 새 IAM 역할을 생성합니다. 역할 수임 작업을 사용하여 Amazon S3에 대한 읽기 전용 액세스 권한이 있는 IAM 역할을 제공합니다.
# **B.** Amazon S3 버킷에 대한 읽기 전용 액세스 권한이 있는 새 IAM 역할을 생성하고 역할 수임 작업을 포함합니다. Amazon Redshift 클러스터를 수정하여 IAM 역할을 추가합니다.
# **C.** 역할 수임 작업으로 Amazon S3 버킷에 대한 읽기 전용 액세스 권한이 있는 새 IAM 역할을 생성합니다. 오류 메시지로 종료된 복사 작업에 사용되는 개발자 IAM 사용자 ID에 이 역할을 추가합니다.
# **D.** 액세스 키가 있는 새 IAM 사용자와 Amazon S3 버킷에 대한 읽기 전용 액세스 권한이 있는 새 역할을 만듭니다. 이 역할을 Amazon Redshift 클러스터에 추가합니다. 생성된 액세스 키를 사용하도록 복사 작업을 변경합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : B (100%)  <br>
# >S3에 대한 읽기 전용 권한이 있는 IAM 역할을 생성하고 S3에서 Redshift 클러스터로 COPY 작업을 위해 이 역할을 Redshift 클러스터에 연결하는 것이 좋습니다.<br>
# >
# >[역할 기반 액세스 제어](https://docs.aws.amazon.com/redshift/latest/dg/copy-usage_notes-access-permissions.html)
# </div></details>

# %% [markdown]
# # 091

# %% [markdown]
# **[Q#091. Q#092. Q#127.](https://www.examtopics.com/discussions/amazon/view/49602-exam-aws-certified-database-specialty-topic-1-question-91/)**
# 대규모 다국적 금융 회사의 데이터베이스 전문가는 개발 중인 고가용성 응용 프로그램에 대한 재해 복구 전략 설계를 담당하고 있습니다. 애플리케이션은 Amazon DynamoDB 테이블을 데이터 저장소로 사용합니다. 애플리케이션에는 1분의 RTO(복구 시간 목표)와 2분의 RPO(복구 시점 목표)가 필요합니다.
# 데이터베이스 전문가가 DynamoDB 테이블에 대해 어떤 운영상 효율적인 재해 복구 전략을 권장해야 합니까?
#
# >**A.** 다른 리전의 DynamoDB 테이블에 데이터를 복사하는 AWS Lambda 함수에 의해 처리되는 DynamoDB 스트림을 생성합니다.
# **B.** 다른 리전에서 DynamoDB 전역 테이블 복제본을 사용합니다. 두 테이블 모두에 대해 특정 시점 복구를 활성화합니다.
# **C.** 다른 리전에서 DynamoDB Accelerator 테이블을 사용합니다. 테이블에 대한 특정 시점 복구를 활성화합니다.
# **D.** AWS Backup 계획을 생성하고 DynamoDB 테이블을 리소스로 할당합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : B(83%), D(17%)  <br>
# >글로벌 테이블은 다중 마스터 복제가 가능한 솔루션입니다. RTO/RPO 요구 사항을 충족합니다.<br>
# >x C. DynamoDB Accelerator(읽기 캐싱용)<br>
# >x D. AWS Backup 계획을 생성하고 DynamoDB 테이블을 자원. (1시간 소요)<br>
# >
# >[글로벌 테이블 - DynamoDB의 다중 리전 복제](https://docs.aws.amazon.com/ko_kr/amazondynamodb/latest/developerguide/GlobalTables.html)
# </div></details>
#
# **[Q#092. Q#127. Q#045.](https://www.examtopics.com/discussions/amazon/view/48683-exam-aws-certified-database-specialty-topic-1-question-92/)**
# 소규모 스타트업 회사는 Amazon RDS for MySQL DB 인스턴스를 사용하여 4TB 온프레미스 MySQL 데이터베이스를 AWS로 마이그레이션하려고 합니다.
# 최소한의 다운타임으로 성공적인 마이그레이션을 허용하는 전략은 무엇입니까?
#
# >**A.** 새로운 RDS for MySQL DB 인스턴스를 배포하고 온프레미스 데이터 센터에서 액세스할 수 있도록 구성합니다. mysqldump 유틸리티를 사용하여 온프레미스 MySQL 서버에서 초기 스냅샷을 생성하고 이를 Amazon S3 버킷에 복사합니다. Amazon EC2 인스턴스에서 실행되는 MySQL 유틸리티를 사용하여 스냅샷을 DB 인스턴스로 가져옵니다. 즉시 애플리케이션이 DB 인스턴스를 가리키도록 합니다.
# **B.** 새 Amazon EC2 인스턴스를 배포하고, EC2 인스턴스에 MySQL 소프트웨어를 설치하고, 온프레미스 데이터 센터에서 액세스할 수 있도록 네트워킹을 구성합니다. mysqldump 유틸리티를 사용하여 온프레미스 MySQL 서버의 스냅샷을 생성합니다. 스냅샷을 EC2 인스턴스로 복사하고 EC2 MySQL 인스턴스로 복원합니다. AWS DMS를 사용하여 데이터를 MySQL용 RDS DB 인스턴스로 마이그레이션하십시오. 애플리케이션이 DB 인스턴스를 가리키도록 합니다.
# **C.** 새 Amazon EC2 인스턴스를 배포하고, EC2 인스턴스에 MySQL 소프트웨어를 설치하고, 온프레미스 데이터 센터에서 액세스할 수 있도록 네트워킹을 구성합니다. mysqldump 유틸리티를 사용하여 온프레미스 MySQL 서버의 스냅샷을 생성합니다. 스냅샷을 Amazon S3 버킷에 복사하고 EC2 인스턴스에서 실행되는 MySQL 유틸리티를 사용하여 새로운 RDS for MySQL DB 인스턴스로 가져옵니다. 애플리케이션이 DB 인스턴스를 가리키도록 합니다.
# **D.** 새 RDS for MySQL DB 인스턴스를 배포하고 온프레미스 데이터 센터에서 액세스할 수 있도록 구성합니다. mysqldump 유틸리티를 사용하여 온프레미스 MySQL 서버에서 초기 스냅샷을 생성하고 이를 Amazon S3 버킷에 복사합니다. Amazon EC2 인스턴스에서 실행되는 MySQL 유틸리티를 사용하여 DB 인스턴스로 스냅샷을 가져옵니다. MySQL 복제를 사용하여 새 DB 인스턴스로 복제를 설정합니다. 온프레미스 MySQL 서버에 대한 애플리케이션 액세스를 중지하고 나머지 트랜잭션이 복제되도록 합니다. 애플리케이션이 DB 인스턴스를 가리키도록 합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : D(100%)  <br>
# >온프레미스 MySQL 서버 -> mysqldump 유틸리티 -> 스냅샷 -> S3에 복사 -> EC2의 MySQL 유틸리티 -> AWS RDS MySQL로 스넵샷 가져오기<br>
# > -> MySQL 복제를 사용하여 새 DB 인스턴스로 복제 설정 -> 온프레미스 MySQL 서버에 대한 애플리케이션 액세스 중지<br>
# > -> 나머지 트랜잭션이 복제되도록 합니다. -> 애플리케이션이 DB 인스턴스를 가리키도록 합니다.<br>
# >
# >[가동 중지 시간을 단축하여 Amazon RDS MySQL MariaDB DB 인스턴스로 데이터 가져오기](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/MySQL.Procedural.Importing.NonRDSRepl.html)
# </div></details>
#
# **[Q#093. Q#032. Q#115.](https://www.examtopics.com/discussions/amazon/view/48684-exam-aws-certified-database-specialty-topic-1-question-93/)**
# 소프트웨어 개발 회사는 개발 및 보고를 비롯한 여러 사용 사례에 Amazon Aurora MySQL DB 클러스터를 사용하고 있습니다. 이러한 사용 사례는 Aurora DB 클러스터에 예측할 수 없고 다양한 요구를 가하고 일시적인 지연 시간 급증을 유발할 수 있습니다. 시스템 사용자는 일주일 내내 산발적으로 임시 쿼리를 실행합니다. 비용은 회사의 주요 관심사이며 상당한 재작업이 필요하지 않은 솔루션이 필요합니다.
# 어떤 솔루션이 이러한 요구 사항을 충족합니까?
#
# >**A.** 개발 및 보고를 위해 새로운 Aurora Serverless DB 클러스터를 생성한 다음 이러한 새로운 DB 클러스터로 마이그레이션하십시오.
# **B.** DB 클러스터 중 하나를 더 큰 크기로 업그레이드하고 이 더 큰 DB 클러스터에서 개발 및 보고 활동을 통합합니다.
# **C.** 기존 DB 클러스터를 사용하고 일정 관리 도구를 사용하여 정기적으로 데이터베이스를 중지/시작합니다.
# **D.** DB 클러스터를 버스트 가능한 인스턴스 패밀리로 변경합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : A(100%)  <br>
# >"예기치 않은 다양한 수요, 임시 검색" => "Aurora Serverless" <br>
# >Amazon Aurora Serverless는 간헐적이거나 예측할 수 없는 워크로드를 위한 간단하고 비용 효율적인 옵션입니다.<br>
# >
# >[Amazon Aurora Serverless](https://aws.amazon.com/ko/rds/aurora/serverless/)<br>
# >[Aurora DB 인스턴스 클래스](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/Concepts.DBInstanceClass.html)
# </div></details>
#
# **[Q#094. Q#114. Q#002.](https://www.examtopics.com/discussions/amazon/view/48808-exam-aws-certified-database-specialty-topic-1-question-94/)**
# 데이터베이스 전문가는 크기가 1GB 미만인 우편 번호 및 관련 지역 정보의 정적 공급업체 데이터 세트를 사용하는 시스템을 구축하고 있습니다. 데이터 세트는 시작 시 애플리케이션의 캐시에 로드됩니다. 회사는 애플리케이션 시작 시간이 짧고 비용이 가장 적게 드는 방식으로 이 데이터를 저장해야 합니다.
# 어떤 접근 방식이 이러한 요구 사항을 충족합니까?
#
# >**A.** Amazon RDS DB 인스턴스를 사용합니다. 데이터를 읽은 후에는 인스턴스를 종료합니다.
# **B.** Amazon Aurora Serverless를 사용합니다. 필요에 따라 서비스가 리소스를 위아래로 회전하도록 허용합니다.
# **C.** 온디맨드 용량 모드에서 Amazon DynamoDB를 사용합니다.
# **D.** Amazon S3를 사용하고 플랫 파일에서 데이터를 로드합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : D(100%)  <br>
# >"정적 공급업체 데이터 세트" 및 "최저 비용"<br>
# >응용 프로그램 캐시로 충분할 수 있습니다. S3에서 애플리케이션 캐시로 바로 로드
# </div></details>
#
# **[Q#095. Q#005. Q#123.](https://www.examtopics.com/discussions/amazon/view/48686-exam-aws-certified-database-specialty-topic-1-question-95/)**
# 데이터베이스 전문가는 성능 문제가 있는 Amazon DynamoDB 테이블을 검토하고 최적화해야 합니다. 데이터베이스 전문가의 철저한 조사에 따르면 파티션 키가 핫 파티션을 유발하므로 새 파티션 키가 생성됩니다. 데이터베이스 전문가는 이 새 파티션 키를 모든 기존 및 새 데이터에 효과적으로 적용해야 합니다.
# 이 솔루션을 어떻게 구현할 수 있습니까?
#
# >**A.** Amazon EMR을 사용하여 현재 DynamoDB 테이블에서 Amazon S3로 데이터를 내보냅니다. 그런 다음 Amazon EMR을 다시 사용하여 Amazon S3의 데이터를 새 파티션 키가 있는 새 DynamoDB 테이블로 가져옵니다.
# **B.** AWS DMS를 사용하여 현재 DynamoDB 테이블에서 Amazon S3로 데이터를 복사합니다. 그런 다음 DynamoDB 테이블을 가져와서 새 파티션 키로 새 DynamoDB 테이블을 생성합니다.
# **C.** AWS CLI를 사용하여 DynamoDB 테이블을 업데이트하고 파티션 키를 수정합니다.
# **D.** AWS CLI를 사용하여 DynamoDB 테이블을 백업합니다. 그런 다음 restore-table-from-backup 명령을 사용하고 파티션 키를 수정합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : A(100%)  <br>
# >DynamoDB에서 파티션 키를 변경할 수 있습니까? 아니요. 테이블이 설정되면 해당 키 스키마를 수정할 수 없습니다. 새 테이블을 프로비저닝하고 해당 테이블로 데이터를 이동한 다음 첫 번째 테이블을 제거하는 것만 가능합니다.<br>
# >DynamoDB에서 S3로의 DynamoDB 백업은 EMR, AWS Glue 또는 AWS Data Pipeline을 통해 가능합니다.<br>
# >
# >[DynamoDB 테이블을 Amazon S3에 백업하려면](https://aws.amazon.com/ko/premiumsupport/knowledge-center/back-up-dynamodb-s3/)
# </div></details>
#
# **[Q#096. Q#062. Q#145.](https://www.examtopics.com/discussions/amazon/view/48687-exam-aws-certified-database-specialty-topic-1-question-96/)**
# 회사에서 보안 감사를 받고 있습니다. 감사 팀은 MySQL DB 인스턴스 용 Amazon RDS용 AWS CloudFormation 템플릿에서 일반 텍스트 마스터 사용자 암호를 식별했습니다 . 감사 팀은 이를 데이터베이스 팀에 대한 보안 위험으로 표시했습니다.
# 데이터베이스 전문가는 이 위험을 완화하기 위해 무엇을 해야 합니까?
#
# >**A.** 인증에 AWS IAM을 사용하도록 모든 데이터베이스를 변경하고 CloudFormation 템플릿에서 모든 일반 텍스트 암호를 제거합니다.
# **B.** AWS Secrets Manager 리소스를 사용하여 임의의 암호를 생성하고 CloudFormation 템플릿에서 암호를 참조합니다.
# **C.** CloudFormation 템플릿에서 암호를 제거하여 데이터베이스가 생성될 때 Amazon RDS가 암호를 묻는 메시지를 표시하도록 합니다.
# **D.** CloudFormation 템플릿에서 비밀번호를 제거하고 별도의 파일에 저장합니다. sed 명령을 사용하여 CloudFormation을 실행하여 암호를 바꿉니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : B (100%)  <br>
# >AWS Secrets Manager 리소스를 사용하여 임의의 암호를 생성하고 CloudFormation 템플릿에서 암호를 참조합니다.
# >
# >[AWS Secrets Manager를 사용하여 AWS Quick Starts에서 암호 보호](https://aws.amazon.com/ko/blogs/infrastructure-and-automation/securing-passwords-in-aws-quick-starts-using-aws-secrets-manager/)
# </div></details>
#
# **[Q#097. Q#125. Q#076.](https://www.examtopics.com/discussions/amazon/view/48688-exam-aws-certified-database-specialty-topic-1-question-97/)**
# 회사의 데이터베이스 전문가가 Amazon DocumentDB 클러스터에서 TLS를 비활성화하여 벤치마킹 테스트를 수행했습니다. 이 변경 사항이 구현된 후 며칠 후 데이터베이스 전문가 연수생이 실수로 여러 테이블을 삭제했습니다. 데이터베이스 전문가가 사용 가능한 스냅샷에서 데이터베이스를 복원했습니다. 클러스터를 복원한 지 한 시간이 지난 후에도 데이터베이스 전문가는 여전히 새 클러스터 끝점에 연결할 수 없습니다.
# 데이터베이스 전문가는 새로 복원된 Amazon DocumentDB 클러스터에 연결하기 위해 무엇을 해야 합니까?
#
# >**A.** 복원된 클러스터의 파라미터 그룹을 원래 클러스터의 사용자 지정 파라미터 그룹으로 변경합니다.
# **B.** 복원된 클러스터의 파라미터 그룹을 Amazon DocumentDB 기본 파라미터 그룹으로 변경합니다.
# **C.** 인터페이스 VPC 엔드포인트를 구성하고 새 Amazon DocumentDB 클러스터를 연결합니다.
# **D.** AWS DataSync에서 syncInstances 명령을 실행합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : A(100%)  <br>
# >트릭 질문: 기본 파라미터 그룹의 파라미터 설정은 수정할 수 없습니다. DB 파라미터 그룹을 사용하여 하나 이상의 DB 인스턴스에 적용되는 엔진 구성 값의 컨테이너 역할을 할 수 있습니다.<br>
# >DB 파라미터 그룹을 지정하지 않고 DB 인스턴스를 생성하면 DB 인스턴스는 기본 DB 파라미터 그룹을 사용합니다. 각 기본 DB 파라미터 그룹에는 데이터베이스 엔진 기본값과 Amazon RDS 시스템 기본값이 포함됩니다. 기본 파라미터 그룹의 파라미터 설정은 수정할 수 없습니다. 대신 고유한 파라미터 설정을 선택하는 고유한 파라미터 그룹을 생성합니다. 생성한 파라미터 그룹에서 모든 DB 엔진 파라미터를 변경할 수 있는 것은 아닙니다.<br>
# </div></details>
#
# **★★★[Q#098. Q#107. Q#122.](https://www.examtopics.com/discussions/amazon/view/49202-exam-aws-certified-database-specialty-topic-1-question-98/)**
# 회사는 MySQL 데이터베이스를 백엔드로 사용하여 온프레미스에서 호스팅되는 CRM(고객 관계 관리) 시스템을 실행합니다. 사용자 지정 저장 프로시저는 데이터가 테이블에 삽입될 때 다른 시스템에 전자 메일 알림을 보내는 데 사용됩니다. 이 회사는 다양한 팀에서 사용하는 데이터베이스 보고 응용 프로그램으로 인해 CRM 시스템의 성능이 저하되었음을 확인했습니다. 이 회사는 유지 관리를 줄이고 성능을 개선하며 이메일 알림 기능을 수용할 AWS 솔루션이 필요합니다.
# 이러한 요구 사항을 충족하는 AWS 솔루션은 무엇입니까?
#
# >**A.** 보고 애플리케이션을 수용하려면 Auto Scaling과 함께 Amazon EC2 인스턴스에서 실행되는 MySQL을 사용하십시오. Amazon SES를 사용하여 다른 시스템에 이메일 알림을 보내는 저장 프로시저 및 AWS Lambda 함수를 구성합니다.
# **B.** 멀티 마스터 클러스터에서 Amazon Aurora MySQL을 사용하여 보고 애플리케이션을 수용합니다. Amazon RDS 이벤트 구독을 구성하여 Amazon SNS 주제에 메시지를 게시하고 다른 시스템의 이메일 주소를 해당 주제에 구독합니다.
# **C.** 보고 애플리케이션을 수용할 수 있도록 읽기 전용 복제본이 있는 Amazon EC2 인스턴스에서 실행되는 MySQL을 사용합니다. 다른 시스템에 이메일 알림을 보내도록 Amazon SES 통합을 구성합니다.
# **D.** 보고 애플리케이션을 위한 읽기 전용 복제본과 함께 Amazon Aurora MySQL을 사용합니다. Amazon SNS 주제에 메시지를 게시하도록 저장 프로시저와 AWS Lambda 함수를 구성합니다. 주제에 대한 다른 시스템의 이메일 주소를 구독하십시오.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : D (100%)  <br>
# >유지 관리를 줄이기 위해 EC2 배제, EC2에서 데이터베이스를 호스팅하면 유지 관리가 늘어납니다.<br>
# >보고 => 읽기 전용 복제본 <br>
# >x B. RDS 이벤트 구독은 "데이터가 테이블에 삽입됨"을 다루지 않습니다. <br>
# >참조 저장 프로시저를 사용하여 Lambda 함수를 호출할 수 있습니다
# >
# >[Amazon RDS 이벤트 범주 및 이벤트 메시지](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/USER_Events.Messages.html)<br>
# >[Amazon Aurora 이벤트에서 트리거되는 규칙 생성](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/rds-cloud-watch-events.html)
# </div></details>
#
# **★★★[Q#099. Q#020. Q#026.](https://www.examtopics.com/discussions/amazon/view/48689-exam-aws-certified-database-specialty-topic-1-question-99/)**
# 회사는 Amazon EC2 인스턴스에서 실행되는 Oracle Database Standard Edition을 다중 AZ가 있는 Oracle DB 인스턴스용 Amazon RDS로 마이그레이션해야 합니다.
# 데이터베이스는 지속적으로 실행되는 전자 상거래 웹사이트를 지원합니다. 회사는 최대 5분의 유지 관리 기간만 제공할 수 있습니다.
# 어떤 솔루션이 이러한 요구 사항을 충족합니까?
#
# >**A.** EC2 인스턴스 및 RDS DB 인스턴스에서 Oracle RAC(Real Application Clusters)를 구성합니다. RAC 클러스터를 가리키도록 연결 문자열을 업데이트합니다. EC2 인스턴스와 RDS DB 인스턴스가 동기화되면 Amazon EC2에서 Amazon RDS로 장애 조치합니다.
# **B.** Oracle Data Pump를 사용하여 EC2 인스턴스에서 Oracle 데이터베이스를 내보내고 Amazon RDS로 가져오기를 수행합니다. 전체 프로세스에 대한 응용 프로그램을 중지합니다. 가져오기가 완료되면 데이터베이스 연결 문자열을 변경한 다음 응용 프로그램을 다시 시작합니다.
# **C.** EC2 인스턴스를 원본으로, RDS DB 인스턴스를 대상으로 하여 AWS DMS를 구성합니다. 복제가 동기화되면 응용 프로그램을 중지하고 데이터베이스 연결 문자열을 변경한 다음 응용 프로그램을 다시 시작합니다.
# **D.** EC2 인스턴스를 원본으로, RDS DB 인스턴스를 대상으로 하여 AWS DataSync를 구성합니다. 복제가 동기화되면 응용 프로그램을 중지하고 데이터베이스 연결 문자열을 변경한 다음 응용 프로그램을 다시 시작합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : C(100%)  <br>
# >x B. 내보내기 가져오기에 시간이 오래 걸립니다.<br>
# >C. EC2 -> DMS -> 새 RDS -> 동기화 시 중지. -> DB 연결 변경<br>
# >
# >[Amazon RDS의 Oracle로 데이터 가져오기](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/Oracle.Procedural.Importing.html)
# </div></details>
#
# **★★★[Q#100. Q#088. Q#109.](https://www.examtopics.com/discussions/amazon/view/48690-exam-aws-certified-database-specialty-topic-1-question-100/)**
# 회사는 애플리케이션의 백엔드에 Amazon Aurora PostgreSQL을 사용하고 있습니다. 시스템 사용자는 응답이 느리다고 불평하고 있습니다. 데이터베이스 전문가는 피크 시간에 Aurora에 대한 쿼리가 더 오래 걸린다고 결정했습니다. Amazon RDS 성능 개선 도우미 대시보드에서 평균 활성 세션에 대한 차트의 로드는 최대 CPU 사용량을 나타내는 선 위에 있는 경우가 많으며 대기 상태는 대부분의 대기 이벤트가 IO:XactSync임을 나타냅니다.
# 이러한 성능 문제를 해결하기 위해 회사는 무엇을 해야 합니까?
#
# >**A.** 읽기 트래픽을 확장하려면 Aurora 복제본을 추가합니다.
# **B.** DB 인스턴스 클래스를 확장합니다.
# **C.** 트랜잭션을 일괄적으로 커밋하도록 애플리케이션을 수정합니다.
# **D.** 잠금을 사용하여 충돌을 방지하도록 애플리케이션을 수정합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : B(64%), C(36%)  <br>
# >IO:XactSync : 백엔드 프로세스는 Aurora 스토리지 하위 시스템이 일반 트랜잭션의 커밋 또는 준비된 트랜잭션의 커밋 또는 롤백을 확인할 때까지 기다리고 있습니다.<br>
# >XactSync는 너무 많은 커밋으로 인해 발생합니다. 솔루션은 일괄 커밋입니다.<br>
# >"이 대기는 시스템에서 매우 높은 비율의 커밋 활동이 있을 때 가장 자주 발생합니다. 때때로 응용 프로그램을 수정하여 트랜잭션을 일괄 처리하여 이 대기를 완화할 수 있습니다. 이 대기는 경우에 따라 CPU가 대기하는 것과 동시에 볼 수 있습니다. 여기서 DB 로드가 DB 인스턴스의 가상 CPU(vCPU) 수를 초과합니다. 이 경우 스토리지 지속성이 CPU 집약적 데이터베이스 워크로드와 CPU를 놓고 경쟁할 수 있습니다. 이 시나리오를 완화하려면 해당 워크로드를 줄이거 나 더 많은 vCPU가 있는 DB 인스턴스로 확장합니다."<br>
# >대기 이벤트의 원인에 따라 다른 작업을 권장합니다. : CPU 확장 / 네트워크 대역폭 향상 / 커밋 수 저감<br>
# >
# >[Amazon Aurora PostgreSQL 대기 이벤트](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/AuroraPostgreSQL.Reference.Waitevents.html)<br>
# >[IO:XactSync](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/apg-waits.xactsync.html)
# </div></details>

# %% [markdown]
# [Best Free AWS Certified Database - Specialty Certification DBS-C01 Exam Dumps PDF-2022 Updated](https://certspilot.com/best-free-aws-certified-database-specialty-certification-dbs-c01-exam-dumps-pdf-updated/)

# %% [markdown]
# # 101

# %% [markdown]
# **[Q#101. Q#072. Q#158.](https://www.examtopics.com/discussions/amazon/view/50908-exam-aws-certified-database-specialty-topic-1-question-101/)**
# 데이터베이스 전문가가 개발 팀의 Dev-VPC1에 Amazon RDS 데이터베이스 인스턴스를 설정했습니다. Dev-VPC1은 Dev-VPC2를 통해 같은 부서의 다른 개발 팀과 피어링 중입니다. 네트워킹 팀은 VPC 간의 라우팅이 양호한지 확인했습니다. 그러나 Dev-VPC2의 데이터베이스 엔지니어가 Dev-VPC1의 데이터베이스에 연결하려고 하면 연결 시간 초과 오류가 발생합니다.
#
# 시간 초과의 원인으로 가장 가능성이 높은 것은 무엇입니까?
#
# >**A.** 데이터베이스가 다른 리전에 있는 VPC에 배포됩니다.
# **B.** 데이터베이스가 다른 가용 영역에 있는 VPC에 배포됩니다.
# **C.** 데이터베이스가 잘못 구성된 보안 그룹과 함께 배포됩니다.
# **D.** 데이터베이스가 잘못된 클라이언트 연결 시간 초과 구성으로 배포되었습니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : C(100%)  <br>
# >보안 그룹에는 인바운드 규칙이 필요합니다. 보안 그룹을 수정해야 합니다.<br>
# </div></details>
#
# **[Q#102. Q#068. Q#143.](https://www.examtopics.com/discussions/amazon/view/49204-exam-aws-certified-database-specialty-topic-1-question-102/)**
# 기업에 SQL Server용 Amazon RDS에서 실행되고 사내 웹 애플리케이션을 통해 액세스되는 프로덕션 환경이 있습니다. 가장 최근의 애플리케이션 유지 관리 기간 동안 웹 애플리케이션은 관리 보고 기능을 개선하기 위한 추가 기능으로 향상되었습니다. 프로그램은 업그레이드 후 특정 보고 요청에 응답하는 데 느립니다.
#
# 기업은 문제의 원인을 어떻게 파악해야 합니까?
#
# >**A.** Microsoft .NET 및 Microsoft SQL Server용 Amazon CloudWatch Application Insights를 설치 및 구성합니다. CloudWatch 대시보드를 사용하여 근본 원인을 식별합니다.
# **B.** RDS 성능 개선 도우미를 활성화하고 문제를 일으키는 쿼리를 확인합니다. 문제를 해결하기 위해 쿼리 변경을 요청합니다.
# **C.** Amazon RDS와 함께 배포된 AWS X-Ray를 사용하여 쿼리 시스템 추적을 추적합니다.
# **D.** 지원 요청을 생성하고 AWS Support와 협력하여 문제의 원인을 식별합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : B(100%)  <br>
# >Amazon RDS 성능 개선 도우미는 데이터베이스의 부하를 신속하게 평가하고 조치를 취해야 할 시기와 위치를 결정하는 데 도움이 되는 데이터베이스 성능 조정 및 모니터링 기능입니다. Performance Insights를 사용하면 데이터베이스 로드를 시각화하는 이해하기 쉬운 대시보드를 통해 비전문가도 성능 문제를 감지할 수 있습니다.<br>
# >
# >[성능 개선 도우미](https://aws.amazon.com/ko/rds/performance-insights/)
# </div></details>
#
# **★★★[Q#103. Q#132. Q#181.](https://www.examtopics.com/discussions/amazon/view/48997-exam-aws-certified-database-specialty-topic-1-question-103/)**
# 유틸리티 회사는 발전소 센서의 데이터를 Amazon DynamoDB 데이터베이스에 저장하려고 합니다. 이 유틸리티 회사는 100개 이상의 발전소를 소유하고 운영하며 각 발전소에는 2초마다 데이터를 전송하는 200개 이상의 센서가 장착되어 있습니다. 센서 데이터는 밀리초 정밀도의 타임스탬프, 값, 센서가 오작동하는지 여부를 나타내는 오류 속성으로 구성됩니다. 전 세계적으로 고유한 식별자는 발전소를 식별하는 데 사용됩니다. 각 발전소 내에서 센서는 고유한 ID로 식별할 수 있습니다. 데이터베이스 전문가는 특정 발전소 내부의 모든 결함 센서를 효과적으로 감지할 수 있도록 테이블을 만들어야 합니다.
#
# 오작동하는 센서를 검색하는 동안 가능한 한 가장 빠른 쿼리 시간을 얻기 위해 데이터베이스 전문가는 DynamoDB 테이블을 설정할 때 어떤 스키마를 사용해야 합니까?
#
# >**A.** 파티션 키로 플랜트 식별자를 사용하고 정렬 키로 측정 시간을 사용합니다. 플랜트 식별자를 파티션 키로 사용하고 오류 속성을 정렬 키로 사용하여 GSI(글로벌 보조 인덱스)를 만듭니다.
# **B.** 파티션 키로 플랜트 식별자와 센서 식별자의 합성물을 생성합니다. 측정 시간을 정렬 키로 사용하십시오. 결함 속성에 로컬 보조 인덱스(LSI)를 생성합니다.
# **C.** 파티션 키로 플랜트 식별자와 센서 식별자의 합성물을 만듭니다. 측정 시간을 정렬 키로 사용하십시오. 플랜트 식별자를 파티션 키로 사용하고 오류 속성을 정렬 키로 사용하여 GSI(글로벌 보조 인덱스)를 만듭니다.
# **D.** 플랜트 식별자를 파티션 키로 사용하고 센서 식별자를 정렬 키로 사용합니다. 결함 속성에 로컬 보조 인덱스(LSI)를 생성합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : B(67%), D(33%)  <br>
# >Primary key로 Plant ID와 Sensor ID의 합성은 두 개의 속성을 별도로 의미하지 않습니다. 이것은 이 두 속성을 결합하는 것을 의미합니다("_"가 있는 문자열 조인일 수 있음).<br>
# >파티션 키로 플랜트 식별자와 센서 식별자의 합성물을 생성합니다. 측정 시간을 정렬 키로 사용하십시오. 결함 속성에 로컬 보조 인덱스(LSI)를 생성합니다. DynamoDB는 기본 키에 3개의 열(파티션 키에 2개, 정렬에 1개)을 허용하지 않는다는 것을 알고 있습니다. 하지만 플랜트 식별자와 센서 식별자가 'PID1-SID1'처럼 연결되어 파티션 키로 사용된다면 어떻게 될까요?
# >I’m going with B
# >• xA "플랜트 식별자를 파티션 키로 사용하고 오류 속성을 정렬 키로 사용"한다고 해서 어떤 센서가 오류 속성을 생성했는지 알려주지 않음.<br>
# >• xC dropped for same reason like A, “Create a global secondary index (GSI) with the plant identifier as the partition key and the fault attribute as the sort key” will not let us know which sensor generated the fault attribute.
# >• xC A와 같은 이유로 "플랜트 식별자를 파티션 키로 만들고 오류 속성을 정렬 키로 사용하여 GSI(Global Secondary Index)를 생성"과 같은 이유로 오류 속성을 생성한 센서를 알려주지 않습니다.
# >• xD 결함속성의 로컬 보조 인덱스는 기본 키로 플랜트 식별자에만 의존하므로 A 및 C와 동일한 문제이므로 결함 속성을 생성한 센서를 알려주지 않습니다.
# • Only Remaining answer is B, it generates partition key which is composed of two values (PlantID+SensorID) – By the way this is not composite key -, and generate time as sort key. then Creating fault attribute as local secondary index which will depend on (PlantID+SensorID) as partition key will allow us to identify the faulty sensor
# >
# >[희소 인덱스(sparse indexes) 활용](https://docs.aws.amazon.com/ko_kr/amazondynamodb/latest/developerguide/bp-indexes-general-sparse-indexes.html)
# </div></details>
#
# **[Q#104. Q#010. Q#167.](https://www.examtopics.com/discussions/amazon/view/49205-exam-aws-certified-database-specialty-topic-1-question-104/)**
# 한 회사에서 팀 플레이 기능을 갖춘 새로운 모바일 게임을 출시합니다. 일련의 모바일 장치 사용자가 상호 작용할 때 Amazon DynamoDB 데이터베이스는 상태를 자세히 설명하는 항목으로 업데이트됩니다. BatchGetltemn 기능을 사용하여 다른 사용자의 장치는 테이블에서 동료의 최신 상태를 주기적으로 읽습니다.
# 출시 전에 여러 테스터가 게임의 상태 데이터가 최신이 아니라고 주장하는 버그 보고서를 제출했습니다. 개발자는 이 문제를 복제할 수 없었고 데이터베이스 전문가에게 조언을 구했습니다.
#
# 이 문제를 해결하는 데 가장 효과적인 제안은 무엇입니까?
#
# >**A.** DynamoDB 테이블이 항상 일관성이 있도록 구성되어 있는지 확인합니다.
# **B.** ConsistentRead 매개변수가 false로 설정된 BatchGetltem 작업이 호출되는지 확인합니다.
# **C.** DynamoDB 테이블에서 스트림을 활성화하고 각 장치를 스트림에 구독하여 모든 장치가 최신 상태 정보를 수신하도록 합니다.
# **D.** ConsistentRead 매개변수가 true로 설정된 BatchGetltem 작업이 호출되는지 확인합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : D(83%), C(17%)  <br>
# >기본적으로 BatchGetItem은 요청의 모든 테이블에 대해 최종적으로 일관된 읽기를 수행합니다. 대신 강력하게 일관된 읽기를 원하는 경우 일부 또는 모든 테이블에 대해 ConsistentRead를 true로 설정할 수 있습니다. <br>
# >
# >[BatchGetItem](https://docs.aws.amazon.com/ko_kr/amazondynamodb/latest/APIReference/API_BatchGetItem.html)<br>
# >[읽기 정합성](https://docs.aws.amazon.com/ko_kr/amazondynamodb/latest/developerguide/HowItWorks.ReadConsistency.html)
# </div></details>
#
# **[Q#105. Q#049. Q#108.](https://www.examtopics.com/discussions/amazon/view/48811-exam-aws-certified-database-specialty-topic-1-question-105/)**
# 한 회사가 Amazon RDS for MySQL 다중 AZ DB 인스턴스에서 비즈니스 크리티컬 워크로드를 운영하고 있습니다. 데이터베이스 인스턴스의 RDS 암호화가 비활성화됩니다. 최근 보안 평가에 따르면 모든 미션 크리티컬 앱은 저장 데이터를 암호화해야 합니다. 회사는 데이터베이스 전문가에게 데이터베이스 인스턴스에 대해 이 작업을 수행하기 위한 전략을 제공하도록 요청했습니다.
#
# 데이터베이스 전문가는 어떤 절차를 제안해야 합니까?
#
# >**A.** 암호화되지 않은 DB 인스턴스의 암호화된 스냅샷을 생성합니다. 암호화된 스냅샷을 Amazon S3에 복사합니다. Amazon S3를 사용하여 암호화된 스냅샷에서 DB 인스턴스를 복원합니다.
# **B.** 암호화가 활성화된 새 RDS for MySQL DB 인스턴스를 생성합니다. 이 DB 인스턴스에 암호화되지 않은 스냅샷을 복원합니다.
# **C.** 암호화되지 않은 DB 인스턴스의 스냅샷을 생성합니다. 스냅샷의 암호화된 복사본을 만듭니다. 암호화된 스냅샷에서 DB 인스턴스를 복원합니다.
# **D.** 암호화되지 않은 DB 인스턴스를 일시적으로 종료합니다. AWS 관리형 CMK를 사용하여 AWS Management 콘솔에서 AWS KMS 암호화를 활성화합니다. 암호화된 상태로 DB 인스턴스를 다시 시작합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C (100%)  <br>
# >스냅샷 -> 스냅샷의 암호화된 복사본 -> 암호화된 스냅샷에서 DB 인스턴스를 복원합니다.<br>
# >
# >[Amazon RDS 리소스 암호화](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/Overview.Encryption.html)<br>
# >[Amazon RDS 암호화된 DB 인스턴스의 제한](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/Overview.Encryption.html#Overview.Encryption.Limitations)
# </div></details>
#
# **[Q#106. Q#099. Q#020.](https://www.examtopics.com/discussions/amazon/view/49000-exam-aws-certified-database-specialty-topic-1-question-106/)**
# 기업이 온프레미스 데이터베이스 워크로드를 Amazon Web Services(AWS) 클라우드로 전송하고 있습니다. 거대한 테이블이 있는 Oracle 데이터베이스를 Amazon RDS로 마이그레이션하는 데이터베이스 전문가가 AWS DMS를 선택했습니다. 데이터베이스 전문가는 AWS DMS가 데이터를 마이그레이션하는 데 상당한 시간을 소비하고 있음을 관찰했습니다.
#
# 어떤 활동으로 데이터 마이그레이션 속도를 높일 수 있습니까? (3개를 선택하세요.)
#
# >**A.** 큰 테이블을 마이그레이션하기 위해 여러 AWS DMS 작업을 생성합니다.
# **B.** 다중 AZ로 AWS DMS 복제 인스턴스를 구성합니다.
# **C.** AWS DMS 복제 서버의 용량을 늘립니다.
# **D.** 온프레미스 데이터 센터와 AWS 간에 AWS Direct Connect 연결을 설정합니다.
# **E.** Amazon RDS 다중 AZ 구성을 활성화합니다.
# **F.** 전체 LOB(Large Binary Object) 모드를 활성화하여 모든 대형 테이블에 대한 모든 LOB 데이터를 마이그레이션합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : ACD(75%), ACF(25%)  <br>
# >A.를 선택하면 성능 향상과 관련이 있는 유일한 옵션은 C.와 D.이고 나머지는 관련이 없다<br>
# >큰 테이블을 마이그레이션할 때 성능을 향상시키려면 마이그레이션을 둘 이상의 작업으로 나누십시오. 행 필터링을 사용하여 마이그레이션을 여러 작업으로 나누려면 키 또는 파티션 키를 사용하십시오. (A)<br>
# >AWS DMS 마이그레이션: 여러 요인이 성능에 영향을 미칩니다.<br>
# >- 소스의 리소스 가용성.<br>
# >- 사용 가능한 네트워크 처리량. (D)<br>
# >- 복제 서버의 리소스 용량입니다. (C)<br>
# >- 변경 사항을 수집하는 대상의 능력.<br>
# >- 소스 데이터의 유형 및 분포.<br>
# >- 마이그레이션할 개체의 수.<br>
# >AWS Direct Connect을 배포하는 데 많은 시간이 소요되므로 D가 정답이 아닙니다.<br>
# >Multi AZ는 속도를 높이지 않고 시간을 더 추가합니다.(Bx,Ex) 전체LOB 모드는 완전한 전송을 보장하지만 더 빠르지는 않습니다.(Fx)
# >
# >[행 필터링을 사용하여 큰 테이블 마이그레이션 시 성능 향상](https://docs.aws.amazon.com/ko_kr/dms/latest/userguide/CHAP_BestPractices.html#CHAP_BestPractices.LargeTables)
# </div></details>
#
# **★★★[Q#107. Q#122. Q#013.](https://www.examtopics.com/discussions/amazon/view/49001-exam-aws-certified-database-specialty-topic-1-question-107/)**
# 한 기업에서 미션 크리티컬한 2TB Oracle 데이터베이스를 온프레미스에서 Amazon Aurora로 이전하고 있습니다. 데이터베이스 마이그레이션은 저렴한 비용으로 유지되어야 하며 조직이 Aurora로 완전히 전환할 준비가 될 때까지 온프레미스 Oracle 데이터베이스와 Aurora DB 클러스터를 모두 쓰기 트래픽에 사용할 수 있어야 합니다.
#
# 데이터베이스 전문가는 이 마이그레이션을 촉진하기 위해 어떤 조치를 취해야 합니까? (2개를 선택하세요.)
#
# >**A.** AWS Schema Conversion Tool(AWS SCT)을 사용하여 소스 데이터베이스 스키마를 변환합니다. 그런 다음 변환된 스키마를 대상 Aurora DB 클러스터로 복원합니다.
# **B.** Oracle의 데이터 펌프 도구를 사용하여 원본 데이터베이스 스키마의 복사본을 내보내고 텍스트 편집기에서 스키마를 수동으로 편집하여 Aurora와 호환되도록 합니다.
# **C.** Oracle 데이터베이스에서 Aurora DB 클러스터로 데이터를 마이그레이션하는 AWS DMS 작업을 생성합니다. 회사가 모든 사용자 트래픽을 Aurora DB 클러스터로 이동할 준비가 될 때까지 원본 및 대상 데이터베이스의 동기화를 유지하기 위해 진행 중인 변경 사항을 복제할 마이그레이션 유형을 선택합니다.
# **D.** Oracle 데이터베이스에서 Aurora DB 클러스터로 데이터를 마이그레이션하는 AWS DMS 작업을 생성합니다. 초기 로드가 완료되면 회사가 모든 사용자 트래픽을 Aurora DB 클러스터로 이동할 준비가 될 때까지 변경 데이터 캡처(CDC)를 수행할 AWS Kinesis Data Firehose 스트림을 생성합니다.
# **E.** Oracle 데이터베이스에서 Aurora DB 클러스터로 데이터를 마이그레이션하기 위해 AWS Glue 작업 및 관련 리소스를 생성합니다. 초기 로드가 완료되면 회사가 모든 사용자 트래픽을 Aurora DB 클러스터로 이동할 준비가 될 때까지 변경 데이터 캡처(CDC)를 수행하는 AWS DMS 작업을 생성합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : AC(100%)  <br>
# >A. AWS SCT을 사용하여 소스 데이터베이스 스키마를 변환합니다. 그런 다음 변환된 스키마를 대상 Aurora DB 클러스터로 복원합니다.<br>
# >x B. 텍스트 편집기<br>
# >C. Oracle 데이터베이스에서 Aurora DB 클러스터로 데이터를 마이그레이션하는 AWS DMS 작업을 생성합니다. 회사에서 모든 사용자 트래픽을 Aurora DB 클러스터로 이동할 준비가 될 때까지 원본 및 대상 데이터베이스의 동기화를 유지하기 위해 진행 중인 변경 사항을 복제할 마이그레이션 유형을 선택합니다.<br>
# >x D. kinesis firehose<br>
# >x E. Glue job<br>
# </div></details>
#
# **[Q#108. Q#106. Q#099.](https://www.examtopics.com/discussions/amazon/view/48812-exam-aws-certified-database-specialty-topic-1-question-108/)**
# 한 기업이 20TB 용량의 프로덕션 Amazon Aurora DB 클러스터를 운영하고 있습니다. 밤새 조직은 대규모 배치 작업을 수행하여 Aurora DB 클러스터를 데이터로 채웁니다. 개발 팀이 테스트에 액세스할 수 있는 최신 데이터를 갖도록 하려면 일괄 작업이 완료된 후 가능한 한 빨리 데이터베이스 클러스터의 복사본을 사용할 수 있어야 합니다.
#
# 이것은 어떻게 달성될 수 있습니까?
#
# >**A.** AWS CLI를 사용하여 DB 클러스터의 수동 스냅샷을 예약합니다. AWS CLI를 사용하여 스냅샷을 새 DB 클러스터로 복원합니다.
# **B.** DB 클러스터에서 덤프 파일을 생성합니다. 덤프 파일을 새 DB 클러스터에 로드합니다.
# **C.** 야간 배치 프로세스가 끝나면 DB 클러스터의 클론을 생성하는 작업을 예약합니다.
# **D.** DB 클러스터에서 복제 및 변경 데이터 캡처(CDC)를 사용하여 데이터를 새 DB 클러스터에 복사하는 새로운 일일 AWS DMS 작업을 설정합니다. 새 클러스터가 최신 클러스터일 때 AWS DMS 스트림이 중지되는 시간을 설정합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C (100%)  <br>
# >클론 생성은 스냅샷 복원과 같은 다른 기술을 사용하여 데이터를 물리적으로 복사하는 것보다 더 빠르고 공간 효율적입니다.<br>
# >복제(클론)가 쉽고 빠릅니다.<br>
# >
# >[Aurora DB 클러스터에 대한 볼륨 복제](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/Aurora.Managing.Clone.html)
# </div></details>
#
# **[Q#109. Q#183. Q#028.](https://www.examtopics.com/discussions/amazon/view/49002-exam-aws-certified-database-specialty-topic-1-question-109/)**
# 회사에는 두 개의 고유한 Amazon Web Services 계정이 있을 수 있습니다. 하나는 각 사업부용이고 다른 하나는 기업 분석용입니다. 조직은 MySQL용 Amazon RDS를 사용하여 us-east-1의 MySQL용 Amazon RDS에 저장된 사업부의 데이터를 us-west-1의 기업 분석 Amazon Redshift 환경으로 복제하려고 합니다. 조직은 Amazon RDS가 소스 엔드포인트로, Amazon Redshift가 대상 엔드포인트로 사용되는 AWS DMS를 사용하려고 합니다.
#
# AVS DMS가 복제할 수 있는 작업은 무엇입니까?
#
# >**A.** Amazon Redshift와 동일한 계정 및 리전에서 AWS DMS 복제 인스턴스를 구성합니다.
# **B.** Amazon Redshift와 동일한 계정 및 Amazon RDS와 동일한 리전에서 AWS DMS 복제 인스턴스를 구성합니다.
# **C.** 자체 계정 및 Amazon Redshift와 동일한 리전에서 AWS DMS 복제 인스턴스를 구성합니다.
# **D.** Amazon RDS와 동일한 계정 및 리전에서 AWS DMS 복제 인스턴스를 구성합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : A (100%)  <br>
# >대상 데이터베이스와 동일한 계정 및 리전에 AWS DMS 복제 인스턴스를 구성합니다.<br>
# >"Amazon Redshift 클러스터는 복제 인스턴스와 동일한 AWS 계정 및 동일한 AWS 리전에 있어야 합니다."<br>
# >
# >[Amazon Redshift 데이터베이스를 AWS Database Migration Service의 대상으로 사용](https://docs.aws.amazon.com/ko_kr/dms/latest/userguide/CHAP_Target.Redshift.html)
# </div></details>
#
# **[Q#110. Q#151. Q#180.](https://www.examtopics.com/discussions/amazon/view/48813-exam-aws-certified-database-specialty-topic-1-question-110/)**
# 데이터베이스 전문가는 us-west-1 리전에 있는 애플리케이션을 담당하고 있으며 us-east-1 리전에 재해 복구를 설정하려고 합니다. Amazon Aurora MySQL DB 클러스터에는 1분 RPO와 2분 RTO가 필요합니다.
#
# 성능 저하 없이 이러한 요구 사항을 충족하는 기술은 무엇입니까?
#
# >**A.** 동기 복제를 활성화합니다.
# **B.** 비동기식 binlog 복제를 활성화합니다.
# **C.** Aurora 글로벌 데이터베이스를 생성합니다.
# **D.** us-east-1 리전에 Aurora 증분 스냅샷을 복사합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : C(100%)  <br>
# >Aurora 글로벌 데이터베이스를 생성합니다. 관리형 계획 장애 조치 RPO = 0초, RTO = 분<br>
# >
# >[Amazon Aurora 글로벌 데이터베이스에서 장애 조치 사용](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/aurora-global-database-disaster-recovery.html)
# </div></details>

# %% [markdown]
# # 111

# %% [markdown]
# **[Q#111. Q#018. Q#085.](https://www.examtopics.com/discussions/amazon/view/48814-exam-aws-certified-database-specialty-topic-1-question-111/)**
# 한 게임 회사가 새로운 모바일 게임을 구축 중이며 Amazon DynamoDB를 활용하여 사용자 데이터를 저장할 계획입니다. 사용자는 현재 Facebook 또는 Amazon 계정을 사용하여 등록하여 절차를 최대한 간단하게 만들 수 있습니다. 회사는 10,000명 이상의 사용자를 예상합니다.
#
# 데이터베이스 관리자는 가능한 최소한의 운영 작업으로 액세스 제어를 어떻게 구현해야 합니까?
#
# >**A.** 모바일 앱에서 웹 자격 증명 연동을 사용하고 IAM 역할이 연결된 AWS STS를 사용하여 DynamoDB에 액세스하기 위한 임시 자격 증명을 얻습니다.
# **B.** 모바일 앱에서 웹 자격 증명 연동을 사용하고 자격 증명이 있는 개별 IAM 사용자를 생성하여 DynamoDB에 액세스합니다.
# **C.** 사용자가 API를 통해 DynamoDB의 데이터에 액세스할 수 있도록 모바일 앱에서 자체 개발한 사용자 관리 시스템을 사용합니다.
# **D.** 모바일 앱에서 단일 IAM 사용자를 사용하여 DynamoDB에 액세스합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : A(100%)  <br>
# >웹 자격 증명 연동을 사용하면 개별 IAM 사용자를 생성할 필요가 없습니다. 그 대신에 사용자는 자격 증명 공급자에 로그인한 후 AWS Security Token Service(AWS STS)에서 임시 보안 자격 증명을 얻을 수 있습니다. 그러면 앱은 이러한 자격 증명을 사용하여 AWS 서비스에 액세스할 수 있습니다.<br>
# >IAM Role is always preferred method.<br>
# >
# >[웹 자격 증명 연동 사용](https://docs.aws.amazon.com/ko_kr/amazondynamodb/latest/developerguide/WIF.html)
# </div></details>
#
# **[Q#112. Q#070. Q#001.](https://www.examtopics.com/discussions/amazon/view/48815-exam-aws-certified-database-specialty-topic-1-question-112/)**
# 최근 한 유명 소매업체가 3계층 전자상거래 앱을 AWS로 전환했습니다. Amazon Aurora PostgreSQL은 회사의 백엔드 데이터베이스를 호스팅하는 데 사용됩니다. 사용자는 바쁜 기간 동안 더 긴 웹 사이트 로드 시간에 대해 불평합니다. 데이터베이스 전문가가 Amazon RDS 성능 개선 도우미를 분석한 결과 IO:XactSync 대기 이벤트의 증가를 확인했습니다. 대기 이벤트와 관련된 모든 SQL 문은 단일 INSERT 문입니다.
#
# 이 상황은 어떻게 해결해야 할까요?
#
# >**A.** 트랜잭션을 일괄적으로 커밋하도록 애플리케이션 수정
# **B.** Aurora DB 클러스터에 새 Aurora 복제본을 추가합니다.
# **C.** Redis용 Amazon ElastiCache 클러스터를 추가하고 쓰기 대상 애플리케이션을 변경합니다.
# **D.** Aurora DB 클러스터 스토리지를 프로비저닝된 IOPS(PIOPS)로 변경합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : A (100%)  <br>
# >이 대기는 시스템에서 커밋 활동의 비율이 매우 높을 때 가장 자주 발생합니다. 때때로 다음을 통해 이 대기를 완화할 수 있습니다. 트랜잭션을 일괄적으로 커밋하도록 애플리케이션을 수정합니다.<br>
# >대기 이벤트의 원인에 따라 다른 조치를 권장합니다. 1.- 리소스 모니터링 2.- CPU 확장 3.- 네트워크 대역폭 증가 4.- 커밋 수 줄이기<br>
# >
# >[IO:XactSync](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/apg-waits.xactsync.html)
# </div></details>
#
# **[Q#113. Q#057. Q#069.](https://www.examtopics.com/discussions/amazon/view/49004-exam-aws-certified-database-specialty-topic-1-question-113/)**
# Amazon DynamoDB는 전자 상거래 웹 사이트의 데이터 리포지토리로 사용됩니다. 밤에는 웹 사이트에 트래픽이 거의 또는 전혀 발생하지 않지만 대부분의 방문자는 낮에 방문합니다. 일일 수준에서 피크 시간 동안의 트래픽 증가는 안정적이고 예측 가능하지만 피크가 아닌 시간의 트래픽 증가보다 훨씬 더 클 수 있습니다.
# 초기에는 트래픽 패턴의 변동을 고려하지 않고 하루 평균 처리량을 기준으로 용량을 할당했습니다. 그러나 웹 사이트는 바쁜 시간 동안 크게 제한됩니다. 회사는 지출을 줄이는 동시에 스로틀링을 최소화하기를 원합니다.
#
# 데이터베이스 전문가는 이러한 요구 사항을 준수하기 위해 어떤 조치를 취해야 합니까?
#
# >**A.** 예약된 용량을 사용합니다. 피크 주간 처리량에 필요한 용량 수준으로 설정합니다.
# **B.** 프로비저닝된 용량을 사용합니다. 피크 주간 처리량에 필요한 용량 수준으로 설정합니다.
# **C.** 프로비저닝된 용량을 사용합니다. 사용량에 따라 용량을 업데이트하는 AWS Application Auto Scaling 정책을 생성합니다.
# **D.** 주문형 용량을 사용합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : C(100%)  <br>
# >- 피크 시간 동안 트래픽 증가는 꾸준하고 예측 가능합니다=> 프로비저닝 용량<br>
# >- 야간에는 사용하지 않음. => 일부 프로비저닝 + 목표 사용률 70% 세트로 자동 크기 조정<br>
# >패턴은 스파이크의 크기로 예측 가능한 로드이므로 자동 크기 조정으로 처리할 수 있습니다. aws에 따라 자동 확장은 온디맨드에 비해 비용을 절감합니다. 패턴이 예측할 수 없다면 온디맨드가 좋을 것입니다.<br>
# >Amazon DynamoDB Auto Scaling은 AWS Application Auto Scaling 서비스를 사용하여 프로비저닝된 처리 능력을 실제 트래픽 패턴에 따라 사용자 대신 동적으로 조정합니다. 따라서 테이블 또는 글로벌 보조 인덱스에 따라 할당된 읽기 및 쓰기 용량을 늘려 병목 현상 없이 갑작스러운 트래픽 증가를 처리할 수 있습니다. 워크로드가 감소할 경우 Application Auto Scaling은 사용하지 않는 프로비저닝된 용량에 대한 요금을 지불하지 않도록 처리량을 줄일 수 있습니다.
# >
# >[Amazon DynamoDB Auto Scaling: 모든 규모의 성능 및 비용 최적화](https://aws.amazon.com/ko/blogs/database/amazon-dynamodb-auto-scaling-performance-and-cost-optimization-at-any-scale/)<br>
# >[DynamoDB Auto Scaling을 사용하여 자동으로 처리량 용량 관리](https://docs.aws.amazon.com/ko_kr/amazondynamodb/latest/developerguide/AutoScaling.html)
# </div></details>
#
# **[Q#114. Q#002. Q#087.](https://www.examtopics.com/discussions/amazon/view/48817-exam-aws-certified-database-specialty-topic-1-question-114/)**
# 기업의 고객 관계 관리(CRM) 시스템은 Amazon RDS for PostgreSQL DB 인스턴스에서 호스팅됩니다. 새로운 규정 준수 규칙에 따라 데이터베이스는 유휴 상태에서 암호화되어야 합니다.
#
# 이러한 기준을 충족하는 조치는 무엇입니까?
#
# >**A.** DB 인스턴스의 수동 스냅샷의 암호화된 사본을 생성합니다. 암호화된 스냅샷에서 새 DB 인스턴스를 복원합니다.
# **B.** DB 인스턴스를 수정하고 암호화를 활성화합니다.
# **C.** 가장 최근의 자동 스냅샷에서 DB 인스턴스를 복원하고 암호화를 활성화합니다.
# **D.** DB 인스턴스의 암호화된 읽기 전용 복제본을 생성합니다. 읽기 전용 복제본을 독립 실행형 인스턴스로 승격합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : A(89%), D(11%)  <br>
# >Amazon RDS DB 인스턴스를 생성할 때만 암호화를 활성화할 수 있으며 DB 인스턴스 생성 후에는 활성화할 수 없음.<br>
# >그러나 암호화되지 않은 DB 인스턴스의 스냅샷을 생성한 다음 해당 스냅샷의 암호화된 복사본을 생성할 수 있음.<br>
# >그런 다음 암호화된 스냅샷에서 DB 인스턴스를 복원하여 원본 DB 인스턴스의 암호화된 복사본을 갖게 됨.
# >
# >[RDS 암호화](https://docs.aws.amazon.com/ko_kr/prescriptive-guidance/latest/patterns/encrypt-an-existing-amazon-rds-for-postgresql-db-instance.html)
# </div></details>
#
# **[Q#115. Q#074. Q#172.](https://www.examtopics.com/discussions/amazon/view/48820-exam-aws-certified-database-specialty-topic-1-question-115/)**
# 데이터베이스 전문가는 100GB 스토리지가 있는 프로덕션 Amazon RDS MariaDB 인스턴스가 스토리지 용량에 도달했다는 알림을 받았습니다. 데이터베이스 전문가는 이에 대응하여 데이터베이스 인스턴스를 변경하고 50GB의 저장 공간을 늘렸습니다. 3시간 후 동일한 데이터베이스 인스턴스에서 사용 가능한 용량이 부족하여 또 다른 경보가 트리거됩니다.
# 데이터베이스 전문가는 인스턴스를 즉시 변경하여 20GB의 저장 공간을 추가하기로 결정했습니다.
#
# 수정 사항을 제출하면 어떻게 됩니까?
#
# >**A.** 이 저장 용량이 너무 커서 요청이 실패합니다.
# **B.** 요청은 기본 인스턴스가 활성 상태인 경우에만 성공합니다.
# **C.** CPU 사용률이 10% 미만인 경우에만 요청이 성공합니다.
# **D.** 가장 최근의 수정 사항이 너무 빠르기 때문에 요청이 실패합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : D (100%)  <br>
# >인스턴스는 6시간 동안 더 이상 스토리지를 수정할 수 없습니다.<br>
# >6시간이 지나거나 "스토리지 최적화" 상태가 완료될 때까지 스토리지를 수정할 수 없습니다(이전 스토리지 용량이 증가한 후 인스턴스에 "스토리지 최적화"가 발생함을 표시합니다. 6시간 이상 걸릴 수 있음)<br>
# >
# >[Amazon RDS DB 인스턴스 스토리지 작업](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/USER_PIOPS.StorageTypes.html)
# </div></details>
#
# **[Q#116. Q#008. Q#134.](https://www.examtopics.com/discussions/amazon/view/49006-exam-aws-certified-database-specialty-topic-1-question-116/)**
# Amazon Aurora는 기업에서 안전한 금융 거래를 수행하는 데 사용됩니다. 컴플라이언스 규정을 준수하려면 저장 데이터와 전송 데이터를 항상 암호화해야 합니다.
#
# 이러한 요구 사항을 달성하기 위해 데이터베이스 전문가는 어떤 단계를 함께 수행해야 합니까? (2개를 선택하세요.)
#
# >**A.** AWS Key Management Service(AWS KMS)를 사용하여 암호화가 활성화된 Aurora 복제본을 생성합니다. 그런 다음 복제본을 마스터로 승격합니다.
# **B.** SSL/TLS를 사용하여 금융 애플리케이션과 Aurora DB 클러스터 간의 전송 중 연결을 보호합니다.
# **C.** 기존 Aurora DB 클러스터를 수정하고 AWS Key Management Service(AWS KMS) 암호화 키를 사용하여 암호화를 활성화합니다. 변경 사항을 즉시 적용하십시오.
# **D.** Aurora DB 클러스터의 스냅샷을 만들고 AWS Key Management Service(AWS KMS) 암호화 키를 사용하여 스냅샷을 암호화합니다. 스냅샷을 새 DB 클러스터로 복원하고 금융 애플리케이션 데이터베이스 엔드포인트를 업데이트합니다.
# **E.** AWS Key Management Service(AWS KMS)를 사용하여 금융 애플리케이션과 Aurora DB 클러스터 간의 전송 중 연결을 보호합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : BD(100%)  <br>
# >B. 애플리케이션에서 SSL(Secure Socket Layer) 또는 TLS(전송 계층 보안)를 사용하여 DB 클러스터에 대한 연결을 암호화할 수 있습니다. SSL/TLS 연결은 클라이언트와 DB 클러스터 사이에 전송되는 데이터를 암호화하여 하나의 보안 계층을 제공합니다.<br>
# >D. 암호화되지 않은 스냅샷을 암호화된 Aurora DB 클러스터로 복원할 수 있습니다. 이렇게 하려면 암호화되지 않은 스냅샷에서 복원할 때 KMS 키를 지정하십시오.<br>
# >
# >[Amazon Aurora 리소스 암호화](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/Overview.Encryption.html)
# >[SSL/TLS를 사용하여 DB 클러스터에 대한 연결 암호화](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/UsingWithRDS.SSL.html)
# </div></details>
#
# **[Q#117. Q#138. Q#104.](https://www.examtopics.com/discussions/amazon/view/49605-exam-aws-certified-database-specialty-topic-1-question-117/)**
# 비즈니스는 여러 가용 영역(AZ)에 분산된 Amazon EC2 인스턴스에서 웹 사이트를 호스팅합니다. 사이트는 1초마다 범용 SSD(gp2) 스토리지를 사용하여 MySQL용 Amazon RDS 다중 AZ DB 인스턴스에서 대량의 읽기 및 쓰기를 반복적으로 실행합니다. 광범위한 테스트 및 분석 후 데이터베이스 전문가는 데이터베이스 인스턴스가 높은 읽기 대기 시간과 높은 CPU 소비를 가지고 있음을 확인합니다.
#
# 프로그램을 변경할 필요 없이 이 문제를 해결하기 위해 데이터베이스 전문가는 어떤 기술을 사용해야 합니까?
#
# >**A.** 여러 RDS for MySQL 데이터베이스에 부하를 분산하기 위해 샤딩을 구현합니다.
# **B.** 프로비저닝된 IOPS(PIOPS) 스토리지와 함께 동일한 RDS for MySQL 인스턴스 클래스를 사용합니다.
# **C.** MySQL 읽기 전용 복제본용 RDS를 추가합니다.
# **D.** RDS for MySQL 데이터베이스 클래스를 더 큰 크기로 수정하고 프로비저닝된 IOPS(PIOPS)를 구현합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : D(100%)  <br>
# >x C. RDS for MySQL 읽기 전용 복제본을 추가합니다. (Read End Point를 사용하려면 프로그램 변경이 필요합니다.)<br>
# >o D. RDS for MySQL 데이터베이스 클래스를 더 큰 크기로 수정하고 프로비저닝된 IOPS(PIOPS)를 구현합니다. (높은 CPU + 코드 변경 없음)
# </div></details>
#
# **[Q#118. Q#007. Q#060.](https://www.examtopics.com/discussions/amazon/view/49010-exam-aws-certified-database-specialty-topic-1-question-118/)**
# 개념 증명 노력의 일환으로 금융 기관은 최근 MySQL DB 인스턴스용 Amazon RDS를 구축했습니다. 자동화된 데이터베이스 스냅샷은 데이터베이스 전문가에 의해 설정되었습니다. 데이터베이스 전문가는 정상적인 테스트 중 어느 날 자동 데이터베이스 스냅샷이 만들어지지 않은 것을 관찰했습니다.
#
# 다음 중 스냅샷이 없는 것에 대한 설명으로 옳지 않은 것은? (2개를 선택하세요.)
#
# >**A.** 이 DB 인스턴스에 대한 RDS 자동 스냅샷의 복사본이 동일한 AWS 리전 내에서 진행 중입니다.
# **B.** 이 DB 인스턴스에 대한 RDS 자동 스냅샷의 복사본이 다른 AWS 리전에서 진행 중입니다.
# **C.** RDS 유지 관리 기간이 구성되지 않았습니다.
# **D.** RDS DB 인스턴스가 STORAGE_FULL 상태입니다.
# **E.** RDS 이벤트 알림이 활성화되지 않았습니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : AD(86%), AC(14%)  <br>
# >A. 동일한 DB 인스턴스에 대해 동일한 AWS 리전에서 DB 스냅샷 복사본이 실행되는 동안에는 자동 백업이 발생하지 않습니다.<br>
# >D. 자동 백업이 실행되려면 DB 인스턴스가 AVAILABLE 상태여야 합니다. AVAILABLE 이 아닌 STORAGE_FULL 상태인 경우 자동 백업이 실행되지 않습니다.<br>
# >
# >[백업 작업](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/USER_WorkingWithAutomatedBackups.html)
# </div></details>
#
# **[Q#119. Q#022. Q#154.](https://www.examtopics.com/discussions/amazon/view/49005-exam-aws-certified-database-specialty-topic-1-question-119/)**
# 매일 온라인 쇼핑 회사는 많은 양의 쇼핑 요청을 받습니다. 결과적으로 회사의 Amazon RDS 데이터베이스는 지속적으로 부담을 느끼고 있습니다. 데이터베이스 전문가는 항상 데이터베이스의 가용성과 기능을 유지 관리할 책임이 있습니다. 데이터베이스 전문가는 데이터베이스 다운타임 또는 데이터베이스 구성 수정을 초래할 수 있는 문제에 대한 자동 경고 시스템을 원합니다.
#
# 이를 위해 데이터베이스 전문가는 무엇을 해야 합니까? (2개를 선택하세요.)
#
# >**A.** AWS CloudTrail에 기록된 모든 API 호출에 대해 Amazon SNS를 사용하여 알림을 보내도록 Amazon CloudWatch Events 이벤트를 생성합니다.
# **B.** RDS 이벤트 구독을 구독하고 Amazon SNS 주제를 사용하여 알림을 보내도록 구성합니다.
# **C.** Amazon SES를 사용하여 구성된 Amazon CloudWatch Events 이벤트를 기반으로 알림을 보냅니다.
# **D.** RDS 인스턴스용 FreeStorageSpace와 같은 다양한 지표에 대한 Amazon CloudWatch 경보를 구성합니다.
# **E.** AWS Trusted Advisor에 대한 이메일 알림을 활성화합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : BD(100%)  <br>
# >x A. 기록된 모든 API 호출에 대해 알림이 필요한 것은 아닙니다.<br>
# >o B. RDS 이벤트 구독을 구독하고 Amazon SNS 주제를 사용하여 알림을 보내도록 구성합니다.<br>
# >o D. RDS 인스턴스용 FreeStorageSpace와 같은 다양한 지표에 대한 Amazon CloudWatch 경보를 구성합니다.<br>
# >스토리지가 부족하면 서비스가 중단되어 다운타임이 발생합니다.
# >
# >[Amazon RDS 이벤트 알림 작업](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/USER_Events.html)<br>
# >[Amazon CloudWatch Events란?](https://docs.aws.amazon.com/ko_kr/AmazonCloudWatch/latest/events/WhatIsCloudWatchEvents.html)
# </div></details>
#
# **★★★[Q#120. Q#086. Q#015.](https://www.examtopics.com/discussions/amazon/view/49003-exam-aws-certified-database-specialty-topic-1-question-120/)**
# 주요 조직은 여러 Amazon DB 클러스터를 유지 관리합니다. 이러한 각 클러스터는 특정 요구 사항을 충족하도록 다르게 구성됩니다. 이러한 구성은 팀 및 사용 사례에 따라 더 넓은 그룹으로 분류될 수 있습니다.
# 데이터베이스 관리자는 이러한 설정을 저장하고 업데이트하는 프로세스를 간소화하려고 합니다. 또한 데이터베이스 관리자는 특정 구성 범주에 대한 변경 사항이 필요에 따라 모든 인스턴스에 자동으로 구현되도록 하려고 합니다.
#
# 이 목표를 자동화하고 달성하는 데 도움이 되는 AWS 서비스 또는 기능은 무엇입니까?
#
# >**A.** AWS 시스템 관리자 파라미터 스토어
# **B.** DB 파라미터 그룹
# **C.** AWS 구성
# **D.** AWS Secrets Manager
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : B(70%), A(30%)  <br>
# >o B. AWS에서 DB 구성은 DB 파라미터 그룹에 저장됩니다. <br>
# >x A. Parameter Store의 매개변수를 RDS의 인스턴스에 적용할 수 없음.<br>
# >B. Parameter store와 RDS는 함께 작동하지 않으므로 Parameter 그룹이 갈 길입니다. 파라미터 그룹은 RDS 전용입니다.<br>
# >DB 인스턴스 및 Aurora DB 클러스터를 파라미터 그룹과 연결하여 데이터베이스 구성을 관리합니다. Aurora는 기본 설정으로 파라미터 그룹을 정의합니다.<br>
# >
# >[파라미터 그룹 작업](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/USER_WorkingWithParamGroups.html)<br>
# >[AWS Systems Manager Parameter Store](https://docs.aws.amazon.com/ko_kr/systems-manager/latest/userguide/systems-manager-parameter-store.html)
# </div></details>

# %% [markdown]
# # 121

# %% [markdown]
# **[Q#121. Q#083. Q#133.](https://www.examtopics.com/discussions/amazon/view/49606-exam-aws-certified-database-specialty-topic-1-question-121/)**
# 회사에서 새로운 웹 애플리케이션을 개발 중입니다. AWS CloudFormation 템플릿은 빌드 프로세스의 일부로 생성되었습니다.
# 최근에 템플릿의 AWS::RDS::DBInstance 리소스가 변경되었습니다. 응용 프로그램이 국제 텍스트를 처리할 수 있도록 CharacterSetName 속성이 변경되었습니다. 업그레이드 중에 기존 DB 인스턴스를 교체해야 함을 나타내는 새 템플릿을 사용하여 변경 세트가 생성되었습니다.
# 스택 업그레이드 중 데이터 손실을 방지하기 위해 데이터베이스 전문가는 무엇을 해야 합니까?
#
# >**A.** DB 인스턴스의 스냅샷을 생성합니다. 템플릿을 수정하여 DB 스냅샷의 ID와 함께 DBSnapshotIdentifier 속성을 추가합니다. 스택을 업데이트합니다.
# **B.** aws cloudformation update-stack 명령과 set-stack-policy 명령을 사용하여 스택 정책을 수정한 후 DB 리소스를 보호합니다.
# **C.** DB 인스턴스의 스냅샷을 생성합니다. 스택을 업데이트합니다. 데이터베이스를 새 인스턴스로 복원합니다.
# **D.** DB 인스턴스를 사용하는 모든 애플리케이션을 비활성화합니다. DB 인스턴스의 스냅샷을 생성합니다. 템플릿을 수정하여 DB 스냅샷의 ID와 함께 DBSnapshotIdentifier 속성을 추가합니다. 스택을 업데이트하고 애플리케이션을 다시 활성화합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : D(100%)  <br>
# >DB 인스턴스를 사용하는 모든 애플리케이션을 비활성화합니다. -> DB 인스턴스의 스냅샷을 생성합니다. -> DBSnapshotIdentifier 속성을 DB 스냅샷의 ID로 추가하도록 템플릿을 수정합니다. -> 스택 업데이트 -> 애플리케이션을 다시 활성화합니다.<br>
# >데이터를 보존하려면 다음 절차를 수행하십시오. <br>
# >1. DB 인스턴스에서 활동이 없도록 DB 인스턴스를 사용하는 모든 애플리케이션을 비활성화합니다.<br>
# >2. DB 인스턴스의 스냅샷을 생성합니다. <br>
# >3. DB 스냅샷을 사용하여 인스턴스를 복원하려면 DB 인스턴스 변경 사항으로 업데이트된 템플릿을 수정하고 사용하려는 DB 스냅샷의 ID와 함께 DBSnapshotIdentifier 속성을 추가합니다.<br>
# >4. 스택을 업데이트합니다.<br>
# >
# >[AWS::RDS::DBInstance](https://docs.aws.amazon.com/ko_kr/AWSCloudFormation/latest/UserGuide/aws-properties-rds-database-instance.html)
# </div></details>
#
# **[Q#122. Q#013. Q#113.](https://www.examtopics.com/discussions/amazon/view/49607-exam-aws-certified-database-specialty-topic-1-question-122/)**
# 회사는 최근에 새로운 사업을 인수했습니다. 데이터베이스 전문가는 암호화되지 않은 12TB Amazon RDS for MySQL DB 인스턴스를 새 AWS 계정으로 마이그레이션해야 합니다. 데이터베이스 전문가는 데이터베이스를 마이그레이션하는 데 필요한 시간을 최소화해야 합니다.
# 어떤 솔루션이 이러한 요구 사항을 충족합니까?
#
# >**A.** 원본 계정에서 원본 DB 인스턴스의 스냅샷을 생성합니다. 대상 계정과 스냅샷을 공유합니다. 대상 계정의 스냅샷에서 DB 인스턴스를 생성합니다.
# **B.** AWS Resource Access Manager를 사용하여 원본 DB 인스턴스를 대상 계정과 공유합니다. 공유 리소스를 사용하여 대상 계정에 DB 인스턴스를 생성합니다.
# **C.** DB 인스턴스의 읽기 전용 복제본을 생성합니다. 대상 계정에 읽기 전용 복제본에 대한 액세스 권한을 부여합니다. 대상 계정에서 공유 읽기 전용 복제본의 스냅샷을 생성하고 MySQL DB 인스턴스용 새 RDS를 프로비저닝합니다.
# **D.** mysqldump를 사용하여 소스 데이터베이스를 백업합니다. 대상 계정에 RDS for MySQL DB 인스턴스를 생성합니다. mysql 명령을 사용하여 대상 데이터베이스에서 백업을 복원합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : A(100%)  <br>
# >스냅샷 생성 -> 대상 계정과 공유 -> 복사 -> 스냅샷에서 인스턴스 생성<br>
# >12T 데이터에 대한 mysqldump는 거의 불가능합니다. Mysqldump는 너무 느립니다.<br>
# >Resource Access Manager는 비Aurora 클러스터를 공유할 수 없습니다.<br>
# >
# >[DB 스냅샷 공유](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/USER_ShareSnapshot.html)
# </div></details>
#
# **★★★[Q#123. Q#126. Q#009.](https://www.examtopics.com/discussions/amazon/view/49014-exam-aws-certified-database-specialty-topic-1-question-123/)**
# 회사에 인터넷 연결이 없는 프라이빗 서브넷의 Amazon EC2 인스턴스에서 실행되는 애플리케이션이 있습니다. 회사에서 Amazon DynamoDB를 사용하는 새 애플리케이션을 배포했지만 애플리케이션이 DynamoDB 테이블에 연결할 수 없습니다. 개발자가 이미 모든 권한이 올바르게 설정되었는지 확인했습니다.
# 데이터베이스 전문가는 외부 리소스에 대한 액세스를 최소화하면서 이 문제를 해결하기 위해 무엇을 해야 합니까?
#
# >**A.** 서브넷의 라우팅 테이블에서 인터넷 게이트웨이에 대한 경로를 추가합니다.
# **B.** 서브넷의 라우팅 테이블에 NAT 게이트웨이에 대한 경로를 추가합니다.
# **C.** 포트 80 및 443에 대한 아웃바운드 규칙을 사용하여 EC2 인스턴스에 새 보안 그룹을 할당합니다.
# **D.** DynamoDB용 VPC 엔드포인트를 생성하고 서브넷의 라우팅 테이블에서 엔드포인트에 대한 경로를 추가합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : D (100%)  <br>
# >DynamoDB용 VPC 엔드포인트 생성 -> 서브넷의 라우팅 테이블에 이 엔드포인트를 추가합니다.<br>
# >
# >[Amazon VPC 엔드포인트를 사용하여 DynamoDB에 액세스](https://docs.aws.amazon.com/ko_kr/amazondynamodb/latest/developerguide/vpc-endpoints-dynamodb.html)
# </div></details>
#
# **[Q#124. Q#082. Q#079.](https://www.examtopics.com/discussions/amazon/view/48873-exam-aws-certified-database-specialty-topic-1-question-124/)**
# Amazon Aurora MySQL DB 인스턴스의 FreeLocalStorage에 대한 Amazon CloudWatch 지표는 로컬 스토리지 양이 10MB 미만임을 보여줍니다. 데이터베이스 엔지니어는 Aurora DB 인스턴스에서 사용 가능한 로컬 스토리지를 늘려야 합니다.
# 데이터베이스 엔지니어는 이 요구 사항을 어떻게 충족해야 합니까?
#
# >**A.** 더 많은 로컬 SSD 스토리지를 제공하는 인스턴스 클래스를 사용하도록 DB 인스턴스를 수정합니다.
# **B.** 자동 볼륨 크기 조정을 활성화하도록 Aurora DB 클러스터를 수정합니다.
# **C.** 데이터베이스 엔진 버전을 업그레이드하여 로컬 스토리지를 늘립니다.
# **D.** DB 인스턴스를 수정하고 구성 섹션에서 필요한 스토리지 볼륨을 구성합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : A (100%)  <br>
# >여기서 핵심은 로컬 스토리지입니다. 데이터베이스 저장소가 아닙니다.<br>
# >"사용 가능한 로컬 스토리지의 양입니다. 다른 DB 엔진과 달리 Aurora DB 인스턴스의 경우 이 지표는 각 DB 인스턴스에 사용 가능한 스토리지의 양을 보고합니다. 이 값은 DB 인스턴스 클래스에 따라 다릅니다(요금 정보는 Amazon RDS 제품 페이지 참조 ). 인스턴스에 대해 더 큰 DB 인스턴스 클래스를 선택하여 인스턴스의 여유 스토리지 공간을 늘릴 수 있습니다."<br>
# >저장 공간이 더 필요하면 로컬 스토리지 양을 늘릴 수 있습니다. 로컬 스토리지를 늘리려면 DB 인스턴스 클래스를 늘려야 합니다.<br>
# >
# >[Amazon Aurora에 대한 Amazon CloudWatch 지표](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/Aurora.AuroraMySQL.Monitoring.Metrics.html)<br>
# >[MySQL용 Aurora 호환 로컬 스토리지에 무엇이 저장되며, 로컬 스토리지 문제를 해결하려면 어떻게 해야 합니까?](https://aws.amazon.com/ko/premiumsupport/knowledge-center/aurora-mysql-local-storage/)
# </div></details>
#
# **[Q#125. Q#076. Q#090.](https://www.examtopics.com/discussions/amazon/view/48822-exam-aws-certified-database-specialty-topic-1-question-125/)**
# 회사에 Amazon RDS for MySQL DB 인스턴스가 있는 전자상거래 웹 애플리케이션이 있습니다. 마케팅 팀은 판매 목표에 영향을 미치는 웹사이트의 제품 및 가격 정보에 대한 예상치 못한 업데이트를 발견했습니다. 마케팅 팀은 데이터베이스 전문가가 향후 데이터베이스 활동을 감사하여 변경 방법과 시기를 식별하기를 원합니다.
# 데이터베이스 전문가는 이러한 요구 사항을 충족하기 위해 무엇을 해야 합니까? (2개를 선택하세요.)
#
# >**A.** 감사 이벤트 유형에 대한 RDS 이벤트 구독을 생성합니다.
# **B.** CONNECT 및 QUERY_DML 이벤트 감사를 활성화합니다.
# **C.** DB 인스턴스에 SSH로 연결하고 데이터베이스 로그를 검토합니다.
# **D.** Amazon CloudWatch Logs에 데이터베이스 로그를 게시합니다.
# **E.** DB 인스턴스에서 향상된 모니터링을 활성화합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : BD (100%)  <br>
# >x A : RDS 이벤트는 DML에 도움이 되지 않음, x C : RDS에 SSH 허용안됨., x E : 성능 모니터링 강화<br>
# >MARIADB_AUDIT_PLUGIN을 통해 감사 로깅을 활성화합니다. 그런 다음 rds 인스턴스를 수정하고 > 감사 로그를 내보내는 옵션을 선택하고 > Cloudwatch에 게시합니다.<br>
# >server_audit_events에서 CONNECT AND QUERY_DML 이벤트 감사를 활성화합니다.<br>
# >
# >[MySQL과 호환되는 Amazon Aurora 및 MySQL용 Amazon RDS에 대한 데이터베이스 활동을 캡처하도록 감사 로그 구성](https://aws.amazon.com/ko/blogs/database/configuring-an-audit-log-to-capture-database-activities-for-amazon-rds-for-mysql-and-amazon-aurora-with-mysql-compatibility/)
# </div></details>
#
# **[Q#126. Q#009. Q#102.](https://www.examtopics.com/discussions/amazon/view/49007-exam-aws-certified-database-specialty-topic-1-question-126/)**
# 대규모 게임 회사는 여러 온라인 게임에 대한 플레이어 세션 상태를 저장하는 중앙 집중식 솔루션을 만들고 있습니다. 워크로드에는 대기 시간이 짧은 키-값 스토리지가 필요했으며 읽기와 쓰기가 동일하게 혼합됩니다. 데이터는 게임의 지리적으로 분산된 사용자 기반에서 사용자와 가장 가까운 AWS 리전에 기록되어야 합니다. 아키텍처는 리전 간 데이터 복제를 관리하는 데 필요한 오버헤드를 최소화해야 합니다.
# 어떤 솔루션이 이러한 요구 사항을 충족합니까?
#
# >**A.** 다중 리전 읽기 전용 복제본이 있는 MySQL용 Amazon RDS
# **B.** Amazon Aurora 글로벌 데이터베이스
# **C.** GoldenGate가 있는 Oracle용 Amazon RDS
# **D.** Amazon DynamoDB 전역 테이블
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : D (100%)  <br>
# >대기 시간이 짧은 키-값 저장소입니다. DynamoDB 전역 테이블.<br>
# >
# >[Amazon DynamoDB](https://aws.amazon.com/ko/dynamodb/?nc1=h_ls%20D)
# </div></details>
#
# **[Q#127. Q#045. Q#101.](https://www.examtopics.com/discussions/amazon/view/48823-exam-aws-certified-database-specialty-topic-1-question-127/)**
# 회사는 웹 계층, 애플리케이션 계층 및 MySQL 데이터베이스 계층으로 구성된 온프레미스 애플리케이션을 실행하고 있습니다. 데이터베이스는 주로 업무 시간에 사용되며 하루 종일 무작위 활동이 최고조에 달합니다. 데이터베이스 전문가는 회사가 AWS로 마이그레이션하는 과정에서 가용성을 개선하고 MySQL 데이터베이스 계층 비용을 줄여야 합니다.
# 어떤 MySQL 데이터베이스 옵션이 이러한 요구 사항을 충족합니까?
#
# >**A.** 다중 AZ가 있는 MySQL용 Amazon RDS
# **B.** Amazon Aurora 서버리스 MySQL 클러스터
# **C.** Amazon Aurora MySQL 클러스터
# **D.** 읽기 전용 복제본이 있는 MySQL용 Amazon RDS
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : B(100%)  <br>
# >Aurora Serverless 두 가지 요구 사항은 비용과 가용성을 줄입니다. Aurora Serverless는 Aurora 클러스터에 비해 저렴합니다.<br>
# >x A : 최소한의 비용을 요구합니다. 다중 AZ는 말 그대로 단일 AZ 가격의 두 배인 매우 비쌉니다.<br>
# >Amazon Aurora Serverless v1은 간헐적이거나 예측할 수 없는 워크로드를 위한 간단하고 비용 효율적인 옵션입니다.<br>
# >
# >[Amazon Aurora Serverless](https://aws.amazon.com/ko/rds/aurora/serverless/)
# </div></details>
#
# **[Q#128. Q#176. Q#160.](https://www.examtopics.com/discussions/amazon/view/48824-exam-aws-certified-database-specialty-topic-1-question-128/)**
# 회사에서 Microsoft SQL Server Enterprise Edition 데이터베이스 인스턴스를 온프레미스에서 AWS로 마이그레이션하려고 합니다. 심층 검토가 수행되고 AWS Schema Conversion Tool(AWS SCT)은 SQL Server Enterprise Edition용 Amazon RDS, SQL Server
# Standard Edition용 Amazon RDS, Amazon Aurora MySQL 및 Amazon Aurora PostgreSQL에서 이 워크로드를 실행하기 위한 옵션을 제공합니다. 회사는 자체 SQL 서버 라이선스를 사용하기를 원하지 않으며 Microsoft SQL Server에서 변경하기를 원하지 않습니다.
# 가장 비용 효율적이고 운영 효율성이 높은 솔루션은 무엇입니까?
#
# >**A.** Amazon EC2에서 SQL Server Enterprise Edition을 실행합니다.
# **B.** Amazon RDS에서 SQL Server Standard Edition을 실행합니다.
# **C.** Amazon RDS에서 SQL Server Enterprise Edition을 실행합니다.
# **D.** Linux 호환성 라이브러리에서 SQL Server를 활용하여 Amazon Aurora MySQL을 실행합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : B(100%)  <br>
# >SCT 평가에 따르면 MSSQL Standard Edition을 사용할 수 있습니다. SQL Server를 계속 사용하기를 원하기 때문에 가장 저렴한 옵션이며 운영상 마이그레이션이 쉽습니다.<br>
# >OPERATIONALLY EFFECTIVE = RDS의 SQL Server 가장 비용 효율적인 = Standard Edition<br>
# >
# >[Microsoft SQL Server 데이터베이스를 엔터프라이즈 표준 버전으로 다운그레이드할 수 있는지 확인](https://docs.aws.amazon.com/ko_kr/prescriptive-guidance/latest/patterns/determine-whether-your-microsoft-sql-server-database-can-be-downgraded-from-enterprise-to-standard-edition.html)
# </div></details>
#
# **[Q#129. Q#065. Q#149.](https://www.examtopics.com/discussions/amazon/view/48874-exam-aws-certified-database-specialty-topic-1-question-129/)**
# 회사의 전자 상거래 웹 사이트는 구매 주문에 Amazon DynamoDB를 사용합니다. 각 주문은 고객 ID와 주문 ID로 구성됩니다. DynamoDB 테이블은 고객 ID를 파티션 키로 사용하고 주문 ID를 정렬 키로 사용합니다.
# 회사는 새로운 요구 사항을 충족하기 위해 Invoice ID라는 세 번째 속성을 사용하여 테이블을 쿼리하는 기능도 원합니다. 송장 ID를 사용하는 쿼리는 강력하게 일관성이 있어야 합니다. 데이터베이스 전문가는 이 기능을 최적의 성능과 최소한의 오버헤드로 제공해야 합니다.
# 데이터베이스 관리자는 이러한 요구 사항을 충족하기 위해 무엇을 해야 합니까?
#
# >**A.** 기존 테이블에 송장 ID에 대한 글로벌 보조 인덱스를 추가합니다.
# **B.** 기존 테이블에 인보이스 ID의 로컬 보조 인덱스를 추가합니다.
# **C.** 인보이스 ID에 로컬 보조 인덱스를 추가하면서 최신 스냅샷을 사용하여 테이블을 다시 만듭니다.
# **D.** 모든 쿼리에 대해 인보이스 ID에 대한 필터와 함께 파티션 키 및 FilterExpression 매개변수를 사용합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C (100%)  <br>
# >Invoice ID를 사용하는 쿼리는 매우 일관성이 있어야 함. => Dynamodb 테이블을 생성하는 동안에만 Local secondary index를 생성할 수 있으므로 테이블을 재생성해야 합니다. 글로벌 보조 인덱스는 최종 일관성만 제공<br>
# >로컬 보조 인덱스여야 합니다. - 보조 인덱스는 테이블이 생성될 때만 생성할 수 있습니다.<br>
# >아래 링크에 따르면 "강력한 일관성 읽기는 글로벌 보조 인덱스에서 지원되지 않습니다"<br>
# >
# >[일관성 읽기](https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/HowItWorks.ReadConsistency.html)
# </div></details>
#
# **★★★[Q#130. Q#046. Q#166.](https://www.examtopics.com/discussions/amazon/view/49707-exam-aws-certified-database-specialty-topic-1-question-130/)**
# 회사에서 온프레미스 MySQL 데이터베이스를 MySQL용 Amazon RDS로 마이그레이션하려고 합니다. 회사의 보안 정책을 준수하기 위해 모든 데이터베이스는 유휴 상태에서 암호화되어야 합니다. 또한 테스트 및 스테이징 환경을 프로비저닝하려면 RDS DB 인스턴스 스냅샷을 다양한 계정에서 공유해야 합니다.
# 어떤 솔루션이 이러한 요구 사항을 충족합니까?
#
# >**A.** AWS Key Management Service(AWS KMS) 고객 관리형 CMK를 사용하여 MySQL용 RDS DB 인스턴스를 생성합니다. 다른 AWS 계정의 Amazon 리소스 이름(ARN)을 보안 주체로 포함하도록 키 정책을 업데이트한 다음 kms:CreateGrant 작업을 허용합니다.
# **B.** AWS 관리형 CMK를 사용하여 MySQL용 RDS DB 인스턴스를 생성합니다. 다른 AWS 계정의 Amazon 리소스 이름(ARN)을 보안 주체로 포함하는 새 키 정책을 생성한 다음 kms:CreateGrant 작업을 허용합니다.
# **C.** AWS 소유 CMK를 사용하여 MySQL용 RDS DB 인스턴스를 생성합니다. 다른 AWS 계정의 관리자 사용자 이름을 보안 주체로 포함하는 새 키 정책을 생성한 다음 kms:CreateGrant 작업을 허용합니다.
# **D.** AWS CloudHSM 키로 RDS for MySQL DB 인스턴스를 생성합니다. 다른 AWS 계정의 Amazon 리소스 이름(ARN)을 보안 주체로 포함하도록 키 정책을 업데이트한 다음 kms:CreateGrant 작업을 허용합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : A (100%)  <br>
# >- 공유를 위해 고객 관리형 CMK가 필요함(Bx Cx),관리자(Cx) - AWS CloudHSM 키도 AWS에서 생성됨(Dx)<br>
# >- KMS 고객관리형 CMK, 다른 AWS 계정의 ARN을 보안 주체로 포함하도록 정책 업데이트 - CreateGrant 작업<br>
# >스냅샷을 공유한 AWS 계정의 기본 KMS 키를 사용하여 암호화된 스냅샷은 공유할 수 없으므로 고객 관리형 키로 암호화해야 합니다.<br>
# >다른 AWS 계정이 KMS 키에 액세스하도록 허용하려면 KMS 키에 대한 키 정책을 업데이트하십시오. KMS 키 정책에서 보안 주체로 공유하려는 AWS 계정의 Amazon 리소스 이름(ARN)으로 업데이트합니다. 그런 다음 kms:CreateGrant 작업을 허용합니다.<br>
# >
# >[DB 스냅샷 공유](https://docs.aws.amazon.com/AmazonRDS/latest/UserGuide/USER_ShareSnapshot.html)
# </div></details>

# %% [markdown]
# # 131

# %% [markdown]
# **[Q#131. Q#121. Q#083.](https://www.examtopics.com/discussions/amazon/view/49008-exam-aws-certified-database-specialty-topic-1-question-131/)**
# 한 소매 회사는 Amazon DynamoDB 테이블에 데이터를 저장하는 웹 애플리케이션을 관리합니다. 회사는 계정 통합 작업을 진행하고 있습니다. 데이터베이스 엔지니어는 DynamoDB 테이블을 현재 AWS 계정에서 새 AWS 계정으로 마이그레이션해야 합니다.
# 최소한의 관리 작업으로 이러한 요구 사항을 충족하는 전략은 무엇입니까?
#
# >**A.** AWS Glue를 사용하여 DynamoDB 테이블의 데이터를 크롤링합니다. 사용 가능한 청사진을 사용하여 작업을 생성하여 데이터를 Amazon S3로 내보냅니다. S3 파일의 데이터를 새 계정의 DynamoDB 테이블로 가져옵니다.
# **B.** 현재 계정의 DynamoDB 테이블 항목을 스캔하고 Amazon S3의 파일에 쓰는 AWS Lambda 함수를 생성합니다. 다른 Lambda 함수를 생성하여 S3 파일을 읽고 새 계정에서 DynamoDB 테이블 항목을 복원합니다.
# **C.** 현재 계정에서 AWS Data Pipeline을 사용하여 DynamoDB 테이블의 데이터를 Amazon S3의 파일로 내보냅니다. Data Pipeline을 사용하여 S3 파일의 데이터를 새 계정의 DynamoDB 테이블로 가져옵니다.
# **D.** 현재 계정의 DynamoDB 테이블에 대해 Amazon DynamoDB 스트림을 구성합니다. 스트림에서 읽고 Amazon S3의 파일에 쓰는 AWS Lambda 함수를 생성합니다. 다른 Lambda 함수를 생성하여 S3 파일을 읽고 항목을 새 계정의 DynamoDB 테이블로 복원합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : C(100%)  <br>
# >DynamoDB를 다른 계정의 S3로 내보내기 -> Glue 작업(또는 데이터 파이프라인 또는 EMR)을 사용하여 데이터 가져오기<br>
# >DynamoDB 테이블에서 데이터를 Amazon S3의 파일로 내보내려면 현재 계정의 AWS Data Pipeline을 사용합니다. Data Pipeline을 사용하여 S3 파일의 데이터를 새 계정의 DynamoDB 테이블로 가져옵니다.
# >최소 작업량에 따라 파이프라인 작업에 동의하지만 질문이 모호하다고 생각합니다.<br>
# >
# >[DynamoDB 테이블을 한 AWS 계정에서 다른 AWS 계정으로 마이그레이션](https://aws.amazon.com/ko/premiumsupport/knowledge-center/dynamodb-cross-account-migration/)
# </div></details>
#
# **[Q#132. Q#181. Q#047.](https://www.examtopics.com/discussions/amazon/view/49161-exam-aws-certified-database-specialty-topic-1-question-132/)**
# 회사는 다음 스키마를 사용하여 계약 시스템에 대해 us-east-1의 Amazon DynamoDB 테이블 contractDB를 사용합니다.
# - orderID (primary key)
# - timestamp (sort key)
# - contract (map)
# - createdBy (string)
# - customerEmail (string)
# 프로덕션 문제 이후 , 운영 팀은 데이터베이스 전문가에게 애플리케이션을 디버그하기 위해 데이터베이스에서 항목을 읽는 IAM 정책을 제공하도록 요청했습니다. 또한 개발자는 규정을 준수하기 위해 customerEmail 필드의 값에 액세스할 수 없습니다.
# 데이터베이스 전문가는 이러한 요구 사항을 달성하기 위해 어떤 IAM 정책을 사용해야 합니까?
#
# >**A.**
# ![image.png](attachment:image.png)
# **B.**
# ![image-2.png](attachment:image-2.png)
# **C.**
# ![image-3.png](attachment:image-3.png)
# **D.**
# ![image-4.png](attachment:image-4.png)
#
# ><details><summary>해설</summary><div markdown="1">
# >A: CustomerEmail을 제외한 모든 열에 액세스할 수 있습니다! <br>
# >IAM 조건 요소를 사용하여 세분화된 액세스 제어 정책을 구현합니다.<br>
# >
# >[세분화된 액세스 제어를 위한 IAM 정책 조건 사용](https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/specifying-conditions.html)
# </div></details>
#
# **[Q#133. Q#103. Q#132.](https://www.examtopics.com/discussions/amazon/view/49011-exam-aws-certified-database-specialty-topic-1-question-133/)**
# 회사에 Amazon DynamoDB 테이블을 사용하여 사용자 데이터를 저장하는 애플리케이션이 있습니다. 매일 아침 단일 스레드 프로세스가 DynamoDB API 스캔 작업을 호출하여 전체 테이블을 스캔하고 관리를 위한 중요한 하루 시작 보고서를 생성합니다. 성공적인 마케팅 캠페인은 최근 테이블에 있는 항목 수를 두 배로 늘렸고 이제 프로세스를 실행하는 데 너무 오래 걸리고 보고서가 제때 생성되지 않습니다.
# 데이터베이스 전문가는 프로세스의 성능을 개선해야 합니다. 데이터베이스 전문가는 프로세스가 실행 중일 때 테이블의 프로비저닝된 읽기 용량 단위(RCU)의 15%가 사용되고 있다고 말합니다.
# 데이터베이스 전문가는 무엇을 해야 합니까?
#
# >**A.** DynamoDB 테이블에 대해 Auto Scaling을 활성화합니다.
# **B.** 4개의 스레드와 병렬 DynamoDB API 스캔 작업을 사용합니다.
# **C.** 테이블의 프로비저닝된 RCU를 두 배로 늘립니다.
# **D.** API를 호출할 때마다 Limit 및 Offset 매개변수를 설정합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : B(100%)  <br>
# >15%는 최대 6개의 스레드가 가능함을 의미하고 4개는 양호함<br>
# >Scan의 처리량은 단일 파티션의 최대 처리량에 따라 제약을 받습니다. 이 문제를 해결하기 위해 Scan 작업에서는 테이블 또는 보조 인덱스를 여러 세그먼트로 논리적으로 나눠 여러 애플리케이션 작업자가 세그먼트를 병렬로 처리하도록 할 수 있습니다.<br>
# >
# >[병렬 스캔](https://docs.aws.amazon.com/ko_kr/amazondynamodb/latest/developerguide/Scan.html#Scan.ParallelScan)
# </div></details>
#
# **[Q#134. Q#078. Q#029.](https://www.examtopics.com/discussions/amazon/view/49017-exam-aws-certified-database-specialty-topic-1-question-134/)**
# 회사는 서비스 응용 프로그램으로 소프트웨어를 구축하고 있습니다.
# 새 사용자 로그온 워크플로의 일부로 Python 스크립트는 Amazon DynamoDB API 를 사용하여 CreateTable 작업을 호출합니다 . 호출이 반환된 후 스크립트는 PutItem 호출을 시도합니다.
# 경우에 따라 PutItem 요청이 ResourceNotFoundException 오류와 함께 실패하여 워크플로가 실패합니다. 개발팀은 두 API 호출에 동일한 테이블 이름이 사용되는 것을 확인했습니다.
# 데이터베이스 전문가는 이 문제를 어떻게 해결해야 합니까?
#
# >**A.** 테이블을 생성하는 애플리케이션에서 사용하는 역할에 연결된 정책에서 dynamodb:PutItem 작업에 대한 허용 문을 추가합니다.
# **B.** StreamSpecification 매개변수의 StreamEnabled 속성을 true로 설정한 다음 PutItem을 호출합니다.
# **C.** TableStatus가 ACTIVE가 될 때까지 주기적으로 DescribeTable을 호출하도록 애플리케이션을 변경한 다음 PutItem을 호출합니다.
# **D.** PutItem 요청에 ConditionExpression 매개변수를 추가합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : C(100%)  <br>
# >TableStatus는 ACTIVE여야 합니다.<br>
# >DescribeTable : 테이블의 현재 상태, 테이블이 생성된 시간, 기본 키 스키마 및 테이블의 모든 인덱스를 포함하여 테이블에 대한 정보를 반환합니다.<br>
# >
# >[DescribeTable](https://docs.aws.amazon.com/ko_kr/amazondynamodb/latest/APIReference/API_DescribeTable.html)<br>
# >[PutItem](https://docs.aws.amazon.com/ko_kr/amazondynamodb/latest/APIReference/API_PutItem.html)
# </div></details>
#
# **[Q#135. Q#110. Q#151.](https://www.examtopics.com/discussions/amazon/view/49012-exam-aws-certified-database-specialty-topic-1-question-135/)**
# 새로운 데이터 규정 준수 요구 사항을 충족하기 위해 회사는 중요한 데이터를 7년 동안 영구적으로 저장하고 쉽게 액세스할 수 있도록 유지해야 합니다. 1년 이상 된 데이터는 보관 데이터로 간주되며 매주 Amazon Aurora MySQL DB 클러스터에서 자동으로 이동해야 합니다. 평균적으로 매월 약 10GB의 새 데이터가 데이터베이스에 추가됩니다. 데이터베이스 전문가는 보관 데이터를 Amazon S3로 마이그레이션하기 위해 운영상 가장 효율적인 솔루션을 선택해야 합니다.
# 어떤 솔루션이 이러한 요구 사항을 충족합니까?
#
# >**A.** SQL 보기를 사용하여 DB 클러스터에서 Amazon S3로 아카이브 데이터를 내보낸 다음 DB 클러스터에서 아카이브 데이터를 삭제하는 사용자 지정 스크립트를 생성합니다. 주간 크론 작업으로 Amazon EC2 인스턴스를 시작하여 사용자 지정 스크립트를 실행합니다.
# **B.** SELECT INTO OUTFILE S3 문을 사용하여 DB 클러스터에서 Amazon S3로 보관 데이터를 내보낸 다음 DB 클러스터에서 보관 데이터를 삭제하는 AWS Lambda 함수를 구성합니다. Amazon EventBridge(Amazon CloudWatch Events)를 사용하여 매주 실행되도록 Lambda 함수를 예약합니다.
# **C.** 두 개의 AWS Lambda 함수를 구성합니다. 하나는 mysqldump 유틸리티를 사용하여 DB 클러스터에서 Amazon S3로 아카이브 데이터를 내보내고 다른 하나는 DB 클러스터에서 아카이브 데이터를 삭제합니다. Amazon EventBridge(Amazon CloudWatch Events)를 사용하여 두 Lambda 함수가 매주 실행되도록 예약합니다.
# **D.** AWS Database Migration Service(AWS DMS)를 사용하여 DB 클러스터에서 Amazon S3로 아카이브 데이터를 지속적으로 내보냅니다. DB 클러스터에서 보관 데이터를 삭제하기 위해 사용자 지정 SQL 스크립트를 실행하는 AWS Data Pipeline 프로세스를 매주 실행하도록 구성합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : B(100%)  <br>
# >SELECT INTO OUTFILE S3는 Aurora에서 사용할 수 있습니다. mysqldump는 S3에 직접 덤프할 수 없습니다.
# >Lambda 함수의 최대 실행 시간은 15분입니다. 매달 약 10GB의 새로운 데이터가 데이터베이스에 업로드 되므로 2.5GB의 주간 데이터 볼륨을 가정할 수 있습니다.<br>
# >따라서 내보내기 및 삭제가 15분 이내에 완료될 것이라고 가정하는 것이 합리적으로 보입니다.<br>
# >
# >[Amazon Aurora MySQL에서 Amazon S3로 데이터 내보내기 및 가져오기](https://aws.amazon.com/ko/blogs/database/best-practices-for-exporting-and-importing-data-from-amazon-aurora-mysql-to-amazon-s3/)
# </div></details>
#
# **[Q#136. Q#174. Q#004.](https://www.examtopics.com/discussions/amazon/view/48876-exam-aws-certified-database-specialty-topic-1-question-136/)**
# 한 회사는 Application Load Balancer 뒤의 Amazon EC2 인스턴스에 배포되는 새로운 애플리케이션을 개발했습니다. EC2 인스턴스는 sg-application-servers라는 보안 그룹을 사용합니다. 회사는 애플리케이션의 데이터를 저장할 데이터베이스가 필요하고 Amazon RDS for MySQL DB 인스턴스를 사용하기로 결정했습니다. DB 인스턴스는 프라이빗 DB 서브넷에 배포됩니다.
# DB 인스턴스 보안 그룹에 대해 가장 제한적인 구성은 무엇입니까?
#
# >**A.** 포트 3306의 sg-application-servers 보안 그룹에서 들어오는 트래픽만 허용합니다.
# **B.** 포트 443의 sg-application-servers 보안 그룹에서 들어오는 트래픽만 허용합니다.
# **C.** 포트 3306의 애플리케이션 서버 서브넷에서 들어오는 트래픽만 허용합니다.
# **D.** 포트 443의 애플리케이션 서버 서브넷에서 들어오는 트래픽만 허용합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : A(100%)  <br>
# >데이터베이스 포트 3306에 응답하고 전체 서브넷 대신 특정 서브넷만 허용하는 것이 좋습니다.<br>
# >가장 제한적인 접근 방식은 포트 3306에서 EC2 인스턴스의 SG로부터 들어오는 연결만 허용하는 것입니다.<br>
# >
# </div></details>
#
# **★★★[Q#137. Q#179. Q#155.](https://www.examtopics.com/discussions/amazon/view/48845-exam-aws-certified-database-specialty-topic-1-question-137/)**
# 한 회사는 사기 탐지 애플리케이션을 온프레미스에서 AWS 클라우드로 옮기고 데이터 저장을 위해 Amazon Neptune을 사용하고 있습니다. 이 회사는 1Gbps AWS Direct Connect 연결을 설정하여 25TB의 사기 탐지 데이터를 온프레미스 데이터 센터에서 Neptune DB 인스턴스로 마이그레이션했습니다. 회사에는 이미 Amazon S3 버킷과 S3 VPC 엔드포인트가 있으며 회사 네트워크 대역폭의 80%를 사용할 수 있습니다.
# 회사는 이 데이터 로드를 어떻게 수행해야 합니까?
#
# >**A.** 멀티파트 업로드와 함께 AWS SDK를 사용하여 온프레미스에서 S3 버킷으로 데이터를 전송합니다. Neptune용 Copy 명령을 사용하여 S3 버킷에서 Neptune DB 인스턴스로 데이터를 대량으로 이동합니다.
# **B.** AWS Database Migration Service(AWS DMS)를 사용하여 온프레미스에서 S3 버킷으로 데이터를 전송합니다. Neptune용 Loader 명령을 사용하여 S3 버킷에서 Neptune DB 인스턴스로 데이터를 대량으로 이동합니다.
# **C.** AWS DataSync를 사용하여 온프레미스에서 S3 버킷으로 데이터를 전송합니다. Neptune용 Loader 명령을 사용하여 S3 버킷에서 Neptune DB 인스턴스로 데이터를 대량으로 이동합니다.
# **D.** AWS CLI를 사용하여 온프레미스에서 S3 버킷으로 데이터를 전송합니다. Neptune용 Copy 명령을 사용하여 S3 버킷에서 Neptune DB 인스턴스로 데이터를 대량으로 이동합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : C(100%)  <br>
# >DMS는 DB를 Source로 할 수 있지만 DB가 언급되지 않았습니다.<br>
# >AWS DataSync는 온프레미스와 AWS 스토리지 서비스 간의 데이터 이동을 자동화하고 가속화하는 안전한 온라인 서비스입니다.<br>
# >S3에서 AWS Neptune으로 데이터를 로드하는 유일한 방법은 Loader를 사용하는 것입니다.<br>
# >
# >[Amazon Neptune 대량 로더를 사용하여 데이터 수집](https://docs.aws.amazon.com/ko_kr/neptune/latest/userguide/bulk-load.html)
# </div></details>
#
# **[Q#138. Q#104. Q#010.](https://www.examtopics.com/discussions/amazon/view/49013-exam-aws-certified-database-specialty-topic-1-question-138/)**
# 회사는 비즈니스 크리티컬 데이터베이스 워크로드 중 하나를 Amazon Aurora 다중 AZ DB 클러스터로 마이그레이션했습니다. 이 회사는 매우 낮은 RTO를 요구하며 데이터베이스 장애 조치 후 애플리케이션 복구 시간을 개선해야 합니다.
# 어떤 접근 방식이 이러한 요구 사항을 충족합니까?
#
# >**A.** 인스턴스 레벨 파라미터 그룹에서 max_connections 파라미터를 16,000으로 설정합니다.
# **B.** 클라이언트 연결 제한 시간을 300초로 수정합니다.
# **C.** Amazon RDS 프록시 데이터베이스 프록시를 생성하고 프록시 엔드포인트를 가리키도록 클라이언트 연결을 업데이트합니다.
# **D.** 인스턴스 수준에서 쿼리 캐시를 활성화합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : C(100%)  <br>
# >Amazon RDS 프록시를 사용하면 애플리케이션이 데이터베이스와 설정된 연결을 풀링하고 공유할 수 있으므로 데이터베이스 효율성과 애플리케이션 확장성이 향상됩니다. RDS Proxy를 사용하면 Aurora 및 RDS 데이터베이스의 장애 조치 시간이 최대 66%까지 단축되고 AWS Secrets Manager 및 AWS Identity and Access Management(IAM)와의 통합을 통해 데이터베이스 자격 증명, 인증 및 액세스를 관리할 수 있습니다.<br>
# >프록시는 장애 조치에 응답하는 클라이언트 연결 풀을 유지 관리하고 실제로 장애 조치 시간을 66% 향상시킵니다.<br>
# >
# >[Amazon RDS 프록시](https://aws.amazon.com/ko/rds/proxy/)
# </div></details>
#
# **[Q#139. Q#162. Q#006.](https://www.examtopics.com/discussions/amazon/view/48844-exam-aws-certified-database-specialty-topic-1-question-139/)**
# 회사에서 내부 애플리케이션에 Amazon RDS for MySQL DB 인스턴스를 사용하고 있습니다. 보안 감사 결과 DB 인스턴스가 미사용 시 암호화되지 않은 것으로 나타났습니다. 회사의 애플리케이션 팀은 DB 인스턴스를 암호화해야 합니다.
# 팀은 이 요구 사항을 충족하기 위해 무엇을 해야 합니까?
#
# >**A.** DB 인스턴스를 중지하고 암호화를 활성화하도록 수정합니다. 예약된 다음 RDS 유지 관리 기간을 기다리지 않고 즉시 이 설정을 적용합니다.
# **B.** DB 인스턴스를 중지하고 암호화된 스냅샷을 생성합니다. 암호화된 스냅샷을 암호화된 새 DB 인스턴스로 복원합니다. 원본 DB 인스턴스를 삭제하고 암호화된 새 DB 인스턴스를 가리키도록 애플리케이션을 업데이트합니다.
# **C.** DB 인스턴스를 중지하고 스냅샷을 생성합니다. 스냅샷을 다른 암호화된 스냅샷으로 복사합니다. 암호화된 스냅샷을 암호화된 새 DB 인스턴스로 복원합니다. 원본 DB 인스턴스를 삭제하고 암호화된 새 DB 인스턴스를 가리키도록 애플리케이션을 업데이트합니다.
# **D.** DB 인스턴스의 암호화된 읽기 전용 복제본을 생성합니다. 읽기 전용 복제본을 마스터로 승격합니다. 원본 DB 인스턴스를 삭제하고 암호화된 새 DB 인스턴스를 가리키도록 애플리케이션을 업데이트합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : C(100%)  <br>
# >스냅샷 복사 작업 중에만 암호화를 활성화할 수 있습니다.<br>
# >DB 인스턴스를 중지하고 스냅샷을 생성합니다. 스냅샷을 다른 암호화된 스냅샷으로 복사합니다. 암호화된 스냅샷을 암호화된 새 DB 인스턴스로 복원합니다. 원본 DB 인스턴스를 삭제하고 암호화된 새 DB 인스턴스를 가리키도록 애플리케이션을 업데이트합니다.
# >
# >[Amazon RDS 리소스 암호화](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/Overview.Encryption.html)
# </div></details>
#
# **[Q#140. Q#014. Q#067.](https://www.examtopics.com/discussions/amazon/view/48843-exam-aws-certified-database-specialty-topic-1-question-140/)**
# 데이터베이스 전문가는 재해 복구 전략의 일환으로 미션 크리티컬 워크로드에서 Amazon DynamoDB 테이블의 야간 백업을 생성해야 합니다.
# 데이터베이스 전문가는 관리 오버헤드를 최소화하기 위해 어떤 백업 방법을 사용해야 합니까?
#
# >**A.** Amazon EC2 인스턴스에 AWS CLI를 설치합니다. DynamoDB 테이블의 백업을 생성하는 CLI 명령을 작성합니다. 야간에 명령을 실행하는 예약된 작업 또는 작업을 만듭니다.
# **B.** DynamoDB 테이블의 백업을 생성하는 AWS Lambda 함수를 생성합니다. 야간에 Lambda 함수를 실행하는 Amazon CloudWatch Events 규칙을 생성합니다.
# **C.** AWS Backup을 사용하여 백업 계획을 생성하고 24시간마다 백업 빈도를 지정하고 계획에 야간 백업 창을 제공합니다.
# **D.** 24시간마다의 주문형 백업 빈도로 DynamoDB 백업 및 복원을 구성합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C (100%)  <br>
# >여기서 핵심 단어는 "최소 오버헤드"입니다. AWS Backup을 사용하면 이를 보장할 수 있습니다.<br>
# >C는 백업 서비스를 사용하고 있으므로 정확합니다. D옵션은 매뉴얼 백업만 가능합니다.<br>
# >
# >[AWS Backup을 사용하여 Amazon DynamoDB에 대한 예약 백업 설정](https://aws.amazon.com/ko/blogs/database/set-up-scheduled-backups-for-amazon-dynamodb-using-aws-backup/)
# </div></details>

# %% [markdown]
# # 141

# %% [markdown]
# **[Q#141. Q#053. Q#041.](https://www.examtopics.com/discussions/amazon/view/48842-exam-aws-certified-database-specialty-topic-1-question-141/)**
# 회사에서 개발을 위해 MySQL DB 인스턴스용 단일 AZ Amazon RDS를 사용하고 있습니다. 쿼리를 실행할 때 DB 인스턴스의 성능이 저하됩니다. Amazon CloudWatch 지표는 인스턴스에 더 많은 I/O 용량이 필요함을 나타냅니다.
# 이 문제를 해결하기 위해 데이터베이스 전문가가 수행할 수 있는 작업은 무엇입니까? (2개를 선택하세요.)
#
# >**A.** 쿼리를 실행하는 데 사용되는 응용 프로그램 도구를 다시 시작합니다.
# **B.** 처리량이 더 높은 데이터베이스 인스턴스 클래스로 변경합니다.
# **C.** 단일 AZ에서 다중 AZ로 변환합니다.
# **D.** Amazon RDS Enhanced Monitoring에서 I/O 파라미터를 늘립니다.
# **E.** 범용에서 프로비저닝된 IOPS(PIOPS)로 변환합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : BE (100%)  <br>
# >B. 더 큰 인스턴스 -> E. 충분한 IOPS 프로비저닝<br>
# >BE - 함께 올바르게 구성되지 않으면 하나가 다른 하나에 병목 현상을 일으킬 수 있으므로 처리량 및 IOPS를 모두 높여야 합니다.<br>
# >만약 당신이 지속적으로 16,000을 초과하는 IOPS 사용 패턴을 찾으면 DB 인스턴스를 수정하고 스토리지 유형을 gp2에서 io1로 변경해야 합니다.<br>
# >
# >[Amazon RDS 또는 Amazon EC2를 사용하여 호스팅된 데이터베이스에서 프로덕션 워크로드를 실행하기 위한 모범 스토리지 사례](https://aws.amazon.com/ko/blogs/database/best-storage-practices-for-running-production-workloads-on-hosted-databases-with-amazon-rds-or-amazon-ec2/)
# </div></details>
#
# **[Q#142. Q#023. Q#093.](https://www.examtopics.com/discussions/amazon/view/48841-exam-aws-certified-database-specialty-topic-1-question-142/)**
# 회사에 새로운 Amazon RDS for MySQL DB 인스턴스를 시작하는 데 사용되는 JSON으로 작성된 AWS CloudFormation 템플릿이 있습니다. 보안 팀은 템플릿을 사용하여 시작되는 모든 새 DB 인스턴스에 대해 마스터 암호가 30일마다 자동으로 교체되도록 데이터베이스 전문가에게 요청했습니다.
# 이러한 요구 사항을 충족하기 위해 운영상 가장 효율적인 솔루션은 무엇입니까?
#
# >**A.** Amazon S3 객체에 암호를 저장합니다. AWS KMS 키로 S3 객체를 암호화합니다. EnableKeyRotation 속성을 true로 설정하여 KMS 키가 30일마다 순환되도록 설정합니다. CloudFormation 사용자 지정 리소스를 사용하여 S3 객체를 읽어 비밀번호를 추출합니다.
# **B.** 보안 암호를 교체할 AWS Lambda 함수를 생성합니다. CloudFormation 템플릿을 수정하여 AWS::SecretsManager::RotationSchedule 리소스를 추가합니다. RotationLambdaARN 값을 구성하고 RotationRules 속성에 대해 AutomaticAfterDays 매개변수를 30으로 설정합니다.
# **C.** AWS KMS 키를 데이터베이스 암호로 사용하도록 CloudFormation 템플릿을 수정합니다. ScheduleExpression 파라미터를 ***/30***으로 설정하여 30일마다 키를 교체하도록 KMS API를 호출하도록 Amazon EventBridge 규칙을 구성합니다.
# **D.** Amazon RDS for MySQL DB 인스턴스를 AWS IAM과 통합하고 마스터 데이터베이스 사용자 암호를 중앙에서 관리합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : B(100%)  <br>
# >Secrete Manager -> 비밀을 교체하는 Lambda -> 교체 일정을 추가하도록 클라우드 구성 수정<br>
# >Secrets Manager가 포함된 Lambda는 완벽하게 작동합니다.<br>
# >
# >[AWS::SecretsManager::RotationSchedule](https://docs.aws.amazon.com/AWSCloudFormation/latest/UserGuide/aws-resource-secretsmanager-rotationschedule.html)
# </div></details>
#
# **★★★[Q#143. Q#184. Q#055.](https://www.examtopics.com/discussions/amazon/view/48840-exam-aws-certified-database-specialty-topic-1-question-143/)**
# 한 신생 기업이 사용자가 온프레미스 및 클라우드 네트워킹 구성 요소를 시각화할 수 있도록 하는 새로운 애플리케이션을 구축하고 있습니다. 회사는 수십억 개의 구성 요소가 저장될 것으로 예상하고 밀리초 내에 응답이 필요합니다. 애플리케이션은 다음을 식별할 수 있어야 합니다.
# ✑ 특정 구성 요소가 실패할 경우 영향을 받는 네트워크 및 경로.
# ✑ 네트워크 간에 중복 경로가 있는 네트워크.
# ✑ 네트워크 간에 중복 경로가 없는 네트워크.
# ✑ 두 네트워크 간의 가장 빠른 경로.
# 어떤 데이터베이스 엔진이 이러한 요구 사항을 충족합니까?
#
# >**A.** Amazon Aurora MySQL
# **B.** Amazon Neptune
# **C.** Redis용 Amazon ElastiCache
# **D.** Amazon DynamoDB
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : B(100%)  <br>
# >Amazon Neptune은 빠르고 안정적인 종합 관리형 그래프 데이터베이스 서비스로, 고도로 연결된 데이터 세트를 사용하는 애플리케이션을 쉽게 빌드하고 실행할 수 있습니다.<br>
# >Neptune 의 핵심은 특별한 용도의 고성능 그래프 데이터베이스 엔진입니다. 이 엔진은 수십억 개의 관계를 저장하고 밀리초 대기 시간으로 그래프를 쿼리하는 데 최적화되어 있습니다.<br>
# >
# >[Amazon Neptune Neptune이란 무엇입니까?](https://docs.aws.amazon.com/ko_kr/neptune/latest/userguide/intro.html)
# </div></details>
#
# **[Q#144. Q#066. Q#182.](https://www.examtopics.com/discussions/amazon/view/48839-exam-aws-certified-database-specialty-topic-1-question-144/)**
# 한 온라인 소매 회사는 초당 최대 5,000개의 주문 처리를 지원해야 하는 여러 날의 플래시 판매를 계획하고 있습니다. 주문 수량과 정확한 판매 일정은 매일 다릅니다. 판매 기간 동안 약 10,000명의 동시 사용자가 상품을 구매하기 전에 거래를 살펴봅니다. 판매 이외의 트래픽 볼륨은 매우 낮습니다. 읽기/쓰기 쿼리에 허용되는 성능은 25ms 미만이어야 합니다. 주문 항목의 크기는 약 2KB이며 고유 식별자가 있습니다. 이 회사는 자동으로 확장되고 가용성이 높은 가장 비용 효율적인 솔루션이 필요합니다.
# 어떤 솔루션이 이러한 요구 사항을 충족합니까?
#
# >**A.** 온디맨드 용량 모드가 있는 Amazon DynamoDB
# **B.** 하나의 라이터 노드와 병렬 쿼리 기능이 활성화된 Aurora 복제본이 있는 Amazon Aurora
# **C.** 5,000 WCU(쓰기 용량 단위) 및 10,000 RCU(읽기 용량 단위)가 있는 프로비저닝된 용량 모드의 Amazon DynamoDB
# **D.** 하나의 라이터 노드와 두 개의 교차 리전 Aurora 복제본이 있는 Amazon Aurora
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : A (100%)  <br>
# >초당 2KB로 5,000개 항목을 쓰는 경우 10,000 WCU와 5,000 RCU가 필요합니다<br>
# >C는 확장 가능하지 않고 비용 효율적이지 않습니다. 또한 10,000 WCU가 필요합니다.
# </div></details>
#
# **[Q#145. Q#033. Q#105.](https://www.examtopics.com/discussions/amazon/view/48838-exam-aws-certified-database-specialty-topic-1-question-145/)**
# 차량 호출 애플리케이션은 Amazon RDS for MySQL DB 인스턴스를 예약용 영구 스토리지로 사용합니다. 이 응용 프로그램은 매우 인기가 있으며 회사는 앞으로 몇 달 안에 사용자 기반이 10배 증가할 것으로 예상합니다. 애플리케이션은 아침과 저녁 시간에 더 많은 트래픽을 경험합니다.
# 이 응용 프로그램은 두 부분으로 구성되어 있습니다.
# - 사용자의 동시 요청에 직접적으로 대응하는 온라인 예약을 수락하는 사내 예약 구성 요소.
# - 고객 관리 담당자가 사용하는 타사 CRM(고객 관계 관리) 구성 요소. CRM은 쿼리를 사용하여 예약 데이터에 액세스합니다.
# 데이터베이스 전문가는 이 워크로드를 처리할 비용 효율적인 데이터베이스 솔루션을 설계해야 합니다.
#
# 어떤 솔루션이 이러한 요구 사항을 충족합니까?
#
# >**A.** Redis용 Amazon ElastiCache를 사용하여 예약을 수락합니다. AWS Lambda 함수를 연결하여 변경 사항을 캡처하고 CRM에서 사용하는 RDS for MySQL DB 인스턴스로 예약 데이터를 푸시합니다.
# **B.** Amazon DynamoDB를 사용하여 예약을 수락합니다. DynamoDB 스트림을 활성화하고 AWS Lambda 함수를 연결하여 변경 사항을 캡처하고 예약 데이터를 Amazon SQS 대기열로 푸시합니다. 그러면 Amazon SQS에서 데이터를 가져와 CRM에서 사용하는 RDS for MySQL DB 인스턴스에 쓰는 또 다른 Lambda 함수가 트리거됩니다.
# **C.** Redis용 Amazon ElastiCache를 사용하여 예약을 수락합니다. AWS Lambda 함수를 연결하여 변경 사항을 캡처하고 CRM에서 사용하는 Amazon Redshift 데이터베이스로 예약 데이터를 푸시합니다.
# **D.** Amazon DynamoDB를 사용하여 예약을 수락합니다. DynamoDB 스트림을 활성화하고 AWS Lambda 함수를 연결하여 변경 사항을 캡처하고 CRM에서 사용하는 Amazon Athena로 예약 데이터를 푸시합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : B (100%)  <br>
# >"변경 사항을 캡처하는 AWS Lambda 함수"에서 무엇에 대한 변경 사항을 캡처합니까? ElastiCache의 주요 용도는 자주 읽는 데이터를 캐시하는 것입니다. 또한 "회사는 사용자 기반이 10배 증가할 것으로 예상" 및 "사용자의 동시 요청에 해당" DynamoDB imo를 제안합니다. 우리는 이미 MySQL RDS를 가지고 있기 때문에 답변 B를 선호합니다.<br>
# >Amazon Athena는 표준 SQL을 사용하여 Amazon Simple Storage Service(Amazon S3)에서 직접 데이터를 쉽게 분석할 수 있는 대화형 쿼리 서비스입니다. S3에 저장된 데이터에 대한 서버리스 DB 쿼리 서비스입니다. 그 자체가 DB 스토리지가 아닙니다.<br>
# >Redis는 메모리 내 데이터 저장소이므로 예약 지속성에 적합하지 않습니다. A와 C가 틀립니다. - Athena는 데이터베이스가 아닌 대화형 쿼리 서비스입니다. D가 잘못되었습니다. CRM에는 MySQL의 데이터가 필요합니다.<br>
# >
# </div></details>
#
# **[Q#146. Q#112. Q#070.](https://www.examtopics.com/discussions/amazon/view/64693-exam-aws-certified-database-specialty-topic-1-question-146/)**
# 온라인 광고 웹 사이트는 온디맨드 용량 모드가 있는 Amazon DynamoDB 테이블을 데이터 저장소로 사용합니다. 또한 웹 사이트에는 웹 애플리케이션 서버와 동일한 VPC에 DynamoDB Accelerator(DAX) 클러스터가 있습니다. 애플리케이션은 DAX 클러스터를 쿼리하여 데이터 저장소에서 빈번하지 않은 쓰기와 많은 강력한 일관된 읽기를 수행해야 합니다.
# 성능 감사 중에 시스템 관리자는 응용 프로그램이 DAX 클러스터를 사용하여 항목을 조회할 수 있음을 확인합니다. 그러나 DAX 클러스터에 대한 QueryCacheHits 지표는 일관되게 0을 표시하는 반면 QueryCacheMisses 지표는 Amazon CloudWatch에서 계속해서 증가하고 있습니다.
# 이 발생의 가장 가능성 있는 이유는 무엇입니까?
#
# >**A.** DynamoDB에 액세스하기 위해 VPC 엔드포인트가 추가되지 않았습니다.
# **B.**  Strongly Consistent Read는 항상 DAX를 통해 DynamoDB로 전달됩니다.
# **C.** 트래픽 급증으로 인해 DynamoDB가 확장되어 성능이 저하됩니다.
# **D.** CloudWatch에 액세스하기 위해 VPC 엔드포인트가 추가되지 않았습니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : B(100%)  <br>
# >강력한 일관성 => Amazon DynamoDB Accelerator(DAX) 우회<br>
# >요청이 최종적으로 일관된 읽기(기본 동작)를 지정하면 DAX에서 항목 읽기를 시도합니다. DAX에 사용 가능한 항목이 있는 경우(캐시 적중) DAX는 DynamoDB에 액세스하지 않고 애플리케이션에 항목을 반환합니다. DAX에 사용 가능한 항목이 없는 경우(캐시 누락) DAX는 요청을 DynamoDB로 전달합니다. DynamoDB에서 응답을 받으면 DAX는 결과를 애플리케이션에 반환합니다. 그러나 기본 노드의 캐시에도 결과를 기록합니다.<br>
# >요청이 강력하게 일관된 읽기를 지정하는 경우 DAX는 요청을 DynamoDB로 전달합니다. DynamoDB의 결과는 DAX에 캐시되지 않습니다. 대신 애플리케이션에 단순히 반환됩니다.<br>
# >
# >[DAX: 작동 방식](https://docs.aws.amazon.com/ko_kr/amazondynamodb/latest/developerguide/DAX.concepts.html)
# </div></details>
#
# **[Q#147. Q#031. Q#089.](https://www.examtopics.com/discussions/amazon/view/64692-exam-aws-certified-database-specialty-topic-1-question-147/)**
# 금융 회사는 최근 포트폴리오 관리 솔루션을 출시했습니다. 애플리케이션의 백엔드는 MySQL과 호환되는 Amazon Aurora에 의해 구동됩니다.
# 회사는 5분의 RTO와 5분의 RPO를 요구합니다. 데이터베이스 전문가는 복제 지연을 최소화하면서 효율적인 재해 복구 솔루션을 구성해야 합니다.
# 데이터베이스 전문가는 이러한 요구 사항을 충족하기 위해 어떤 접근 방식을 취해야 합니까?
#
# >**A.** AWS Database Migration Service(AWS DMS)를 구성하고 다른 AWS 리전에 복제본을 생성합니다.
# **B.** Amazon Aurora 글로벌 데이터베이스를 구성하고 다른 AWS 리전을 추가합니다.
# **C.** binlog를 구성하고 다른 AWS 리전에 복제본을 생성합니다.
# **D.** 리전 간 읽기 전용 복제본을 구성합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : B(90%), C(10%)  <br>
# >Aurora 글로벌 테이블. (교차 리전 읽기 전용 복제본의 대안으로 Aurora 글로벌 데이터베이스를 사용하여 최소 지연 시간으로 읽기 작업을 확장할 수 있습니다.)<br>
# >5분 RTO 5분 RPO, Aurora GLOBAL RPO 1초 및 RTO 1분<br>
# >Amazon Aurora 글로벌 데이터베이스는 여러 AWS 리전에 걸쳐 있으므로 지연 시간이 짧은 글로벌 읽기가 가능하고 전체 AWS 리전에 영향을 미칠 수 있는 드문 중단으로부터 빠른 복구를 제공합니다.<br>
# >
# >[Amazon Aurora 글로벌 데이터베이스 사용](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/aurora-global-database.html)<br>
# >[Amazon Aurora MySQL 클러스터에 가장 적합한 재해 복구 옵션을 선택하는 방법](https://aws.amazon.com/ko/blogs/database/how-to-choose-the-best-disaster-recovery-option-for-your-amazon-aurora-mysql-cluster/)
# </div></details>
#
# **[Q#148. Q#044. Q#129.](https://www.examtopics.com/discussions/amazon/view/65860-exam-aws-certified-database-specialty-topic-1-question-148/)**
# 회사는 VPC_A의 Amazon EC2 인스턴스에서 실행되는 내부 파일 공유 애플리케이션을 호스팅합니다. 이 애플리케이션은 VPC_B에 있고 VPC_A와 피어링되는 Amazon ElastiCache 클러스터에 의해 지원됩니다. 회사는 애플리케이션 인스턴스를 VPC_A에서 VPC_B로 마이그레이션합니다. 로그는 파일 공유 애플리케이션이 더 이상 ElastiCache 클러스터에 연결할 수 없음을 나타냅니다.
# 데이터베이스 전문가는 이 문제를 해결하기 위해 무엇을 해야 합니까?
#
# >**A.** EC2 인스턴스에 두 번째 보안 그룹을 생성합니다. ElastiCache 클러스터 보안 그룹의 트래픽을 허용하는 아웃바운드 규칙을 추가합니다.
# **B.** ElastiCache 보안 그룹을 삭제합니다. EC2 인스턴스가 ElastiCache 클러스터에 연결할 수 있도록 인터페이스 VPC 엔드포인트를 추가합니다.
# **C.** ElastiCache 클러스터에서 VPC_B의 CIDR 블록으로 트래픽을 허용하는 아웃바운드 규칙을 추가하여 ElastiCache 보안 그룹을 수정합니다.
# **D.** EC2 인스턴스의 보안 그룹에서 ElastiCache 클러스터로의 트래픽을 허용하는 인바운드 규칙을 추가하여 ElastiCache 보안 그룹을 수정합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : D(100%)  <br>
# >피어링이 최선의 선택입니다<br>
# >피어링된 VPC의 보안 그룹을 참조하도록 VPC 보안 그룹의 인바운드 또는 아웃바운드 규칙을 업데이트할 수 있습니다. 그렇게 하면 피어링된 VPC의 참조 보안 그룹과 연결된 인스턴스 간에 트래픽을 주고받을 수 있습니다.<br>
# >
# >[피어 VPC 그룹을 참조하도록 보안 그룹 업데이트](https://docs.aws.amazon.com/ko_kr/vpc/latest/peering/vpc-peering-security-groups.html)
# </div></details>
#
# **★★★[Q#149. Q#152. Q#034.](https://www.examtopics.com/discussions/amazon/view/65970-exam-aws-certified-database-specialty-topic-1-question-149/)**
# 데이터베이스 전문가는 회사의 온프레미스 스토리지에서 Amazon Neptune 데이터베이스로 25GB의 데이터 파일을 로드해야 합니다.
# 데이터를 로드하는 어떤 접근 방식이 가장 빠릅니까?
#
# >**A.** 데이터를 Amazon S3에 업로드하고 Loader 명령을 사용하여 Amazon S3에서 Neptune 데이터베이스로 데이터를 로드합니다.
# **B.** 온프레미스 스토리지에서 데이터를 읽고 루프에서 INSERT 문을 실행하여 데이터를 Neptune 데이터베이스에 로드하는 유틸리티를 작성합니다.
# **C.** AWS CLI를 사용하여 온프레미스 스토리지에서 Neptune 데이터베이스로 직접 데이터를 로드합니다.
# **D.** AWS DataSync를 사용하여 온프레미스 스토리지에서 Neptune 데이터베이스로 직접 데이터를 로드합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : A(100%)  <br>
# >1. 데이터 파일을 Amazon Simple Storage Service(Amazon S3) 버킷에 복사합니다. <br>
# >2. 버킷에 대한 읽기 및 나열 액세스 권한이 있는 IAM 역할을 생성합니다. <br>
# >3. Amazon S3 VPC 엔드포인트를 생성합니다. <br>
# >4. HTTP를 통해 Neptune DB 인스턴스에 요청을 보내 Neptune 로더를 시작합니다. <br>
# >5. Neptune DB 인스턴스는 버킷에서 데이터를 로드하는 IAM 역할을 맡습니다.<br>
# >
# >[Amazon Neptune 대량 로더를 사용하여 데이터 수집](https://docs.aws.amazon.com/ko_kr/neptune/latest/userguide/bulk-load.html)
# </div></details>
#
# **[Q#150. Q#016. Q#019.](https://www.examtopics.com/discussions/amazon/view/65935-exam-aws-certified-database-specialty-topic-1-question-150/)**
# 금융 회사는 MySQL 데이터베이스 백업이 최근 90일 동안 사용 가능한지 확인해야 합니다.
# 모든 MySQL 데이터베이스는 Amazon RDS for MySQL DB 인스턴스 에서 호스팅됩니다 . 데이터베이스 전문가는 최소한의 개발 노력으로 백업 보존 요구 사항을 충족하는 솔루션을 구현해야 합니다.
# 데이터베이스 전문가는 어떤 접근 방식을 취해야 합니까?
#
# >**A.** AWS Backup을 사용하여 필요한 보존 기간 동안 백업 계획을 세웁니다. 백업 계획에 DB 인스턴스를 할당합니다.
# **B.** 자동 백업 옵션을 활성화하도록 DB 인스턴스를 수정합니다. 필요한 백업 보존 기간을 선택합니다.
# **C.** Amazon EC2 인스턴스에서 일일 크론 작업을 자동화하여 MySQL 덤프를 생성하고, Amazon S3로 전송하고, 보존 요구 사항을 충족하도록 S3 수명 주기 정책을 구현합니다.
# **D.** AWS Lambda를 사용하여 DB 인스턴스의 일일 수동 스냅샷을 예약합니다. 보존 요구 사항을 초과하는 스냅샷을 삭제합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : A(100%)  <br>
# >자동 백업에 대한 최대 한도는 35일입니다.<br>
# >DB 인스턴스를 생성할 때 백업 보존 기간을 설정할 수 있습니다.<br>
# >백업 보존 기간을 설정하지 않은 경우 Amazon RDS API 또는 AWS CLI를 사용하여 DB 인스턴스를 생성하는 경우 기본 백업 보존 기간은 1일입니다.<br>
# >콘솔을 사용하여 DB 인스턴스를 생성하는 경우 기본 백업 보존 기간은 7일입니다.<br>
# >DB 인스턴스를 생성한 후 백업 보존 기간을 수정할 수 있습니다. 백업 보존 기간은 0일에서 35일 사이로 설정할 수 있습니다.<br>
# >백업 보존 기간을 0으로 설정하면 자동 백업이 비활성화됩니다. 수동 스냅샷 제한(리전당 100개)은 자동 백업에 적용되지 않습니다. <br>
# >AWS Backup 서비스 + 보존 기간 설정<br>
# >
# >[백업 보존 기간](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/USER_WorkingWithAutomatedBackups.html#USER_WorkingWithAutomatedBackups.BackupRetention)
# </div></details>

# %% [markdown]
# # 151

# %% [markdown]
# **[Q#151. Q#180. Q#137.](https://www.examtopics.com/discussions/amazon/view/65971-exam-aws-certified-database-specialty-topic-1-question-151/)**
# 온라인 광고 회사는 Amazon DynamoDb 테이블을 데이터 저장소로 사용합니다. 테이블에는 Amazon DynamoDB 스트림이 활성화되어 있고 키 중 하나에 글로벌 보조 인덱스가 있습니다. 테이블은 AWS Key Management Service(AWS KMS) 고객 관리형 키를 사용하여 암호화됩니다.
# 이 회사는 운영을 전 세계로 확장하기로 결정했으며 DynamoDB 글로벌 테이블을 사용하여 다른 AWS 리전에 데이터베이스를 복제하려고 합니다.
# 검토 시 관리자는 다음을 확인합니다.
#
# - 계정에 dynamodb: CreateGlobalTable 권한이 있는 역할이 없습니다.
# - 복제를 원하는 새 Region에 동일한 이름의 빈 테이블이 존재합니다.
# - 복제를 원하는 새 리전에 파티션 키가 같지만 정렬 키가 다른 글로벌 보조 인덱스가 존재합니다.
#
# 새 리전에서 전역 테이블 또는 복제본을 생성하지 못하게 하는 설정은 무엇입니까? (2개를 선택하세요.)
#
# >**A.** 복제가 필요한 새 리전에 파티션 키가 같지만 정렬 키가 다른 글로벌 보조 인덱스가 있습니다.
# **B.** 복제를 원하는 지역에 동일한 이름의 빈 테이블이 존재합니다.
# **C.** 계정에 dynamodb:CreateGlobalTable 권한이 있는 역할이 없습니다.
# **D.** 테이블에 대해 DynamoDB 스트림이 활성화되었습니다.
# **E.** 테이블은 KMS 고객 관리 키를 사용하여 암호화됩니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : BC(50%), AC(33%), AB (17%)  <br>
# >BC가 정답입니다. A는 문제가 아닙니다. 정확히 동일한 이름과 인덱스를 가진 GSI와 원래 테이블과 다른 이름과 인덱스를 가진 GSI 두 개를 사용하여 대상 영역에 다른 테이블 이름을 만들어 테스트했습니다. GSI는 테이블에 따라 다릅니다. 키 제약 조건은 동일한 이름을 가진 테이블이 존재해서는 안 되며 액세스 권한이 있어야 한다는 것입니다.<br>
# >DynamoDB에서 전역 테이블을 생성 및 유지 관리하려면 dynamodb:CreateGlobalTable 액세스 권한이 있어야 합니다.<br>
# >콘솔에서 선택한 리전에 이름이 같은 테이블이 없는지 확인합니다. 동일한 이름의 테이블이 존재하는 경우 해당 리전에 새 복제본 테이블을 생성하기 전에 기존 테이블을 삭제해야 합니다.<br>
# >
# >[전역 테이블과 함께 IAM 사용](https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/gt_IAM.html)<br>
# >[전역 테이블 생성](https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/globaltables.tutorial.html)
# </div></details>
#
# **[Q#152. Q#034. Q#037.](https://www.examtopics.com/discussions/amazon/view/66017-exam-aws-certified-database-specialty-topic-1-question-152/)**
# 한 대형 자동차 회사가 중요한 금융 애플리케이션의 데이터베이스를 Amazon DynamoDB로 마이그레이션하고 있습니다. 회사의 위험 및 규정 준수 정책에 따라 데이터베이스의 모든 변경 사항은 감사를 위한 로그 항목으로 기록되어야 합니다. 시스템은 분당 500,000개 이상의 로그 항목을 예상하고 있습니다. 로그 항목은 Apache Parquet 형식의 각 파일에 최소 100,000개 레코드의 배치로 저장해야 합니다.
# 데이터베이스 전문가는 DynamoDB로 이러한 요구 사항을 어떻게 구현해야 합니까?
#
# >**A.** 테이블에서 Amazon DynamoDB 스트림을 활성화합니다. 스트림에 의해 트리거되는 AWS Lambda 함수를 생성합니다. Amazon S3 객체에 로그 항목을 씁니다.
# **B.** AWS Backup에서 백업 계획을 생성하여 DynamoDB 테이블을 하루에 한 번 백업합니다. 다른 테이블의 백업을 복원하고 두 테이블의 변경 사항을 비교하는 AWS Lambda 함수를 생성합니다. 로그 항목을 생성하고 Amazon S3 객체에 씁니다.
# **C.** 테이블에서 AWS CloudTrail 로그를 활성화합니다. 한 시간에 한 번씩 로그 파일을 읽고 DynamoDB API 작업을 필터링하는 AWS Lambda 함수를 생성합니다. 필터링된 로그 파일을 Amazon S3에 씁니다.
# **D.** 테이블에서 Amazon DynamoDB 스트림을 활성화합니다. 스트림에 의해 트리거되는 AWS Lambda 함수를 생성합니다. 버퍼링과 Amazon S3를 대상으로 사용하여 Amazon Kinesis Data Firehose 전송 스트림에 로그 항목을 씁니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : D (100%)  <br>
# >DynamoDB 스트림 -> Lambda 함수 -> 로그 항목 버퍼링이 있는 Kinesis Data Firehose 전송 스트림 -> S3<br>
# >Kinesis Data Firehose는 스트리밍 데이터를 데이터 레이크, 데이터 저장소 및 분석 서비스에 안정적으로 로드하는 데 도움이 됩니다. 스트리밍 데이터를 캡처, 변환 및 Amazon S3 및 기타 대상으로 전달할 수 있습니다. 데이터 처리량에 맞게 자동으로 확장되며 지속적인 관리가 필요하지 않은 완전 관리형 서비스입니다. 또한 로드하기 전에 데이터 스트림을 일괄 처리, 압축, 변환 및 암호화할 수 있으므로 사용되는 스토리지의 양이 최소화되고 보안이 향상됩니다.<br>
# >
# >[Amazon DynamoDB 데이터를 중앙 집중식 데이터 레이크로 스트리밍](https://aws.amazon.com/ko/blogs/big-data/streaming-amazon-dynamodb-data-into-a-centralized-data-lake/)
# </div></details>
#
# **[Q#153. Q#061. Q#080.](https://www.examtopics.com/discussions/amazon/view/66079-exam-aws-certified-database-specialty-topic-1-question-153/)**
# 한 회사가 북미에서 일일 활성 사용자가 천만 명으로 빠르게 성장한 모바일 게임을 출시했습니다. 게임의 백엔드는 AWS에서 호스팅되며 TTL 속성으로 구성된 Amazon DynamoDB 테이블을 광범위하게 사용합니다.
# 항목이 추가되거나 업데이트되면 해당 TTL은 현재 에포크 시간에 600초를 더한 값으로 설정됩니다. 게임 로직은 보상 포인트를 정확하게 계산할 수 있도록 삭제되는 오래된 데이터에 의존합니다. 경우에 따라 TTL 만료 몇 시간이 지난 테이블에서 항목을 읽습니다.
# 데이터베이스 전문가는 이 문제를 어떻게 해결해야 합니까?
#
# >**A.** DynamoDB용 TTL 기능을 지원하는 클라이언트 라이브러리를 사용하십시오.
# **B.** 만료된 TTL이 있는 항목을 무시하는 쿼리 필터 표현식을 포함합니다.
# **C.** 테이블을 쿼리할 때 ConsistentRead 매개변수를 true로 설정합니다.
# **D.** TTL 속성에 로컬 보조 인덱스를 만듭니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : B (100%)  <br>
# >만료되었지만 아직 TTL에 의해 삭제되지 않은 항목은 읽기, 쿼리 및 스캔에 계속 표시됩니다. 결과 집합에서 만료된 항목을 원하지 않으면 항목을 필터링해야 합니다. 이렇게 하려면 TTL 만료 값이 epoch 형식의 현재 시간보다 큰 항목만 반환하는 필터 식을 사용합니다.<br>
# >
# >[작동 방식: DynamoDB TTL(Time to Live)](https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/howitworks-ttl.html)
# </div></details>
#
# **★★★[Q#154. Q#159. Q#119.](https://www.examtopics.com/discussions/amazon/view/66501-exam-aws-certified-database-specialty-topic-1-question-154/)**
# 국제 게임 회사의 개발 팀은 3개의 모바일 게임에 대한 게임 내 이벤트를 저장하기 위해 Amazon DynamoDB를 실험하고 있습니다. 가장 인기 있는 게임은 최대 500,000명의 동시 사용자를 호스팅하고 가장 인기가 적은 게임은 최대 10,000명의 동시 사용자를 호스팅합니다. 이벤트의 평균 크기는 20KB이고 평균 사용자 세션은 초당 하나의 이벤트를 생성합니다. 각 이벤트는 밀리초 단위의 시간과 글로벌 고유 식별자로 태그가 지정됩니다.
# 수석 개발자는 다음 스키마를 사용하여 이벤트에 대해 단일 DynamoDB 테이블을 생성했습니다.
#
# - Partition key: game name
# - Sort key: event identifier
# - Local secondary index: player identifier
# - Event time
#
# 테스트는 소규모 개발 환경에서 성공적이었습니다. 그러나 프로덕션에 배포하면 새 이벤트가 테이블에 추가되지 않고 로그에 ItemCollectionSizeLimitExceededException 오류 코드와 함께 DynamoDB 오류가 표시됩니다.
# 데이터베이스 전문가가 개발 팀에 권장해야 하는 설계 변경 사항은 무엇입니까?
#
# >**A.** 플레이어 식별자를 파티션 키로 사용합니다. 이벤트 시간을 정렬 키로 사용하십시오. 게임 이름을 파티션 키로, 이벤트 시간을 정렬 키로 사용하여 글로벌 보조 인덱스를 추가합니다.
# **B.** 두 개의 테이블을 만듭니다. 두 테이블에서 게임 이름을 파티션 키로 사용하십시오. 이벤트 시간을 첫 번째 테이블의 정렬 키로 사용하십시오. 플레이어 식별자를 두 번째 테이블의 정렬 키로 사용하십시오.
# **C.** 정렬 키를 이벤트 시간과 대조되는 플레이어 식별자로 구성된 복합 값으로 교체하고 대시로 구분합니다. 플레이어 식별자를 정렬 키로 사용하여 로컬 보조 인덱스를 추가합니다.
# **D.** 각 게임에 대해 하나의 테이블을 만듭니다. 플레이어 식별자를 파티션 키로 사용하십시오. 이벤트 시간을 정렬 키로 사용하십시오.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : D(73%), A (27%)
# >항목 컬렉션의 총 크기가 최대 한도인 10GB를 초과했습니다. 이 예외는 하나 이상의 로컬 보조 인덱스가 있는 테이블에 대해서만 반환됩니다.<br>
# >ItemCollectionSizeLimitExceededException 메시지: 컬렉션 크기를 초과했습니다. 로컬 보조 인덱스가 있는 테이블의 경우 파티션 키 값이 동일한 항목 그룹이 최대 크기 제한인 10GB를 초과했습니다.<br>
# >파티션의 데이터가 너무 많으면 LocalSecondaryIndex에 문제가 발생합니다. 하나의 game_id에는 이벤트당 20K 데이터가 있는 500K 사용자가 있습니다 = 10GB/event<br>
# >솔루션은 player_id를 파티션으로 하는 각 게임별 별도의 테이블입니다. 각 테이블에는 최대 500,000개의 파티션을 가지게 됩니다.<br>
# >각 파티션은 시간당 3600개의 이벤트 * 20KB/events = 72MB 이므로 10GB/72MB = 13시간 데이터를 저장할 수 있습니다.<br>
# >옵션 D의 경우 13시간보다 작게 TTL 설정을 하면 ItemCollectionSizeLimitExceededException 발생을 피할 수 있습니다.<br>
# >
# >[DynamoDB를 사용한 오류 처리](https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/Programming.Errors.html)<br>
# >[클래스: Aws::DynamoDB::Types::ItemCollectionSizeLimitExceededException](https://docs.aws.amazon.com/sdk-for-ruby/v3/api/Aws/DynamoDB/Types/ItemCollectionSizeLimitExceededException.html)
# </div></details>
#
# **[Q#155. Q#096. Q#062.](https://www.examtopics.com/discussions/amazon/view/65689-exam-aws-certified-database-specialty-topic-1-question-155/)**
# 전자 상거래 회사는 최근 SQL Server 데이터베이스 중 하나를 SQL Server Enterprise Edition DB 인스턴스용 Amazon RDS로 마이그레이션했습니다. 회사는 다가오는 판매로 인해 읽기 트래픽이 급증할 것으로 예상합니다. 데이터베이스 전문가는 예상되는 읽기 트래픽을 처리하기 위해 DB 인스턴스의 읽기 전용 복제본을 생성해야 합니다.
# 데이터베이스 전문가는 읽기 전용 복제본을 생성하기 전에 어떤 조치를 취해야 합니까? (2개를 선택하세요.)
#
# >**A.** 잠재적인 다운타임 창을 식별하고 소스 DB 인스턴스에 대한 애플리케이션 호출을 중지합니다.
# **B.** 원본 DB 인스턴스에 대해 자동 백업이 활성화되어 있는지 확인합니다.
# **C.** 원본 DB 인스턴스가 Always ON 가용성 그룹이 있는 다중 AZ 배포인지 확인합니다.
# **D.** 원본 DB 인스턴스가 SQL Server 데이터베이스 미러링(DBM)을 사용하는 다중 AZ 배포인지 확인합니다.
# **E.** 읽기 전용 복제본 파라미터 그룹 설정을 수정하고 값을 1로 설정합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : BC(100%)  <br>
# >DB 인스턴스가 복제를 위한 원본 인스턴스 역할을 하려면 원본 DB 인스턴스에서 자동 백업을 활성화해야 합니다.<br>
# >원본 DB 인스턴스는 Always ON AG(가용성 그룹)가 있는 다중 AZ 배포여야 합니다. 이 유형의 배포를 설정하면 자동 백업도 활성화됩니다.<br>
# >
# >[Amazon RDS에서 Microsoft SQL Server용 읽기 전용 복제본 작업](https://docs.aws.amazon.com/AmazonRDS/latest/UserGuide/SQLServer.ReadReplicas.html)
# </div></details>
#
# **[Q#156. Q#043. Q#164.](https://www.examtopics.com/discussions/amazon/view/66370-exam-aws-certified-database-specialty-topic-1-question-156/)**
# 회사는 하나의 AWS 계정에서 2계층 전자상거래 애플리케이션을 실행하고 있습니다. 애플리케이션은 Amazon RDS for MySQL 다중 AZ DB 인스턴스에서 지원됩니다. 개발자가 실수로 프로덕션 환경에서 DB 인스턴스를 삭제했습니다. 회사는 데이터베이스를 복원하지만 이 이벤트로 인해 몇 시간의 가동 중지 시간과 수익 손실이 발생합니다.
# 미래에 이러한 실수가 발생할 위험을 최소화하는 변경 조합은 무엇입니까? (3개를 선택하세요.)
#
# >**A.** 그룹, IAM 사용자 및 역할에 최소 권한을 부여합니다.
# **B.** 모든 사용자가 백업에서 데이터베이스를 복원할 수 있습니다.
# **C.** 기존 프로덕션 DB 인스턴스에서 삭제 방지를 활성화합니다.
# **D.** ACL 정책을 사용하여 사용자의 DB 인스턴스 삭제를 제한합니다.
# **E.** AWS CloudTrail 로깅 및 향상된 모니터링을 활성화합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : ACD(86%), (14%)  <br>
# >최소 개인 정보 삭제 보호 액세스 제어<br>
# >ACL은 S3에서만 사용됩니다. AC는 절대적으로 정확하지만 질문에 결함이 있는 것 같습니다. Enhanced Monitoring은 개발자가 인스턴스를 삭제하는 데 도움이 되지 않습니다.<br>
# >ACL이 아닌 IAM이 있는 AC D<br>
# >ACL 정책을 사용하여 사용자를 제한할 수 없습니다. IAM 정책만 사용하여 사용자를 제한할 수 있습니다.<br>
# </div></details>
#
# **[Q#157. Q#011. Q#081.](https://www.examtopics.com/discussions/amazon/view/65738-exam-aws-certified-database-specialty-topic-1-question-157/)**
# 금융 서비스 회사는 TDE(투명한 데이터 암호화)와 함께 Oracle용 Amazon RDS를 사용합니다. 회사는 항상 미사용 데이터를 암호화해야 합니다. 데이터를 해독하는 데 필요한 키는 가용성이 높아야 하며 키에 대한 액세스가 제한되어야 합니다. 규제 요구 사항에 따라 회사는 필요에 따라 암호화 키를 교체할 수 있는 기능이 있어야 합니다. 회사는 잠재적인 보안 침해가 발견될 경우 키를 사용할 수 없게 만들 수 있어야 합니다. 회사는 또한 최소한의 오버헤드로 이러한 작업을 수행해야 합니다.
# 데이터베이스 관리자는 이러한 요구 사항을 충족하도록 암호화를 설정하기 위해 무엇을 사용해야 합니까?
#
# >**A.** AWS CloudHSM
# **B.** AWS 관리형 키가 있는 AWS Key Management Service(AWS KMS)
# **C.** 서버 측 암호화를 사용하는 AWS Key Management Service(AWS KMS)
# **D.** 고객 제공 자료가 포함된 AWS Key Management Service(AWS KMS) CMK
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : D (100%)  <br>
# >키 회전 ✓ 키 삭제 ✓ 최소한의 오버헤드 ✓<br>
# >Ax: Amazon RDS의 Oracle 인스턴스를 사용하여 AWS CloudHSM과 통합할 수 없습니다. Amazon EC2 인스턴스에 Oracle Database를 설치해야 합니다. hardware security module (HSM)<br>
# >D: "요청 시 암호화 키 회전" CMK만이 그렇게 할 수 있습니다. AWS 관리형 키는 1년마다 자동으로 교체되며 조직에서는 변경할 수 없습니다.
# >
# >[Amazon RDS 리소스 암호화](https://docs.aws.amazon.com/AmazonRDS/latest/UserGuide/Overview.Encryption.html)<br>
# >[AWS CloudHSM을 사용한 Oracle 데이터베이스 TDE(투명한 데이터 암호화)](https://docs.aws.amazon.com/cloudhsm/latest/userguide/oracle-tde.html)
# </div></details>
#
# **★★★[Q#158. Q#073. Q#144.](https://www.examtopics.com/discussions/amazon/view/66993-exam-aws-certified-database-specialty-topic-1-question-158/)**
# 회사에서 SQL Server DB 인스턴스용 새 Amazon RDS를 설정하고 있습니다. 회사는 데이터베이스에 대한 SQL Server 감사를 활성화하려고 합니다.
# 데이터베이스 전문가는 이 요구 사항을 충족하기 위해 어떤 단계 조합을 취해야 합니까? (2개를 선택하세요.)
#
# >**A.** Amazon RDS가 Amazon S3에 감사 로그를 저장할 수 있는 권한을 부여하는 Amazon RDS에 대한 서비스 연결 역할을 생성합니다.
# **B.** 파라미터 그룹을 설정하여 감사 로그 저장을 위한 IAM 역할과 Amazon S3 버킷을 구성합니다. 파라미터 그룹을 DB 인스턴스와 연결합니다.
# **C.** DB 인스턴스에서 다중 AZ를 비활성화한 다음 감사를 활성화합니다. 감사가 활성화된 후 다중 AZ를 활성화합니다.
# **D.** DB 인스턴스에서 자동 백업을 비활성화한 다음 감사를 활성화합니다. 감사가 활성화된 후 자동 백업을 활성화합니다.
# **E.** 옵션 그룹을 설정하여 감사 로그 저장을 위한 IAM 역할과 Amazon S3 버킷을 구성합니다. 옵션 그룹을 DB 인스턴스와 연결합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : AE(100%)  <br>
# >Amazon RDS 서비스가 Amazon S3 버킷을 사용할 수 있도록 IAM 역할을 생성하고 권한을 위임합니다.<br>
# >RDS는 사용자가 제공한 IAM 역할을 사용하여 완료된 감사 로그를 S3 버킷에 업로드합니다. 보존을 활성화하면 RDS는 구성된 기간 동안 DB 인스턴스에 감사 로그를 보관합니다.<br>
# >A. S3에 감사 로그를 저장할 수 있는 권한을 RDS에 부여하는 서비스 연결 역할 생성.<br>
# >SQL Server Audit 옵션을 추가한 후 옵션 그룹이 활성화되면 S3 버킷에 감사를 생성하고 감사 로그를 저장할 수 있습니다.<br>
# >
# >[SQL Server Audit](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/Appendix.SQLServer.Options.Audit.html)<br>
# >[Amazon RDS에서 IAM을 사용하는 방법](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/security_iam_service-with-iam.html)
# </div></details>
#
# **★★★[Q#159. Q#119. Q#022.](https://www.examtopics.com/discussions/amazon/view/67696-exam-aws-certified-database-specialty-topic-1-question-159/)**
# 데이터베이스 전문가가 AWS CloudFormation 스택을 생성하고 있습니다. 데이터베이스 전문가는 스택에서 Amazon RDS ProductionDatabase 리소스가 실수로 삭제되는 것을 방지하려고 합니다.
# 이 요구 사항을 충족하는 솔루션은 무엇입니까?
#
# >**A.** 업데이트를 방지하는 스택 정책을 만듭니다. 정책에 "Effect": "ProductionDatabase" 및 "Resource": "Deny"를 포함합니다.
# **B.** XML 형식으로 AWS CloudFormation 스택을 생성합니다. xAttribute를 false로 설정합니다.
# **C.** DeletionPolicy 속성 없이 RDS DB 인스턴스를 생성합니다. 종료 보호를 비활성화합니다.
# **D.** 업데이트를 방지하는 스택 정책을 만듭니다. 정책에 "Effect": "Deny" 및 "Resource": "ProductionDatabase"를 포함합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : D(100%)  <br>
# >스택 정책을 설정하면 기본적으로 모든 리소스가 보호됩니다. 모든 리소스에 대한 업데이트를 허용하려면 모든 리소스에 대한 모든 작업을 허용하는 Allow 문을 추가합니다. Allow 문은 모든 리소스를 지정하지만 명시적 Deny 문은 ProductionDatabase 논리 ID가 있는 리소스에 대해 이를 재정의합니다. 이 Deny 문은 교체 또는 ProductionDatabase 리소스에서 삭제합니다.<br>
# >
# >```
# >{
# >  "Statement" : [
# >    {
# >      "Effect" : "Allow",
# >      "Action" : "Update:*",
# >      "Principal": "*",
# >      "Resource" : "*"
# >    },
# >    {
# >      "Effect" : "Deny",
# >      "Action" : "Update:*",
# >      "Principal": "*",
# >      "Resource" : "LogicalResourceId/ProductionDatabase"
# >    }
# >  ]
# >}
# >```
# >
# >
# >[스택 리소스에 대한 업데이트 방지](https://docs.aws.amazon.com/ko_kr/AWSCloudFormation/latest/UserGuide/protect-stack-resources.html)
# </div></details>
#
# **[Q#160. Q#051. Q#003.](https://www.examtopics.com/discussions/amazon/view/65891-exam-aws-certified-database-specialty-topic-1-question-160/)**
# 전자 상거래 회사는 온프레미스 MongoDB 데이터베이스를 Amazon DocumentDB(MongoDB 호환 가능)로 마이그레이션합니다. 마이그레이션 후 데이터베이스 전문가는 Amazon DocumentDB 클러스터에 대해 미사용 데이터 암호화가 설정되지 않았음을 알게 됩니다.
# 데이터베이스 전문가는 Amazon DocumentDB 클러스터에 대해 유휴 암호화를 활성화하려면 어떻게 해야 합니까?
#
# >**A.** Amazon DocumentDB 클러스터의 스냅샷을 만듭니다. 암호화 옵션을 지정하면서 암호화되지 않은 스냅샷을 새 클러스터로 복원하고 AWS Key Management Service(AWS KMS) 키를 제공합니다.
# **B.** AWS Management 콘솔에서 Amazon DocumentDB 클러스터에 대한 암호화를 활성화합니다. 클러스터를 재부팅합니다.
# **C.** --storage-encrypted 파라미터를 true로 설정하고 modify-db-cluster 명령을 사용하여 Amazon DocumentDB 클러스터를 수정합니다.
# **D.** Amazon DocumentDB 클러스터에 암호화된 새 인스턴스를 추가한 다음 클러스터에서 암호화되지 않은 인스턴스를 삭제합니다. 모든 인스턴스가 암호화될 때까지 반복합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : A (100%)  <br>
# >암호화되지 않은 클러스터의 DocumentDB 전용 스냅샷 -> 미사용 시 암호화 옵션을 지정하면서 암호화되지 않은 스냅샷을 새 클러스터로 복원합니다.<br>
# >Amazon DocumentDB 클러스터에 대한 유휴 데이터 암호화를 활성화하거나 비활성화할 수 있고 클러스터를 생성한 이후에는 불가능합니다. 그러나 암호화되지 않은 클러스터의 스냅샷을 생성한 후 유휴 데이터 암호화 옵션을 지정하여 암호화되지 않은 클러스터의 암호화된 복사본을 생성할 수 있습니다.<br>
# >
# >[Amazon DocumentDB 유휴 데이터 암호화](https://docs.aws.amazon.com/ko_kr/documentdb/latest/developerguide/encryption-at-rest.html)
# </div></details>

# %% [markdown]
# # 161

# %% [markdown]
# **★★★[Q#161. Q#091. Q#092.](https://www.examtopics.com/discussions/amazon/view/66266-exam-aws-certified-database-specialty-topic-1-question-161/)**
# 주식 시장을 분석하는 회사에는 us-east-1 지역과 eu-west-2 지역의 두 사무실이 있습니다. 회사는 빠르고 정확한 업데이트를 제공할 수 있는 AWS 데이터베이스 솔루션을 구현하고자 합니다.
# eu-west-2의 사무실에는 데이터를 표시하기 위한 복잡한 분석 쿼리가 포함된 대시보드가 ​​있습니다. 회사는 이러한 대시보드를 사용하여 구매 결정을 내리므로 대시보드는 1초 이내에 애플리케이션 데이터에 액세스할 수 있어야 합니다.
# 이러한 요구 사항을 충족하고 가장 최신 대시보드를 제공하는 솔루션은 무엇입니까?
#
# >**A.** eu-west-2의 읽기 전용 복제본 인스턴스와 함께 us-east-1의 Amazon RDS DB 인스턴스를 배포합니다. eu-west-2에 Amazon ElastiCache 클러스터를 생성하여 읽기 전용 복제본의 데이터를 캐시하여 대시보드를 생성합니다.
# **B.** eu-west-2로 복제하는 us-east-1의 Amazon DynamoDB 글로벌 테이블을 사용합니다. 다중 활성 복제를 사용하여 업데이트가 eu-west-2로 빠르게 전파되도록 합니다.
# **C.** Amazon Aurora 글로벌 데이터베이스를 사용합니다. us-east-1에 기본 DB 클러스터를 배포합니다. eu-west-2에 보조 DB 클러스터를 배포합니다. 보조 클러스터에서 읽도록 대시보드 애플리케이션을 구성합니다.
# **D.** eu-west-2의 읽기 전용 복제본 인스턴스와 함께 us-east-1의 Amazon RDS for MySQL DB 인스턴스를 배포합니다. 읽기 전용 복제본에서 읽도록 대시보드 애플리케이션을 구성합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : C(100%)  <br>
# >고급 분석 쿼리 => RDS, 1초 이내 액세스 => Aurora 글로벌<br>
# >Amazon Aurora 글로벌 데이터베이스는 전 세계적으로 분산된 애플리케이션을 위해 설계되어 단일 Amazon Aurora 데이터베이스가 여러 AWS 리전에 걸쳐 있을 수 있습니다. 글로벌 데이터베이스는 애플리케이션 워크로드를 처리하기 위해 데이터베이스를 완전히 사용할 수 있도록 하는 전용 인프라를 사용하여 일반적인 대기 시간이 1초 미만인 스토리지 기반 복제를 사용합니다.<br>
# >고급 분석 쿼리"는 DynamoDB를 배제합니다.<br>
# >읽기 전용 복제본은 동일한 지역에만 배포할 수 있습니다.<br>
# >1초 미만의 리전 간 복제를 위해 Amazon Aurora 글로벌 데이터베이스를 사용합니다.<br>
# >
# >[Amazon Aurora 글로벌 데이터베이스](https://aws.amazon.com/ko/rds/aurora/global-database/)<br>
# >[Amazon Aurora 글로벌 데이터베이스 사용](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/aurora-global-database.html)
# </div></details>
#
# **[Q#162. Q#006. Q#094.](https://www.examtopics.com/discussions/amazon/view/65925-exam-aws-certified-database-specialty-topic-1-question-162/)**
# 한 회사가 Amazon Aurora MySQL에서 고객 피드백 애플리케이션을 실행하고 있습니다. 회사는 매일 보고서를 실행하여 고객 피드백을 추출하고 팀은 피드백을 읽고 고객 의견이 긍정적인지 부정적인지 판단합니다. 회사가 불만이 있는 고객에게 연락하여 시정 조치를 취하는 데 며칠이 걸리는 경우가 있습니다. 이 회사는 기계 학습을 사용하여 이 워크플로를 자동화하려고 합니다.
# 최소한의 노력으로 이 요구 사항을 충족하는 솔루션은 무엇입니까?
#
# >**A.** AWS Database Migration Service(AWS DMS)를 사용하여 Aurora MySQL 데이터베이스를 Amazon S3로 내보냅니다. Amazon Comprehend를 사용하여 내보낸 파일에 대한 감정 분석을 실행합니다.
# **B.** AWS Database Migration Service(AWS DMS)를 사용하여 Aurora MySQL 데이터베이스를 Amazon S3로 내보냅니다. Amazon SageMaker를 사용하여 내보낸 파일에 대한 감정 분석을 실행합니다.
# **C.** Amazon Comprehend와 Aurora 기본 통합을 설정합니다. SQL 함수를 사용하여 감정 분석을 추출합니다.
# **D.** Amazon SageMaker와 Aurora 기본 통합을 설정합니다. SQL 함수를 사용하여 감정 분석을 추출합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : C(100%)  <br>
# >Amazon Comprehend는 기계 학습을 사용하여 텍스트에서 귀중한 통찰력과 연결을 찾아내는 자연어 처리(NLP) 서비스입니다.<br>
# >ML 쿼리를 실행할 때 Aurora는 다양한 ML 알고리즘을 위해 Amazon SageMaker를 호출하거나 감정 분석을 위해 Amazon Comprehend를 호출합니다.<br>
# >Comprehend는 간단한 ML 솔루션이며 최소한의 노력이 필요합니다.<br>
# >
# >[Amazon Comprehend](https://aws.amazon.com/ko/comprehend/)<br>
# >[감정 분석 수행 - Amazon Aurora ML 통합](https://aws.amazon.com/ko/getting-started/hands-on/sentiment-analysis-amazon-aurora-ml-integration/)<br>
# >[Amazon Aurora에서 기계 학습(ML) 기능 사용](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/aurora-ml.html)
# </div></details>
#
# **[Q#163. Q#140. Q#014.](https://www.examtopics.com/discussions/amazon/view/68497-exam-aws-certified-database-specialty-topic-1-question-163/)**
# 한 은행에서 Amazon RDS for MySQL DB 인스턴스를 사용할 계획입니다. 데이터베이스는 반복 쿼리가 거의 없는 읽기 집약적인 트래픽을 지원해야 합니다.
# 어떤 솔루션이 이러한 요구 사항을 충족합니까?
#
# >**A.** Amazon ElastiCache 클러스터를 생성합니다. 연속 기입 전략을 사용하여 캐시를 채웁니다.
# **B.** Amazon ElastiCache 클러스터를 생성합니다. 캐시를 채우려면 지연 로드 전략을 사용하십시오.
# **C.** DB 인스턴스를 다른 AWS 리전의 대기 인스턴스가 있는 다중 AZ로 변경합니다.
# **D.** DB 인스턴스의 읽기 전용 복제본을 생성합니다. 읽기 전용 복제본을 사용하여 읽기 트래픽을 분산합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : D (100%)  <br>
# >반복되는 쿼리가 거의 없습니다. 이 경우 탄력적 캐시는 Elasticache의 목적에 어긋나는 정보를 얻기 위해 데이터베이스에 도달해야 합니다.<br>
# >기본적으로 "많은 다른 쿼리"를 의미하는 "반복 쿼리가 극히 적음" 때문에 Elasticache는 도움이 되지 않습니다.<br>
# >
# >[AWS에서 RDS 읽기 전용 복제본 관리](https://cloudbasic.net/aws/rds/sqlserver/managing-rds-read-replicas-on-aws/)
# </div></details>
#
# **[Q#164. Q#025. Q#142.](https://www.examtopics.com/discussions/amazon/view/65816-exam-aws-certified-database-specialty-topic-1-question-164/)**
# 데이터베이스 전문가에게는 기본 DB 파라미터 그룹을 사용하는 Amazon RDS DB 인스턴스 집합이 있습니다. 데이터베이스 전문가는 사용자 지정 파라미터 그룹을 일부 DB 인스턴스와 연결해야 합니다.
# 데이터베이스 전문가가 이 변경 작업을 수행한 후 언제 인스턴스가 이 새 매개변수 그룹에 할당됩니까?
#
# >**A.** 파라미터 그룹 변경 직후
# **B.** DB 인스턴스의 다음 예정된 유지 관리 기간
# **C.** DB 인스턴스를 수동으로 재부팅한 후
# **D.** 파라미터 그룹 변경 후 24시간 이내
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : C(100%)  <br>
# >해당 DB 인스턴스에 최신 파라미터 변경 사항을 적용하려면 DB 인스턴스를 수동으로 재부팅하십시오.<br>
# >새 DB 파라미터 그룹을 DB 인스턴스와 연결할 때 수정된 정적 및 동적 파라미터는 DB 인스턴스가 재부팅된 후에만 적용됩니다. 그러나 새로 연결된 DB 파라미터 그룹에서 동적 파라미터를 수정하면 이러한 변경 사항은 재부팅 없이 즉시 적용됩니다.<br>
# >
# >[파라미터 그룹 작업](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/USER_WorkingWithParamGroups.html)
# </div></details>
#
# **[Q#165. Q#050. Q#177.](https://www.examtopics.com/discussions/amazon/view/66015-exam-aws-certified-database-specialty-topic-1-question-165/)**
# 한 회사는 AWS Schema Conversion Tool(AWS SCT) 및 AWS DMS 를 사용하여 Oracle에서 Amazon Aurora PostgreSQL로 500GB 데이터베이스를 마이그레이션할 계획입니다. 데이터베이스에 마이그레이션할 저장 프로시저가 없지만 크거나 분할된 일부 테이블이 있습니다. 애플리케이션은 비즈니스에 매우 중요하므로 가동 중지 시간이 최소화된 마이그레이션이 선호됩니다.
# 마이그레이션 프로세스를 가속화하기 위해 데이터베이스 전문가가 취해야 하는 단계의 조합은 무엇입니까? (3개를 선택하세요.)
#
# >**A.** AWS SCT 데이터 추출 에이전트를 사용하여 Oracle에서 Aurora PostgreSQL로 스키마를 마이그레이션합니다.
# **B.** 큰 테이블의 경우 병렬 로드할 최대 테이블 수 설정을 변경하고 AWS DMS를 사용하여 전체 로드를 수행합니다.
# **C.** 큰 테이블의 경우 AWS DMS에서 병렬 로드 옵션을 사용하여 테이블 설정 규칙을 생성한 다음 DMS를 사용하여 전체 로드를 수행합니다.
# **D.** AWS DMS를 사용하여 전환 날짜까지 연속 복제를 위한 변경 데이터 캡처(CDC)를 설정합니다.
# **E.** AWS SCT를 사용하여 스키마를 Oracle에서 Aurora PostgreSQL로 변환합니다.
# **F.** AWS DMS를 사용하여 스키마를 Oracle에서 Aurora PostgreSQL로 변환하고 연속 복제를 수행합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : CDE(100%)  <br>
# >E. 스키마 변환을 위해 SCT 사용 -> C. 병렬 로드 옵션으로 테이블 설정 규칙 생성, DMS를 사용하여 로드 -> D. 컷오버 날짜까지 DMS 계속<br>
# >Ax: AWS SCT는 데이터 추출 도구가 아닙니다.<br>
# >
# >[온프레미스 Oracle 데이터베이스에서 Aurora PostgreSQL 로 데이터 마이그레이션](https://docs.aws.amazon.com/ko_kr/prescriptive-guidance/latest/patterns/migrate-data-from-an-on-premises-oracle-database-to-aurora-postgresql.html)<br>
# >[선택한 테이블, 뷰 및 컬렉션에 parallel 로드 사용](https://docs.aws.amazon.com/ko_kr/dms/latest/userguide/CHAP_Tasks.CustomizingTasks.TableMapping.SelectionTransformation.Tablesettings.html#CHAP_Tasks.CustomizingTasks.TableMapping.SelectionTransformation.Tablesettings.ParallelLoad)
# </div></details>
#
# **[Q#166. Q#056. Q#054.](https://www.examtopics.com/discussions/amazon/view/67108-exam-aws-certified-database-specialty-topic-1-question-166/)**
# 회사에서 IBM Informix 데이터베이스를 Always On AG(가용성 그룹)가 있는 SQL Server용 Amazon RDS의 다중 AZ 배포로 마이그레이션하고 있습니다.
# Always On AG 리스너의 SQL Server 에이전트 작업은 Informix 데이터베이스와 SQL Server 데이터베이스 간에 데이터를 동기화하기 위해 5분 간격으로 실행됩니다. 사용자는 최소 대기 시간으로 보조 노드로의 성공적인 장애 조치 후 몇 시간 동안 부실 데이터를 경험합니다.
# 장애 조치 후 사용자가 최근 데이터를 볼 수 있도록 데이터베이스 전문가는 무엇을 해야 합니까?
#
# >**A.** Always On AG 리스너의 캐시된 DNS 값에 대해 TTL을 30초 미만으로 설정합니다.
# **B.** 큰 트랜잭션을 5분 이내에 완료되는 여러 개의 작은 트랜잭션으로 나눕니다.
# **C.** 보조 노드의 데이터베이스를 읽기 전용 모드로 설정합니다.
# **D.** 오류 후 보조 노드가 인계받을 때 스크립트에서 보조 노드에 SQL Server 에이전트 작업을 만듭니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : D(67%), A(33%)  <br>
# >Amazon RDS는 SQL Server 데이터베이스 미러링(DBM) 또는 상시 가동 가용성 그룹(AG)을 사용하여 Microsoft SQL Server에 대한 다중 AZ 배포를 지원합니다.<br>
# >SQL Server 에이전트 작업은 Informix와 SQL Server 데이터베이스 간에 데이터를 동기화하는 데 사용되며 보조 노드에서 생성되지 않으면 데이터가 동기화되지 않습니다.<br>
# >SQL Server 에이전트 작업이 있는 경우 보조에서 다시 생성합니다. 이러한 작업은 msdb 데이터베이스에 저장되고 DBM(데이터베이스 미러링) 또는 AG(상시 가동 가용성 그룹)를 사용하여 이 데이터베이스를 복제할 수 없기 때문에 그렇게 하는 것입니다. 원래 기본에서 먼저 작업을 생성한 다음 장애 조치하고 새 기본에서 동일한 작업을 생성합니다.<br>
# >Cx: 데이터베이스 읽기 활동을 허용하도록 보조 DB 인스턴스를 구성할 수 없음.<br>
# >A: HostRecordTTL 설정 은 캐시된 DNS 항목의 TTL(Time to Live)을 제어합니다. 기본값은 1200초입니다. HostRecordTTL 을 훨씬 낮은 설정(60초 이하)으로 변경하는 것이 좋습니다 . 이로 인해 캐시된 값이 더 빨리 만료되므로 장애 조치(failover)의 경우 클라이언트 시스템이 새 IP를 더 빨리 확인할 수 있습니다.<br>
# >
# >[mazon RDS for Microsoft SQL Server의 다중 AZ 배포](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/USER_SQLServerMultiAZ.html)<br>
# >[Always On 가용성 그룹 구성](https://docs.aws.amazon.com/prescriptive-guidance/latest/sql-server-ec2-best-practices/configure-availability-groups.html)
# </div></details>
#
# **[Q#167. Q#157. Q#011.](https://www.examtopics.com/discussions/amazon/view/66483-exam-aws-certified-database-specialty-topic-1-question-167/)**
# 데이터베이스 전문가는 900초 후에 비활성화되는 비대화형 연결을 닫도록 MySQL DB 인스턴스용 Amazon RDS를 구성해야 합니다.
# 데이터베이스 전문가는 이 작업을 수행하기 위해 무엇을 해야 합니까?
#
# >**A.** 사용자 지정 DB 파라미터 그룹을 생성하고 wait_timeout 파라미터 값을 900으로 설정합니다. DB 인스턴스를 사용자 지정 파라미터 그룹과 연결합니다.
# **B.** MySQL 데이터베이스에 연결하고 SET SESSION wait_timeout=900 명령을 실행합니다.
# **C.** my.cnf 파일을 편집하고 wait_timeout 파라미터 값을 900으로 설정합니다. DB 인스턴스를 다시 시작합니다.
# **D.** 기본 DB 파라미터 그룹을 수정하고 wait_timeout 파라미터 값을 900으로 설정합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : A(100%)  <br>
# >A: wait_timeout: 서버가 닫기 전에 비대화형 TCP/IP 또는 UNIX 파일 연결에서 활동을 기다리는 시간(초)입니다.<br>
# >A: RDS에는 매개변수 그룹이 필요합니다. wait_timeout: 서버가 닫기 전에 비대화형 TCP/IP 또는 UNIX 파일 연결에서 활동을 기다리는 시간(초)입니다.<br>
# >매개변수 그룹을 사용하여 전역적으로 매개변수를 설정할 수 있습니다. 또는 SET 명령을 사용하여 특정 세션에 대해 설정할 수 있습니다.<br>
# >Cx: Amazon RDS는 Amazon 관리형 서비스이므로 my.cnf 파일을 직접 편집할 수 없습니다. SET 명령 또는 매개변수 그룹을 사용해야 합니다.<br>
# >
# >[Amazon RDS for MySQL의 파라미터 구성 모범 사례, 1부: 성능 관련 파라미터](https://aws.amazon.com/ko/blogs/database/best-practices-for-configuring-parameters-for-amazon-rds-for-mysql-part-1-parameters-related-to-performance/)
# </div></details>
#
# **[Q#168. Q#161. Q#091.](https://www.examtopics.com/discussions/amazon/view/68542-exam-aws-certified-database-specialty-topic-1-question-168/)**
# 회사는 3TB Amazon Aurora MySQL DB 클러스터에서 프로덕션 데이터베이스를 실행하고 있습니다. DB 클러스터는 us-east-1 리전에 배포됩니다. 재해 복구(DR) 목적을 위해 회사의 데이터베이스 전문가는 2시간 미만의 RTO로 프로덕션 로드를 처리하기 위해 다른 AWS 리전에서 DB 클러스터를 신속하게 사용할 수 있도록 해야 합니다.
# 이러한 요구 사항을 충족하기 위해 운영상 가장 효율적인 솔루션은 무엇입니까?
#
# >**A.** 2시간마다 프로덕션 DB 클러스터의 스냅샷을 생성하고 해당 스냅샷을 DR 리전의 Amazon S3 버킷에 복사하는 AWS Lambda 함수를 구현합니다. DR 리전에서 적절한 크기의 DB 클러스터로 스냅샷을 복원합니다.
# **B.** 현재 기본 인스턴스와 동일한 인스턴스 유형을 사용하여 DR 리전에 교차 리전 읽기 전용 복제본을 추가합니다. DR 리전의 읽기 전용 복제본을 프로덕션에 사용해야 하는 경우 읽기 전용 복제본을 독립 실행형 DB 클러스터로 승격합니다.
# **C.** DR 리전에 더 작은 DB 클러스터를 생성합니다. 현재 프로덕션 DB 클러스터에서 DR 리전의 DB 클러스터로 데이터를 복제할 수 있도록 CDC(변경 데이터 캡처)가 활성화된 AWS Database Migration Service(AWS DMS) 작업을 구성합니다.
# **D.** 두 리전에 걸쳐 있는 Aurora 글로벌 데이터베이스를 생성합니다. AWS Database Migration Service(AWS DMS)를 사용하여 기존 데이터베이스를 새로운 글로벌 데이터베이스로 마이그레이션합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : B (100%)  <br>
# >Dx: 글로벌 데이터베이스를 선택했지만 DMS가 필요하지 않습니다.
# >RTO는 2시간입니다. 3TB 데이터베이스의 경우 교차 리전 복제본이 더 나은 옵션입니다.<br>
# >
# >[읽기 전용 복제본 작업](https://docs.aws.amazon.com/AmazonRDS/latest/UserGuide/USER_ReadRepl.html)<br>
# >[AWS 리전에서 Amazon Aurora MySQL DB 클러스터 복제](https://docs.aws.amazon.com/AmazonRDS/latest/AuroraUserGuide/AuroraMySQL.Replication.CrossRegion.html)
# </div></details>
#
# **[Q#169. Q#012. Q#098.](https://www.examtopics.com/discussions/amazon/view/65739-exam-aws-certified-database-specialty-topic-1-question-169/)**
# 회사에 온-프레미스 SQL Server 데이터베이스가 있습니다. 사용자는 Active Directory 인증을 사용하여 데이터베이스에 액세스합니다. 이 회사는 데이터베이스를 SQL Server용 Amazon RDS로 성공적으로 마이그레이션했습니다. 그러나 회사는 AWS 클라우드 환경에서 사용자 인증에 대해 우려하고 있습니다.
# 데이터베이스 전문가는 사용자가 인증할 수 있도록 어떤 솔루션을 제공해야 합니까?
#
# >**A.** AD FS(Active Directory Federation Services)를 온프레미스에 배포하고 온프레미스 Active Directory로 구성합니다. AmazonRDSDirectoryServiceAccess 관리형 IAM 정책을 사용하여 사용자 자격 증명을 역할에 매핑하도록 온프레미스 AD FS와 AWS Security Token Service(AWS STS) 간의 위임을 설정합니다.
# **B.** 온프레미스 Active Directory와 Microsoft Active Directory용 AWS Directory Service 간에 포리스트 트러스트를 설정합니다. AWS SSO를 사용하여 SQL Server용 RDS의 데이터베이스에 액세스하도록 위임된 Active Directory 사용자를 구성합니다.
# **C.** Active Directory Connector를 사용하여 클라우드에 정보를 캐싱하지 않고 디렉터리 요청을 회사의 온-프레미스 Active Directory로 리디렉션합니다. RDS 마스터 사용자 자격 증명을 사용하여 DB 인스턴스에 연결하고 Active Directory 사용자 및 그룹에서 SQL Server 로그인 및 사용자를 구성합니다.
# **D.** 온프레미스 Active Directory와 Microsoft Active Directory용 AWS Directory Service 간에 포리스트 신뢰를 설정합니다. SQL Server용 RDS가 혼합 모드 인증을 사용하고 있는지 확인합니다. RDS 마스터 사용자 자격 증명을 사용하여 DB 인스턴스에 연결하고 Active Directory 사용자 및 그룹에서 SQL Server 로그인 및 사용자를 구성합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : D(80%), B(20%)  <br>
# >D: Amazon RDS는 Windows 인증에 혼합 모드를 사용합니다<br>
# >기준 Amazon RDS는 Windows 인증에 혼합 모드를 사용합니다. 이 접근 방식은 마스터 사용자(SQL Server DB 인스턴스를 생성하는 데 사용된 이름 및 암호)가 SQL 인증을 사용함을 의미합니다. 마스터 사용자 계정은 권한 있는 자격 증명이므로 이 계정에 대한 액세스를 제한해야 합니다.<br>
# >온-프레미스 또는 자체 호스팅 Microsoft Active Directory를 사용하여 Windows 인증을 받으려면 포리스트 트러스트를 만듭니다.<br>
# >D: Active Directory 사용자 및 그룹의 SQL Server 로그인 및 사용자를 구성하려면 마스터 사용자 자격 증명과 함께 sql 인증을 사용해야 하므로 혼합 모드 인증은 필수입니다. <br>
# >
# >[Amazon RDS for SQL Server DB 인스턴스에 Windows 인증 사용](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/UserGuide/USER_SQLServerWinAuth.html)
# </div></details>
#
# **[Q#170. Q#059. Q#058.](https://www.examtopics.com/discussions/amazon/view/65890-exam-aws-certified-database-specialty-topic-1-question-170/)**
# 회사는 Amazon Redshift 클러스터를 사용하여 분석 워크로드를 실행합니다. 회사 정책에 따라 회사의 데이터는 고객 관리 키로 암호화됩니다. 회사의 재해 복구 계획에 따라 클러스터의 백업을 정기적으로 다른 AWS 리전에 복사해야 합니다.
# 데이터베이스 전문가는 이러한 정책에 따라 클러스터 데이터를 백업하는 프로세스를 어떻게 자동화해야 합니까?
#
# >**A.** AWS Key Management Service(AWS KMS) 고객 관리형 키를 원본 리전에서 대상 리전으로 복사합니다. 원본 리전에서 Amazon Redshift 클러스터의 최신 스냅샷을 원본 리전에서 대상 리전으로 복사하도록 AWS Glue 작업을 설정합니다. AWS Glue에서 시간 기반 일정을 사용하여 매일 작업을 실행합니다.
# **B.** 대상 리전에서 새 AWS Key Management Service(AWS KMS) 고객 관리형 키를 생성합니다. 새 키를 지정하여 대상 리전에서 스냅샷 복사 권한을 생성합니다. 원본 리전에서 대상 리전, 스냅샷 복사 권한, 스냅샷 보존 기간을 지정하여 Amazon Redshift 클러스터에 대한 교차 리전 스냅샷을 구성합니다.
# **C.** 소스 리전에서 대상 리전으로 AWS Key Management Service(AWS KMS) 고객 관리형 키를 복사합니다. 해당 리전의 키를 사용하여 각 리전에 Amazon S3 버킷을 생성합니다. Amazon EventBridge(Amazon CloudWatch Events)를 사용하여 소스 리전의 AWS Lambda 함수를 예약하여 해당 리전의 S3 버킷에 최신 스냅샷을 복사합니다. 복제 구성에서 소스 및 대상 KMS 키 ID를 지정하여 스냅샷을 대상 리전에 복사하도록 S3 교차 리전 복제를 구성합니다.
# **D.** 동일한 고객 제공 키 자료를 사용하여 대상 리전에서 동일한 프라이빗 키를 사용하여 CMK를 생성합니다. 대상 리전을 대상으로 하는 소스 리전에서 교차 리전 스냅샷을 구성합니다. 스냅샷을 암호화할 대상 리전에서 해당 CMK를 지정합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : B(100%)  <br>
# >대상 리전의 새 KMS CMK -> 새 키를 지정하는 대상 리전의 스냅샷 복사 권한 부여 -> 원본 리전에서 - 대상 리전 - 스냅샷 복사 권한 및 스냅샷의 보존 기간을 지정하여 Amazon Redshift 클러스터에 대한 교차 리전 스냅샷을 구성합니다.<br>
# >
# >```
# >new KMS CMK in the destination Region
# >-> snapshot copy grant in the destination Region specifying the new key
# >->In the source Region, configure cross-Region snapshots for the Amazon Redshift cluster specifying
# >- the destination Region,
# >- the snapshot copy grant,
# >- and retention periods for the snapshot.
# >```
# >[AWS KMS 암호화 클러스터에 대한 리전 간 스냅샷 복사 구성](https://docs.aws.amazon.com/ko_kr/redshift/latest/mgmt/managing-snapshots-console.html#xregioncopy-kms-encrypted-snapshot)
# </div></details>

# %% [markdown]
# # 171

# %% [markdown]
# **[Q#171. Q#017. Q#097.](https://www.examtopics.com/discussions/amazon/view/65814-exam-aws-certified-database-specialty-topic-1-question-171/)**
# 데이터베이스 전문가가 Amazon Neptune을 사용하여 처음으로 테스트 그래프 데이터베이스를 시작합니다. 데이터베이스 전문가는 Amazon S3에 저장된 .csv 파일에서 수백만 행의 테스트 관찰을 삽입해야 합니다. 데이터베이스 전문가는 일련의 API 호출을 사용하여 데이터를 Neptune DB 인스턴스에 업로드했습니다.
# 데이터베이스 전문가가 데이터를 더 빨리 업로드할 수 있도록 하는 단계 조합은 무엇입니까? (3개를 선택하세요.)
#
# >**A.** Amazon Cognito가 Neptune DB 인스턴스를 CSV 파일을 호스팅하는 S3 버킷에 인증하기 위해 적절한 AWS STS 토큰을 반환하는지 확인하십시오.
# **B.** 꼭짓점과 가장자리가 적절한 헤더 열 형식으로 다른 .csv 파일에 지정되었는지 확인합니다.
# **C.** AWS DMS를 사용하여 Amazon S3에서 Neptune Loader로 데이터를 이동합니다.
# **D.** Neptune DB 인스턴스 내부에서 S3 URI를 curl 명령으로 실행한 다음 addVertex 또는 addEdge 명령을 실행합니다.
# **E.** Neptune DB 인스턴스의 IAM 역할이 S3 버킷의 파일에 대한 액세스를 허용하는 적절한 권한으로 구성되었는지 확인합니다.
# **F.** S3 VPC 엔드포인트를 생성하고 데이터베이스의 로더 엔드포인트에 HTTP POST를 실행합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : BEF(100%)  <br>
# >B. 별도 csv의 사양 E. Neptune에서 S3로의 액세스 F. Loader 명령을 실행하기 위한 S3 VPC 엔드포인트<br>
# >Amazon Neptune은 외부 파일의 데이터를 Neptune DB 인스턴스로 직접 로드하기 위한 Loader 명령을 제공합니다. 많은 수의 INSERT 문, addV 및 addE 단계 또는 기타 API 호출을 실행하는 대신 이 명령을 사용할 수 있습니다. <br>
# >S3 VPC 엔드포인트를 설정합니다. S3에 대한 GET 및 LIST 권한이 있는 IAM 역할을 설정합니다. CSV의 내용이 정확한지 확인하십시오. (B) (E) (F)입니다!!
# >Apache 로드 TinkerPop CSV 형식을 사용하는 Gremlin 데이터의 경우 별도 파일에 버텍스와 엣지를 지정해야 합니다.<br>
# >로더는 로드 작업 한 번으로 여러 Vertex 파일과 여러 엣지 파일을 로드할 수 있습니다.<br>
# >
# >[Amazon Neptune 대량 로더를 사용하여 데이터 수집](https://docs.aws.amazon.com/neptune/latest/userguide/bulk-load.html)<br>
# >[그렘린 로드 데이터 형식](https://docs.aws.amazon.com/neptune/latest/userguide/bulk-load-tutorial-format-gremlin.html)
# </div></details>
#
# **[Q#172. Q#024. Q#168.](https://www.examtopics.com/discussions/amazon/view/65815-exam-aws-certified-database-specialty-topic-1-question-172/)**
# 한 회사에서 온라인 게임 애플리케이션에 Amazon DynamoDB 글로벌 테이블을 사용하고 있습니다. 이 게임에는 전 세계의 플레이어가 있습니다. 게임이 대중화되면서 DynamoDB에 대한 요청이 크게 증가했습니다. 최근 플레이어들은 게임 상태가 다른 국가의 플레이어 간에 일치하지 않는다는 보고를 받았습니다. 데이터베이스 전문가는 일부 복제 테이블에 대한 ReplicationLatency 지표가 너무 높다는 것을 관찰했습니다.
# 어떤 접근 방식이 문제를 완화할 것입니까?
#
# >**A.** DynamoDB Auto Scaling을 사용하도록 모든 복제본 테이블을 구성합니다.
# **B.** 각 복제본에 DynamoDB Accelerator(DAX) 클러스터를 구성합니다.
# **C.** DynamoDB Auto Scaling을 사용하도록 기본 테이블을 구성하고 수동으로 프로비저닝된 용량을 사용하도록 복제본 테이블을 구성합니다.
# **D.** 테이블 수준 쓰기 처리량 제한 서비스 할당량을 더 높은 값으로 구성합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : A(100%)  <br>
# >DynamoDB Auto Scaling을 사용하는 것은 프로비저닝된 모드를 사용하는 복제본 테이블에 대한 처리 용량 설정을 관리하는 데 권장되는 방법입니다.<br>
# >데이터의 적절한 복제를 보장하려면 글로벌 테이블의 복제본 테이블과 보조 인덱스가 동일한 쓰기 용량 설정을 갖는 것이 중요합니다.<br>
# >Auto Scaling으로 프로비저닝된 온디맨드 모드 또는 온디맨드 용량 모드를 사용하면 전역 테이블의 모든 리전에 대한 복제된 쓰기를 수행하는 데 충분한 용량을 전역 테이블에 확보하는 데 도움이 됩니다.<br>
# >
# >[전역 테이블 관리 모범 사례 및 요구 사항](https://docs.aws.amazon.com/amazondynamodb/latest/developerguide/V2globaltables_reqs_bestpractices.html)
# </div></details>
#
# **[Q#173. Q#038. Q#128.](https://www.examtopics.com/discussions/amazon/view/66628-exam-aws-certified-database-specialty-topic-1-question-173/)**
# 회사는 단일 Amazon RDS DB 인스턴스에서 전자상거래 애플리케이션용 MySQL 데이터베이스를 실행합니다. 애플리케이션 구매는 자동으로 데이터베이스에 저장되므로 쓰기가 많이 필요합니다. 회사 직원은 자주 구매 보고서를 생성합니다. 회사는 데이터베이스 성능을 개선하고 업그레이드 패치로 인한 다운타임을 줄여야 합니다.
# 최소한의 운영 오버헤드로 이러한 요구 사항을 충족하는 접근 방식은 무엇입니까?
#
# >**A.** RDS for MySQL DB 인스턴스의 다중 AZ 배포를 활성화하고 MySQL 옵션 그룹에서 Memcached를 활성화합니다.
# **B.** RDS for MySQL DB 인스턴스의 다중 AZ 배포를 활성화하고 Amazon EC2에서 실행되는 MySQL DB 인스턴스에 대한 복제를 설정합니다.
# **C.** RDS for MySQL DB 인스턴스의 다중 AZ 배포를 활성화하고 읽기 전용 복제본을 추가합니다.
# **D.** 읽기 전용 복제본을 추가하고 Amazon Aurora MySQL DB 클러스터 마스터로 승격합니다. 그런 다음 Amazon Aurora Serverless를 활성화합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C (100%)  <br>
# >RDS for MySQL DB 인스턴스의 다중 AZ 배포를 활성화하고 읽기 전용 복제본을 추가합니다.<br>
# >C. 질문은 가장 적은 운영 오버헤드를 언급하고 직원들은 자주 구매 보고서를 작성합니다(많이 읽음). 쿼리를 읽기 전용 복제본으로 이동하면 쓰기와 함께 추가 로드를 수행할 기본이 열립니다.<br>
# >
# >[읽기 전용 복제본 작업](https://docs.aws.amazon.com/AmazonRDS/latest/UserGuide/USER_ReadRepl.html)
# </div></details>
#
# **[Q#174. Q#004. Q#148.](https://www.examtopics.com/discussions/amazon/view/66252-exam-aws-certified-database-specialty-topic-1-question-174/)**
# 전자 상거래 회사는 핵심 애플리케이션 데이터베이스를 Amazon Aurora MySQL로 마이그레이션하고 있습니다. 회사는 현재 동시 데이터베이스 세션으로 온라인 트랜잭션 처리(OLTP) 스트레스 테스트를 수행하고 있습니다. 첫 번째 테스트에서 데이터베이스 전문가는 일부 특정 쓰기 작업의 성능이 저하되는 것을 발견했습니다.
# Aurora DB 클러스터에 대한 Amazon CloudWatch 지표를 검토한 결과 CPU 사용률이 90%로 나타났습니다.
# 높은 CPU 사용률과 느린 성능의 근본 원인을 가장 효과적으로 식별하기 위해 데이터베이스 전문가는 어떤 단계를 수행해야 합니까? (2개를 선택하세요.)
#
# >**A.** 다음 테스트 라운드 전에 운영 체제 메트릭을 검토하려면 30초 미만의 세부 단위로 Enhanced Monitoring을 활성화하십시오.
# **B.** CloudWatch의 VolumeBytesUsed 지표를 검토하여 쓰기 I/O에 스파이크가 있는지 확인합니다.
# **C.** Amazon RDS 성능 개선 도우미를 검토하여 상위 SQL 문 및 대기 이벤트를 식별합니다.
# **D.** AWS CloudTrail에서 Amazon RDS API 호출을 검토하여 장기 실행 쿼리를 식별합니다.
# **E.** 고급 감사를 활성화하여 다음 테스트 라운드 전에 Amazon CloudWatch에서 QUERY 이벤트를 기록합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : AC(100%)  <br>
# >Bx: VolumeBytesUsed 메트릭은 CPU가 아니라 사용된 총 스토리지 크기에 대한 것입니다.<br>
# >A,C는 성능과 관련이 있습니다. B는 저장과 관련이 있습니다. D는 보안(API 호출 추적)과 관련이 있으며 E(고급 감사)는 존재하지 않습니다.<br>
# >
# >[Amazon RDS for MySQL 인스턴스에서 높은 CPU 사용률 문제는 어떻게 해결합니까?](https://aws.amazon.com/ko/premiumsupport/knowledge-center/rds-instance-high-cpu/)
# </div></details>
#
# **[Q#175. Q#052. Q#124.](https://www.examtopics.com/discussions/amazon/view/65861-exam-aws-certified-database-specialty-topic-1-question-175/)**
# 온라인 광고 회사는 사용자에게 광고를 표시하는 애플리케이션을 구현하고 있습니다. 애플리케이션은 Amazon DynamoDB 테이블을 데이터 저장소로 사용합니다. 또한 애플리케이션은 DynamoDB Accelerator(DAX) 클러스터를 사용하여 읽기를 캐시합니다. 대부분의 읽기는 GetItem 쿼리 및 BatchGetItem 쿼리에서 수행됩니다. 읽기 일관성은 이 애플리케이션의 요구 사항이 아닙니다.
# 배포 시 애플리케이션 캐시가 예상대로 작동하지 않습니다. DAX 클러스터에 대해 실행되는 강력하게 일관된 특정 쿼리는 응답하는 데 마이크로초 대신 몇 밀리초가 걸립니다.
# 회사에서 캐시 동작을 개선하여 애플리케이션 성능을 향상시킬 수 있는 방법은 무엇입니까?
#
# >**A.** DAX 클러스터의 크기를 늘립니다.
# **B.** 쿼리 캐시가 없는 항목 캐시가 되도록 DAX 구성
# **C.** 강력한 일관성 읽기 대신 최종 일관성 읽기를 사용합니다.
# **D.** 항목 캐시에 대해 더 높은 TTL을 사용하여 새 DAX 클러스터를 만듭니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C (100%)  <br>
# >"Strongly Consistent Reads가 최종 일관성 읽기보다 더 긴 대기 시간을 가질 수 있음"에 대해 확신하지 못합니다. 따라서 최종 일관성 읽기는 더 낮은 대기 시간을 가지며, 우리는 대기 시간을 낮추려고 노력하고 있습니다. C가 맞을 수 있습니다.<br>
# >Eventually consistent reads are good. 최종 일관성 읽기가 좋습니다.<br>
# >강력한 일관성 읽기 => bypass DAX, DynamoDB로 직접 전송되므로 응답시간이 더 길어집니다.<br>
# >
# >[읽기 정합성](https://docs.aws.amazon.com/ko_kr/amazondynamodb/latest/developerguide/HowItWorks.ReadConsistency.html)
# </div></details>
#
# **[Q#176. Q#160. Q#051.](https://www.examtopics.com/discussions/amazon/view/67082-exam-aws-certified-database-specialty-topic-1-question-176/)**
# 회사는 500GB Amazon Aurora MySQL DB 클러스터에서 중요한 프로덕션 워크로드를 실행하고 있습니다. 데이터베이스 엔지니어는 데이터 손실 없이 워크로드를 새로운 Amazon Aurora Serverless MySQL DB 클러스터로 이동해야 합니다.
# 가동 중지 시간과 애플리케이션에 미치는 영향이 가장 적은 솔루션은 무엇입니까?
#
# >**A.** 기존 DB 클러스터를 수정하고 Aurora 구성을 "서버리스"로 업데이트합니다.
# **B.** 기존 DB 클러스터의 스냅샷을 생성하고 이를 새로운 Aurora Serverless DB 클러스터로 복원합니다.
# **C.** 기존 DB 클러스터에서 Aurora Serverless 복제본을 생성하고 복제본 지연이 최소화되면 기본으로 승격합니다.
# **D.** 변경 데이터 캡처(CDC)가 활성화된 AWS Database Migration Service(AWS DMS)를 사용하여 기존 DB 클러스터와 새로운 Aurora Serverless DB 클러스터 간에 데이터를 복제합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : D(100%)  <br>
# >C와 D 모두 거의 0에 가까운 다운 시간을 제공하지만 옵션 C는 "...복제 지연이 최소일 때"라고 나와 있습니다. 이것은 "비즈니스의 미션 크리티컬 프로덕션 워크로드"에는 허용되지 않으며 B는 다운 타임 없이는 불가능합니다. 나는 D와 함께 갈 것이다<br>
# >D. 변경 데이터 캡처(CDC)가 활성화된 AWS DMS(AWS Database Migration Service)를 사용하여 기존 DB 클러스터와 새로운 Aurora Serverless DB 클러스터 간에 데이터를 복제합니다. DMS의 경우: Aurora Serverless는 소스가 될 수 없지만 대상이 될 수 있습니다.<br>
# >제한된 가동 중지 시간 요구 사항 때문에 DMS 및 D를 사용하겠습니다.<br>
# </div></details>
#
# **[Q#177. Q#139. Q#162.](https://www.examtopics.com/discussions/amazon/view/67569-exam-aws-certified-database-specialty-topic-1-question-177/)**
# 회사는 AWS에서 웹 애플리케이션을 구축하고 있습니다. 애플리케이션은 데이터베이스가 여러 AWS 리전에서 동시에 읽기 및 쓰기 작업을 지원해야 합니다. 또한 데이터베이스는 변경 사항이 발생하면 리전 간에 데이터 변경 사항을 전파해야 합니다. 애플리케이션은 가용성이 높아야 하며 한 자릿수 밀리초의 대기 시간을 제공해야 합니다.
# 어떤 솔루션이 이러한 요구 사항을 충족합니까?
#
# >**A.** Amazon DynamoDB 전역 테이블
# **B.** Amazon DynamoDB는 AWS Lambda로 스트리밍하여 데이터 복제
# **C.** 클러스터 모드가 활성화되고 여러 샤드가 있는 Redis용 Amazon ElastiCache 클러스터
# **D.** Amazon Aurora 글로벌 데이터베이스
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : A(100%)  <br>
# >글로벌 테이블을 사용하면 데이터를 로컬에서 읽고 쓸 수 있어 규모에 상관없이 전 세계에 분산된 애플리케이션에 대해 한 자릿수 밀리초의 대기 시간을 제공합니다.<br>
# >여러 리전에서 작성해야 합니다. -> Aurora Global은 단일 마스터이므로 DynamoDB Global이 답입니다.<br>
# >A: DynamoDB 글로벌 테이블 Aurora 글로벌 데이터베이스는 기본 리전에서 라이터 및 리더 엔드포인트를 제공하지만 다른 리전에서는 리더 엔드포인트만 제공합니다. 강력하게 일관성이 있지만 모든 지역에서 "많은 읽기/쓰기 활동이 있다"는 요구 사항을 충족하지 않습니다.<br>
# >질문에는 데이터베이스가 "여러 AWS 리전에서 동시 읽기 및 쓰기 활동을 지원"해야 한다고 나와 있습니다. Aurora 글로벌 데이터베이스는 단일 리전의 단일 마스터에 대한 쓰기만 허용합니다. DynamoDB 글로벌 테이블은 모든 리전의 모든 인스턴스에 대한 읽기 및 쓰기를 허용합니다. 답은 A<br>
# >
# >[Amazon DynamoDB 글로벌 테이블](https://aws.amazon.com/ko/dynamodb/global-tables/)
# </div></details>
#
# **[Q#178. Q#039. Q#178.](https://www.examtopics.com/discussions/amazon/view/65858-exam-aws-certified-database-specialty-topic-1-question-178/)**
# 회사는 Amazon Neptune을 자사 제품 중 하나의 그래프 데이터베이스로 사용하고 있습니다. 회사의 데이터 과학 팀은 ETL 프로세스 중에 실수로 대량의 임시 정보를 생성했습니다. Neptune DB 클러스터는 새 데이터를 수용하기 위해 자동으로 저장 공간을 늘렸지만 데이터 과학 팀은 사용하지 않는 정보를 삭제했습니다.
# 사용하지 않은 클러스터 볼륨 공간에 대한 불필요한 요금이 부과되지 않도록 데이터베이스 전문가는 어떻게 해야 합니까?
#
# >**A.** 클러스터 볼륨의 스냅샷을 만듭니다. 볼륨 크기가 더 작은 다른 클러스터의 스냅샷을 복원합니다.
# **B.** AWS CLI를 사용하여 클러스터 볼륨의 자동 크기 조정을 켭니다.
# **C.** 클러스터 데이터를 새 Neptune DB 클러스터로 내보냅니다.
# **D.** 클러스터에 Neptune 읽기 전용 복제본을 추가합니다. 이 복제본을 새 기본 DB 인스턴스로 승격합니다. 클러스터의 저장 공간을 재설정합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : C (100%)
# >C. 사용하지 않은 할당 공간이 많을 때 DB 클러스터에서 사용하는 스토리지 공간을 줄이는 유일한 방법은 그래프의 모든 데이터를 내보낸 다음 새 DB 클러스터에 다시 로드하는 것입니다. 스냅샷을 생성하고 복원해도 DB 클러스터에 할당된 스토리지의 양은 줄어들지 않습니다. 스냅샷은 클러스터 기본 스토리지의 원본 이미지를 유지하기 때문입니다.<br>
# >C "사용하지 않은 할당된 공간이 많을 때 DB 클러스터에서 사용하는 저장 공간을 줄이는 유일한 방법은 그래프의 모든 데이터를 내보낸 다음 새 DB 클러스터로 다시 로드하는 것입니다. " " 스냅샷은 클러스터 기본 스토리지의 원본 이미지를 유지하기 때문에 스냅샷은 DB 클러스터에 할당된 스토리지의 양을 줄이지 않습니다."<br>
# >
# >[Amazon Neptune 스토리지, 안정성 및 가용성](https://docs.aws.amazon.com/ko_kr/neptune/latest/userguide/feature-overview-storage.html)
# </div></details>
#
# **[Q#179. Q#155. Q#096.](https://www.examtopics.com/discussions/amazon/view/66480-exam-aws-certified-database-specialty-topic-1-question-179/)**
# 데이터베이스 전문가는 Amazon RDS for MySQL 프로덕션 데이터베이스를 사용하여 OLTP(온라인 트랜잭션 처리)를 위한 고가용성 솔루션을 설계하는 일을 담당합니다. 재해 복구 요구 사항에는 5분의 RPO 및 30분의 RTO와 함께 교차 리전 배포가 포함됩니다.
# 데이터베이스 전문가는 고가용성 및 재해 복구 요구 사항을 충족하기 위해 무엇을 해야 합니까?
#
# >**A.** 각 리전에서 다중 AZ 배포를 사용합니다.
# **B.** 보조 리전의 모든 가용 영역에서 읽기 전용 복제본 배포를 사용합니다.
# **C.** 한 리전 내에서 다중 AZ 및 읽기 전용 복제본 배포를 사용합니다.
# **D.** 다중 AZ를 사용하고 보조 리전에 읽기 전용 복제본을 배포합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : D(100%)  <br>
# >D. 고가용성 = 다중 AZ 재해 복구 = 보조 지역(또는 대기 인스턴스)의 읽기 전용 복제본<br>
# >HA -> 다중 AZ, 교차 지역 DR -> 보조 지역의 복제본 읽기<br>
# >이 질문은 고가용성 및 재해 복구를 요구합니다. 따라서 고가용성을 위한 다중 AZ와 DR을 위한 읽기 전용 복제본이 모두 필요합니다. 답은 D
# </div></details>
#
# **[Q#180. Q#137. Q#179.](https://www.examtopics.com/discussions/amazon/view/67242-exam-aws-certified-database-specialty-topic-1-question-180/)**
# 미디어 회사는 Amazon Aurora MySQL 데이터베이스에 ZDP(제로 다운타임 패치)를 사용하려고 합니다. 여러 처리 응용 프로그램이 SSL 인증서를 사용하여 데이터베이스 endpoint 및 읽기 전용 복제본에 연결하고 있습니다.
# ZDP의 성공에 가장 적은 영향을 미치는 요소는 무엇입니까?
#
# >**A.** 바이너리 로깅이 활성화되었거나 바이너리 로그 복제가 진행 중입니다.
# **B.** 현재 SSL 연결이 데이터베이스에 열려 있습니다.
# **C.** 임시 테이블 또는 테이블 잠금이 사용 중입니다.
# **D.** 테이블 생성 시 lower_case_table_names 서버 매개변수의 값이 0으로 설정되었습니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : D(100%)  <br>
# >ZeroDowntime 패치는 다음 중 하나라도 해당되면 작동불가. - 바이너리 로깅이 활성화됨 - 장기 실행 쿼리/트랜잭션이 진행 중임 - 임시 테이블이 사용 중임 - 테이블 잠금이 사용 중임 - SSL 연결이 제거에 의해 열려 있음<br>
# >D는 ZDP에 영향을 미치지 않음.<br>
# >Ax. 바이너리 로깅이 활성화되어 있거나 바이너리 로그 복제가 진행 중입니다. (MySQL 2.10 이전에 차단하는 데 사용, 더 이상 ZDP에 영향을 미치지 않음)<br>
# >B. 현재 SSL 연결이 데이터베이스에 열려 있습니다. (ZDP에 영향)<br>
# >C. 임시 테이블 또는 테이블 잠금이 사용 중입니다.(ZDP에 영향)<br>
# >D. 테이블 생성 시 lower_case_table_names 서버 매개변수의 값이 0으로 설정되었습니다. (ZDP와 관련 없음)
# >
# >[Aurora MySQL DB 클러스터의 마이너 버전 또는 패치 수준 업그레이드](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/AuroraMySQL.Updates.Patching.html)
# </div></details>

# %% [markdown]
# # 181

# %% [markdown]
# **[Q#181. Q#047. Q#100.](https://www.examtopics.com/discussions/amazon/view/66035-exam-aws-certified-database-specialty-topic-1-question-181/)**
# 금융 서비스 회사에 Amazon Aurora PostgreSQL DB 클러스터를 사용하는 애플리케이션이 AWS에 배포되어 있습니다. 최근 감사에 따르면 데이터베이스 관리자 활동이 포함된 로그 파일이 없습니다. 데이터베이스 전문가는 데이터베이스 액세스 및 활동 로그를 제공하는 솔루션을 추천해야 합니다. 솔루션은 최소한의 노력으로 성능에 미치는 영향을 최소화해야 합니다.
# 데이터베이스 전문가는 어떤 솔루션을 추천해야 합니까?
#
# >**A.** 동기 모드의 데이터베이스에서 Aurora 데이터베이스 활동 스트림을 활성화합니다. Amazon Kinesis 데이터 스트림을 Kinesis Data Firehose에 연결합니다. Kinesis Data Firehose 대상을 Amazon S3 버킷으로 설정합니다.
# **B.** 데이터베이스가 실행되는 리전에서 AWS CloudTrail 추적을 생성합니다. 데이터베이스 활동 로그를 추적과 연결합니다.
# **C.** 비동기 모드에서 데이터베이스에서 Aurora 데이터베이스 활동 스트림을 활성화합니다. Amazon Kinesis 데이터 스트림을 Kinesis Data Firehose에 연결합니다. Firehose 대상을 Amazon S3 버킷으로 설정합니다.
# **D.** 배스천 호스트를 통해서만 DB 클러스터에 대한 연결을 허용합니다. 배스천 호스트 및 애플리케이션 서버에 대한 데이터베이스 액세스를 제한합니다. CloudWatch Logs 에이전트를 사용하여 배스천 호스트 로그를 Amazon CloudWatch Logs로 푸시합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : C(100%)  <br>
# >데이터베이스 활동 스트림을 모니터링 도구와 통합하면 Amazon Aurora 클러스터에서 감사 활동에 대한 경보를 모니터링하고 설정할 수 있습니다.<br>
# >비동기 모드는 활동 스트림의 정확성보다 데이터베이스 성능을 우선시합니다.<br>
# >동기 모드는 데이터베이스 성능보다 활동 스트림의 정확성을 우선시합니다.<br>
# >Amazon Kinesis는 데이터베이스 활동 스트림에 필요합니다.<br>
# >데이터베이스 활동 스트림은 항상 암호화되기 때문에 AWS Key Management Service(AWS KMS)가 필요합니다.<br>
# >
# >[데이터베이스 활동 스트림 개요](https://docs.aws.amazon.com/ko_kr/AmazonRDS/latest/AuroraUserGuide/DBActivityStreams.Overview.html)
# </div></details>
#
# **[Q#182. Q#048. Q#169.](https://www.examtopics.com/discussions/amazon/view/66371-exam-aws-certified-database-specialty-topic-1-question-182/)**
# 회사는 프로덕션 데이터베이스에 단일 노드 Amazon RDS for MySQL DB 인스턴스를 사용합니다. DB 인스턴스는 미국의 AWS 리전에서 실행됩니다.
# 대규모 판매 이벤트를 일주일 앞두고 DB 인스턴스에 대한 새로운 유지 관리 업데이트가 제공됩니다. 유지 관리 업데이트는 필수로 표시됩니다. 회사는 DB 인스턴스의 가동 중지 시간을 최소화하기 위해 데이터베이스 전문가에게 판매 이벤트가 끝날 때까지 DB 인스턴스를 고가용성으로 만들도록 요청합니다.
# 어떤 솔루션이 이러한 요구 사항을 충족합니까?
#
# >**A.** 판매 이벤트가 끝날 때까지 유지 관리 업데이트를 연기하십시오.
# **B.** 최신 업데이트로 읽기 전용 복제본을 생성합니다. 판매 이벤트 전에 장애 조치를 시작합니다.
# **C.** 최신 업데이트로 읽기 전용 복제본을 생성합니다. 판매 이벤트 중에 모든 읽기 전용 트래픽을 읽기 전용 복제본으로 전송합니다.
# **D.** DB 인스턴스를 다중 AZ 배포로 변환합니다. 유지 관리 업데이트를 적용합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : D (100%)  <br>
# >다중 AZ 중단은 장애 조치를 위한 시간이 됩니다(60초).<br>
# >업데이트는 필수입니다. "유지 관리 업데이트가 필요에 따라 지정되었습니다."라는 질문에 바로 거기에 있습니다.<br>
# >DB를 Multi-AZ로 전환해야 하며, 유지보수 업데이트가 의무적인 특성으로 인해 연기가 불가능<br>
# >가동 중지를 최소화하려면 Amazon RDS DB 인스턴스를 다중 AZ 배포로 수정합니다. 다중 AZ 배포의 경우 OS 유지 관리는 보조 인스턴스에 먼저 적용되고, 해당 인스턴스에서 장애 조치를 수행한 후 기본 인스턴스가 업데이트됩니다. 장애 조치 시 가동이 중지됩니다.<br>
# >
# >[필수 Amazon RDS 유지 관리 동안 가동 중지를 최소화하려면 어떻게 해야 하나요?](https://aws.amazon.com/ko/premiumsupport/knowledge-center/rds-required-maintenance/)
# </div></details>
#
# **[Q#183. Q#028. Q#116.](https://www.examtopics.com/discussions/amazon/view/65834-exam-aws-certified-database-specialty-topic-1-question-183/)**
# 회사에서 SQL Server DB 인스턴스용 Amazon RDS의 데이터베이스를 한 AWS 리전에서 다른 리전으로 마이그레이션하고 있습니다. 회사는 마이그레이션 중 데이터베이스 다운타임을 최소화하려고 합니다.
# 이 교차 리전 마이그레이션을 위해 회사는 어떤 전략을 선택해야 합니까?
#
# >**A.** 동일한 리전의 Amazon S3 버킷에 기본 백업을 사용하여 소스 데이터베이스를 백업합니다. 그런 다음 대상 지역에서 백업을 복원합니다.
# **B.** 동일한 리전의 Amazon S3 버킷에 기본 백업을 사용하여 소스 데이터베이스를 백업합니다. Amazon S3 교차 리전 복제를 사용하여 대상 리전의 S3 버킷에 백업을 복사합니다. 그런 다음 대상 지역에서 백업을 복원합니다.
# **C.** 원본 데이터베이스와 대상 데이터베이스 간에 데이터를 복제하도록 AWS Database Migration Service(AWS DMS)를 구성합니다. 복제가 동기화되면 DMS 작업을 종료합니다.
# **D.** 대상 지역에서 SQL Server용 RDS 지역 간 읽기 전용 복제본을 추가합니다. 복제가 동기화되면 읽기 전용 복제본을 마스터로 승격합니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분배 : C(100%)  <br>
# >최소 가동 중지 시간 > AWS DMS(Co)
# >A. 느림 B. 느림 C. 소스-> AWS DMS -> 대상 리전 데이터베이스 -> 동기화 -> DMS 종료 D. RDS SQL Server에 대해 리전 간 읽기 전용 복제본이 지원되지 않음
# >
# </div></details>
#
# **★★★[Q#184. Q#055. Q#153.](https://www.examtopics.com/discussions/amazon/view/65888-exam-aws-certified-database-specialty-topic-1-question-184/)**
# 금융 회사가 AWS에서 웹 애플리케이션을 호스팅하고 있습니다. 애플리케이션의 데이터베이스는 자동화된 백업이 활성화된 Amazon RDS for MySQL에서 호스팅됩니다.
# 응용 프로그램이 데이터베이스의 논리적 손상을 일으켜 응용 프로그램이 응답하지 않게 되었습니다. 손상의 특정 시간이 식별되었으며 백업 보존 기간 내에 있었습니다.
# 데이터베이스 전문가는 데이터베이스를 손상 전 가장 최근 시점으로 어떻게 복구해야 합니까?
#
# >**A.** 지정 시간 복원 기능을 사용하여 DB 인스턴스를 지정된 시간으로 복원합니다. 애플리케이션 연결 문자열을 변경할 필요가 없습니다.
# **B.** 지정 시간 복원 기능을 사용하여 DB 인스턴스를 지정된 시간으로 복원합니다. 애플리케이션 연결 문자열을 새로 복원된 DB 인스턴스로 변경합니다.
# **C.** 최신 자동 백업을 사용하여 복원합니다. 애플리케이션 연결 문자열을 새로 복원된 DB 인스턴스로 변경합니다.
# **D.** 적절한 자동 백업을 사용하여 복원합니다. 애플리케이션 연결 문자열을 변경할 필요가 없습니다.
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 분포 : B (100%)  <br>
# >특정 시점으로 복원 작업을 수행하거나 DB 스냅샷에서 새 DB 인스턴스가 생성되면 새 엔드포인트로 새 DB 인스턴스가 생성됩니다(원하는 경우 이전 DB 삭제가능).<br>
# >특정 DB 스냅샷 또는 특정 시점에서 여러 DB 인스턴스를 생성할 수 있도록 하기 위한 것입니다."<br>
# >
# >[Amazon RDS FAQ](https://aws.amazon.com/ko/rds/faqs/)
# </div></details>
#
# **[Q#185. Q#075. Q#170.](https://www.examtopics.com/discussions/amazon/view/66062-exam-aws-certified-database-specialty-topic-1-question-185/)**
# 데이터베이스 전문가가 일회성 쿼리에 응답하는 응용 프로그램을 설계하고 있습니다. 애플리케이션은 복잡한 고객 데이터를 쿼리하고 최종 사용자에게 보고서를 제공합니다.
# 이러한 보고서에는 많은 필드가 포함될 수 있습니다. 데이터베이스 전문가는 제공된 필드를 사용하여 데이터베이스를 쿼리할 수 있는 기능을 사용자에게 제공하려고 합니다.
# 데이터베이스의 트래픽 볼륨은 높지만 피크 시간에는 가변적입니다. 그러나 하루 중 다른 시간에는 데이터베이스에 트래픽이 많지 않습니다.
# 어떤 솔루션이 이러한 요구 사항을 가장 비용 효율적으로 충족합니까?
#
# >**A.** 프로비저닝된 용량 모드 및 Auto Scaling이 있는 Amazon DynamoDB
# **B.** 온디맨드 용량 모드가 있는 Amazon DynamoDB
# **C.** Auto Scaling이 활성화된 Amazon Aurora
# **D.** 서버리스 모드의 Amazon Aurora
#
# ><details><summary>해설</summary><div markdown="1">
# >커뮤니티 투표 배분 : D (100%)  <br>
# >"데이터베이스 전문가는 사용자가 제공된 필드를 사용하여 데이터베이스를 쿼리할 수 있도록 하고 싶어"하므로 DynamoDB는 해당되지 않음(Ax, Bx)
# >피크 시간(변수)에 최대 부하를 알 수 없으므로 D가 유일한 옵션입니다.<br>
# >Auto Scaling을 사용하는 경우 자동 크기 조정에 대한 최소 및 최대 ACU를 정의해야 하지만 변경되므로 정확하지 않습니다.
# </div></details>
